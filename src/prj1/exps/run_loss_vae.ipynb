# %% [markdown]
# #### GAU

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\7.synthetic_vae\InceptionV2\inceptionv2_base.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# C:/Users/Admin/Data/ads_fraud_detection
# No GPU found. Using CPU.
# (330, 2) (1022, 2)
# (330, 2)
# 39
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_1 (InputLayer)        [(None, 39, 1)]              0         []
#
#  conv1d (Conv1D)             (None, 19, 16)               64        ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 19, 16)               57        ['conv1d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 19, 16)               0         ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 17, 16)               784       ['activation[0][0]']
#
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\7.synthetic_vae\InceptionV2\inceptionv2_class_weight.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# No GPU found. Using CPU.
# (330, 2) (1022, 2)
# (330, 2)
# 39
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_2 (InputLayer)        [(None, 39, 1)]              0         []
#
#  conv1d_203 (Conv1D)         (None, 19, 16)               64        ['input_2[0][0]']
#
#  batch_normalization_203 (B  (None, 19, 16)               57        ['conv1d_203[0][0]']
#  atchNormalization)
#
#  activation_203 (Activation  (None, 19, 16)               0         ['batch_normalization_203[0][0
#  )                                                                  ]']
#
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\7.synthetic_vae\InceptionV2\inceptionv2_dice.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# No GPU found. Using CPU.
# (330, 2) (1022, 2)
# (330, 2)
# 39
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_3 (InputLayer)        [(None, 39, 1)]              0         []
#
#  conv1d_406 (Conv1D)         (None, 19, 16)               64        ['input_3[0][0]']
#
#  batch_normalization_406 (B  (None, 19, 16)               57        ['conv1d_406[0][0]']
#  atchNormalization)
#
#  activation_406 (Activation  (None, 19, 16)               0         ['batch_normalization_406[0][0
#  )                                                                  ]']
#
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\7.synthetic_vae\InceptionV2\inceptionv2_class_weight_dice.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\7.synthetic_vae\InceptionV2\inceptionv2_focal.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\7.synthetic_vae\InceptionV2\inceptionv2_class_weight_focal.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\7.synthetic_vae\InceptionV2\inceptionv2_f1.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\7.synthetic_vae\InceptionV2\inceptionv2_class_weight_f1.ipynb"

# %% [markdown]
# #### Inception V3

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\7.synthetic_vae\InceptionV3\inceptionv3_base.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\7.synthetic_vae\InceptionV3\inceptionv3_class_weight.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\7.synthetic_vae\InceptionV3\inceptionv3_dice.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\7.synthetic_vae\InceptionV3\inceptionv3_class_weight_dice.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\7.synthetic_vae\InceptionV3\inceptionv3_focal.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\7.synthetic_vae\InceptionV3\inceptionv3_class_weight_focal.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\7.synthetic_vae\InceptionV3\inceptionv3_f1.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\7.synthetic_vae\InceptionV3\inceptionv3_class_weight_f1.ipynb"

# %%
#
