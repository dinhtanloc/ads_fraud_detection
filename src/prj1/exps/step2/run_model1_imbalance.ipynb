# %% [markdown]
# #### ADASYN

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\2.adasyn\VGG16\vgg16_base.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# C:/Users/Admin/Data/ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (330, 2) (998, 2)
# (330, 2)
# 39
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 39, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 39, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 39, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 19, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 19, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 19, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 9, 256)            0
#
#  block3_conv1 (Conv1D)       (None, 9, 512)            393728
#
#  block3_conv2 (Conv1D)       (None, 9, 512)            786944
#
#  block3_conv3 (Conv1D)       (None, 9, 512)            786944
#
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\2.adasyn\VGG16\vgg16_class_weight.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (330, 2) (998, 2)
# (330, 2)
# 39
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 39, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 39, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 39, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 19, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 19, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 19, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 9, 256)            0
#
#  block3_conv1 (Conv1D)       (None, 9, 512)            393728
#
#  block3_conv2 (Conv1D)       (None, 9, 512)            786944
#
#  block3_conv3 (Conv1D)       (None, 9, 512)            786944
#
# ...

# %% [markdown]
# #### SMOTE

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\3.smote\VGG16\vgg16_base.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (330, 2) (1022, 2)
# (330, 2)
# 39
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_3 (InputLayer)        [(None, 39, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 39, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 39, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 19, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 19, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 19, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 9, 256)            0
#
#  block3_conv1 (Conv1D)       (None, 9, 512)            393728
#
#  block3_conv2 (Conv1D)       (None, 9, 512)            786944
#
#  block3_conv3 (Conv1D)       (None, 9, 512)            786944
#
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\3.smote\VGG16\vgg16_class_weight.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (330, 2) (1022, 2)
# (330, 2)
# 39
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_4 (InputLayer)        [(None, 39, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 39, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 39, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 19, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 19, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 19, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 9, 256)            0
#
#  block3_conv1 (Conv1D)       (None, 9, 512)            393728
#
#  block3_conv2 (Conv1D)       (None, 9, 512)            786944
#
#  block3_conv3 (Conv1D)       (None, 9, 512)            786944
#
# ...

# %% [markdown]
# #### GAU

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\4.synthetic_gau\VGG16\vgg16_class_weight.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (330, 2) (1022, 2)
# (330, 2)
# 39
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_5 (InputLayer)        [(None, 39, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 39, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 39, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 19, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 19, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 19, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 9, 256)            0
#
#  block3_conv1 (Conv1D)       (None, 9, 512)            393728
#
#  block3_conv2 (Conv1D)       (None, 9, 512)            786944
#
#  block3_conv3 (Conv1D)       (None, 9, 512)            786944
#
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\4.synthetic_gau\VGG16\vgg16_base.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (330, 2) (1022, 2)
# (330, 2)
# 39
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_6 (InputLayer)        [(None, 39, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 39, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 39, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 19, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 19, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 19, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 9, 256)            0
#
#  block3_conv1 (Conv1D)       (None, 9, 512)            393728
#
#  block3_conv2 (Conv1D)       (None, 9, 512)            786944
#
#  block3_conv3 (Conv1D)       (None, 9, 512)            786944
#
# ...

# %% [markdown]
# #### GAN

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\5.synthetic_gan\VGG16\vgg16_class_weight.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (330, 2) (1022, 2)
# (330, 2)
# 39
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_7 (InputLayer)        [(None, 39, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 39, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 39, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 19, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 19, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 19, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 9, 256)            0
#
#  block3_conv1 (Conv1D)       (None, 9, 512)            393728
#
#  block3_conv2 (Conv1D)       (None, 9, 512)            786944
#
#  block3_conv3 (Conv1D)       (None, 9, 512)            786944
#
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\5.synthetic_gan\VGG16\vgg16_base.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (330, 2) (1022, 2)
# (330, 2)
# 39
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_8 (InputLayer)        [(None, 39, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 39, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 39, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 19, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 19, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 19, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 9, 256)            0
#
#  block3_conv1 (Conv1D)       (None, 9, 512)            393728
#
#  block3_conv2 (Conv1D)       (None, 9, 512)            786944
#
#  block3_conv3 (Conv1D)       (None, 9, 512)            786944
#
# ...

# %% [markdown]
# #### GAN Copula

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\6.synthetic_gancopula\VGG16\vgg16_class_weight.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (330, 2) (1022, 2)
# (330, 2)
# 39
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_9 (InputLayer)        [(None, 39, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 39, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 39, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 19, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 19, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 19, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 9, 256)            0
#
#  block3_conv1 (Conv1D)       (None, 9, 512)            393728
#
#  block3_conv2 (Conv1D)       (None, 9, 512)            786944
#
#  block3_conv3 (Conv1D)       (None, 9, 512)            786944
#
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\6.synthetic_gancopula\VGG16\vgg16_base.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (330, 2) (1022, 2)
# (330, 2)
# 39
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_10 (InputLayer)       [(None, 39, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 39, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 39, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 19, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 19, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 19, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 9, 256)            0
#
#  block3_conv1 (Conv1D)       (None, 9, 512)            393728
#
#  block3_conv2 (Conv1D)       (None, 9, 512)            786944
#
#  block3_conv3 (Conv1D)       (None, 9, 512)            786944
#
# ...

# %% [markdown]
# #### VAE

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\7.synthetic_vae\VGG16\vgg16_base.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (330, 2) (1022, 2)
# (330, 2)
# 39
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_11 (InputLayer)       [(None, 39, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 39, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 39, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 19, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 19, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 19, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 9, 256)            0
#
#  block3_conv1 (Conv1D)       (None, 9, 512)            393728
#
#  block3_conv2 (Conv1D)       (None, 9, 512)            786944
#
#  block3_conv3 (Conv1D)       (None, 9, 512)            786944
#
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\7.synthetic_vae\VGG16\vgg16_class_weight.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (330, 2) (1022, 2)
# (330, 2)
# 39
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_12 (InputLayer)       [(None, 39, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 39, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 39, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 19, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 19, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 19, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 9, 256)            0
#
#  block3_conv1 (Conv1D)       (None, 9, 512)            393728
#
#  block3_conv2 (Conv1D)       (None, 9, 512)            786944
#
#  block3_conv3 (Conv1D)       (None, 9, 512)            786944
#
# ...
