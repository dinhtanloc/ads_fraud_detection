# %%
# %run "C:\Users\PC\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\3.smote\Tabnet\tabnet_class_weight.ipynb"
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# C:/Users/Admin/Data/ads_fraud_detection
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
# ...

# %%
# %run "C:\Users\PC\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\3.smote\Tabnet\tabnet_base.ipynb"
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# (330, 2) (1022, 2)
# (330, 2)
# 39
# Epoch 1/1200
# 32/32 [==============================] - 30s 25ms/step - loss: 0.7466 - accuracy: 0.5568 - f1_score: 0.4896 - val_loss: 0.7381 - val_accuracy: 0.5515 - val_f1_score: 0.5051 - lr: 0.1000
# Epoch 2/1200
# 32/32 [==============================] - 0s 12ms/step - loss: 0.6147 - accuracy: 0.6908 - f1_score: 0.6824 - val_loss: 0.6414 - val_accuracy: 0.7333 - val_f1_score: 0.6744 - lr: 0.1000
# Epoch 3/1200
# 32/32 [==============================] - 0s 12ms/step - loss: 0.5605 - accuracy: 0.7309 - f1_score: 0.7242 - val_loss: 0.5556 - val_accuracy: 0.7273 - val_f1_score: 0.6858 - lr: 0.1000
# Epoch 4/1200
# 32/32 [==============================] - 0s 15ms/step - loss: 0.5479 - accuracy: 0.7613 - f1_score: 0.7571 - val_loss: 0.6223 - val_accuracy: 0.7424 - val_f1_score: 0.7063 - lr: 0.1000
# Epoch 5/1200
# ...
