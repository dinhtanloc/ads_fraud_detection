# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\3.smote\InceptionV2\inceptionv2_base.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# C:/Users/Admin/Data/ads_fraud_detection
# No GPU found. Using CPU.
# (330, 2) (1022, 2)
# (330, 2)
# 39
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_30072\2137732481.py:93
#      86     model = Model(x_input, x, name='inception_resnet_v2')
#      90     return model
# ---> 93 model = InceptionResNetV2()
#      94 lr=0.0001
#      95 # model.compile(optimizer=Adam(lr=lr), loss='binary_crossentropy', metrics=['accuracy'])
#
# File ~\AppData\Local\Temp\ipykernel_30072\2137732481.py:49, in InceptionResNetV2()
#      47 # 20x block17 (Inception-ResNet-B block): 17 x 17 x 1088
#      48 for block_idx in range(1, 21):
# ---> 49     x = inception_resnet_block(x,
#      50                                scale=0.1,
#      51                                block_type='block17',
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\3.smote\InceptionV2\inceptionv2_class_weight.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (330, 2) (1022, 2)
# (330, 2)
# 39
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 39, 1)]      0           []
#
#  conv1d_203 (Conv1D)            (None, 19, 16)       64          ['input_2[0][0]']
#
#  batch_normalization_203 (Batch  (None, 19, 16)      57          ['conv1d_203[0][0]']
#  Normalization)
#
#  activation_203 (Activation)    (None, 19, 16)       0           ['batch_normalization_203[0][0]']
#
#  conv1d_204 (Conv1D)            (None, 17, 16)       784         ['activation_203[0][0]']
#
#  batch_normalization_204 (Batch  (None, 17, 16)      51          ['conv1d_204[0][0]']
#  Normalization)
#
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\3.smote\InceptionV3\inceptionv3_base.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (330, 2) (1022, 2)
# (330, 2)
# 39
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_3 (InputLayer)           [(None, 39, 1)]      0           []
#
#  conv1d_406 (Conv1D)            (None, 19, 32)       96          ['input_3[0][0]']
#
#  batch_normalization_406 (Batch  (None, 19, 32)      57          ['conv1d_406[0][0]']
#  Normalization)
#
#  activation_406 (Activation)    (None, 19, 32)       0           ['batch_normalization_406[0][0]']
#
#  conv1d_407 (Conv1D)            (None, 17, 32)       3072        ['activation_406[0][0]']
#
#  batch_normalization_407 (Batch  (None, 17, 32)      51          ['conv1d_407[0][0]']
#  Normalization)
#
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\5.deep_learning_model\3.smote\InceptionV3\inceptionv3_class_weight.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (330, 2) (1022, 2)
# (330, 2)
# 39
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_4 (InputLayer)           [(None, 39, 1)]      0           []
#
#  conv1d_452 (Conv1D)            (None, 19, 32)       96          ['input_4[0][0]']
#
#  batch_normalization_452 (Batch  (None, 19, 32)      57          ['conv1d_452[0][0]']
#  Normalization)
#
#  activation_452 (Activation)    (None, 19, 32)       0           ['batch_normalization_452[0][0]']
#
#  conv1d_453 (Conv1D)            (None, 17, 32)       3072        ['activation_452[0][0]']
#
#  batch_normalization_453 (Batch  (None, 17, 32)      51          ['conv1d_453[0][0]']
#  Normalization)
#
# ...
