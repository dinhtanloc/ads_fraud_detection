# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\1.EDA\EDA_mainbaseline.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# C:/Users/Admin/Data/ads_fraud_detection
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
# ...

# %% [markdown]
# #### Gau

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\2.pre-processing\4.synthetic_gau\pre_process_gau.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# (670, 40) (330, 40)
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 40/40 [00:00<00:00, 3935.82it/s]|
# Data Validity Score: 97.26%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 493.56it/s]|
# Data Structure Score: 35.59%
#
# Overall Score (Average): 66.43%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 40/40 [00:00<00:00, 1495.67it/s]|
# Column Shapes Score: 88.59%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 780/780 [00:01<00:00, 455.17it/s]|
# Column Pair Trends Score: 82.34%
#
# Overall Score (Average): 85.46%
#
# fraud_reported
# 1    511
# 0    511
# Name: count, dtype: int64
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\3.feature-selection\4.synthetic_gau\feature_selection5_1.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# (1022, 39) (1022, 1) (330, 39) (330, 1)
# LR
# bi loai bo                Feature  Coefficient
# 38  year_incident_date          0.0
# Xếp hạng các đặc trưng theo mức độ quan trọng:
#                         Feature  Coefficient
# 16            incident_severity    -1.327581
# 27                 injury_claim    -0.312054
# 7                   insured_sex     0.263966
# 0            months_as_customer    -0.255664
# 2                  policy_state     0.222869
# 36            day_incident_date    -0.204400
# 6                umbrella_limit     0.203495
# 32                    auto_year    -0.174354
# 29                vehicle_claim     0.146606
# 28               property_claim     0.110968
# 3                    policy_csl    -0.105435
# 14                incident_type     0.092628
# 4             policy_deductable     0.086879
# 26           total_claim_amount     0.086571
# 24                    witnesses    -0.086487
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\4.traditional_model\4.synthetic_gau\traditional model5_2.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# (1022, 39) (1022, 1) (330, 39) (330, 1)
# (330, 2) (1022, 2)
# 0    1
# 0.0  1.0    511
# 1.0  0.0    511
# Name: count, dtype: int64
# 0    1
# 1.0  0.0    242
# 0.0  1.0     88
# Name: count, dtype: int64
# Accuracy LR: 85.616% (1.924%)
# Accuracy LDA: 69.278% (4.083%)
# Accuracy DTC: 89.534% (1.541%)
# Accuracy RD: 89.531% (1.090%)
# Accuracy KNC: 86.013% (2.936%)
# Accuracy NB: 87.675% (2.761%)
# Accuracy SVM: 86.209% (3.262%)
# Accuracy NN: 88.162% (2.359%)
# Accuracy BG: 86.499% (1.581%)
# [LightGBM] [Info] Number of positive: 409, number of negative: 408
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000105 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2221
# [LightGBM] [Info] Number of data points in the train set: 817, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500612 -> initscore=0.002448
# ...

# %% [markdown]
# #### VAE

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\2.pre-processing\6.synthetic_vae\pre_process_vae.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# (670, 40) (330, 40)
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 40/40 [00:00<00:00, 3591.24it/s]|
# Data Validity Score: 96.57%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 496.96it/s]|
# Data Structure Score: 35.59%
#
# Overall Score (Average): 66.08%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 40/40 [00:00<00:00, 1258.65it/s]|
# Column Shapes Score: 87.49%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 780/780 [00:01<00:00, 401.63it/s]|
# Column Pair Trends Score: 76.6%
#
# Overall Score (Average): 82.05%
#
# fraud_reported
# 1    511
# 0    511
# Name: count, dtype: int64

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\3.feature-selection\6.synthetic_vae\feature_selection5_1.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# (1022, 39) (1022, 1) (330, 39) (330, 1)
# LR
# bi loai bo                Feature  Coefficient
# 38  year_incident_date          0.0
# Xếp hạng các đặc trưng theo mức độ quan trọng:
#                         Feature  Coefficient
# 16            incident_severity    -1.407171
# 0            months_as_customer    -0.375244
# 7                   insured_sex     0.252473
# 27                 injury_claim    -0.218981
# 29                vehicle_claim     0.202547
# 6                umbrella_limit     0.199055
# 2                  policy_state     0.192402
# 28               property_claim     0.184487
# 36            day_incident_date    -0.169115
# 32                    auto_year    -0.131573
# 21  number_of_vehicles_involved    -0.115981
# 25      police_report_available     0.110816
# 14                incident_type     0.108361
# 3                    policy_csl    -0.104684
# 35        year_policy_bind_date    -0.096888
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\4.traditional_model\6.synthetic_vae\traditional model5_2.ipynb"

# %% [markdown]
# #### Gan

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\2.pre-processing\5.synthetic_gan\pre_process_gan.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# (670, 40) (330, 40)
# Gen. (-2.48) | Discrim. (0.06): 100%|██████████| 300/300 [00:47<00:00,  6.35it/s]
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 40/40 [00:00<00:00, 3806.34it/s]|
# Data Validity Score: 97.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 1000.07it/s]|
# Data Structure Score: 35.59%
#
# Overall Score (Average): 66.3%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 40/40 [00:00<00:00, 1094.52it/s]|
# Column Shapes Score: 85.84%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 780/780 [00:01<00:00, 447.87it/s]|
# Column Pair Trends Score: 78.4%
#
# Overall Score (Average): 82.12%
#
# fraud_reported
# 1    511
# 0    511
# Name: count, dtype: int64

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\3.feature-selection\5.synthetic_gan\feature_selection_gan.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# (1022, 39) (1022, 1) (330, 39) (330, 1)
# LR
# bi loai bo                Feature  Coefficient
# 38  year_incident_date          0.0
# Xếp hạng các đặc trưng theo mức độ quan trọng:
#                         Feature  Coefficient
# 16            incident_severity    -1.427572
# 27                 injury_claim    -0.319195
# 7                   insured_sex     0.301108
# 0            months_as_customer    -0.281324
# 2                  policy_state     0.222181
# 6                umbrella_limit     0.189043
# 36            day_incident_date    -0.187352
# 29                vehicle_claim     0.155191
# 32                    auto_year    -0.110636
# 28               property_claim     0.102190
# 1                           age     0.083455
# 3                    policy_csl    -0.082408
# 4             policy_deductable     0.079913
# 21  number_of_vehicles_involved    -0.077665
# 12                capital-gains    -0.075448
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\4.traditional_model\5.synthetic_gan\traditional model_gan.ipynb"

# %% [markdown]
# #### GanCopula

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\2.pre-processing\5.synthetic_gan\pre_process_gancopula.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\3.feature-selection\5.synthetic_gan\feature_selection_gancopula.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj1\4.traditional_model\5.synthetic_gan\traditional model_gancopula.ipynb"
