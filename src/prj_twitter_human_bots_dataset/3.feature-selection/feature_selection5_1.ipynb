# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)
from libs.lib import *
# Out:
# c:\Users\PC\Data\ads_prj_nckh
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.34.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Lựa chọn đặc trưng

# %% [markdown]
# ### (1) Tạo thư mục lưu trữ (nếu chưa có)

# %%
exps_dir = "../../exps/exp1"
if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/Standard_Label/class_dict_weight_SMOTE/data"
os.makedirs(save_dir, exist_ok=True)

test_size=0.33
seed=42

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# (19430, 34) (19430, 1) (5089, 34) (5089, 1)

# %% [markdown]
# ### (2) Lựa chọn các đặc trưng

# %%
x_train
# Out:
#        Month  WeekOfMonth  DayOfWeek  Make  AccidentArea  DayOfWeekClaimed  \
# 0          9            2          0    13             1                 1
# 1          5            2          2     6             1                 1
# 2          8            1          6    13             1                 6
# 3          8            0          6    18             1                 6
# 4          3            1          5     9             1                 5
# ...      ...          ...        ...   ...           ...               ...
# 19425      0            2          3     7             1                 2
# 19426      5            2          1     5             1                 0
# 19427      7            0          0     1             1                 1
# 19428      7            3          4    10             1                 6
# 19429     10            2          3     9             1                 0
#
#        MonthClaimed  WeekOfMonthClaimed  Sex  MaritalStatus  ...  \
# 0                 9                   3    1              1  ...
# 1                 5                   2    1              1  ...
# 2                 6                   2    1              1  ...
# 3                 8                   0    0              1  ...
# 4                 3                   1    0              1  ...
# ...             ...                 ...  ...            ...  ...
# 19425             9                   0    1              2  ...
# 19426            11                   0    1              1  ...
# 19427             7                   1    1              1  ...
# 19428             0                   1    0              1  ...
# 19429             9                   1    1              1  ...
#
#        PoliceReportFiled  WitnessPresent  AgentType  NumberOfSuppliments  \
# 0                      0               0          0                    0
# 1                      0               0          0                    3
# 2                      0               0          0                    0
# 3                      0               0          0                    0
# 4                      0               0          0                    0
# ...                  ...             ...        ...                  ...
# 19425                  0               0          0                    1
# 19426                  0               0          0                    1
# 19427                  0               0          0                    0
# 19428                  0               0          0                    0
# 19429                  0               0          0                    2
#
#        AddressChange_Claim  NumberOfCars  Year  BasePolicy  week_claimed  \
# 0                        3             0     1           2           559
# 1                        3             0     0           2           140
# 2                        3             0     2           1           778
# 3                        3             0     2           2           817
# 4                        3             2     2           2           699
# ...                    ...           ...   ...         ...           ...
# 19425                    3             0     2           0           858
# 19426                    3             0     2           0           892
# 19427                    3             0     1           0           495
# 19428                    3             0     1           0           328
# 19429                    0             0     2           1           874
#
#        week_incident
# 0                698
# 1                177
# 2               1053
# 3               1046
# 4                891
# ...              ...
# 19425            819
# 19426            957
# 19427            624
# 19428            645
# 19429           1120
#
# [19430 rows x 34 columns]

# %%
def modelcheck_info(model,name):
    print(name)
    try:
        coefficients = model.coef_.flatten()
    except:
        coefficients = model.feature_importances_.flatten()
    feature_importance = pd.DataFrame({
        'Feature': x_train.columns,
        'Coefficient': coefficients
    })

    print('bi loai bo',feature_importance[feature_importance['Coefficient'] == 0])
    feature_importance = feature_importance[feature_importance['Coefficient'] != 0]
    feature_importance['Absolute Coefficient'] = feature_importance['Coefficient'].abs()
    feature_importance.sort_values(by='Absolute Coefficient', ascending=False, inplace=True)

    print("Xếp hạng các đặc trưng theo mức độ quan trọng:")
    print(feature_importance[['Feature', 'Coefficient']])

# %%
models=[]
models.append(LogisticRegression())
models.append(LinearDiscriminantAnalysis())
models.append(DecisionTreeClassifier())
names=['LR','LDA','DTC']
feature_SelectFromModel={}
for model,name in zip(models,names):
    check = model.fit(x_train, y_train)
    selector = SelectFromModel(check, prefit=True)

    selected_features = x_train.columns[(selector.get_support())]
    modelcheck_info(model,name)
    print("Các đặc trưng được chọn:")
    feature_SelectFromModel[name]=list(selected_features)
    print(selected_features)
# Out:
# LR
# bi loai bo Empty DataFrame
# Columns: [Feature, Coefficient]
# Index: []
# Xếp hạng các đặc trưng theo mức độ quan trọng:
#                  Feature  Coefficient
# 31            BasePolicy    -1.452331
# 11                 Fault    -1.184012
# 19  Days_Policy_Accident     0.994277
# 20     Days_Policy_Claim     0.657498
# 13       VehicleCategory    -0.572627
# 9          MaritalStatus    -0.402490
# 22          AgeOfVehicle    -0.317717
# 15          PolicyNumber    -0.307498
# 4           AccidentArea    -0.294846
# 28   AddressChange_Claim     0.290833
# 18          DriverRating    -0.285608
# 21    PastNumberOfClaims    -0.273807
# 29          NumberOfCars    -0.221468
# 10                   Age    -0.208415
# 17            Deductible     0.198605
# 27   NumberOfSuppliments    -0.176108
# 1            WeekOfMonth    -0.149695
# 12            PolicyType    -0.144659
# 5       DayOfWeekClaimed    -0.112630
# 14          VehiclePrice    -0.107851
# 24     PoliceReportFiled    -0.105104
# 23     AgeOfPolicyHolder    -0.057643
# 7     WeekOfMonthClaimed    -0.056953
# 3                   Make    -0.053917
# 26             AgentType    -0.053501
# 30                  Year    -0.042062
# 8                    Sex     0.037590
# 6           MonthClaimed    -0.036161
# 25        WitnessPresent    -0.023449
# 0                  Month     0.013229
# 2              DayOfWeek     0.013088
# 16             RepNumber     0.004204
# 32          week_claimed     0.002484
# 33         week_incident    -0.000899
# Các đặc trưng được chọn:
# Index(['AccidentArea', 'MaritalStatus', 'Fault', 'VehicleCategory',
#        'PolicyNumber', 'DriverRating', 'Days_Policy_Accident',
#        'Days_Policy_Claim', 'PastNumberOfClaims', 'AgeOfVehicle',
#        'AddressChange_Claim', 'BasePolicy'],
#       dtype='object')
# LDA
# bi loai bo Empty DataFrame
# Columns: [Feature, Coefficient]
# Index: []
# Xếp hạng các đặc trưng theo mức độ quan trọng:
#                  Feature  Coefficient
# 30                  Year    -8.803547
# 11                 Fault    -3.610067
# 10                   Age     2.960172
# 23     AgeOfPolicyHolder    -2.472722
# 31            BasePolicy    -1.986523
# 9          MaritalStatus    -1.813450
# 24     PoliceReportFiled    -1.730472
# 13       VehicleCategory    -1.722112
# 4           AccidentArea    -0.891607
# 29          NumberOfCars    -0.865304
# 20     Days_Policy_Claim    -0.644214
# 0                  Month    -0.643744
# 26             AgentType    -0.639924
# 28   AddressChange_Claim    -0.636052
# 25        WitnessPresent    -0.533386
# 12            PolicyType     0.525765
# 22          AgeOfVehicle    -0.427322
# 1            WeekOfMonth    -0.326899
# 8                    Sex    -0.325158
# 17            Deductible    -0.323666
# 18          DriverRating    -0.280484
# 27   NumberOfSuppliments    -0.244411
# 21    PastNumberOfClaims    -0.243860
# 7     WeekOfMonthClaimed    -0.140521
# 2              DayOfWeek    -0.139827
# 14          VehiclePrice    -0.111670
# 6           MonthClaimed    -0.109783
# 5       DayOfWeekClaimed    -0.075509
# 19  Days_Policy_Accident     0.061557
# 15          PolicyNumber    -0.051411
# 3                   Make    -0.029643
# 33         week_incident     0.019699
# 16             RepNumber    -0.015970
# 32          week_claimed     0.003944
# Các đặc trưng được chọn:
# Index(['MaritalStatus', 'Age', 'Fault', 'VehicleCategory', 'AgeOfPolicyHolder',
#        'PoliceReportFiled', 'Year', 'BasePolicy'],
#       dtype='object')
# DTC
# bi loai bo Empty DataFrame
# Columns: [Feature, Coefficient]
# Index: []
# Xếp hạng các đặc trưng theo mức độ quan trọng:
#                  Feature  Coefficient
# 31            BasePolicy     0.250486
# 11                 Fault     0.188123
# 22          AgeOfVehicle     0.052989
# 15          PolicyNumber     0.052707
# 32          week_claimed     0.049225
# 33         week_incident     0.045358
# 3                   Make     0.036080
# 10                   Age     0.035865
# 23     AgeOfPolicyHolder     0.029868
# 9          MaritalStatus     0.024584
# 5       DayOfWeekClaimed     0.022685
# 16             RepNumber     0.021713
# 18          DriverRating     0.021599
# 21    PastNumberOfClaims     0.019254
# 6           MonthClaimed     0.017140
# 7     WeekOfMonthClaimed     0.014354
# 1            WeekOfMonth     0.014107
# 0                  Month     0.013556
# 2              DayOfWeek     0.013116
# 14          VehiclePrice     0.012837
# 13       VehicleCategory     0.011852
# 28   AddressChange_Claim     0.010559
# 27   NumberOfSuppliments     0.008703
# 4           AccidentArea     0.008283
# 12            PolicyType     0.004910
# 29          NumberOfCars     0.004892
# 17            Deductible     0.004326
# 8                    Sex     0.003522
# 19  Days_Policy_Accident     0.001867
# 20     Days_Policy_Claim     0.001571
# 24     PoliceReportFiled     0.001519
# 30                  Year     0.001445
# 26             AgentType     0.000523
# 25        WitnessPresent     0.000383
# Các đặc trưng được chọn:
# Index(['Make', 'Age', 'Fault', 'PolicyNumber', 'AgeOfVehicle',
#        'AgeOfPolicyHolder', 'BasePolicy', 'week_claimed', 'week_incident'],
#       dtype='object')

# %% [markdown]
# ### Giải thích:
#
# Phương pháp **SelectFromModel** từ thư viện sklearn.feature_selection. Phương pháp này hoạt động bằng cách sử dụng một mô hình học máy để đánh giá độ quan trọng của từng đặc trưng và sau đó chọn những đặc trưng quan trọng nhất.
#
#    Các model được dùng trong phương pháp này:
#    * **'LR'**: LogisticRegression
#    * **'LDA'**: LinearDiscriminantAnalysis
#    * **'DTC'**: DecisionTreeClassifier
#
#        #### 1. LogisticRegression:
#        Các đặc trưng được chọn:
# * Index(['age', 'policy_csl', 'insured_education_level', 'insured_occupation',
#        'incident_severity', 'incident_state', 'incident_city',
#        'incident_hour_of_the_day', 'property_damage', 'witnesses',
#        'property_claim', 'vehicle_claim', 'auto_make'],
#       dtype='object')
#
#    #### 2. LinearDiscriminantAnalysis:
#    Các đặc trưng được chọn:
# * Index(['policy_number', 'policy_annual_premium', 'insured_zip', 'insured_sex',
#        'incident_severity', 'incident_hour_of_the_day', 'property_damage',
#        'total_claim_amount', 'injury_claim', 'property_claim',
#        'vehicle_claim'],
#       dtype='object')
#
#    #### 3. DecisionTreeClassifier:
#    Các đặc trưng được chọn:
# * Index(['policy_number', 'policy_annual_premium', 'insured_zip',
#        'insured_occupation', 'insured_hobbies', 'incident_severity',
#        'incident_location', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'month_policy_bind_date', 'day_incident_date'],
#       dtype='object')

# %%
def feature_selection_inRFE(model,name):
    rfe=RFE(estimator=model, n_features_to_select=10)
    fit=rfe.fit(x_train, y_train)
#     print("Num Features: %d"% fit.n_features_)
#     print("Selected Features: %s" % fit.support_)
#     print("Features Ranking: %s" %fit.ranking_)
#     for index, value in enumerate(fit.ranking_):
#         print(f"{value}: {x_train.columns[index]}")
    sorted_columns = [x for _, x in sorted(zip(fit.ranking_, x_train.columns))]
    sort=sorted(fit.ranking_)

#     for i,j in zip(sort,sorted_columns):
#         print("Columns sorted by RFE ranking",i,":",j)

    return [j for i,j in zip(sort,sorted_columns) if i==1]

# %%
models=[]
models.append(LogisticRegression())
models.append(LinearDiscriminantAnalysis())
models.append(DecisionTreeClassifier())
models.append(RandomForestClassifier())
feature_RFE={}

names=['LR','LDA','DTC','RD']
for model,name in zip(models,names):
    print("RFE")
    print(f"Kiểm tra mô hình {name}")
    model.fit(x_train,y_train)
    print(feature_selection_inRFE(model,name))
    feature_RFE[name]=feature_selection_inRFE(model,name)
# Out:
# RFE
# Kiểm tra mô hình LR
# ['Age', 'AgeOfPolicyHolder', 'AgentType', 'BasePolicy', 'Fault', 'MaritalStatus', 'PoliceReportFiled', 'PolicyType', 'VehicleCategory', 'WitnessPresent']
# RFE
# Kiểm tra mô hình LDA
# ['AccidentArea', 'Age', 'AgeOfPolicyHolder', 'BasePolicy', 'Days_Policy_Claim', 'Fault', 'MaritalStatus', 'NumberOfCars', 'PoliceReportFiled', 'VehicleCategory']
# RFE
# Kiểm tra mô hình DTC
# ['Age', 'AgeOfVehicle', 'BasePolicy', 'DayOfWeekClaimed', 'Fault', 'Make', 'PolicyNumber', 'RepNumber', 'week_claimed', 'week_incident']
# RFE
# Kiểm tra mô hình RD
# ['Age', 'AgeOfVehicle', 'BasePolicy', 'Fault', 'Make', 'PolicyNumber', 'PolicyType', 'VehicleCategory', 'week_claimed', 'week_incident']

# %% [markdown]
# ### Giải thích:
# **Recursive Feature Elimination (RFE)** là một phương pháp trong lựa chọn đặc trưng (feature selection) được sử dụng trong học máy để giảm số lượng đặc trưng của mô hình mà vẫn giữ được hiệu suất tốt.
#
# Các model được dùng trong phương pháp này:
#    * **'LR'**: LogisticRegression
#    * **'LDA'**: LinearDiscriminantAnalysis
#    * **'DTC'**: DecisionTreeClassifier
#    * **'RD'**: RandomForestClassifier

# %%
special_models=[KNeighborsClassifier(),GaussianNB(),MLPClassifier(),GradientBoostingClassifier(),MultinomialNB(),SVC()]
names=['KNC','GNB','NN','BG','NB','SVM']
def feature_selection_inKBest(model, name):
    k_best = SelectKBest(score_func=f_classif, k=11)
    fit = k_best.fit(x_train, y_train)
    selected_features = fit.get_support()
    selected_column_names = x_train.columns[selected_features]
    return selected_column_names
feature_Kbest={}
for model,name in zip(special_models,names):
    print(f'Lua chon dac trung {name}')
    print(feature_selection_inKBest(model, name))
    feature_Kbest[name]=list(feature_selection_inKBest(model, name))
# Out:
# Lua chon dac trung KNC
# Index(['WeekOfMonth', 'DayOfWeek', 'AccidentArea', 'WeekOfMonthClaimed',
#        'MaritalStatus', 'Fault', 'PolicyType', 'VehicleCategory',
#        'AgeOfVehicle', 'AgeOfPolicyHolder', 'BasePolicy'],
#       dtype='object')
# Lua chon dac trung GNB
# Index(['WeekOfMonth', 'DayOfWeek', 'AccidentArea', 'WeekOfMonthClaimed',
#        'MaritalStatus', 'Fault', 'PolicyType', 'VehicleCategory',
#        'AgeOfVehicle', 'AgeOfPolicyHolder', 'BasePolicy'],
#       dtype='object')
# Lua chon dac trung NN
# Index(['WeekOfMonth', 'DayOfWeek', 'AccidentArea', 'WeekOfMonthClaimed',
#        'MaritalStatus', 'Fault', 'PolicyType', 'VehicleCategory',
#        'AgeOfVehicle', 'AgeOfPolicyHolder', 'BasePolicy'],
#       dtype='object')
# Lua chon dac trung BG
# Index(['WeekOfMonth', 'DayOfWeek', 'AccidentArea', 'WeekOfMonthClaimed',
#        'MaritalStatus', 'Fault', 'PolicyType', 'VehicleCategory',
#        'AgeOfVehicle', 'AgeOfPolicyHolder', 'BasePolicy'],
#       dtype='object')
# Lua chon dac trung NB
# Index(['WeekOfMonth', 'DayOfWeek', 'AccidentArea', 'WeekOfMonthClaimed',
#        'MaritalStatus', 'Fault', 'PolicyType', 'VehicleCategory',
#        'AgeOfVehicle', 'AgeOfPolicyHolder', 'BasePolicy'],
#       dtype='object')
# Lua chon dac trung SVM
# Index(['WeekOfMonth', 'DayOfWeek', 'AccidentArea', 'WeekOfMonthClaimed',
#        'MaritalStatus', 'Fault', 'PolicyType', 'VehicleCategory',
#        'AgeOfVehicle', 'AgeOfPolicyHolder', 'BasePolicy'],
#       dtype='object')

# %% [markdown]
# ### Giải thích:
# Phương pháp **SelectKBest** từ thư viện sklearn.feature_selection để lựa chọn đặc trưng dựa trên kỹ thuật kiểm định thống kê.
#
# Các model được dùng trong phương pháp này:
#    * **'KNC'**: KNeighborsClassifier
#    * **'GNB'**: GaussianNB
#    * **'NN'**: MLPClassifier
#    * **'BG'**: GradientBoostingClassifier
#    * **'NB'**: MultinomialNB
#    * **'SVM'**: SVC

# %%
print(feature_Kbest)
print(feature_SelectFromModel)
print(feature_RFE)
# Out:
# {'KNC': ['WeekOfMonth', 'DayOfWeek', 'AccidentArea', 'WeekOfMonthClaimed', 'MaritalStatus', 'Fault', 'PolicyType', 'VehicleCategory', 'AgeOfVehicle', 'AgeOfPolicyHolder', 'BasePolicy'], 'GNB': ['WeekOfMonth', 'DayOfWeek', 'AccidentArea', 'WeekOfMonthClaimed', 'MaritalStatus', 'Fault', 'PolicyType', 'VehicleCategory', 'AgeOfVehicle', 'AgeOfPolicyHolder', 'BasePolicy'], 'NN': ['WeekOfMonth', 'DayOfWeek', 'AccidentArea', 'WeekOfMonthClaimed', 'MaritalStatus', 'Fault', 'PolicyType', 'VehicleCategory', 'AgeOfVehicle', 'AgeOfPolicyHolder', 'BasePolicy'], 'BG': ['WeekOfMonth', 'DayOfWeek', 'AccidentArea', 'WeekOfMonthClaimed', 'MaritalStatus', 'Fault', 'PolicyType', 'VehicleCategory', 'AgeOfVehicle', 'AgeOfPolicyHolder', 'BasePolicy'], 'NB': ['WeekOfMonth', 'DayOfWeek', 'AccidentArea', 'WeekOfMonthClaimed', 'MaritalStatus', 'Fault', 'PolicyType', 'VehicleCategory', 'AgeOfVehicle', 'AgeOfPolicyHolder', 'BasePolicy'], 'SVM': ['WeekOfMonth', 'DayOfWeek', 'AccidentArea', 'WeekOfMonthClaimed', 'MaritalStatus', 'Fault', 'PolicyType', 'VehicleCategory', 'AgeOfVehicle', 'AgeOfPolicyHolder', 'BasePolicy']}
# {'LR': ['AccidentArea', 'MaritalStatus', 'Fault', 'VehicleCategory', 'PolicyNumber', 'DriverRating', 'Days_Policy_Accident', 'Days_Policy_Claim', 'PastNumberOfClaims', 'AgeOfVehicle', 'AddressChange_Claim', 'BasePolicy'], 'LDA': ['MaritalStatus', 'Age', 'Fault', 'VehicleCategory', 'AgeOfPolicyHolder', 'PoliceReportFiled', 'Year', 'BasePolicy'], 'DTC': ['Make', 'Age', 'Fault', 'PolicyNumber', 'AgeOfVehicle', 'AgeOfPolicyHolder', 'BasePolicy', 'week_claimed', 'week_incident']}
# {'LR': ['Age', 'AgeOfPolicyHolder', 'AgentType', 'BasePolicy', 'Fault', 'MaritalStatus', 'PoliceReportFiled', 'PolicyType', 'VehicleCategory', 'WitnessPresent'], 'LDA': ['AccidentArea', 'Age', 'AgeOfPolicyHolder', 'BasePolicy', 'Days_Policy_Claim', 'Fault', 'MaritalStatus', 'NumberOfCars', 'PoliceReportFiled', 'VehicleCategory'], 'DTC': ['Age', 'AgeOfVehicle', 'BasePolicy', 'DayOfWeekClaimed', 'Fault', 'Make', 'PolicyNumber', 'RepNumber', 'week_claimed', 'week_incident'], 'RD': ['Age', 'AgeOfVehicle', 'BasePolicy', 'Fault', 'Make', 'PolicyNumber', 'PolicyType', 'VehicleCategory', 'week_claimed', 'week_incident']}

# %%
feature_model_selection={**feature_RFE,**feature_Kbest}
np.savez(f'{save_dir}/feature_model_selection.npz', feature_model_selection = feature_model_selection)
feature_model_selection
# Out:
# {'LR': ['Age',
#   'AgeOfPolicyHolder',
#   'AgentType',
#   'BasePolicy',
#   'Fault',
#   'MaritalStatus',
#   'PoliceReportFiled',
#   'PolicyType',
#   'VehicleCategory',
#   'WitnessPresent'],
#  'LDA': ['AccidentArea',
#   'Age',
#   'AgeOfPolicyHolder',
#   'BasePolicy',
#   'Days_Policy_Claim',
#   'Fault',
#   'MaritalStatus',
#   'NumberOfCars',
#   'PoliceReportFiled',
#   'VehicleCategory'],
#  'DTC': ['Age',
#   'AgeOfVehicle',
#   'BasePolicy',
#   'DayOfWeekClaimed',
#   'Fault',
#   'Make',
#   'PolicyNumber',
#   'RepNumber',
#   'week_claimed',
#   'week_incident'],
#  'RD': ['Age',
#   'AgeOfVehicle',
#   'BasePolicy',
#   'Fault',
#   'Make',
#   'PolicyNumber',
#   'PolicyType',
#   'VehicleCategory',
#   'week_claimed',
#   'week_incident'],
#  'KNC': ['WeekOfMonth',
#   'DayOfWeek',
#   'AccidentArea',
#   'WeekOfMonthClaimed',
#   'MaritalStatus',
#   'Fault',
#   'PolicyType',
#   'VehicleCategory',
#   'AgeOfVehicle',
#   'AgeOfPolicyHolder',
#   'BasePolicy'],
#  'GNB': ['WeekOfMonth',
#   'DayOfWeek',
#   'AccidentArea',
#   'WeekOfMonthClaimed',
#   'MaritalStatus',
#   'Fault',
#   'PolicyType',
#   'VehicleCategory',
#   'AgeOfVehicle',
#   'AgeOfPolicyHolder',
#   'BasePolicy'],
#  'NN': ['WeekOfMonth',
#   'DayOfWeek',
#   'AccidentArea',
#   'WeekOfMonthClaimed',
#   'MaritalStatus',
#   'Fault',
#   'PolicyType',
#   'VehicleCategory',
#   'AgeOfVehicle',
#   'AgeOfPolicyHolder',
#   'BasePolicy'],
#  'BG': ['WeekOfMonth',
#   'DayOfWeek',
#   'AccidentArea',
#   'WeekOfMonthClaimed',
#   'MaritalStatus',
#   'Fault',
#   'PolicyType',
#   'VehicleCategory',
#   'AgeOfVehicle',
#   'AgeOfPolicyHolder',
#   'BasePolicy'],
#  'NB': ['WeekOfMonth',
#   'DayOfWeek',
#   'AccidentArea',
#   'WeekOfMonthClaimed',
#   'MaritalStatus',
#   'Fault',
#   'PolicyType',
#   'VehicleCategory',
#   'AgeOfVehicle',
#   'AgeOfPolicyHolder',
#   'BasePolicy'],
#  'SVM': ['WeekOfMonth',
#   'DayOfWeek',
#   'AccidentArea',
#   'WeekOfMonthClaimed',
#   'MaritalStatus',
#   'Fault',
#   'PolicyType',
#   'VehicleCategory',
#   'AgeOfVehicle',
#   'AgeOfPolicyHolder',
#   'BasePolicy']}

# %% [markdown]
# * gom nhóm thông tin về các đặc trưng được chọn từ hai phương pháp lựa chọn đặc trưng khác nhau (RFE và SelectKBest) vào từ điển **feature_model_selection**.

# %%
dict(np.load(f'{save_dir}/feature_model_selection.npz',allow_pickle=True))['feature_model_selection']
# Out:
# array({'LR': ['Age', 'AgeOfPolicyHolder', 'AgentType', 'BasePolicy', 'Fault', 'MaritalStatus', 'PoliceReportFiled', 'PolicyType', 'VehicleCategory', 'WitnessPresent'], 'LDA': ['AccidentArea', 'Age', 'AgeOfPolicyHolder', 'BasePolicy', 'Days_Policy_Claim', 'Fault', 'MaritalStatus', 'NumberOfCars', 'PoliceReportFiled', 'VehicleCategory'], 'DTC': ['Age', 'AgeOfVehicle', 'BasePolicy', 'DayOfWeekClaimed', 'Fault', 'Make', 'PolicyNumber', 'RepNumber', 'week_claimed', 'week_incident'], 'RD': ['Age', 'AgeOfVehicle', 'BasePolicy', 'Fault', 'Make', 'PolicyNumber', 'PolicyType', 'VehicleCategory', 'week_claimed', 'week_incident'], 'KNC': ['WeekOfMonth', 'DayOfWeek', 'AccidentArea', 'WeekOfMonthClaimed', 'MaritalStatus', 'Fault', 'PolicyType', 'VehicleCategory', 'AgeOfVehicle', 'AgeOfPolicyHolder', 'BasePolicy'], 'GNB': ['WeekOfMonth', 'DayOfWeek', 'AccidentArea', 'WeekOfMonthClaimed', 'MaritalStatus', 'Fault', 'PolicyType', 'VehicleCategory', 'AgeOfVehicle', 'AgeOfPolicyHolder', 'BasePolicy'], 'NN': ['WeekOfMonth', 'DayOfWeek', 'AccidentArea', 'WeekOfMonthClaimed', 'MaritalStatus', 'Fault', 'PolicyType', 'VehicleCategory', 'AgeOfVehicle', 'AgeOfPolicyHolder', 'BasePolicy'], 'BG': ['WeekOfMonth', 'DayOfWeek', 'AccidentArea', 'WeekOfMonthClaimed', 'MaritalStatus', 'Fault', 'PolicyType', 'VehicleCategory', 'AgeOfVehicle', 'AgeOfPolicyHolder', 'BasePolicy'], 'NB': ['WeekOfMonth', 'DayOfWeek', 'AccidentArea', 'WeekOfMonthClaimed', 'MaritalStatus', 'Fault', 'PolicyType', 'VehicleCategory', 'AgeOfVehicle', 'AgeOfPolicyHolder', 'BasePolicy'], 'SVM': ['WeekOfMonth', 'DayOfWeek', 'AccidentArea', 'WeekOfMonthClaimed', 'MaritalStatus', 'Fault', 'PolicyType', 'VehicleCategory', 'AgeOfVehicle', 'AgeOfPolicyHolder', 'BasePolicy']},
#       dtype=object)
