# %%
# !git clone https://github.com/dinhtanloc/ads_fraud_detection.git

# %%
# pip install kaggle==1.5.0

# %%
# pip install tensorflow==2.12.0
# #

# %%
# pip install joblib cufflinks pydantic-settings mlxtend keras-tuner wandb shap lime tabnet-keras imbalanced-learn scikit-learn-extra xgboost lightgbm faker sdv

# %%
# from kaggle_secrets import UserSecretsClient
# import os
# user_secrets = UserSecretsClient()
# KAGGLE_KEY = user_secrets.get_secret("KAGGLE_KEY")
# KAGGLE_USERNAME = user_secrets.get_secret("KAGGLE_USERNAME")
# os.environ['KAGGLE_USERNAME'] = KAGGLE_USERNAME
# os.environ['KAGGLE_KEY'] = KAGGLE_KEY

# from kaggle.api.kaggle_api_extended import KaggleApi

# api = KaggleApi()
# api.authenticate()

# print("Kaggle API authenticated successfully!")

# %%
# import os
# os.system("kaggle command")

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj3/1.EDA/EDA_mainbaseline_kaggle.ipynb

# %% [markdown]
# smote

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj3/2.preprocessing/3.smote/pre-processing-mainbaseline_SMOTE_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/3.smote/Tabnet/tabnet_class_weight_kaggle_diceloss.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# C:/Users/PC/Data/ads_fraud_detection
# (46631, 2) (292440, 2)
# (46631, 2)
# 43
# c:\ProgramData\miniconda3\envs\tensorflow_gpu\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
#
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#
# c:\ProgramData\miniconda3\envs\tensorflow_gpu\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning:
#
# Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.11.0 and strictly below 2.14.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.1 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#
# c:\ProgramData\miniconda3\envs\tensorflow_gpu\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning:
#
# The `lr` argument is deprecated, use `learning_rate` instead.
# Epoch 1/1200
# 1134/1134 [==============================] - 190s 142ms/step - loss: 0.6246 - accuracy: 0.5793 - f1_score: 0.5749 - cohen_kappa: -0.9845 - val_loss: 0.5102 - val_accuracy: 0.4929 - val_f1_score: 0.4590 - val_cohen_kappa: -0.8881 - lr: 0.0010
# Epoch 2/1200
# 1134/1134 [==============================] - 201s 177ms/step - loss: 0.6109 - accuracy: 0.5884 - f1_score: 0.5849 - cohen_kappa: -0.9879 - val_loss: 0.4850 - val_accuracy: 0.5182 - val_f1_score: 0.4684 - val_cohen_kappa: -0.8340 - lr: 0.0010
# Epoch 3/1200
# 1134/1134 [==============================] - 201s 177ms/step - loss: 0.6062 - accuracy: 0.5916 - f1_score: 0.5892 - cohen_kappa: -0.9932 - val_loss: 0.5102 - val_accuracy: 0.4925 - val_f1_score: 0.4552 - val_cohen_kappa: -0.8764 - lr: 0.0010
# Epoch 4/1200
# 1134/1134 [==============================] - 200s 176ms/step - loss: 0.6045 - accuracy: 0.5927 - f1_score: 0.5893 - cohen_kappa: -0.9874 - val_loss: 0.4910 - val_accuracy: 0.5121 - val_f1_score: 0.4692 - val_cohen_kappa: -0.8584 - lr: 0.0010
# Epoch 5/1200
# 1134/1134 [==============================] - ETA: 0s - loss: 0.6027 - accuracy: 0.5938 - f1_score: 0.5927 - cohen_kappa: -0.9989
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1134/1134 [==============================] - 209s 185ms/step - loss: 0.6027 - accuracy: 0.5938 - f1_score: 0.5927 - cohen_kappa: -0.9989 - val_loss: 0.5022 - val_accuracy: 0.5014 - val_f1_score: 0.4626 - val_cohen_kappa: -0.8700 - lr: 0.0010
# Epoch 6/1200
# 1134/1134 [==============================] - 204s 180ms/step - loss: 0.5948 - accuracy: 0.5991 - f1_score: 0.5972 - cohen_kappa: -0.9937 - val_loss: 0.5208 - val_accuracy: 0.4825 - val_f1_score: 0.4516 - val_cohen_kappa: -0.8991 - lr: 5.0000e-04
# Epoch 7/1200
# 1134/1134 [==============================] - 201s 177ms/step - loss: 0.5914 - accuracy: 0.6014 - f1_score: 0.5976 - cohen_kappa: -0.9852 - val_loss: 0.5032 - val_accuracy: 0.5002 - val_f1_score: 0.4618 - val_cohen_kappa: -0.8727 - lr: 5.0000e-04
# Epoch 8/1200
# 1134/1134 [==============================] - ETA: 0s - loss: 0.5916 - accuracy: 0.6013 - f1_score: 0.5986 - cohen_kappa: -0.9900
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1134/1134 [==============================] - 201s 178ms/step - loss: 0.5916 - accuracy: 0.6013 - f1_score: 0.5986 - cohen_kappa: -0.9900 - val_loss: 0.4871 - val_accuracy: 0.5160 - val_f1_score: 0.4696 - val_cohen_kappa: -0.8437 - lr: 5.0000e-04
# Epoch 9/1200
# 1134/1134 [==============================] - 205s 181ms/step - loss: 0.5865 - accuracy: 0.6048 - f1_score: 0.6032 - cohen_kappa: -0.9951 - val_loss: 0.5067 - val_accuracy: 0.4965 - val_f1_score: 0.4585 - val_cohen_kappa: -0.8742 - lr: 2.5000e-04
# Epoch 10/1200
# 1134/1134 [==============================] - 207s 182ms/step - loss: 0.5839 - accuracy: 0.6064 - f1_score: 0.6034 - cohen_kappa: -0.9877 - val_loss: 0.5026 - val_accuracy: 0.5010 - val_f1_score: 0.4627 - val_cohen_kappa: -0.8739 - lr: 2.5000e-04
# Epoch 11/1200
# 1134/1134 [==============================] - 207s 183ms/step - loss: 0.5822 - accuracy: 0.6077 - f1_score: 0.6053 - cohen_kappa: -0.9913 - val_loss: 0.4800 - val_accuracy: 0.5231 - val_f1_score: 0.4726 - val_cohen_kappa: -0.8310 - lr: 2.5000e-04
# Epoch 12/1200
# 1134/1134 [==============================] - 209s 184ms/step - loss: 0.5822 - accuracy: 0.6078 - f1_score: 0.6062 - cohen_kappa: -0.9953 - val_loss: 0.4786 - val_accuracy: 0.5247 - val_f1_score: 0.4732 - val_cohen_kappa: -0.8278 - lr: 2.5000e-04
# Epoch 13/1200
# 1134/1134 [==============================] - 207s 182ms/step - loss: 0.5806 - accuracy: 0.6088 - f1_score: 0.6068 - cohen_kappa: -0.9934 - val_loss: 0.5124 - val_accuracy: 0.4910 - val_f1_score: 0.4553 - val_cohen_kappa: -0.8819 - lr: 2.5000e-04
# Epoch 14/1200
# 1134/1134 [==============================] - 208s 183ms/step - loss: 0.5805 - accuracy: 0.6088 - f1_score: 0.6055 - cohen_kappa: -0.9862 - val_loss: 0.5084 - val_accuracy: 0.4948 - val_f1_score: 0.4575 - val_cohen_kappa: -0.8775 - lr: 2.5000e-04
# Epoch 15/1200
# 1134/1134 [==============================] - ETA: 0s - loss: 0.5776 - accuracy: 0.6108 - f1_score: 0.6086 - cohen_kappa: -0.9918
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1134/1134 [==============================] - 209s 185ms/step - loss: 0.5776 - accuracy: 0.6108 - f1_score: 0.6086 - cohen_kappa: -0.9918 - val_loss: 0.4951 - val_accuracy: 0.5080 - val_f1_score: 0.4650 - val_cohen_kappa: -0.8575 - lr: 2.5000e-04
# Epoch 16/1200
# 1134/1134 [==============================] - 208s 183ms/step - loss: 0.5763 - accuracy: 0.6117 - f1_score: 0.6093 - cohen_kappa: -0.9906 - val_loss: 0.5151 - val_accuracy: 0.4882 - val_f1_score: 0.4539 - val_cohen_kappa: -0.8883 - lr: 1.2500e-04
# Epoch 17/1200
# 1134/1134 [==============================] - 208s 183ms/step - loss: 0.5751 - accuracy: 0.6125 - f1_score: 0.6092 - cohen_kappa: -0.9864 - val_loss: 0.5067 - val_accuracy: 0.4968 - val_f1_score: 0.4581 - val_cohen_kappa: -0.8723 - lr: 1.2500e-04
# Epoch 18/1200
# 1134/1134 [==============================] - ETA: 0s - loss: 0.5751 - accuracy: 0.6123 - f1_score: 0.6101 - cohen_kappa: -0.9915
# Epoch 18: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 1134/1134 [==============================] - 208s 184ms/step - loss: 0.5751 - accuracy: 0.6123 - f1_score: 0.6101 - cohen_kappa: -0.9915 - val_loss: 0.4974 - val_accuracy: 0.5060 - val_f1_score: 0.4638 - val_cohen_kappa: -0.8600 - lr: 1.2500e-04
# Epoch 19/1200
# 1134/1134 [==============================] - 208s 183ms/step - loss: 0.5732 - accuracy: 0.6138 - f1_score: 0.6116 - cohen_kappa: -0.9917 - val_loss: 0.4950 - val_accuracy: 0.5080 - val_f1_score: 0.4639 - val_cohen_kappa: -0.8539 - lr: 6.2500e-05
# Epoch 20/1200
# 1134/1134 [==============================] - 210s 185ms/step - loss: 0.5719 - accuracy: 0.6146 - f1_score: 0.6123 - cohen_kappa: -0.9905 - val_loss: 0.4895 - val_accuracy: 0.5139 - val_f1_score: 0.4673 - val_cohen_kappa: -0.8449 - lr: 6.2500e-05
# Epoch 21/1200
# 1134/1134 [==============================] - ETA: 0s - loss: 0.5710 - accuracy: 0.6152 - f1_score: 0.6133 - cohen_kappa: -0.9933
# Epoch 21: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 1134/1134 [==============================] - 210s 185ms/step - loss: 0.5710 - accuracy: 0.6152 - f1_score: 0.6133 - cohen_kappa: -0.9933 - val_loss: 0.4905 - val_accuracy: 0.5131 - val_f1_score: 0.4666 - val_cohen_kappa: -0.8458 - lr: 6.2500e-05
# Epoch 22/1200
# 1134/1134 [==============================] - ETA: 0s - loss: 0.5729 - accuracy: 0.6141 - f1_score: 0.6122 - cohen_kappa: -0.9933Restoring model weights from the end of the best epoch: 12.
# 1134/1134 [==============================] - 208s 184ms/step - loss: 0.5729 - accuracy: 0.6141 - f1_score: 0.6122 - cohen_kappa: -0.9933 - val_loss: 0.4902 - val_accuracy: 0.5130 - val_f1_score: 0.4667 - val_cohen_kappa: -0.8462 - lr: 3.1250e-05
# Epoch 22: early stopping
# Model: "tab_net_classifier"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  tab_net_encoder (TabNetEnco  multiple                 19160240
#  der)
#
#  classifier (Dense)          multiple                  1024
#
# =================================================================
# Total params: 19,161,264
# Trainable params: 19,095,384
# Non-trainable params: 65,880
# _________________________________________________________________
# Model: "tab_net_classifier"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  tab_net_encoder (TabNetEnco  multiple                 19160240
#  der)
#
#  classifier (Dense)          multiple                  1024
#
# =================================================================
# Total params: 19,161,264
# Trainable params: 19,095,384
# Non-trainable params: 65,880
# _________________________________________________________________
# 1458/1458 [==============================] - 11s 7ms/step
# Accuracy: 0.5246938731744977
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.53      0.64     36323
#            1       0.23      0.49      0.31     10308
#
#     accuracy                           0.52     46631
#    macro avg       0.51      0.51      0.48     46631
# weighted avg       0.66      0.52      0.57     46631
#
# Confusion Matrix:
# [[19389 16934]
#  [ 5230  5078]]

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/3.smote/Tabnet/tabnet_class_weight_kaggle_multiloss.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# (46631, 2) (292440, 2)
# (46631, 2)
# 43
# c:\ProgramData\miniconda3\envs\tensorflow_gpu\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning:
#
# The `lr` argument is deprecated, use `learning_rate` instead.
# Epoch 1/1200
# 1134/1134 [==============================] - 269s 185ms/step - loss: 0.8685 - accuracy: 0.5810 - f1_score: 0.5789 - cohen_kappa: -0.9974 - val_loss: 0.6265 - val_accuracy: 0.5191 - val_f1_score: 0.4723 - val_cohen_kappa: -0.8438 - lr: 1.0000e-04
# Epoch 2/1200
# 1134/1134 [==============================] - 209s 184ms/step - loss: 0.8294 - accuracy: 0.6011 - f1_score: 0.5991 - cohen_kappa: -0.9955 - val_loss: 0.5737 - val_accuracy: 0.5755 - val_f1_score: 0.4968 - val_cohen_kappa: -0.7344 - lr: 1.0000e-04
# Epoch 3/1200
# 1134/1134 [==============================] - 206s 182ms/step - loss: 0.8129 - accuracy: 0.6111 - f1_score: 0.6089 - cohen_kappa: -0.9949 - val_loss: 0.6003 - val_accuracy: 0.5437 - val_f1_score: 0.4856 - val_cohen_kappa: -0.8049 - lr: 1.0000e-04
# Epoch 4/1200
# 1134/1134 [==============================] - 207s 183ms/step - loss: 0.8053 - accuracy: 0.6148 - f1_score: 0.6128 - cohen_kappa: -0.9945 - val_loss: 0.5956 - val_accuracy: 0.5420 - val_f1_score: 0.4812 - val_cohen_kappa: -0.7961 - lr: 1.0000e-04
# Epoch 5/1200
# 1134/1134 [==============================] - ETA: 0s - loss: 0.8004 - accuracy: 0.6184 - f1_score: 0.6163 - cohen_kappa: -0.9941
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 1134/1134 [==============================] - 150s 132ms/step - loss: 0.8004 - accuracy: 0.6184 - f1_score: 0.6163 - cohen_kappa: -0.9941 - val_loss: 0.6331 - val_accuracy: 0.4979 - val_f1_score: 0.4591 - val_cohen_kappa: -0.8735 - lr: 1.0000e-04
# Epoch 6/1200
# 1134/1134 [==============================] - 108s 96ms/step - loss: 0.7905 - accuracy: 0.6242 - f1_score: 0.6222 - cohen_kappa: -0.9935 - val_loss: 0.6080 - val_accuracy: 0.5230 - val_f1_score: 0.4717 - val_cohen_kappa: -0.8303 - lr: 5.0000e-05
# Epoch 7/1200
# 1134/1134 [==============================] - 92s 81ms/step - loss: 0.7871 - accuracy: 0.6264 - f1_score: 0.6244 - cohen_kappa: -0.9939 - val_loss: 0.5999 - val_accuracy: 0.5397 - val_f1_score: 0.4817 - val_cohen_kappa: -0.8055 - lr: 5.0000e-05
# Epoch 8/1200
# 1134/1134 [==============================] - ETA: 0s - loss: 0.7844 - accuracy: 0.6288 - f1_score: 0.6266 - cohen_kappa: -0.9932
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 1134/1134 [==============================] - 98s 87ms/step - loss: 0.7844 - accuracy: 0.6288 - f1_score: 0.6266 - cohen_kappa: -0.9932 - val_loss: 0.5919 - val_accuracy: 0.5543 - val_f1_score: 0.4895 - val_cohen_kappa: -0.7811 - lr: 5.0000e-05
# Epoch 9/1200
# 1134/1134 [==============================] - 144s 127ms/step - loss: 0.7770 - accuracy: 0.6336 - f1_score: 0.6316 - cohen_kappa: -0.9936 - val_loss: 0.5840 - val_accuracy: 0.5601 - val_f1_score: 0.4911 - val_cohen_kappa: -0.7679 - lr: 2.5000e-05
# Epoch 10/1200
# 1134/1134 [==============================] - 187s 165ms/step - loss: 0.7745 - accuracy: 0.6358 - f1_score: 0.6338 - cohen_kappa: -0.9931 - val_loss: 0.5929 - val_accuracy: 0.5563 - val_f1_score: 0.4914 - val_cohen_kappa: -0.7801 - lr: 2.5000e-05
# Epoch 11/1200
# 1134/1134 [==============================] - ETA: 0s - loss: 0.7722 - accuracy: 0.6377 - f1_score: 0.6357 - cohen_kappa: -0.9933
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 1134/1134 [==============================] - 179s 158ms/step - loss: 0.7722 - accuracy: 0.6377 - f1_score: 0.6357 - cohen_kappa: -0.9933 - val_loss: 0.5904 - val_accuracy: 0.5547 - val_f1_score: 0.4895 - val_cohen_kappa: -0.7796 - lr: 2.5000e-05
# Epoch 12/1200
# 1134/1134 [==============================] - ETA: 0s - loss: 0.7674 - accuracy: 0.6406 - f1_score: 0.6386 - cohen_kappa: -0.9929Restoring model weights from the end of the best epoch: 2.
# 1134/1134 [==============================] - 180s 159ms/step - loss: 0.7674 - accuracy: 0.6406 - f1_score: 0.6386 - cohen_kappa: -0.9929 - val_loss: 0.5844 - val_accuracy: 0.5575 - val_f1_score: 0.4919 - val_cohen_kappa: -0.7780 - lr: 1.2500e-05
# Epoch 12: early stopping
# Model: "tab_net_classifier_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  tab_net_encoder_1 (TabNetEn  multiple                 19160240
#  coder)
#
#  classifier (Dense)          multiple                  1024
#
# =================================================================
# Total params: 19,161,264
# Trainable params: 19,095,384
# Non-trainable params: 65,880
# _________________________________________________________________
# Model: "tab_net_classifier_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  tab_net_encoder_1 (TabNetEn  multiple                 19160240
#  coder)
#
#  classifier (Dense)          multiple                  1024
#
# =================================================================
# Total params: 19,161,264
# Trainable params: 19,095,384
# Non-trainable params: 65,880
# _________________________________________________________________
# 1458/1458 [==============================] - 9s 6ms/step
# Accuracy: 0.5754969869829084
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.62      0.69     36323
#            1       0.24      0.42      0.30     10308
#
#     accuracy                           0.58     46631
#    macro avg       0.51      0.52      0.50     46631
# weighted avg       0.67      0.58      0.61     46631
#
# Confusion Matrix:
# [[22541 13782]
#  [ 6013  4295]]
