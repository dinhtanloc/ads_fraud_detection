# %% [markdown]
# #### GAU

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\5.synthetic_gan\InceptionV2\inceptionv2_base.ipynb"
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_3244\3802462488.py:1
# ----> 1 import tensorflow as tf
#       2 import pandas as pd
#       3 import numpy as np
#
# File c:\Users\Admin\Data\ads_fraud_detection\.conda\lib\site-packages\tensorflow\__init__.py:38
#      35 import sys as _sys
#      36 import typing as _typing
# ---> 38 from tensorflow.python.tools import module_util as _module_util
#      39 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      41 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File c:\Users\Admin\Data\ads_fraud_detection\.conda\lib\site-packages\tensorflow\python\__init__.py:42
#      37 from tensorflow.python.eager import context
#      39 # pylint: enable=wildcard-import
#      40
#      41 # Bring in subpackages.
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\5.synthetic_gan\InceptionV2\inceptionv2_class_weight.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\5.synthetic_gan\InceptionV2\inceptionv2_class_weight_dice.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\5.synthetic_gan\InceptionV2\inceptionv2_class_weight_focal.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\5.synthetic_gan\InceptionV2\inceptionv2_class_weight_f1.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\5.synthetic_gan\InceptionV3\inceptionv3_base.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\5.synthetic_gan\InceptionV3\inceptionv3_class_weight.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\5.synthetic_gan\InceptionV3\inceptionv3_class_weight_dice.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\5.synthetic_gan\InceptionV3\inceptionv3_class_weight_focal.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\5.synthetic_gan\InceptionV3\inceptionv3_class_weight_f1.ipynb"

# %%
#
