# %%
# !git clone https://github.com/dinhtanloc/ads_fraud_detection.git

# %%
# pip install kaggle==1.5.0

# %%
# pip install tensorflow==2.12.0
# #

# %%
# pip install joblib cufflinks pydantic-settings mlxtend keras-tuner wandb shap lime tabnet-keras imbalanced-learn scikit-learn-extra xgboost lightgbm faker sdv

# %%
# from kaggle_secrets import UserSecretsClient
# import os
# user_secrets = UserSecretsClient()
# KAGGLE_KEY = user_secrets.get_secret("KAGGLE_KEY")
# KAGGLE_USERNAME = user_secrets.get_secret("KAGGLE_USERNAME")
# os.environ['KAGGLE_USERNAME'] = KAGGLE_USERNAME
# os.environ['KAGGLE_KEY'] = KAGGLE_KEY

# from kaggle.api.kaggle_api_extended import KaggleApi

# api = KaggleApi()
# api.authenticate()

# print("Kaggle API authenticated successfully!")

# %%
# import os
# os.system("kaggle command")

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/1.EDA/EDA_mainbaseline_kaggle.ipynb

# %% [markdown]
# smote

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/2.preprocessing/3.smote/pre-processing-mainbaseline_SMOTE_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/3.smote/InceptionV2/inceptionv2_class_weight_kaggle_diceloss.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# C:/Users/PC/Data/ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (46631, 2) (292440, 2)
# (46631, 2)
# c:\ProgramData\miniconda3\envs\tensorflow_gpu\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# ...

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/3.smote/VGG16/vgg16_class_weight_kaggle_diceloss.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (46631, 2) (292440, 2)
# (46631, 2)
# 43
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 43, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 43, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 43, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 21, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 21, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 21, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 10, 256)           0
#
#  block3_conv1 (Conv1D)       (None, 10, 512)           393728
#
#  block3_conv2 (Conv1D)       (None, 10, 512)           786944
#
#  block3_conv3 (Conv1D)       (None, 10, 512)           786944
#
# ...

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/3.smote/InceptionV3/inceptionv3_class_weight_kaggle_diceloss.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (46631, 2) (292440, 2)
# (46631, 2)
# 43
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_3 (InputLayer)           [(None, 43, 1)]      0           []
#
#  conv1d_203 (Conv1D)            (None, 21, 32)       96          ['input_3[0][0]']
#
#  batch_normalization_203 (Batch  (None, 21, 32)      63          ['conv1d_203[0][0]']
#  Normalization)
#
#  activation_203 (Activation)    (None, 21, 32)       0           ['batch_normalization_203[0][0]']
#
#  conv1d_204 (Conv1D)            (None, 19, 32)       3072        ['activation_203[0][0]']
#
#  batch_normalization_204 (Batch  (None, 19, 32)      57          ['conv1d_204[0][0]']
#  Normalization)
#
# ...

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/3.smote/InceptionV2/inceptionv2_class_weight_kaggle_multi_loss.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (46631, 2) (292440, 2)
# (46631, 2)
# 43
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_4 (InputLayer)           [(None, 43, 1)]      0           []
#
#  conv1d_249 (Conv1D)            (None, 21, 16)       64          ['input_4[0][0]']
#
#  batch_normalization_249 (Batch  (None, 21, 16)      63          ['conv1d_249[0][0]']
#  Normalization)
#
#  activation_249 (Activation)    (None, 21, 16)       0           ['batch_normalization_249[0][0]']
#
#  conv1d_250 (Conv1D)            (None, 19, 16)       784         ['activation_249[0][0]']
#
#  batch_normalization_250 (Batch  (None, 19, 16)      57          ['conv1d_250[0][0]']
#  Normalization)
#
# ...

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/3.smote/VGG16/vgg16_class_weight_kaggle_multi_loss.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (46631, 2) (292440, 2)
# (46631, 2)
# 43
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_5 (InputLayer)        [(None, 43, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 43, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 43, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 21, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 21, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 21, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 10, 256)           0
#
#  block3_conv1 (Conv1D)       (None, 10, 512)           393728
#
#  block3_conv2 (Conv1D)       (None, 10, 512)           786944
#
#  block3_conv3 (Conv1D)       (None, 10, 512)           786944
#
# ...

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/3.smote/InceptionV3/inceptionv3_class_weight_kaggle_multi_loss.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (46631, 2) (292440, 2)
# (46631, 2)
# 43
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_6 (InputLayer)           [(None, 43, 1)]      0           []
#
#  conv1d_452 (Conv1D)            (None, 21, 32)       96          ['input_6[0][0]']
#
#  batch_normalization_452 (Batch  (None, 21, 32)      63          ['conv1d_452[0][0]']
#  Normalization)
#
#  activation_452 (Activation)    (None, 21, 32)       0           ['batch_normalization_452[0][0]']
#
#  conv1d_453 (Conv1D)            (None, 19, 32)       3072        ['activation_452[0][0]']
#
#  batch_normalization_453 (Batch  (None, 19, 32)      57          ['conv1d_453[0][0]']
#  Normalization)
#
# ...
