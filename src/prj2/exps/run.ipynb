# %%
# %run "C:\Users\PC\Data\ads_fraud_detection\src\prj2\5.deep_learning_model\3.smote\InceptionV2\inceptionv2_base.ipynb"
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# C:/Users/PC/Data/ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (330, 2) (1022, 2)
# (330, 2)
# 39
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 39, 1)]      0           []
#
#  conv1d (Conv1D)                (None, 19, 16)       64          ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 19, 16)      57          ['conv1d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 19, 16)       0           ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 17, 16)       784         ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 17, 16)      51          ['conv1d_1[0][0]']
#  rmalization)
#
# ...

# %%
# %run "C:\Users\PC\Data\ads_fraud_detection\src\prj2\5.deep_learning_model\3.smote\InceptionV2\inceptionv2_class_weight.ipynb"

# %%
# %run "C:\Users\PC\Data\ads_fraud_detection\src\prj2\5.deep_learning_model\3.smote\InceptionV3\inceptionv3_base.ipynb"

# %%
# %run "C:\Users\PC\Data\ads_fraud_detection\src\prj2\5.deep_learning_model\3.smote\InceptionV3\inceptionv3_class_weight.ipynb"

# %%
# %run "C:\Users\PC\Data\ads_fraud_detection\src\prj2\5.deep_learning_model\3.smote\Tabnet\tabnet_base.ipynb"

# %%
# %run "C:\Users\PC\Data\ads_fraud_detection\src\prj2\5.deep_learning_model\3.smote\Tabnet\tabnet_class_weight.ipynb"
