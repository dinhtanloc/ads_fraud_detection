# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\3.smote\InceptionV2\inceptionv2_base.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (3300, 2) (12728, 2)
# (3300, 2)
# 37
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 37, 1)]      0           []
#
#  conv1d_203 (Conv1D)            (None, 18, 16)       64          ['input_2[0][0]']
#
#  batch_normalization_203 (Batch  (None, 18, 16)      54          ['conv1d_203[0][0]']
#  Normalization)
#
#  activation_203 (Activation)    (None, 18, 16)       0           ['batch_normalization_203[0][0]']
#
#  conv1d_204 (Conv1D)            (None, 16, 16)       784         ['activation_203[0][0]']
#
#  batch_normalization_204 (Batch  (None, 16, 16)      48          ['conv1d_204[0][0]']
#  Normalization)
#
#  activation_204 (Activation)    (None, 16, 16)       0           ['batch_normalization_204[0][0]']
#
#  conv1d_205 (Conv1D)            (None, 16, 32)       1568        ['activation_204[0][0]']
#
#  batch_normalization_205 (Batch  (None, 16, 32)      48          ['conv1d_205[0][0]']
#  Normalization)
#
#  activation_205 (Activation)    (None, 16, 32)       0           ['batch_normalization_205[0][0]']
#
#  max_pooling1d_4 (MaxPooling1D)  (None, 7, 32)       0           ['activation_205[0][0]']
#
#  conv1d_206 (Conv1D)            (None, 7, 80)        2640        ['max_pooling1d_4[0][0]']
#
#  batch_normalization_206 (Batch  (None, 7, 80)       21          ['conv1d_206[0][0]']
#  Normalization)
#
#  activation_206 (Activation)    (None, 7, 80)        0           ['batch_normalization_206[0][0]']
#
#  conv1d_207 (Conv1D)            (None, 5, 192)       46272       ['activation_206[0][0]']
#
#  batch_normalization_207 (Batch  (None, 5, 192)      15          ['conv1d_207[0][0]']
#  Normalization)
#
#  activation_207 (Activation)    (None, 5, 192)       0           ['batch_normalization_207[0][0]']
#
#  max_pooling1d_5 (MaxPooling1D)  (None, 2, 192)      0           ['activation_207[0][0]']
#
#  conv1d_211 (Conv1D)            (None, 2, 32)        6176        ['max_pooling1d_5[0][0]']
#
#  batch_normalization_211 (Batch  (None, 2, 32)       6           ['conv1d_211[0][0]']
#  Normalization)
#
#  activation_211 (Activation)    (None, 2, 32)        0           ['batch_normalization_211[0][0]']
#
#  conv1d_209 (Conv1D)            (None, 2, 48)        9264        ['max_pooling1d_5[0][0]']
#
#  conv1d_212 (Conv1D)            (None, 2, 64)        6208        ['activation_211[0][0]']
#
#  batch_normalization_209 (Batch  (None, 2, 48)       6           ['conv1d_209[0][0]']
#  Normalization)
#
#  batch_normalization_212 (Batch  (None, 2, 64)       6           ['conv1d_212[0][0]']
#  Normalization)
#
#  activation_209 (Activation)    (None, 2, 48)        0           ['batch_normalization_209[0][0]']
#
#  activation_212 (Activation)    (None, 2, 64)        0           ['batch_normalization_212[0][0]']
#
#  average_pooling1d_1 (AveragePo  (None, 2, 192)      0           ['max_pooling1d_5[0][0]']
#  oling1D)
#
#  conv1d_208 (Conv1D)            (None, 2, 64)        12352       ['max_pooling1d_5[0][0]']
#
#  conv1d_210 (Conv1D)            (None, 2, 32)        7712        ['activation_209[0][0]']
#
#  conv1d_213 (Conv1D)            (None, 2, 64)        12352       ['activation_212[0][0]']
#
#  conv1d_214 (Conv1D)            (None, 2, 32)        6176        ['average_pooling1d_1[0][0]']
#
#  batch_normalization_208 (Batch  (None, 2, 64)       6           ['conv1d_208[0][0]']
#  Normalization)
#
#  batch_normalization_210 (Batch  (None, 2, 32)       6           ['conv1d_210[0][0]']
#  Normalization)
#
#  batch_normalization_213 (Batch  (None, 2, 64)       6           ['conv1d_213[0][0]']
#  Normalization)
#
#  batch_normalization_214 (Batch  (None, 2, 32)       6           ['conv1d_214[0][0]']
#  Normalization)
#
#  activation_208 (Activation)    (None, 2, 64)        0           ['batch_normalization_208[0][0]']
#
#  activation_210 (Activation)    (None, 2, 32)        0           ['batch_normalization_210[0][0]']
#
#  activation_213 (Activation)    (None, 2, 64)        0           ['batch_normalization_213[0][0]']
#
#  activation_214 (Activation)    (None, 2, 32)        0           ['batch_normalization_214[0][0]']
#
#  mixed_5b (Concatenate)         (None, 2, 192)       0           ['activation_208[0][0]',
#                                                                   'activation_210[0][0]',
#                                                                   'activation_213[0][0]',
#                                                                   'activation_214[0][0]']
#
#  conv1d_218 (Conv1D)            (None, 2, 32)        6176        ['mixed_5b[0][0]']
#
#  batch_normalization_218 (Batch  (None, 2, 32)       6           ['conv1d_218[0][0]']
#  Normalization)
#
#  activation_218 (Activation)    (None, 2, 32)        0           ['batch_normalization_218[0][0]']
#
#  conv1d_216 (Conv1D)            (None, 2, 32)        6176        ['mixed_5b[0][0]']
#
#  conv1d_219 (Conv1D)            (None, 2, 48)        4656        ['activation_218[0][0]']
#
#  batch_normalization_216 (Batch  (None, 2, 32)       6           ['conv1d_216[0][0]']
#  Normalization)
#
#  batch_normalization_219 (Batch  (None, 2, 48)       6           ['conv1d_219[0][0]']
#  Normalization)
#
#  activation_216 (Activation)    (None, 2, 32)        0           ['batch_normalization_216[0][0]']
#
#  activation_219 (Activation)    (None, 2, 48)        0           ['batch_normalization_219[0][0]']
#
#  conv1d_215 (Conv1D)            (None, 2, 32)        6176        ['mixed_5b[0][0]']
#
#  conv1d_217 (Conv1D)            (None, 2, 32)        3104        ['activation_216[0][0]']
#
#  conv1d_220 (Conv1D)            (None, 2, 64)        9280        ['activation_219[0][0]']
#
#  batch_normalization_215 (Batch  (None, 2, 32)       6           ['conv1d_215[0][0]']
#  Normalization)
#
#  batch_normalization_217 (Batch  (None, 2, 32)       6           ['conv1d_217[0][0]']
#  Normalization)
#
#  batch_normalization_220 (Batch  (None, 2, 64)       6           ['conv1d_220[0][0]']
#  Normalization)
#
#  activation_215 (Activation)    (None, 2, 32)        0           ['batch_normalization_215[0][0]']
#
#  activation_217 (Activation)    (None, 2, 32)        0           ['batch_normalization_217[0][0]']
#
#  activation_220 (Activation)    (None, 2, 64)        0           ['batch_normalization_220[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 2, 128)       0           ['activation_215[0][0]',
#                                                                   'activation_217[0][0]',
#                                                                   'activation_220[0][0]']
#
#  block35_1_conv (Conv1D)        (None, 2, 192)       24768       ['block35_1_mixed[0][0]']
#
#  block35_1_conv_bn (BatchNormal  (None, 2, 192)      6           ['block35_1_conv[0][0]']
#  ization)
#
#  block35_1 (Lambda)             (None, 2, 192)       0           ['mixed_5b[0][0]',
#                                                                   'block35_1_conv_bn[0][0]']
#
#  block35_1_ac (Activation)      (None, 2, 192)       0           ['block35_1[0][0]']
#
#  conv1d_224 (Conv1D)            (None, 2, 32)        6176        ['block35_1_ac[0][0]']
#
#  batch_normalization_224 (Batch  (None, 2, 32)       6           ['conv1d_224[0][0]']
#  Normalization)
#
#  activation_224 (Activation)    (None, 2, 32)        0           ['batch_normalization_224[0][0]']
#
#  conv1d_222 (Conv1D)            (None, 2, 32)        6176        ['block35_1_ac[0][0]']
#
#  conv1d_225 (Conv1D)            (None, 2, 48)        4656        ['activation_224[0][0]']
#
#  batch_normalization_222 (Batch  (None, 2, 32)       6           ['conv1d_222[0][0]']
#  Normalization)
#
#  batch_normalization_225 (Batch  (None, 2, 48)       6           ['conv1d_225[0][0]']
#  Normalization)
#
#  activation_222 (Activation)    (None, 2, 32)        0           ['batch_normalization_222[0][0]']
#
#  activation_225 (Activation)    (None, 2, 48)        0           ['batch_normalization_225[0][0]']
#
#  conv1d_221 (Conv1D)            (None, 2, 32)        6176        ['block35_1_ac[0][0]']
#
#  conv1d_223 (Conv1D)            (None, 2, 32)        3104        ['activation_222[0][0]']
#
#  conv1d_226 (Conv1D)            (None, 2, 64)        9280        ['activation_225[0][0]']
#
#  batch_normalization_221 (Batch  (None, 2, 32)       6           ['conv1d_221[0][0]']
#  Normalization)
#
#  batch_normalization_223 (Batch  (None, 2, 32)       6           ['conv1d_223[0][0]']
#  Normalization)
#
#  batch_normalization_226 (Batch  (None, 2, 64)       6           ['conv1d_226[0][0]']
#  Normalization)
#
#  activation_221 (Activation)    (None, 2, 32)        0           ['batch_normalization_221[0][0]']
#
#  activation_223 (Activation)    (None, 2, 32)        0           ['batch_normalization_223[0][0]']
#
#  activation_226 (Activation)    (None, 2, 64)        0           ['batch_normalization_226[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 2, 128)       0           ['activation_221[0][0]',
#                                                                   'activation_223[0][0]',
#                                                                   'activation_226[0][0]']
#
#  block35_2_conv (Conv1D)        (None, 2, 192)       24768       ['block35_2_mixed[0][0]']
#
#  block35_2_conv_bn (BatchNormal  (None, 2, 192)      6           ['block35_2_conv[0][0]']
#  ization)
#
#  block35_2 (Lambda)             (None, 2, 192)       0           ['block35_1_ac[0][0]',
#                                                                   'block35_2_conv_bn[0][0]']
#
#  block35_2_ac (Activation)      (None, 2, 192)       0           ['block35_2[0][0]']
#
#  conv1d_230 (Conv1D)            (None, 2, 32)        6176        ['block35_2_ac[0][0]']
#
#  batch_normalization_230 (Batch  (None, 2, 32)       6           ['conv1d_230[0][0]']
#  Normalization)
#
#  activation_230 (Activation)    (None, 2, 32)        0           ['batch_normalization_230[0][0]']
#
#  conv1d_228 (Conv1D)            (None, 2, 32)        6176        ['block35_2_ac[0][0]']
#
#  conv1d_231 (Conv1D)            (None, 2, 48)        4656        ['activation_230[0][0]']
#
#  batch_normalization_228 (Batch  (None, 2, 32)       6           ['conv1d_228[0][0]']
#  Normalization)
#
#  batch_normalization_231 (Batch  (None, 2, 48)       6           ['conv1d_231[0][0]']
#  Normalization)
#
#  activation_228 (Activation)    (None, 2, 32)        0           ['batch_normalization_228[0][0]']
#
#  activation_231 (Activation)    (None, 2, 48)        0           ['batch_normalization_231[0][0]']
#
#  conv1d_227 (Conv1D)            (None, 2, 32)        6176        ['block35_2_ac[0][0]']
#
#  conv1d_229 (Conv1D)            (None, 2, 32)        3104        ['activation_228[0][0]']
#
#  conv1d_232 (Conv1D)            (None, 2, 64)        9280        ['activation_231[0][0]']
#
#  batch_normalization_227 (Batch  (None, 2, 32)       6           ['conv1d_227[0][0]']
#  Normalization)
#
#  batch_normalization_229 (Batch  (None, 2, 32)       6           ['conv1d_229[0][0]']
#  Normalization)
#
#  batch_normalization_232 (Batch  (None, 2, 64)       6           ['conv1d_232[0][0]']
#  Normalization)
#
#  activation_227 (Activation)    (None, 2, 32)        0           ['batch_normalization_227[0][0]']
#
#  activation_229 (Activation)    (None, 2, 32)        0           ['batch_normalization_229[0][0]']
#
#  activation_232 (Activation)    (None, 2, 64)        0           ['batch_normalization_232[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 2, 128)       0           ['activation_227[0][0]',
#                                                                   'activation_229[0][0]',
#                                                                   'activation_232[0][0]']
#
#  block35_3_conv (Conv1D)        (None, 2, 192)       24768       ['block35_3_mixed[0][0]']
#
#  block35_3_conv_bn (BatchNormal  (None, 2, 192)      6           ['block35_3_conv[0][0]']
#  ization)
#
#  block35_3 (Lambda)             (None, 2, 192)       0           ['block35_2_ac[0][0]',
#                                                                   'block35_3_conv_bn[0][0]']
#
#  block35_3_ac (Activation)      (None, 2, 192)       0           ['block35_3[0][0]']
#
#  conv1d_236 (Conv1D)            (None, 2, 32)        6176        ['block35_3_ac[0][0]']
#
#  batch_normalization_236 (Batch  (None, 2, 32)       6           ['conv1d_236[0][0]']
#  Normalization)
#
#  activation_236 (Activation)    (None, 2, 32)        0           ['batch_normalization_236[0][0]']
#
#  conv1d_234 (Conv1D)            (None, 2, 32)        6176        ['block35_3_ac[0][0]']
#
#  conv1d_237 (Conv1D)            (None, 2, 48)        4656        ['activation_236[0][0]']
#
#  batch_normalization_234 (Batch  (None, 2, 32)       6           ['conv1d_234[0][0]']
#  Normalization)
#
#  batch_normalization_237 (Batch  (None, 2, 48)       6           ['conv1d_237[0][0]']
#  Normalization)
#
#  activation_234 (Activation)    (None, 2, 32)        0           ['batch_normalization_234[0][0]']
#
#  activation_237 (Activation)    (None, 2, 48)        0           ['batch_normalization_237[0][0]']
#
#  conv1d_233 (Conv1D)            (None, 2, 32)        6176        ['block35_3_ac[0][0]']
#
#  conv1d_235 (Conv1D)            (None, 2, 32)        3104        ['activation_234[0][0]']
#
#  conv1d_238 (Conv1D)            (None, 2, 64)        9280        ['activation_237[0][0]']
#
#  batch_normalization_233 (Batch  (None, 2, 32)       6           ['conv1d_233[0][0]']
#  Normalization)
#
#  batch_normalization_235 (Batch  (None, 2, 32)       6           ['conv1d_235[0][0]']
#  Normalization)
#
#  batch_normalization_238 (Batch  (None, 2, 64)       6           ['conv1d_238[0][0]']
#  Normalization)
#
#  activation_233 (Activation)    (None, 2, 32)        0           ['batch_normalization_233[0][0]']
#
#  activation_235 (Activation)    (None, 2, 32)        0           ['batch_normalization_235[0][0]']
#
#  activation_238 (Activation)    (None, 2, 64)        0           ['batch_normalization_238[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 2, 128)       0           ['activation_233[0][0]',
#                                                                   'activation_235[0][0]',
#                                                                   'activation_238[0][0]']
#
#  block35_4_conv (Conv1D)        (None, 2, 192)       24768       ['block35_4_mixed[0][0]']
#
#  block35_4_conv_bn (BatchNormal  (None, 2, 192)      6           ['block35_4_conv[0][0]']
#  ization)
#
#  block35_4 (Lambda)             (None, 2, 192)       0           ['block35_3_ac[0][0]',
#                                                                   'block35_4_conv_bn[0][0]']
#
#  block35_4_ac (Activation)      (None, 2, 192)       0           ['block35_4[0][0]']
#
#  conv1d_242 (Conv1D)            (None, 2, 32)        6176        ['block35_4_ac[0][0]']
#
#  batch_normalization_242 (Batch  (None, 2, 32)       6           ['conv1d_242[0][0]']
#  Normalization)
#
#  activation_242 (Activation)    (None, 2, 32)        0           ['batch_normalization_242[0][0]']
#
#  conv1d_240 (Conv1D)            (None, 2, 32)        6176        ['block35_4_ac[0][0]']
#
#  conv1d_243 (Conv1D)            (None, 2, 48)        4656        ['activation_242[0][0]']
#
#  batch_normalization_240 (Batch  (None, 2, 32)       6           ['conv1d_240[0][0]']
#  Normalization)
#
#  batch_normalization_243 (Batch  (None, 2, 48)       6           ['conv1d_243[0][0]']
#  Normalization)
#
#  activation_240 (Activation)    (None, 2, 32)        0           ['batch_normalization_240[0][0]']
#
#  activation_243 (Activation)    (None, 2, 48)        0           ['batch_normalization_243[0][0]']
#
#  conv1d_239 (Conv1D)            (None, 2, 32)        6176        ['block35_4_ac[0][0]']
#
#  conv1d_241 (Conv1D)            (None, 2, 32)        3104        ['activation_240[0][0]']
#
#  conv1d_244 (Conv1D)            (None, 2, 64)        9280        ['activation_243[0][0]']
#
#  batch_normalization_239 (Batch  (None, 2, 32)       6           ['conv1d_239[0][0]']
#  Normalization)
#
#  batch_normalization_241 (Batch  (None, 2, 32)       6           ['conv1d_241[0][0]']
#  Normalization)
#
#  batch_normalization_244 (Batch  (None, 2, 64)       6           ['conv1d_244[0][0]']
#  Normalization)
#
#  activation_239 (Activation)    (None, 2, 32)        0           ['batch_normalization_239[0][0]']
#
#  activation_241 (Activation)    (None, 2, 32)        0           ['batch_normalization_241[0][0]']
#
#  activation_244 (Activation)    (None, 2, 64)        0           ['batch_normalization_244[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 2, 128)       0           ['activation_239[0][0]',
#                                                                   'activation_241[0][0]',
#                                                                   'activation_244[0][0]']
#
#  block35_5_conv (Conv1D)        (None, 2, 192)       24768       ['block35_5_mixed[0][0]']
#
#  block35_5_conv_bn (BatchNormal  (None, 2, 192)      6           ['block35_5_conv[0][0]']
#  ization)
#
#  block35_5 (Lambda)             (None, 2, 192)       0           ['block35_4_ac[0][0]',
#                                                                   'block35_5_conv_bn[0][0]']
#
#  block35_5_ac (Activation)      (None, 2, 192)       0           ['block35_5[0][0]']
#
#  conv1d_248 (Conv1D)            (None, 2, 32)        6176        ['block35_5_ac[0][0]']
#
#  batch_normalization_248 (Batch  (None, 2, 32)       6           ['conv1d_248[0][0]']
#  Normalization)
#
#  activation_248 (Activation)    (None, 2, 32)        0           ['batch_normalization_248[0][0]']
#
#  conv1d_246 (Conv1D)            (None, 2, 32)        6176        ['block35_5_ac[0][0]']
#
#  conv1d_249 (Conv1D)            (None, 2, 48)        4656        ['activation_248[0][0]']
#
#  batch_normalization_246 (Batch  (None, 2, 32)       6           ['conv1d_246[0][0]']
#  Normalization)
#
#  batch_normalization_249 (Batch  (None, 2, 48)       6           ['conv1d_249[0][0]']
#  Normalization)
#
#  activation_246 (Activation)    (None, 2, 32)        0           ['batch_normalization_246[0][0]']
#
#  activation_249 (Activation)    (None, 2, 48)        0           ['batch_normalization_249[0][0]']
#
#  conv1d_245 (Conv1D)            (None, 2, 32)        6176        ['block35_5_ac[0][0]']
#
#  conv1d_247 (Conv1D)            (None, 2, 32)        3104        ['activation_246[0][0]']
#
#  conv1d_250 (Conv1D)            (None, 2, 64)        9280        ['activation_249[0][0]']
#
#  batch_normalization_245 (Batch  (None, 2, 32)       6           ['conv1d_245[0][0]']
#  Normalization)
#
#  batch_normalization_247 (Batch  (None, 2, 32)       6           ['conv1d_247[0][0]']
#  Normalization)
#
#  batch_normalization_250 (Batch  (None, 2, 64)       6           ['conv1d_250[0][0]']
#  Normalization)
#
#  activation_245 (Activation)    (None, 2, 32)        0           ['batch_normalization_245[0][0]']
#
#  activation_247 (Activation)    (None, 2, 32)        0           ['batch_normalization_247[0][0]']
#
#  activation_250 (Activation)    (None, 2, 64)        0           ['batch_normalization_250[0][0]']
#
#  block35_6_mixed (Concatenate)  (None, 2, 128)       0           ['activation_245[0][0]',
#                                                                   'activation_247[0][0]',
#                                                                   'activation_250[0][0]']
#
#  block35_6_conv (Conv1D)        (None, 2, 192)       24768       ['block35_6_mixed[0][0]']
#
#  block35_6_conv_bn (BatchNormal  (None, 2, 192)      6           ['block35_6_conv[0][0]']
#  ization)
#
#  block35_6 (Lambda)             (None, 2, 192)       0           ['block35_5_ac[0][0]',
#                                                                   'block35_6_conv_bn[0][0]']
#
#  block35_6_ac (Activation)      (None, 2, 192)       0           ['block35_6[0][0]']
#
#  conv1d_254 (Conv1D)            (None, 2, 32)        6176        ['block35_6_ac[0][0]']
#
#  batch_normalization_254 (Batch  (None, 2, 32)       6           ['conv1d_254[0][0]']
#  Normalization)
#
#  activation_254 (Activation)    (None, 2, 32)        0           ['batch_normalization_254[0][0]']
#
#  conv1d_252 (Conv1D)            (None, 2, 32)        6176        ['block35_6_ac[0][0]']
#
#  conv1d_255 (Conv1D)            (None, 2, 48)        4656        ['activation_254[0][0]']
#
#  batch_normalization_252 (Batch  (None, 2, 32)       6           ['conv1d_252[0][0]']
#  Normalization)
#
#  batch_normalization_255 (Batch  (None, 2, 48)       6           ['conv1d_255[0][0]']
#  Normalization)
# c:\Users\Admin\miniconda3\envs\tensorflow_gpu\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
#  activation_252 (Activation)    (None, 2, 32)        0           ['batch_normalization_252[0][0]']
#
#  activation_255 (Activation)    (None, 2, 48)        0           ['batch_normalization_255[0][0]']
#
#  conv1d_251 (Conv1D)            (None, 2, 32)        6176        ['block35_6_ac[0][0]']
#
#  conv1d_253 (Conv1D)            (None, 2, 32)        3104        ['activation_252[0][0]']
#
#  conv1d_256 (Conv1D)            (None, 2, 64)        9280        ['activation_255[0][0]']
#
#  batch_normalization_251 (Batch  (None, 2, 32)       6           ['conv1d_251[0][0]']
#  Normalization)
#
#  batch_normalization_253 (Batch  (None, 2, 32)       6           ['conv1d_253[0][0]']
#  Normalization)
#
#  batch_normalization_256 (Batch  (None, 2, 64)       6           ['conv1d_256[0][0]']
#  Normalization)
#
#  activation_251 (Activation)    (None, 2, 32)        0           ['batch_normalization_251[0][0]']
#
#  activation_253 (Activation)    (None, 2, 32)        0           ['batch_normalization_253[0][0]']
#
#  activation_256 (Activation)    (None, 2, 64)        0           ['batch_normalization_256[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 2, 128)       0           ['activation_251[0][0]',
#                                                                   'activation_253[0][0]',
#                                                                   'activation_256[0][0]']
# ...
#  batch_normalization_393 (Batch  (None, 1, 256)      3           ['conv1d_393[0][0]']
#  Normalization)
#
#  activation_390 (Activation)    (None, 1, 192)       0           ['batch_normalization_390[0][0]']
#
#  activation_393 (Activation)    (None, 1, 256)       0           ['batch_normalization_393[0][0]']
#
#  block8_7_mixed (Concatenate)   (None, 1, 448)       0           ['activation_390[0][0]',
#                                                                   'activation_393[0][0]']
#
#  block8_7_conv (Conv1D)         (None, 1, 992)       445408      ['block8_7_mixed[0][0]']
#
#  block8_7_conv_bn (BatchNormali  (None, 1, 992)      3           ['block8_7_conv[0][0]']
#  zation)
#
#  block8_7 (Lambda)              (None, 1, 992)       0           ['block8_6_ac[0][0]',
#                                                                   'block8_7_conv_bn[0][0]']
#
#  block8_7_ac (Activation)       (None, 1, 992)       0           ['block8_7[0][0]']
#
#  conv1d_395 (Conv1D)            (None, 1, 192)       190656      ['block8_7_ac[0][0]']
#
#  batch_normalization_395 (Batch  (None, 1, 192)      3           ['conv1d_395[0][0]']
#  Normalization)
#
#  activation_395 (Activation)    (None, 1, 192)       0           ['batch_normalization_395[0][0]']
#
#  conv1d_396 (Conv1D)            (None, 1, 224)       43232       ['activation_395[0][0]']
#
#  batch_normalization_396 (Batch  (None, 1, 224)      3           ['conv1d_396[0][0]']
#  Normalization)
#
#  activation_396 (Activation)    (None, 1, 224)       0           ['batch_normalization_396[0][0]']
#
#  conv1d_394 (Conv1D)            (None, 1, 192)       190656      ['block8_7_ac[0][0]']
#
#  conv1d_397 (Conv1D)            (None, 1, 256)       172288      ['activation_396[0][0]']
#
#  batch_normalization_394 (Batch  (None, 1, 192)      3           ['conv1d_394[0][0]']
#  Normalization)
#
#  batch_normalization_397 (Batch  (None, 1, 256)      3           ['conv1d_397[0][0]']
#  Normalization)
#
#  activation_394 (Activation)    (None, 1, 192)       0           ['batch_normalization_394[0][0]']
#
#  activation_397 (Activation)    (None, 1, 256)       0           ['batch_normalization_397[0][0]']
#
#  block8_8_mixed (Concatenate)   (None, 1, 448)       0           ['activation_394[0][0]',
#                                                                   'activation_397[0][0]']
#
#  block8_8_conv (Conv1D)         (None, 1, 992)       445408      ['block8_8_mixed[0][0]']
#
#  block8_8_conv_bn (BatchNormali  (None, 1, 992)      3           ['block8_8_conv[0][0]']
#  zation)
#
#  block8_8 (Lambda)              (None, 1, 992)       0           ['block8_7_ac[0][0]',
#                                                                   'block8_8_conv_bn[0][0]']
#
#  block8_8_ac (Activation)       (None, 1, 992)       0           ['block8_8[0][0]']
#
#  conv1d_399 (Conv1D)            (None, 1, 192)       190656      ['block8_8_ac[0][0]']
#
#  batch_normalization_399 (Batch  (None, 1, 192)      3           ['conv1d_399[0][0]']
#  Normalization)
#
#  activation_399 (Activation)    (None, 1, 192)       0           ['batch_normalization_399[0][0]']
#
#  conv1d_400 (Conv1D)            (None, 1, 224)       43232       ['activation_399[0][0]']
#
#  batch_normalization_400 (Batch  (None, 1, 224)      3           ['conv1d_400[0][0]']
#  Normalization)
#
#  activation_400 (Activation)    (None, 1, 224)       0           ['batch_normalization_400[0][0]']
#
#  conv1d_398 (Conv1D)            (None, 1, 192)       190656      ['block8_8_ac[0][0]']
#
#  conv1d_401 (Conv1D)            (None, 1, 256)       172288      ['activation_400[0][0]']
#
#  batch_normalization_398 (Batch  (None, 1, 192)      3           ['conv1d_398[0][0]']
#  Normalization)
#
#  batch_normalization_401 (Batch  (None, 1, 256)      3           ['conv1d_401[0][0]']
#  Normalization)
#
#  activation_398 (Activation)    (None, 1, 192)       0           ['batch_normalization_398[0][0]']
#
#  activation_401 (Activation)    (None, 1, 256)       0           ['batch_normalization_401[0][0]']
#
#  block8_9_mixed (Concatenate)   (None, 1, 448)       0           ['activation_398[0][0]',
#                                                                   'activation_401[0][0]']
#
#  block8_9_conv (Conv1D)         (None, 1, 992)       445408      ['block8_9_mixed[0][0]']
#
#  block8_9_conv_bn (BatchNormali  (None, 1, 992)      3           ['block8_9_conv[0][0]']
#  zation)
#
#  block8_9 (Lambda)              (None, 1, 992)       0           ['block8_8_ac[0][0]',
#                                                                   'block8_9_conv_bn[0][0]']
#
#  block8_9_ac (Activation)       (None, 1, 992)       0           ['block8_9[0][0]']
#
#  conv1d_403 (Conv1D)            (None, 1, 192)       190656      ['block8_9_ac[0][0]']
#
#  batch_normalization_403 (Batch  (None, 1, 192)      3           ['conv1d_403[0][0]']
#  Normalization)
#
#  activation_403 (Activation)    (None, 1, 192)       0           ['batch_normalization_403[0][0]']
#
#  conv1d_404 (Conv1D)            (None, 1, 224)       43232       ['activation_403[0][0]']
#
#  batch_normalization_404 (Batch  (None, 1, 224)      3           ['conv1d_404[0][0]']
#  Normalization)
#
#  activation_404 (Activation)    (None, 1, 224)       0           ['batch_normalization_404[0][0]']
#
#  conv1d_402 (Conv1D)            (None, 1, 192)       190656      ['block8_9_ac[0][0]']
#
#  conv1d_405 (Conv1D)            (None, 1, 256)       172288      ['activation_404[0][0]']
#
#  batch_normalization_402 (Batch  (None, 1, 192)      3           ['conv1d_402[0][0]']
#  Normalization)
#
#  batch_normalization_405 (Batch  (None, 1, 256)      3           ['conv1d_405[0][0]']
#  Normalization)
#
#  activation_402 (Activation)    (None, 1, 192)       0           ['batch_normalization_402[0][0]']
#
#  activation_405 (Activation)    (None, 1, 256)       0           ['batch_normalization_405[0][0]']
#
#  block8_10_mixed (Concatenate)  (None, 1, 448)       0           ['activation_402[0][0]',
#                                                                   'activation_405[0][0]']
#
#  block8_10_conv (Conv1D)        (None, 1, 992)       445408      ['block8_10_mixed[0][0]']
#
#  block8_10_conv_bn (BatchNormal  (None, 1, 992)      3           ['block8_10_conv[0][0]']
#  ization)
#
#  block8_10 (Lambda)             (None, 1, 992)       0           ['block8_9_ac[0][0]',
#                                                                   'block8_10_conv_bn[0][0]']
#
#  conv_7b (Conv1D)               (None, 1, 1536)      1525248     ['block8_10[0][0]']
#
#  conv_7b_bn (BatchNormalization  (None, 1, 1536)     3           ['conv_7b[0][0]']
#  )
#
#  conv_7b_ac (Activation)        (None, 1, 1536)      0           ['conv_7b_bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 1536)        0           ['conv_7b_ac[0][0]']
#  1D)
#
#  predictions (Dense)            (None, 2)            3074        ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 24,308,038
# Trainable params: 24,307,278
# Non-trainable params: 760
# __________________________________________________________________________________________________
# 104/104 [==============================] - 9s 46ms/step
# Accuracy: 0.9133333333333333
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95      3133
#            1       0.07      0.06      0.07       167
#
#     accuracy                           0.91      3300
#    macro avg       0.51      0.51      0.51      3300
# weighted avg       0.91      0.91      0.91      3300
#
# Confusion Matrix:
# [[3004  129]
#  [ 157   10]]

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\3.smote\InceptionV2\inceptionv2_class_weight.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (3300, 2) (12728, 2)
# (3300, 2)
# 37
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 37, 1)]      0           []
#
#  conv1d_406 (Conv1D)            (None, 18, 16)       64          ['input_3[0][0]']
#
#  batch_normalization_406 (Batch  (None, 18, 16)      54          ['conv1d_406[0][0]']
#  Normalization)
#
#  activation_406 (Activation)    (None, 18, 16)       0           ['batch_normalization_406[0][0]']
#
#  conv1d_407 (Conv1D)            (None, 16, 16)       784         ['activation_406[0][0]']
#
#  batch_normalization_407 (Batch  (None, 16, 16)      48          ['conv1d_407[0][0]']
#  Normalization)
#
#  activation_407 (Activation)    (None, 16, 16)       0           ['batch_normalization_407[0][0]']
#
#  conv1d_408 (Conv1D)            (None, 16, 32)       1568        ['activation_407[0][0]']
#
#  batch_normalization_408 (Batch  (None, 16, 32)      48          ['conv1d_408[0][0]']
#  Normalization)
#
#  activation_408 (Activation)    (None, 16, 32)       0           ['batch_normalization_408[0][0]']
#
#  max_pooling1d_8 (MaxPooling1D)  (None, 7, 32)       0           ['activation_408[0][0]']
#
#  conv1d_409 (Conv1D)            (None, 7, 80)        2640        ['max_pooling1d_8[0][0]']
#
#  batch_normalization_409 (Batch  (None, 7, 80)       21          ['conv1d_409[0][0]']
#  Normalization)
#
#  activation_409 (Activation)    (None, 7, 80)        0           ['batch_normalization_409[0][0]']
#
#  conv1d_410 (Conv1D)            (None, 5, 192)       46272       ['activation_409[0][0]']
#
#  batch_normalization_410 (Batch  (None, 5, 192)      15          ['conv1d_410[0][0]']
#  Normalization)
#
#  activation_410 (Activation)    (None, 5, 192)       0           ['batch_normalization_410[0][0]']
#
#  max_pooling1d_9 (MaxPooling1D)  (None, 2, 192)      0           ['activation_410[0][0]']
#
#  conv1d_414 (Conv1D)            (None, 2, 32)        6176        ['max_pooling1d_9[0][0]']
#
#  batch_normalization_414 (Batch  (None, 2, 32)       6           ['conv1d_414[0][0]']
#  Normalization)
#
#  activation_414 (Activation)    (None, 2, 32)        0           ['batch_normalization_414[0][0]']
#
#  conv1d_412 (Conv1D)            (None, 2, 48)        9264        ['max_pooling1d_9[0][0]']
#
#  conv1d_415 (Conv1D)            (None, 2, 64)        6208        ['activation_414[0][0]']
#
#  batch_normalization_412 (Batch  (None, 2, 48)       6           ['conv1d_412[0][0]']
#  Normalization)
#
#  batch_normalization_415 (Batch  (None, 2, 64)       6           ['conv1d_415[0][0]']
#  Normalization)
#
#  activation_412 (Activation)    (None, 2, 48)        0           ['batch_normalization_412[0][0]']
#
#  activation_415 (Activation)    (None, 2, 64)        0           ['batch_normalization_415[0][0]']
#
#  average_pooling1d_2 (AveragePo  (None, 2, 192)      0           ['max_pooling1d_9[0][0]']
#  oling1D)
#
#  conv1d_411 (Conv1D)            (None, 2, 64)        12352       ['max_pooling1d_9[0][0]']
#
#  conv1d_413 (Conv1D)            (None, 2, 32)        7712        ['activation_412[0][0]']
#
#  conv1d_416 (Conv1D)            (None, 2, 64)        12352       ['activation_415[0][0]']
#
#  conv1d_417 (Conv1D)            (None, 2, 32)        6176        ['average_pooling1d_2[0][0]']
#
#  batch_normalization_411 (Batch  (None, 2, 64)       6           ['conv1d_411[0][0]']
#  Normalization)
#
#  batch_normalization_413 (Batch  (None, 2, 32)       6           ['conv1d_413[0][0]']
#  Normalization)
#
#  batch_normalization_416 (Batch  (None, 2, 64)       6           ['conv1d_416[0][0]']
#  Normalization)
#
#  batch_normalization_417 (Batch  (None, 2, 32)       6           ['conv1d_417[0][0]']
#  Normalization)
#
#  activation_411 (Activation)    (None, 2, 64)        0           ['batch_normalization_411[0][0]']
#
#  activation_413 (Activation)    (None, 2, 32)        0           ['batch_normalization_413[0][0]']
#
#  activation_416 (Activation)    (None, 2, 64)        0           ['batch_normalization_416[0][0]']
#
#  activation_417 (Activation)    (None, 2, 32)        0           ['batch_normalization_417[0][0]']
#
#  mixed_5b (Concatenate)         (None, 2, 192)       0           ['activation_411[0][0]',
#                                                                   'activation_413[0][0]',
#                                                                   'activation_416[0][0]',
#                                                                   'activation_417[0][0]']
#
#  conv1d_421 (Conv1D)            (None, 2, 32)        6176        ['mixed_5b[0][0]']
#
#  batch_normalization_421 (Batch  (None, 2, 32)       6           ['conv1d_421[0][0]']
#  Normalization)
#
#  activation_421 (Activation)    (None, 2, 32)        0           ['batch_normalization_421[0][0]']
#
#  conv1d_419 (Conv1D)            (None, 2, 32)        6176        ['mixed_5b[0][0]']
#
#  conv1d_422 (Conv1D)            (None, 2, 48)        4656        ['activation_421[0][0]']
#
#  batch_normalization_419 (Batch  (None, 2, 32)       6           ['conv1d_419[0][0]']
#  Normalization)
#
#  batch_normalization_422 (Batch  (None, 2, 48)       6           ['conv1d_422[0][0]']
#  Normalization)
#
#  activation_419 (Activation)    (None, 2, 32)        0           ['batch_normalization_419[0][0]']
#
#  activation_422 (Activation)    (None, 2, 48)        0           ['batch_normalization_422[0][0]']
#
#  conv1d_418 (Conv1D)            (None, 2, 32)        6176        ['mixed_5b[0][0]']
#
#  conv1d_420 (Conv1D)            (None, 2, 32)        3104        ['activation_419[0][0]']
#
#  conv1d_423 (Conv1D)            (None, 2, 64)        9280        ['activation_422[0][0]']
#
#  batch_normalization_418 (Batch  (None, 2, 32)       6           ['conv1d_418[0][0]']
#  Normalization)
#
#  batch_normalization_420 (Batch  (None, 2, 32)       6           ['conv1d_420[0][0]']
#  Normalization)
#
#  batch_normalization_423 (Batch  (None, 2, 64)       6           ['conv1d_423[0][0]']
#  Normalization)
#
#  activation_418 (Activation)    (None, 2, 32)        0           ['batch_normalization_418[0][0]']
#
#  activation_420 (Activation)    (None, 2, 32)        0           ['batch_normalization_420[0][0]']
#
#  activation_423 (Activation)    (None, 2, 64)        0           ['batch_normalization_423[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 2, 128)       0           ['activation_418[0][0]',
#                                                                   'activation_420[0][0]',
#                                                                   'activation_423[0][0]']
#
#  block35_1_conv (Conv1D)        (None, 2, 192)       24768       ['block35_1_mixed[0][0]']
#
#  block35_1_conv_bn (BatchNormal  (None, 2, 192)      6           ['block35_1_conv[0][0]']
#  ization)
#
#  block35_1 (Lambda)             (None, 2, 192)       0           ['mixed_5b[0][0]',
#                                                                   'block35_1_conv_bn[0][0]']
#
#  block35_1_ac (Activation)      (None, 2, 192)       0           ['block35_1[0][0]']
#
#  conv1d_427 (Conv1D)            (None, 2, 32)        6176        ['block35_1_ac[0][0]']
#
#  batch_normalization_427 (Batch  (None, 2, 32)       6           ['conv1d_427[0][0]']
#  Normalization)
#
#  activation_427 (Activation)    (None, 2, 32)        0           ['batch_normalization_427[0][0]']
#
#  conv1d_425 (Conv1D)            (None, 2, 32)        6176        ['block35_1_ac[0][0]']
#
#  conv1d_428 (Conv1D)            (None, 2, 48)        4656        ['activation_427[0][0]']
#
#  batch_normalization_425 (Batch  (None, 2, 32)       6           ['conv1d_425[0][0]']
#  Normalization)
#
#  batch_normalization_428 (Batch  (None, 2, 48)       6           ['conv1d_428[0][0]']
#  Normalization)
#
#  activation_425 (Activation)    (None, 2, 32)        0           ['batch_normalization_425[0][0]']
#
#  activation_428 (Activation)    (None, 2, 48)        0           ['batch_normalization_428[0][0]']
#
#  conv1d_424 (Conv1D)            (None, 2, 32)        6176        ['block35_1_ac[0][0]']
#
#  conv1d_426 (Conv1D)            (None, 2, 32)        3104        ['activation_425[0][0]']
#
#  conv1d_429 (Conv1D)            (None, 2, 64)        9280        ['activation_428[0][0]']
#
#  batch_normalization_424 (Batch  (None, 2, 32)       6           ['conv1d_424[0][0]']
#  Normalization)
#
#  batch_normalization_426 (Batch  (None, 2, 32)       6           ['conv1d_426[0][0]']
#  Normalization)
#
#  batch_normalization_429 (Batch  (None, 2, 64)       6           ['conv1d_429[0][0]']
#  Normalization)
#
#  activation_424 (Activation)    (None, 2, 32)        0           ['batch_normalization_424[0][0]']
#
#  activation_426 (Activation)    (None, 2, 32)        0           ['batch_normalization_426[0][0]']
#
#  activation_429 (Activation)    (None, 2, 64)        0           ['batch_normalization_429[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 2, 128)       0           ['activation_424[0][0]',
#                                                                   'activation_426[0][0]',
#                                                                   'activation_429[0][0]']
#
#  block35_2_conv (Conv1D)        (None, 2, 192)       24768       ['block35_2_mixed[0][0]']
#
#  block35_2_conv_bn (BatchNormal  (None, 2, 192)      6           ['block35_2_conv[0][0]']
#  ization)
#
#  block35_2 (Lambda)             (None, 2, 192)       0           ['block35_1_ac[0][0]',
#                                                                   'block35_2_conv_bn[0][0]']
#
#  block35_2_ac (Activation)      (None, 2, 192)       0           ['block35_2[0][0]']
#
#  conv1d_433 (Conv1D)            (None, 2, 32)        6176        ['block35_2_ac[0][0]']
#
#  batch_normalization_433 (Batch  (None, 2, 32)       6           ['conv1d_433[0][0]']
#  Normalization)
#
#  activation_433 (Activation)    (None, 2, 32)        0           ['batch_normalization_433[0][0]']
#
#  conv1d_431 (Conv1D)            (None, 2, 32)        6176        ['block35_2_ac[0][0]']
#
#  conv1d_434 (Conv1D)            (None, 2, 48)        4656        ['activation_433[0][0]']
#
#  batch_normalization_431 (Batch  (None, 2, 32)       6           ['conv1d_431[0][0]']
#  Normalization)
#
#  batch_normalization_434 (Batch  (None, 2, 48)       6           ['conv1d_434[0][0]']
#  Normalization)
#
#  activation_431 (Activation)    (None, 2, 32)        0           ['batch_normalization_431[0][0]']
#
#  activation_434 (Activation)    (None, 2, 48)        0           ['batch_normalization_434[0][0]']
#
#  conv1d_430 (Conv1D)            (None, 2, 32)        6176        ['block35_2_ac[0][0]']
#
#  conv1d_432 (Conv1D)            (None, 2, 32)        3104        ['activation_431[0][0]']
#
#  conv1d_435 (Conv1D)            (None, 2, 64)        9280        ['activation_434[0][0]']
#
#  batch_normalization_430 (Batch  (None, 2, 32)       6           ['conv1d_430[0][0]']
#  Normalization)
#
#  batch_normalization_432 (Batch  (None, 2, 32)       6           ['conv1d_432[0][0]']
#  Normalization)
#
#  batch_normalization_435 (Batch  (None, 2, 64)       6           ['conv1d_435[0][0]']
#  Normalization)
#
#  activation_430 (Activation)    (None, 2, 32)        0           ['batch_normalization_430[0][0]']
#
#  activation_432 (Activation)    (None, 2, 32)        0           ['batch_normalization_432[0][0]']
#
#  activation_435 (Activation)    (None, 2, 64)        0           ['batch_normalization_435[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 2, 128)       0           ['activation_430[0][0]',
#                                                                   'activation_432[0][0]',
#                                                                   'activation_435[0][0]']
#
#  block35_3_conv (Conv1D)        (None, 2, 192)       24768       ['block35_3_mixed[0][0]']
#
#  block35_3_conv_bn (BatchNormal  (None, 2, 192)      6           ['block35_3_conv[0][0]']
#  ization)
#
#  block35_3 (Lambda)             (None, 2, 192)       0           ['block35_2_ac[0][0]',
#                                                                   'block35_3_conv_bn[0][0]']
#
#  block35_3_ac (Activation)      (None, 2, 192)       0           ['block35_3[0][0]']
#
#  conv1d_439 (Conv1D)            (None, 2, 32)        6176        ['block35_3_ac[0][0]']
#
#  batch_normalization_439 (Batch  (None, 2, 32)       6           ['conv1d_439[0][0]']
#  Normalization)
#
#  activation_439 (Activation)    (None, 2, 32)        0           ['batch_normalization_439[0][0]']
#
#  conv1d_437 (Conv1D)            (None, 2, 32)        6176        ['block35_3_ac[0][0]']
#
#  conv1d_440 (Conv1D)            (None, 2, 48)        4656        ['activation_439[0][0]']
#
#  batch_normalization_437 (Batch  (None, 2, 32)       6           ['conv1d_437[0][0]']
#  Normalization)
#
#  batch_normalization_440 (Batch  (None, 2, 48)       6           ['conv1d_440[0][0]']
#  Normalization)
#
#  activation_437 (Activation)    (None, 2, 32)        0           ['batch_normalization_437[0][0]']
#
#  activation_440 (Activation)    (None, 2, 48)        0           ['batch_normalization_440[0][0]']
#
#  conv1d_436 (Conv1D)            (None, 2, 32)        6176        ['block35_3_ac[0][0]']
#
#  conv1d_438 (Conv1D)            (None, 2, 32)        3104        ['activation_437[0][0]']
#
#  conv1d_441 (Conv1D)            (None, 2, 64)        9280        ['activation_440[0][0]']
#
#  batch_normalization_436 (Batch  (None, 2, 32)       6           ['conv1d_436[0][0]']
#  Normalization)
#
#  batch_normalization_438 (Batch  (None, 2, 32)       6           ['conv1d_438[0][0]']
#  Normalization)
#
#  batch_normalization_441 (Batch  (None, 2, 64)       6           ['conv1d_441[0][0]']
#  Normalization)
#
#  activation_436 (Activation)    (None, 2, 32)        0           ['batch_normalization_436[0][0]']
#
#  activation_438 (Activation)    (None, 2, 32)        0           ['batch_normalization_438[0][0]']
#
#  activation_441 (Activation)    (None, 2, 64)        0           ['batch_normalization_441[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 2, 128)       0           ['activation_436[0][0]',
#                                                                   'activation_438[0][0]',
#                                                                   'activation_441[0][0]']
#
#  block35_4_conv (Conv1D)        (None, 2, 192)       24768       ['block35_4_mixed[0][0]']
#
#  block35_4_conv_bn (BatchNormal  (None, 2, 192)      6           ['block35_4_conv[0][0]']
#  ization)
#
#  block35_4 (Lambda)             (None, 2, 192)       0           ['block35_3_ac[0][0]',
#                                                                   'block35_4_conv_bn[0][0]']
#
#  block35_4_ac (Activation)      (None, 2, 192)       0           ['block35_4[0][0]']
#
#  conv1d_445 (Conv1D)            (None, 2, 32)        6176        ['block35_4_ac[0][0]']
#
#  batch_normalization_445 (Batch  (None, 2, 32)       6           ['conv1d_445[0][0]']
#  Normalization)
#
#  activation_445 (Activation)    (None, 2, 32)        0           ['batch_normalization_445[0][0]']
#
#  conv1d_443 (Conv1D)            (None, 2, 32)        6176        ['block35_4_ac[0][0]']
#
#  conv1d_446 (Conv1D)            (None, 2, 48)        4656        ['activation_445[0][0]']
#
#  batch_normalization_443 (Batch  (None, 2, 32)       6           ['conv1d_443[0][0]']
#  Normalization)
#
#  batch_normalization_446 (Batch  (None, 2, 48)       6           ['conv1d_446[0][0]']
#  Normalization)
#
#  activation_443 (Activation)    (None, 2, 32)        0           ['batch_normalization_443[0][0]']
#
#  activation_446 (Activation)    (None, 2, 48)        0           ['batch_normalization_446[0][0]']
#
#  conv1d_442 (Conv1D)            (None, 2, 32)        6176        ['block35_4_ac[0][0]']
#
#  conv1d_444 (Conv1D)            (None, 2, 32)        3104        ['activation_443[0][0]']
#
#  conv1d_447 (Conv1D)            (None, 2, 64)        9280        ['activation_446[0][0]']
#
#  batch_normalization_442 (Batch  (None, 2, 32)       6           ['conv1d_442[0][0]']
#  Normalization)
#
#  batch_normalization_444 (Batch  (None, 2, 32)       6           ['conv1d_444[0][0]']
#  Normalization)
#
#  batch_normalization_447 (Batch  (None, 2, 64)       6           ['conv1d_447[0][0]']
#  Normalization)
#
#  activation_442 (Activation)    (None, 2, 32)        0           ['batch_normalization_442[0][0]']
#
#  activation_444 (Activation)    (None, 2, 32)        0           ['batch_normalization_444[0][0]']
#
#  activation_447 (Activation)    (None, 2, 64)        0           ['batch_normalization_447[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 2, 128)       0           ['activation_442[0][0]',
#                                                                   'activation_444[0][0]',
#                                                                   'activation_447[0][0]']
#
#  block35_5_conv (Conv1D)        (None, 2, 192)       24768       ['block35_5_mixed[0][0]']
#
#  block35_5_conv_bn (BatchNormal  (None, 2, 192)      6           ['block35_5_conv[0][0]']
#  ization)
#
#  block35_5 (Lambda)             (None, 2, 192)       0           ['block35_4_ac[0][0]',
#                                                                   'block35_5_conv_bn[0][0]']
#
#  block35_5_ac (Activation)      (None, 2, 192)       0           ['block35_5[0][0]']
#
#  conv1d_451 (Conv1D)            (None, 2, 32)        6176        ['block35_5_ac[0][0]']
#
#  batch_normalization_451 (Batch  (None, 2, 32)       6           ['conv1d_451[0][0]']
#  Normalization)
#
#  activation_451 (Activation)    (None, 2, 32)        0           ['batch_normalization_451[0][0]']
#
#  conv1d_449 (Conv1D)            (None, 2, 32)        6176        ['block35_5_ac[0][0]']
#
#  conv1d_452 (Conv1D)            (None, 2, 48)        4656        ['activation_451[0][0]']
#
#  batch_normalization_449 (Batch  (None, 2, 32)       6           ['conv1d_449[0][0]']
#  Normalization)
#
#  batch_normalization_452 (Batch  (None, 2, 48)       6           ['conv1d_452[0][0]']
#  Normalization)
#
#  activation_449 (Activation)    (None, 2, 32)        0           ['batch_normalization_449[0][0]']
#
#  activation_452 (Activation)    (None, 2, 48)        0           ['batch_normalization_452[0][0]']
#
#  conv1d_448 (Conv1D)            (None, 2, 32)        6176        ['block35_5_ac[0][0]']
#
#  conv1d_450 (Conv1D)            (None, 2, 32)        3104        ['activation_449[0][0]']
#
#  conv1d_453 (Conv1D)            (None, 2, 64)        9280        ['activation_452[0][0]']
#
#  batch_normalization_448 (Batch  (None, 2, 32)       6           ['conv1d_448[0][0]']
#  Normalization)
#
#  batch_normalization_450 (Batch  (None, 2, 32)       6           ['conv1d_450[0][0]']
#  Normalization)
#
#  batch_normalization_453 (Batch  (None, 2, 64)       6           ['conv1d_453[0][0]']
#  Normalization)
#
#  activation_448 (Activation)    (None, 2, 32)        0           ['batch_normalization_448[0][0]']
#
#  activation_450 (Activation)    (None, 2, 32)        0           ['batch_normalization_450[0][0]']
#
#  activation_453 (Activation)    (None, 2, 64)        0           ['batch_normalization_453[0][0]']
#
#  block35_6_mixed (Concatenate)  (None, 2, 128)       0           ['activation_448[0][0]',
#                                                                   'activation_450[0][0]',
#                                                                   'activation_453[0][0]']
#
#  block35_6_conv (Conv1D)        (None, 2, 192)       24768       ['block35_6_mixed[0][0]']
#
#  block35_6_conv_bn (BatchNormal  (None, 2, 192)      6           ['block35_6_conv[0][0]']
#  ization)
#
#  block35_6 (Lambda)             (None, 2, 192)       0           ['block35_5_ac[0][0]',
#                                                                   'block35_6_conv_bn[0][0]']
#
#  block35_6_ac (Activation)      (None, 2, 192)       0           ['block35_6[0][0]']
#
#  conv1d_457 (Conv1D)            (None, 2, 32)        6176        ['block35_6_ac[0][0]']
#
#  batch_normalization_457 (Batch  (None, 2, 32)       6           ['conv1d_457[0][0]']
#  Normalization)
#
#  activation_457 (Activation)    (None, 2, 32)        0           ['batch_normalization_457[0][0]']
#
#  conv1d_455 (Conv1D)            (None, 2, 32)        6176        ['block35_6_ac[0][0]']
#
#  conv1d_458 (Conv1D)            (None, 2, 48)        4656        ['activation_457[0][0]']
#
#  batch_normalization_455 (Batch  (None, 2, 32)       6           ['conv1d_455[0][0]']
#  Normalization)
#
#  batch_normalization_458 (Batch  (None, 2, 48)       6           ['conv1d_458[0][0]']
#  Normalization)
#
#  activation_455 (Activation)    (None, 2, 32)        0           ['batch_normalization_455[0][0]']
#
#  activation_458 (Activation)    (None, 2, 48)        0           ['batch_normalization_458[0][0]']
#
#  conv1d_454 (Conv1D)            (None, 2, 32)        6176        ['block35_6_ac[0][0]']
#
#  conv1d_456 (Conv1D)            (None, 2, 32)        3104        ['activation_455[0][0]']
#
#  conv1d_459 (Conv1D)            (None, 2, 64)        9280        ['activation_458[0][0]']
#
#  batch_normalization_454 (Batch  (None, 2, 32)       6           ['conv1d_454[0][0]']
#  Normalization)
#
#  batch_normalization_456 (Batch  (None, 2, 32)       6           ['conv1d_456[0][0]']
#  Normalization)
#
#  batch_normalization_459 (Batch  (None, 2, 64)       6           ['conv1d_459[0][0]']
# c:\Users\Admin\miniconda3\envs\tensorflow_gpu\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
#  Normalization)
#
#  activation_454 (Activation)    (None, 2, 32)        0           ['batch_normalization_454[0][0]']
#
#  activation_456 (Activation)    (None, 2, 32)        0           ['batch_normalization_456[0][0]']
#
#  activation_459 (Activation)    (None, 2, 64)        0           ['batch_normalization_459[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 2, 128)       0           ['activation_454[0][0]',
# ...
#  batch_normalization_596 (Batch  (None, 1, 256)      3           ['conv1d_596[0][0]']
#  Normalization)
#
#  activation_593 (Activation)    (None, 1, 192)       0           ['batch_normalization_593[0][0]']
#
#  activation_596 (Activation)    (None, 1, 256)       0           ['batch_normalization_596[0][0]']
#
#  block8_7_mixed (Concatenate)   (None, 1, 448)       0           ['activation_593[0][0]',
#                                                                   'activation_596[0][0]']
#
#  block8_7_conv (Conv1D)         (None, 1, 992)       445408      ['block8_7_mixed[0][0]']
#
#  block8_7_conv_bn (BatchNormali  (None, 1, 992)      3           ['block8_7_conv[0][0]']
#  zation)
#
#  block8_7 (Lambda)              (None, 1, 992)       0           ['block8_6_ac[0][0]',
#                                                                   'block8_7_conv_bn[0][0]']
#
#  block8_7_ac (Activation)       (None, 1, 992)       0           ['block8_7[0][0]']
#
#  conv1d_598 (Conv1D)            (None, 1, 192)       190656      ['block8_7_ac[0][0]']
#
#  batch_normalization_598 (Batch  (None, 1, 192)      3           ['conv1d_598[0][0]']
#  Normalization)
#
#  activation_598 (Activation)    (None, 1, 192)       0           ['batch_normalization_598[0][0]']
#
#  conv1d_599 (Conv1D)            (None, 1, 224)       43232       ['activation_598[0][0]']
#
#  batch_normalization_599 (Batch  (None, 1, 224)      3           ['conv1d_599[0][0]']
#  Normalization)
#
#  activation_599 (Activation)    (None, 1, 224)       0           ['batch_normalization_599[0][0]']
#
#  conv1d_597 (Conv1D)            (None, 1, 192)       190656      ['block8_7_ac[0][0]']
#
#  conv1d_600 (Conv1D)            (None, 1, 256)       172288      ['activation_599[0][0]']
#
#  batch_normalization_597 (Batch  (None, 1, 192)      3           ['conv1d_597[0][0]']
#  Normalization)
#
#  batch_normalization_600 (Batch  (None, 1, 256)      3           ['conv1d_600[0][0]']
#  Normalization)
#
#  activation_597 (Activation)    (None, 1, 192)       0           ['batch_normalization_597[0][0]']
#
#  activation_600 (Activation)    (None, 1, 256)       0           ['batch_normalization_600[0][0]']
#
#  block8_8_mixed (Concatenate)   (None, 1, 448)       0           ['activation_597[0][0]',
#                                                                   'activation_600[0][0]']
#
#  block8_8_conv (Conv1D)         (None, 1, 992)       445408      ['block8_8_mixed[0][0]']
#
#  block8_8_conv_bn (BatchNormali  (None, 1, 992)      3           ['block8_8_conv[0][0]']
#  zation)
#
#  block8_8 (Lambda)              (None, 1, 992)       0           ['block8_7_ac[0][0]',
#                                                                   'block8_8_conv_bn[0][0]']
#
#  block8_8_ac (Activation)       (None, 1, 992)       0           ['block8_8[0][0]']
#
#  conv1d_602 (Conv1D)            (None, 1, 192)       190656      ['block8_8_ac[0][0]']
#
#  batch_normalization_602 (Batch  (None, 1, 192)      3           ['conv1d_602[0][0]']
#  Normalization)
#
#  activation_602 (Activation)    (None, 1, 192)       0           ['batch_normalization_602[0][0]']
#
#  conv1d_603 (Conv1D)            (None, 1, 224)       43232       ['activation_602[0][0]']
#
#  batch_normalization_603 (Batch  (None, 1, 224)      3           ['conv1d_603[0][0]']
#  Normalization)
#
#  activation_603 (Activation)    (None, 1, 224)       0           ['batch_normalization_603[0][0]']
#
#  conv1d_601 (Conv1D)            (None, 1, 192)       190656      ['block8_8_ac[0][0]']
#
#  conv1d_604 (Conv1D)            (None, 1, 256)       172288      ['activation_603[0][0]']
#
#  batch_normalization_601 (Batch  (None, 1, 192)      3           ['conv1d_601[0][0]']
#  Normalization)
#
#  batch_normalization_604 (Batch  (None, 1, 256)      3           ['conv1d_604[0][0]']
#  Normalization)
#
#  activation_601 (Activation)    (None, 1, 192)       0           ['batch_normalization_601[0][0]']
#
#  activation_604 (Activation)    (None, 1, 256)       0           ['batch_normalization_604[0][0]']
#
#  block8_9_mixed (Concatenate)   (None, 1, 448)       0           ['activation_601[0][0]',
#                                                                   'activation_604[0][0]']
#
#  block8_9_conv (Conv1D)         (None, 1, 992)       445408      ['block8_9_mixed[0][0]']
#
#  block8_9_conv_bn (BatchNormali  (None, 1, 992)      3           ['block8_9_conv[0][0]']
#  zation)
#
#  block8_9 (Lambda)              (None, 1, 992)       0           ['block8_8_ac[0][0]',
#                                                                   'block8_9_conv_bn[0][0]']
#
#  block8_9_ac (Activation)       (None, 1, 992)       0           ['block8_9[0][0]']
#
#  conv1d_606 (Conv1D)            (None, 1, 192)       190656      ['block8_9_ac[0][0]']
#
#  batch_normalization_606 (Batch  (None, 1, 192)      3           ['conv1d_606[0][0]']
#  Normalization)
#
#  activation_606 (Activation)    (None, 1, 192)       0           ['batch_normalization_606[0][0]']
#
#  conv1d_607 (Conv1D)            (None, 1, 224)       43232       ['activation_606[0][0]']
#
#  batch_normalization_607 (Batch  (None, 1, 224)      3           ['conv1d_607[0][0]']
#  Normalization)
#
#  activation_607 (Activation)    (None, 1, 224)       0           ['batch_normalization_607[0][0]']
#
#  conv1d_605 (Conv1D)            (None, 1, 192)       190656      ['block8_9_ac[0][0]']
#
#  conv1d_608 (Conv1D)            (None, 1, 256)       172288      ['activation_607[0][0]']
#
#  batch_normalization_605 (Batch  (None, 1, 192)      3           ['conv1d_605[0][0]']
#  Normalization)
#
#  batch_normalization_608 (Batch  (None, 1, 256)      3           ['conv1d_608[0][0]']
#  Normalization)
#
#  activation_605 (Activation)    (None, 1, 192)       0           ['batch_normalization_605[0][0]']
#
#  activation_608 (Activation)    (None, 1, 256)       0           ['batch_normalization_608[0][0]']
#
#  block8_10_mixed (Concatenate)  (None, 1, 448)       0           ['activation_605[0][0]',
#                                                                   'activation_608[0][0]']
#
#  block8_10_conv (Conv1D)        (None, 1, 992)       445408      ['block8_10_mixed[0][0]']
#
#  block8_10_conv_bn (BatchNormal  (None, 1, 992)      3           ['block8_10_conv[0][0]']
#  ization)
#
#  block8_10 (Lambda)             (None, 1, 992)       0           ['block8_9_ac[0][0]',
#                                                                   'block8_10_conv_bn[0][0]']
#
#  conv_7b (Conv1D)               (None, 1, 1536)      1525248     ['block8_10[0][0]']
#
#  conv_7b_bn (BatchNormalization  (None, 1, 1536)     3           ['conv_7b[0][0]']
#  )
#
#  conv_7b_ac (Activation)        (None, 1, 1536)      0           ['conv_7b_bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 1536)        0           ['conv_7b_ac[0][0]']
#  1D)
#
#  predictions (Dense)            (None, 2)            3074        ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 24,308,038
# Trainable params: 24,307,278
# Non-trainable params: 760
# __________________________________________________________________________________________________
# 104/104 [==============================] - 9s 45ms/step
# Accuracy: 0.8854545454545455
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94      3133
#            1       0.07      0.10      0.08       167
#
#     accuracy                           0.89      3300
#    macro avg       0.51      0.51      0.51      3300
# weighted avg       0.91      0.89      0.90      3300
#
# Confusion Matrix:
# [[2905  228]
#  [ 150   17]]

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\3.smote\InceptionV3\inceptionv3_base.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (3300, 2) (12728, 2)
# (3300, 2)
# 37
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 37, 1)]      0           []
#
#  conv1d_609 (Conv1D)            (None, 18, 32)       96          ['input_4[0][0]']
#
#  batch_normalization_609 (Batch  (None, 18, 32)      54          ['conv1d_609[0][0]']
#  Normalization)
#
#  activation_609 (Activation)    (None, 18, 32)       0           ['batch_normalization_609[0][0]']
#
#  conv1d_610 (Conv1D)            (None, 16, 32)       3072        ['activation_609[0][0]']
#
#  batch_normalization_610 (Batch  (None, 16, 32)      48          ['conv1d_610[0][0]']
#  Normalization)
#
#  activation_610 (Activation)    (None, 16, 32)       0           ['batch_normalization_610[0][0]']
#
#  conv1d_611 (Conv1D)            (None, 14, 64)       6144        ['activation_610[0][0]']
#
#  batch_normalization_611 (Batch  (None, 14, 64)      42          ['conv1d_611[0][0]']
#  Normalization)
#
#  activation_611 (Activation)    (None, 14, 64)       0           ['batch_normalization_611[0][0]']
#
#  block1_pool (MaxPooling1D)     (None, 6, 64)        0           ['activation_611[0][0]']
#
#  conv1d_615 (Conv1D)            (None, 6, 64)        4096        ['block1_pool[0][0]']
#
#  batch_normalization_615 (Batch  (None, 6, 64)       18          ['conv1d_615[0][0]']
#  Normalization)
#
#  activation_615 (Activation)    (None, 6, 64)        0           ['batch_normalization_615[0][0]']
#
#  conv1d_613 (Conv1D)            (None, 6, 48)        3072        ['block1_pool[0][0]']
#
#  conv1d_616 (Conv1D)            (None, 6, 96)        18432       ['activation_615[0][0]']
#
#  batch_normalization_613 (Batch  (None, 6, 48)       18          ['conv1d_613[0][0]']
#  Normalization)
#
#  batch_normalization_616 (Batch  (None, 6, 96)       18          ['conv1d_616[0][0]']
#  Normalization)
#
#  activation_613 (Activation)    (None, 6, 48)        0           ['batch_normalization_613[0][0]']
#
#  activation_616 (Activation)    (None, 6, 96)        0           ['batch_normalization_616[0][0]']
#
#  average_pooling1d_3 (AveragePo  (None, 6, 64)       0           ['block1_pool[0][0]']
#  oling1D)
#
#  conv1d_612 (Conv1D)            (None, 6, 64)        4096        ['block1_pool[0][0]']
#
#  conv1d_614 (Conv1D)            (None, 6, 64)        15360       ['activation_613[0][0]']
#
#  conv1d_617 (Conv1D)            (None, 6, 96)        27648       ['activation_616[0][0]']
#
#  conv1d_618 (Conv1D)            (None, 6, 32)        2048        ['average_pooling1d_3[0][0]']
#
#  batch_normalization_612 (Batch  (None, 6, 64)       18          ['conv1d_612[0][0]']
#  Normalization)
#
#  batch_normalization_614 (Batch  (None, 6, 64)       18          ['conv1d_614[0][0]']
#  Normalization)
#
#  batch_normalization_617 (Batch  (None, 6, 96)       18          ['conv1d_617[0][0]']
#  Normalization)
#
#  batch_normalization_618 (Batch  (None, 6, 32)       18          ['conv1d_618[0][0]']
#  Normalization)
#
#  activation_612 (Activation)    (None, 6, 64)        0           ['batch_normalization_612[0][0]']
#
#  activation_614 (Activation)    (None, 6, 64)        0           ['batch_normalization_614[0][0]']
#
#  activation_617 (Activation)    (None, 6, 96)        0           ['batch_normalization_617[0][0]']
#
#  activation_618 (Activation)    (None, 6, 32)        0           ['batch_normalization_618[0][0]']
#
#  mixed0 (Concatenate)           (None, 6, 256)       0           ['activation_612[0][0]',
#                                                                   'activation_614[0][0]',
#                                                                   'activation_617[0][0]',
#                                                                   'activation_618[0][0]']
#
#  conv1d_622 (Conv1D)            (None, 6, 64)        16384       ['mixed0[0][0]']
#
#  batch_normalization_622 (Batch  (None, 6, 64)       18          ['conv1d_622[0][0]']
#  Normalization)
#
#  activation_622 (Activation)    (None, 6, 64)        0           ['batch_normalization_622[0][0]']
#
#  conv1d_620 (Conv1D)            (None, 6, 48)        12288       ['mixed0[0][0]']
#
#  conv1d_623 (Conv1D)            (None, 6, 96)        18432       ['activation_622[0][0]']
#
#  batch_normalization_620 (Batch  (None, 6, 48)       18          ['conv1d_620[0][0]']
#  Normalization)
#
#  batch_normalization_623 (Batch  (None, 6, 96)       18          ['conv1d_623[0][0]']
#  Normalization)
#
#  activation_620 (Activation)    (None, 6, 48)        0           ['batch_normalization_620[0][0]']
#
#  activation_623 (Activation)    (None, 6, 96)        0           ['batch_normalization_623[0][0]']
#
#  average_pooling1d_4 (AveragePo  (None, 6, 256)      0           ['mixed0[0][0]']
#  oling1D)
#
#  conv1d_619 (Conv1D)            (None, 6, 64)        16384       ['mixed0[0][0]']
#
#  conv1d_621 (Conv1D)            (None, 6, 64)        15360       ['activation_620[0][0]']
#
#  conv1d_624 (Conv1D)            (None, 6, 96)        27648       ['activation_623[0][0]']
#
#  conv1d_625 (Conv1D)            (None, 6, 64)        16384       ['average_pooling1d_4[0][0]']
#
#  batch_normalization_619 (Batch  (None, 6, 64)       18          ['conv1d_619[0][0]']
#  Normalization)
#
#  batch_normalization_621 (Batch  (None, 6, 64)       18          ['conv1d_621[0][0]']
#  Normalization)
#
#  batch_normalization_624 (Batch  (None, 6, 96)       18          ['conv1d_624[0][0]']
#  Normalization)
#
#  batch_normalization_625 (Batch  (None, 6, 64)       18          ['conv1d_625[0][0]']
#  Normalization)
#
#  activation_619 (Activation)    (None, 6, 64)        0           ['batch_normalization_619[0][0]']
#
#  activation_621 (Activation)    (None, 6, 64)        0           ['batch_normalization_621[0][0]']
#
#  activation_624 (Activation)    (None, 6, 96)        0           ['batch_normalization_624[0][0]']
#
#  activation_625 (Activation)    (None, 6, 64)        0           ['batch_normalization_625[0][0]']
#
#  mixed1 (Concatenate)           (None, 6, 288)       0           ['activation_619[0][0]',
#                                                                   'activation_621[0][0]',
#                                                                   'activation_624[0][0]',
#                                                                   'activation_625[0][0]']
#
#  conv1d_629 (Conv1D)            (None, 6, 64)        18432       ['mixed1[0][0]']
#
#  batch_normalization_629 (Batch  (None, 6, 64)       18          ['conv1d_629[0][0]']
#  Normalization)
#
#  activation_629 (Activation)    (None, 6, 64)        0           ['batch_normalization_629[0][0]']
#
#  conv1d_627 (Conv1D)            (None, 6, 48)        13824       ['mixed1[0][0]']
#
#  conv1d_630 (Conv1D)            (None, 6, 96)        18432       ['activation_629[0][0]']
#
#  batch_normalization_627 (Batch  (None, 6, 48)       18          ['conv1d_627[0][0]']
#  Normalization)
#
#  batch_normalization_630 (Batch  (None, 6, 96)       18          ['conv1d_630[0][0]']
#  Normalization)
#
#  activation_627 (Activation)    (None, 6, 48)        0           ['batch_normalization_627[0][0]']
#
#  activation_630 (Activation)    (None, 6, 96)        0           ['batch_normalization_630[0][0]']
#
#  average_pooling1d_5 (AveragePo  (None, 6, 288)      0           ['mixed1[0][0]']
#  oling1D)
#
#  conv1d_626 (Conv1D)            (None, 6, 64)        18432       ['mixed1[0][0]']
#
#  conv1d_628 (Conv1D)            (None, 6, 64)        15360       ['activation_627[0][0]']
#
#  conv1d_631 (Conv1D)            (None, 6, 96)        27648       ['activation_630[0][0]']
#
#  conv1d_632 (Conv1D)            (None, 6, 64)        18432       ['average_pooling1d_5[0][0]']
#
#  batch_normalization_626 (Batch  (None, 6, 64)       18          ['conv1d_626[0][0]']
#  Normalization)
#
#  batch_normalization_628 (Batch  (None, 6, 64)       18          ['conv1d_628[0][0]']
#  Normalization)
#
#  batch_normalization_631 (Batch  (None, 6, 96)       18          ['conv1d_631[0][0]']
#  Normalization)
#
#  batch_normalization_632 (Batch  (None, 6, 64)       18          ['conv1d_632[0][0]']
#  Normalization)
#
#  activation_626 (Activation)    (None, 6, 64)        0           ['batch_normalization_626[0][0]']
#
#  activation_628 (Activation)    (None, 6, 64)        0           ['batch_normalization_628[0][0]']
#
#  activation_631 (Activation)    (None, 6, 96)        0           ['batch_normalization_631[0][0]']
#
#  activation_632 (Activation)    (None, 6, 64)        0           ['batch_normalization_632[0][0]']
#
#  mixed2 (Concatenate)           (None, 6, 288)       0           ['activation_626[0][0]',
#                                                                   'activation_628[0][0]',
#                                                                   'activation_631[0][0]',
#                                                                   'activation_632[0][0]']
#
#  conv1d_634 (Conv1D)            (None, 6, 64)        18432       ['mixed2[0][0]']
#
#  batch_normalization_634 (Batch  (None, 6, 64)       18          ['conv1d_634[0][0]']
#  Normalization)
#
#  activation_634 (Activation)    (None, 6, 64)        0           ['batch_normalization_634[0][0]']
#
#  conv1d_635 (Conv1D)            (None, 6, 96)        18432       ['activation_634[0][0]']
#
#  batch_normalization_635 (Batch  (None, 6, 96)       18          ['conv1d_635[0][0]']
#  Normalization)
#
#  activation_635 (Activation)    (None, 6, 96)        0           ['batch_normalization_635[0][0]']
#
#  conv1d_633 (Conv1D)            (None, 2, 128)       110592      ['mixed2[0][0]']
#
#  conv1d_636 (Conv1D)            (None, 2, 96)        27648       ['activation_635[0][0]']
#
#  batch_normalization_633 (Batch  (None, 2, 128)      6           ['conv1d_633[0][0]']
#  Normalization)
#
#  batch_normalization_636 (Batch  (None, 2, 96)       6           ['conv1d_636[0][0]']
#  Normalization)
#
#  activation_633 (Activation)    (None, 2, 128)       0           ['batch_normalization_633[0][0]']
#
#  activation_636 (Activation)    (None, 2, 96)        0           ['batch_normalization_636[0][0]']
#
#  max_pooling1d_12 (MaxPooling1D  (None, 2, 288)      0           ['mixed2[0][0]']
#  )
#
#  mixed3 (Concatenate)           (None, 2, 512)       0           ['activation_633[0][0]',
#                                                                   'activation_636[0][0]',
#                                                                   'max_pooling1d_12[0][0]']
#
#  conv1d_641 (Conv1D)            (None, 2, 96)        49152       ['mixed3[0][0]']
#
#  batch_normalization_641 (Batch  (None, 2, 96)       6           ['conv1d_641[0][0]']
#  Normalization)
#
#  activation_641 (Activation)    (None, 2, 96)        0           ['batch_normalization_641[0][0]']
#
#  conv1d_642 (Conv1D)            (None, 2, 96)        64512       ['activation_641[0][0]']
#
#  batch_normalization_642 (Batch  (None, 2, 96)       6           ['conv1d_642[0][0]']
#  Normalization)
#
#  activation_642 (Activation)    (None, 2, 96)        0           ['batch_normalization_642[0][0]']
#
#  conv1d_638 (Conv1D)            (None, 2, 96)        49152       ['mixed3[0][0]']
#
#  conv1d_643 (Conv1D)            (None, 2, 96)        9216        ['activation_642[0][0]']
#
#  batch_normalization_638 (Batch  (None, 2, 96)       6           ['conv1d_638[0][0]']
#  Normalization)
#
#  batch_normalization_643 (Batch  (None, 2, 96)       6           ['conv1d_643[0][0]']
#  Normalization)
#
#  activation_638 (Activation)    (None, 2, 96)        0           ['batch_normalization_638[0][0]']
#
#  activation_643 (Activation)    (None, 2, 96)        0           ['batch_normalization_643[0][0]']
#
#  conv1d_639 (Conv1D)            (None, 2, 96)        9216        ['activation_638[0][0]']
#
#  conv1d_644 (Conv1D)            (None, 2, 96)        64512       ['activation_643[0][0]']
#
#  batch_normalization_639 (Batch  (None, 2, 96)       6           ['conv1d_639[0][0]']
#  Normalization)
#
#  batch_normalization_644 (Batch  (None, 2, 96)       6           ['conv1d_644[0][0]']
#  Normalization)
#
#  activation_639 (Activation)    (None, 2, 96)        0           ['batch_normalization_639[0][0]']
#
#  activation_644 (Activation)    (None, 2, 96)        0           ['batch_normalization_644[0][0]']
#
#  average_pooling1d_6 (AveragePo  (None, 2, 512)      0           ['mixed3[0][0]']
#  oling1D)
#
#  conv1d_637 (Conv1D)            (None, 2, 128)       65536       ['mixed3[0][0]']
#
#  conv1d_640 (Conv1D)            (None, 2, 128)       86016       ['activation_639[0][0]']
#
#  conv1d_645 (Conv1D)            (None, 2, 128)       12288       ['activation_644[0][0]']
#
#  conv1d_646 (Conv1D)            (None, 2, 128)       65536       ['average_pooling1d_6[0][0]']
#
#  batch_normalization_637 (Batch  (None, 2, 128)      6           ['conv1d_637[0][0]']
#  Normalization)
#
#  batch_normalization_640 (Batch  (None, 2, 128)      6           ['conv1d_640[0][0]']
#  Normalization)
#
#  batch_normalization_645 (Batch  (None, 2, 128)      6           ['conv1d_645[0][0]']
#  Normalization)
#
#  batch_normalization_646 (Batch  (None, 2, 128)      6           ['conv1d_646[0][0]']
#  Normalization)
#
#  activation_637 (Activation)    (None, 2, 128)       0           ['batch_normalization_637[0][0]']
#
#  activation_640 (Activation)    (None, 2, 128)       0           ['batch_normalization_640[0][0]']
#
#  activation_645 (Activation)    (None, 2, 128)       0           ['batch_normalization_645[0][0]']
#
#  activation_646 (Activation)    (None, 2, 128)       0           ['batch_normalization_646[0][0]']
#
#  mixed4 (Concatenate)           (None, 2, 512)       0           ['activation_637[0][0]',
#                                                                   'activation_640[0][0]',
#                                                                   'activation_645[0][0]',
#                                                                   'activation_646[0][0]']
#
#  conv1d_648 (Conv1D)            (None, 2, 192)       98304       ['mixed4[0][0]']
#
#  conv1d_651 (Conv1D)            (None, 2, 192)       98304       ['mixed4[0][0]']
#
#  batch_normalization_648 (Batch  (None, 2, 192)      6           ['conv1d_648[0][0]']
#  Normalization)
#
#  batch_normalization_651 (Batch  (None, 2, 192)      6           ['conv1d_651[0][0]']
#  Normalization)
#
#  activation_648 (Activation)    (None, 2, 192)       0           ['batch_normalization_648[0][0]']
#
#  activation_651 (Activation)    (None, 2, 192)       0           ['batch_normalization_651[0][0]']
#
#  conv1d_649 (Conv1D)            (None, 2, 192)       36864       ['activation_648[0][0]']
#
#  conv1d_652 (Conv1D)            (None, 2, 192)       258048      ['activation_651[0][0]']
#
#  batch_normalization_649 (Batch  (None, 2, 192)      6           ['conv1d_649[0][0]']
#  Normalization)
#
#  batch_normalization_652 (Batch  (None, 2, 192)      6           ['conv1d_652[0][0]']
#  Normalization)
#
#  activation_649 (Activation)    (None, 2, 192)       0           ['batch_normalization_649[0][0]']
#
#  activation_652 (Activation)    (None, 2, 192)       0           ['batch_normalization_652[0][0]']
#
#  average_pooling1d_7 (AveragePo  (None, 2, 512)      0           ['mixed4[0][0]']
#  oling1D)
#
#  conv1d_647 (Conv1D)            (None, 2, 192)       98304       ['mixed4[0][0]']
#
#  conv1d_650 (Conv1D)            (None, 2, 192)       258048      ['activation_649[0][0]']
#
#  conv1d_653 (Conv1D)            (None, 2, 192)       36864       ['activation_652[0][0]']
#
#  conv1d_654 (Conv1D)            (None, 2, 192)       98304       ['average_pooling1d_7[0][0]']
#
#  batch_normalization_647 (Batch  (None, 2, 192)      6           ['conv1d_647[0][0]']
#  Normalization)
#
#  batch_normalization_650 (Batch  (None, 2, 192)      6           ['conv1d_650[0][0]']
#  Normalization)
#
#  batch_normalization_653 (Batch  (None, 2, 192)      6           ['conv1d_653[0][0]']
#  Normalization)
#
#  batch_normalization_654 (Batch  (None, 2, 192)      6           ['conv1d_654[0][0]']
#  Normalization)
#
#  activation_647 (Activation)    (None, 2, 192)       0           ['batch_normalization_647[0][0]']
#
#  activation_650 (Activation)    (None, 2, 192)       0           ['batch_normalization_650[0][0]']
#
#  activation_653 (Activation)    (None, 2, 192)       0           ['batch_normalization_653[0][0]']
#
#  activation_654 (Activation)    (None, 2, 192)       0           ['batch_normalization_654[0][0]']
#
#  mixed7 (Concatenate)           (None, 2, 768)       0           ['activation_647[0][0]',
#                                                                   'activation_650[0][0]',
#                                                                   'activation_653[0][0]',
#                                                                   'activation_654[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 768)         0           ['mixed7[0][0]']
#  1D)
#
#  predictions (Dense)            (None, 2)            1538        ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 1,973,000
# Trainable params: 1,972,548
# Non-trainable params: 452
# __________________________________________________________________________________________________
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 37, 1)]      0           []
#
#  conv1d_609 (Conv1D)            (None, 18, 32)       96          ['input_4[0][0]']
#
#  batch_normalization_609 (Batch  (None, 18, 32)      54          ['conv1d_609[0][0]']
#  Normalization)
#
#  activation_609 (Activation)    (None, 18, 32)       0           ['batch_normalization_609[0][0]']
#
#  conv1d_610 (Conv1D)            (None, 16, 32)       3072        ['activation_609[0][0]']
#
#  batch_normalization_610 (Batch  (None, 16, 32)      48          ['conv1d_610[0][0]']
#  Normalization)
#
#  activation_610 (Activation)    (None, 16, 32)       0           ['batch_normalization_610[0][0]']
#
#  conv1d_611 (Conv1D)            (None, 14, 64)       6144        ['activation_610[0][0]']
#
#  batch_normalization_611 (Batch  (None, 14, 64)      42          ['conv1d_611[0][0]']
#  Normalization)
#
#  activation_611 (Activation)    (None, 14, 64)       0           ['batch_normalization_611[0][0]']
#
#  block1_pool (MaxPooling1D)     (None, 6, 64)        0           ['activation_611[0][0]']
#
#  conv1d_615 (Conv1D)            (None, 6, 64)        4096        ['block1_pool[0][0]']
# c:\Users\Admin\miniconda3\envs\tensorflow_gpu\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
#
#  batch_normalization_615 (Batch  (None, 6, 64)       18          ['conv1d_615[0][0]']
#  Normalization)
#
#  activation_615 (Activation)    (None, 6, 64)        0           ['batch_normalization_615[0][0]']
#
#  conv1d_613 (Conv1D)            (None, 6, 48)        3072        ['block1_pool[0][0]']
#
#  conv1d_616 (Conv1D)            (None, 6, 96)        18432       ['activation_615[0][0]']
#
#  batch_normalization_613 (Batch  (None, 6, 48)       18          ['conv1d_613[0][0]']
#  Normalization)
#
#  batch_normalization_616 (Batch  (None, 6, 96)       18          ['conv1d_616[0][0]']
#  Normalization)
#
#  activation_613 (Activation)    (None, 6, 48)        0           ['batch_normalization_613[0][0]']
#
#  activation_616 (Activation)    (None, 6, 96)        0           ['batch_normalization_616[0][0]']
#
#  average_pooling1d_3 (AveragePo  (None, 6, 64)       0           ['block1_pool[0][0]']
#  oling1D)
#
#  conv1d_612 (Conv1D)            (None, 6, 64)        4096        ['block1_pool[0][0]']
#
#  conv1d_614 (Conv1D)            (None, 6, 64)        15360       ['activation_613[0][0]']
#
#  conv1d_617 (Conv1D)            (None, 6, 96)        27648       ['activation_616[0][0]']
#
#  conv1d_618 (Conv1D)            (None, 6, 32)        2048        ['average_pooling1d_3[0][0]']
#
#  batch_normalization_612 (Batch  (None, 6, 64)       18          ['conv1d_612[0][0]']
#  Normalization)
#
#  batch_normalization_614 (Batch  (None, 6, 64)       18          ['conv1d_614[0][0]']
#  Normalization)
#
#  batch_normalization_617 (Batch  (None, 6, 96)       18          ['conv1d_617[0][0]']
#  Normalization)
#
#  batch_normalization_618 (Batch  (None, 6, 32)       18          ['conv1d_618[0][0]']
#  Normalization)
#
#  activation_612 (Activation)    (None, 6, 64)        0           ['batch_normalization_612[0][0]']
#
#  activation_614 (Activation)    (None, 6, 64)        0           ['batch_normalization_614[0][0]']
#
#  activation_617 (Activation)    (None, 6, 96)        0           ['batch_normalization_617[0][0]']
#
#  activation_618 (Activation)    (None, 6, 32)        0           ['batch_normalization_618[0][0]']
#
#  mixed0 (Concatenate)           (None, 6, 256)       0           ['activation_612[0][0]',
#                                                                   'activation_614[0][0]',
#                                                                   'activation_617[0][0]',
#                                                                   'activation_618[0][0]']
#
#  conv1d_622 (Conv1D)            (None, 6, 64)        16384       ['mixed0[0][0]']
#
#  batch_normalization_622 (Batch  (None, 6, 64)       18          ['conv1d_622[0][0]']
#  Normalization)
#
#  activation_622 (Activation)    (None, 6, 64)        0           ['batch_normalization_622[0][0]']
#
#  conv1d_620 (Conv1D)            (None, 6, 48)        12288       ['mixed0[0][0]']
#
#  conv1d_623 (Conv1D)            (None, 6, 96)        18432       ['activation_622[0][0]']
#
#  batch_normalization_620 (Batch  (None, 6, 48)       18          ['conv1d_620[0][0]']
# ...
#  )
#
#  mixed3 (Concatenate)           (None, 2, 512)       0           ['activation_633[0][0]',
#                                                                   'activation_636[0][0]',
#                                                                   'max_pooling1d_12[0][0]']
#
#  conv1d_641 (Conv1D)            (None, 2, 96)        49152       ['mixed3[0][0]']
#
#  batch_normalization_641 (Batch  (None, 2, 96)       6           ['conv1d_641[0][0]']
#  Normalization)
#
#  activation_641 (Activation)    (None, 2, 96)        0           ['batch_normalization_641[0][0]']
#
#  conv1d_642 (Conv1D)            (None, 2, 96)        64512       ['activation_641[0][0]']
#
#  batch_normalization_642 (Batch  (None, 2, 96)       6           ['conv1d_642[0][0]']
#  Normalization)
#
#  activation_642 (Activation)    (None, 2, 96)        0           ['batch_normalization_642[0][0]']
#
#  conv1d_638 (Conv1D)            (None, 2, 96)        49152       ['mixed3[0][0]']
#
#  conv1d_643 (Conv1D)            (None, 2, 96)        9216        ['activation_642[0][0]']
#
#  batch_normalization_638 (Batch  (None, 2, 96)       6           ['conv1d_638[0][0]']
#  Normalization)
#
#  batch_normalization_643 (Batch  (None, 2, 96)       6           ['conv1d_643[0][0]']
#  Normalization)
#
#  activation_638 (Activation)    (None, 2, 96)        0           ['batch_normalization_638[0][0]']
#
#  activation_643 (Activation)    (None, 2, 96)        0           ['batch_normalization_643[0][0]']
#
#  conv1d_639 (Conv1D)            (None, 2, 96)        9216        ['activation_638[0][0]']
#
#  conv1d_644 (Conv1D)            (None, 2, 96)        64512       ['activation_643[0][0]']
#
#  batch_normalization_639 (Batch  (None, 2, 96)       6           ['conv1d_639[0][0]']
#  Normalization)
#
#  batch_normalization_644 (Batch  (None, 2, 96)       6           ['conv1d_644[0][0]']
#  Normalization)
#
#  activation_639 (Activation)    (None, 2, 96)        0           ['batch_normalization_639[0][0]']
#
#  activation_644 (Activation)    (None, 2, 96)        0           ['batch_normalization_644[0][0]']
#
#  average_pooling1d_6 (AveragePo  (None, 2, 512)      0           ['mixed3[0][0]']
#  oling1D)
#
#  conv1d_637 (Conv1D)            (None, 2, 128)       65536       ['mixed3[0][0]']
#
#  conv1d_640 (Conv1D)            (None, 2, 128)       86016       ['activation_639[0][0]']
#
#  conv1d_645 (Conv1D)            (None, 2, 128)       12288       ['activation_644[0][0]']
#
#  conv1d_646 (Conv1D)            (None, 2, 128)       65536       ['average_pooling1d_6[0][0]']
#
#  batch_normalization_637 (Batch  (None, 2, 128)      6           ['conv1d_637[0][0]']
#  Normalization)
#
#  batch_normalization_640 (Batch  (None, 2, 128)      6           ['conv1d_640[0][0]']
#  Normalization)
#
#  batch_normalization_645 (Batch  (None, 2, 128)      6           ['conv1d_645[0][0]']
#  Normalization)
#
#  batch_normalization_646 (Batch  (None, 2, 128)      6           ['conv1d_646[0][0]']
#  Normalization)
#
#  activation_637 (Activation)    (None, 2, 128)       0           ['batch_normalization_637[0][0]']
#
#  activation_640 (Activation)    (None, 2, 128)       0           ['batch_normalization_640[0][0]']
#
#  activation_645 (Activation)    (None, 2, 128)       0           ['batch_normalization_645[0][0]']
#
#  activation_646 (Activation)    (None, 2, 128)       0           ['batch_normalization_646[0][0]']
#
#  mixed4 (Concatenate)           (None, 2, 512)       0           ['activation_637[0][0]',
#                                                                   'activation_640[0][0]',
#                                                                   'activation_645[0][0]',
#                                                                   'activation_646[0][0]']
#
#  conv1d_648 (Conv1D)            (None, 2, 192)       98304       ['mixed4[0][0]']
#
#  conv1d_651 (Conv1D)            (None, 2, 192)       98304       ['mixed4[0][0]']
#
#  batch_normalization_648 (Batch  (None, 2, 192)      6           ['conv1d_648[0][0]']
#  Normalization)
#
#  batch_normalization_651 (Batch  (None, 2, 192)      6           ['conv1d_651[0][0]']
#  Normalization)
#
#  activation_648 (Activation)    (None, 2, 192)       0           ['batch_normalization_648[0][0]']
#
#  activation_651 (Activation)    (None, 2, 192)       0           ['batch_normalization_651[0][0]']
#
#  conv1d_649 (Conv1D)            (None, 2, 192)       36864       ['activation_648[0][0]']
#
#  conv1d_652 (Conv1D)            (None, 2, 192)       258048      ['activation_651[0][0]']
#
#  batch_normalization_649 (Batch  (None, 2, 192)      6           ['conv1d_649[0][0]']
#  Normalization)
#
#  batch_normalization_652 (Batch  (None, 2, 192)      6           ['conv1d_652[0][0]']
#  Normalization)
#
#  activation_649 (Activation)    (None, 2, 192)       0           ['batch_normalization_649[0][0]']
#
#  activation_652 (Activation)    (None, 2, 192)       0           ['batch_normalization_652[0][0]']
#
#  average_pooling1d_7 (AveragePo  (None, 2, 512)      0           ['mixed4[0][0]']
#  oling1D)
#
#  conv1d_647 (Conv1D)            (None, 2, 192)       98304       ['mixed4[0][0]']
#
#  conv1d_650 (Conv1D)            (None, 2, 192)       258048      ['activation_649[0][0]']
#
#  conv1d_653 (Conv1D)            (None, 2, 192)       36864       ['activation_652[0][0]']
#
#  conv1d_654 (Conv1D)            (None, 2, 192)       98304       ['average_pooling1d_7[0][0]']
#
#  batch_normalization_647 (Batch  (None, 2, 192)      6           ['conv1d_647[0][0]']
#  Normalization)
#
#  batch_normalization_650 (Batch  (None, 2, 192)      6           ['conv1d_650[0][0]']
#  Normalization)
#
#  batch_normalization_653 (Batch  (None, 2, 192)      6           ['conv1d_653[0][0]']
#  Normalization)
#
#  batch_normalization_654 (Batch  (None, 2, 192)      6           ['conv1d_654[0][0]']
#  Normalization)
#
#  activation_647 (Activation)    (None, 2, 192)       0           ['batch_normalization_647[0][0]']
#
#  activation_650 (Activation)    (None, 2, 192)       0           ['batch_normalization_650[0][0]']
#
#  activation_653 (Activation)    (None, 2, 192)       0           ['batch_normalization_653[0][0]']
#
#  activation_654 (Activation)    (None, 2, 192)       0           ['batch_normalization_654[0][0]']
#
#  mixed7 (Concatenate)           (None, 2, 768)       0           ['activation_647[0][0]',
#                                                                   'activation_650[0][0]',
#                                                                   'activation_653[0][0]',
#                                                                   'activation_654[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 768)         0           ['mixed7[0][0]']
#  1D)
#
#  predictions (Dense)            (None, 2)            1538        ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 1,973,000
# Trainable params: 1,972,548
# Non-trainable params: 452
# __________________________________________________________________________________________________
# 104/104 [==============================] - 1s 8ms/step
# Accuracy: 0.9284848484848485
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96      3133
#            1       0.04      0.02      0.02       167
#
#     accuracy                           0.93      3300
#    macro avg       0.49      0.50      0.49      3300
# weighted avg       0.90      0.93      0.92      3300
#
# Confusion Matrix:
# [[3061   72]
#  [ 164    3]]

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\3.smote\InceptionV3\inceptionv3_class_weight.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (3300, 2) (12728, 2)
# (3300, 2)
# 37
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 37, 1)]      0           []
#
#  conv1d_655 (Conv1D)            (None, 18, 32)       96          ['input_5[0][0]']
#
#  batch_normalization_655 (Batch  (None, 18, 32)      54          ['conv1d_655[0][0]']
#  Normalization)
#
#  activation_655 (Activation)    (None, 18, 32)       0           ['batch_normalization_655[0][0]']
#
#  conv1d_656 (Conv1D)            (None, 16, 32)       3072        ['activation_655[0][0]']
#
#  batch_normalization_656 (Batch  (None, 16, 32)      48          ['conv1d_656[0][0]']
#  Normalization)
#
#  activation_656 (Activation)    (None, 16, 32)       0           ['batch_normalization_656[0][0]']
#
#  conv1d_657 (Conv1D)            (None, 14, 64)       6144        ['activation_656[0][0]']
#
#  batch_normalization_657 (Batch  (None, 14, 64)      42          ['conv1d_657[0][0]']
#  Normalization)
#
#  activation_657 (Activation)    (None, 14, 64)       0           ['batch_normalization_657[0][0]']
#
#  block1_pool (MaxPooling1D)     (None, 6, 64)        0           ['activation_657[0][0]']
#
#  conv1d_661 (Conv1D)            (None, 6, 64)        4096        ['block1_pool[0][0]']
#
#  batch_normalization_661 (Batch  (None, 6, 64)       18          ['conv1d_661[0][0]']
#  Normalization)
#
#  activation_661 (Activation)    (None, 6, 64)        0           ['batch_normalization_661[0][0]']
#
#  conv1d_659 (Conv1D)            (None, 6, 48)        3072        ['block1_pool[0][0]']
#
#  conv1d_662 (Conv1D)            (None, 6, 96)        18432       ['activation_661[0][0]']
#
#  batch_normalization_659 (Batch  (None, 6, 48)       18          ['conv1d_659[0][0]']
#  Normalization)
#
#  batch_normalization_662 (Batch  (None, 6, 96)       18          ['conv1d_662[0][0]']
#  Normalization)
#
#  activation_659 (Activation)    (None, 6, 48)        0           ['batch_normalization_659[0][0]']
#
#  activation_662 (Activation)    (None, 6, 96)        0           ['batch_normalization_662[0][0]']
#
#  average_pooling1d_8 (AveragePo  (None, 6, 64)       0           ['block1_pool[0][0]']
#  oling1D)
#
#  conv1d_658 (Conv1D)            (None, 6, 64)        4096        ['block1_pool[0][0]']
#
#  conv1d_660 (Conv1D)            (None, 6, 64)        15360       ['activation_659[0][0]']
#
#  conv1d_663 (Conv1D)            (None, 6, 96)        27648       ['activation_662[0][0]']
#
#  conv1d_664 (Conv1D)            (None, 6, 32)        2048        ['average_pooling1d_8[0][0]']
#
#  batch_normalization_658 (Batch  (None, 6, 64)       18          ['conv1d_658[0][0]']
#  Normalization)
#
#  batch_normalization_660 (Batch  (None, 6, 64)       18          ['conv1d_660[0][0]']
#  Normalization)
#
#  batch_normalization_663 (Batch  (None, 6, 96)       18          ['conv1d_663[0][0]']
#  Normalization)
#
#  batch_normalization_664 (Batch  (None, 6, 32)       18          ['conv1d_664[0][0]']
#  Normalization)
#
#  activation_658 (Activation)    (None, 6, 64)        0           ['batch_normalization_658[0][0]']
#
#  activation_660 (Activation)    (None, 6, 64)        0           ['batch_normalization_660[0][0]']
#
#  activation_663 (Activation)    (None, 6, 96)        0           ['batch_normalization_663[0][0]']
#
#  activation_664 (Activation)    (None, 6, 32)        0           ['batch_normalization_664[0][0]']
#
#  mixed0 (Concatenate)           (None, 6, 256)       0           ['activation_658[0][0]',
#                                                                   'activation_660[0][0]',
#                                                                   'activation_663[0][0]',
#                                                                   'activation_664[0][0]']
#
#  conv1d_668 (Conv1D)            (None, 6, 64)        16384       ['mixed0[0][0]']
#
#  batch_normalization_668 (Batch  (None, 6, 64)       18          ['conv1d_668[0][0]']
#  Normalization)
#
#  activation_668 (Activation)    (None, 6, 64)        0           ['batch_normalization_668[0][0]']
#
#  conv1d_666 (Conv1D)            (None, 6, 48)        12288       ['mixed0[0][0]']
#
#  conv1d_669 (Conv1D)            (None, 6, 96)        18432       ['activation_668[0][0]']
#
#  batch_normalization_666 (Batch  (None, 6, 48)       18          ['conv1d_666[0][0]']
#  Normalization)
#
#  batch_normalization_669 (Batch  (None, 6, 96)       18          ['conv1d_669[0][0]']
#  Normalization)
#
#  activation_666 (Activation)    (None, 6, 48)        0           ['batch_normalization_666[0][0]']
#
#  activation_669 (Activation)    (None, 6, 96)        0           ['batch_normalization_669[0][0]']
#
#  average_pooling1d_9 (AveragePo  (None, 6, 256)      0           ['mixed0[0][0]']
#  oling1D)
#
#  conv1d_665 (Conv1D)            (None, 6, 64)        16384       ['mixed0[0][0]']
#
#  conv1d_667 (Conv1D)            (None, 6, 64)        15360       ['activation_666[0][0]']
#
#  conv1d_670 (Conv1D)            (None, 6, 96)        27648       ['activation_669[0][0]']
#
#  conv1d_671 (Conv1D)            (None, 6, 64)        16384       ['average_pooling1d_9[0][0]']
#
#  batch_normalization_665 (Batch  (None, 6, 64)       18          ['conv1d_665[0][0]']
#  Normalization)
#
#  batch_normalization_667 (Batch  (None, 6, 64)       18          ['conv1d_667[0][0]']
#  Normalization)
#
#  batch_normalization_670 (Batch  (None, 6, 96)       18          ['conv1d_670[0][0]']
#  Normalization)
#
#  batch_normalization_671 (Batch  (None, 6, 64)       18          ['conv1d_671[0][0]']
#  Normalization)
#
#  activation_665 (Activation)    (None, 6, 64)        0           ['batch_normalization_665[0][0]']
#
#  activation_667 (Activation)    (None, 6, 64)        0           ['batch_normalization_667[0][0]']
#
#  activation_670 (Activation)    (None, 6, 96)        0           ['batch_normalization_670[0][0]']
#
#  activation_671 (Activation)    (None, 6, 64)        0           ['batch_normalization_671[0][0]']
#
#  mixed1 (Concatenate)           (None, 6, 288)       0           ['activation_665[0][0]',
#                                                                   'activation_667[0][0]',
#                                                                   'activation_670[0][0]',
#                                                                   'activation_671[0][0]']
#
#  conv1d_675 (Conv1D)            (None, 6, 64)        18432       ['mixed1[0][0]']
#
#  batch_normalization_675 (Batch  (None, 6, 64)       18          ['conv1d_675[0][0]']
#  Normalization)
#
#  activation_675 (Activation)    (None, 6, 64)        0           ['batch_normalization_675[0][0]']
#
#  conv1d_673 (Conv1D)            (None, 6, 48)        13824       ['mixed1[0][0]']
#
#  conv1d_676 (Conv1D)            (None, 6, 96)        18432       ['activation_675[0][0]']
#
#  batch_normalization_673 (Batch  (None, 6, 48)       18          ['conv1d_673[0][0]']
#  Normalization)
#
#  batch_normalization_676 (Batch  (None, 6, 96)       18          ['conv1d_676[0][0]']
#  Normalization)
#
#  activation_673 (Activation)    (None, 6, 48)        0           ['batch_normalization_673[0][0]']
#
#  activation_676 (Activation)    (None, 6, 96)        0           ['batch_normalization_676[0][0]']
#
#  average_pooling1d_10 (AverageP  (None, 6, 288)      0           ['mixed1[0][0]']
#  ooling1D)
#
#  conv1d_672 (Conv1D)            (None, 6, 64)        18432       ['mixed1[0][0]']
#
#  conv1d_674 (Conv1D)            (None, 6, 64)        15360       ['activation_673[0][0]']
#
#  conv1d_677 (Conv1D)            (None, 6, 96)        27648       ['activation_676[0][0]']
#
#  conv1d_678 (Conv1D)            (None, 6, 64)        18432       ['average_pooling1d_10[0][0]']
#
#  batch_normalization_672 (Batch  (None, 6, 64)       18          ['conv1d_672[0][0]']
#  Normalization)
#
#  batch_normalization_674 (Batch  (None, 6, 64)       18          ['conv1d_674[0][0]']
#  Normalization)
#
#  batch_normalization_677 (Batch  (None, 6, 96)       18          ['conv1d_677[0][0]']
#  Normalization)
#
#  batch_normalization_678 (Batch  (None, 6, 64)       18          ['conv1d_678[0][0]']
#  Normalization)
#
#  activation_672 (Activation)    (None, 6, 64)        0           ['batch_normalization_672[0][0]']
#
#  activation_674 (Activation)    (None, 6, 64)        0           ['batch_normalization_674[0][0]']
#
#  activation_677 (Activation)    (None, 6, 96)        0           ['batch_normalization_677[0][0]']
#
#  activation_678 (Activation)    (None, 6, 64)        0           ['batch_normalization_678[0][0]']
#
#  mixed2 (Concatenate)           (None, 6, 288)       0           ['activation_672[0][0]',
#                                                                   'activation_674[0][0]',
#                                                                   'activation_677[0][0]',
#                                                                   'activation_678[0][0]']
#
#  conv1d_680 (Conv1D)            (None, 6, 64)        18432       ['mixed2[0][0]']
#
#  batch_normalization_680 (Batch  (None, 6, 64)       18          ['conv1d_680[0][0]']
#  Normalization)
#
#  activation_680 (Activation)    (None, 6, 64)        0           ['batch_normalization_680[0][0]']
#
#  conv1d_681 (Conv1D)            (None, 6, 96)        18432       ['activation_680[0][0]']
#
#  batch_normalization_681 (Batch  (None, 6, 96)       18          ['conv1d_681[0][0]']
#  Normalization)
#
#  activation_681 (Activation)    (None, 6, 96)        0           ['batch_normalization_681[0][0]']
#
#  conv1d_679 (Conv1D)            (None, 2, 128)       110592      ['mixed2[0][0]']
#
#  conv1d_682 (Conv1D)            (None, 2, 96)        27648       ['activation_681[0][0]']
#
#  batch_normalization_679 (Batch  (None, 2, 128)      6           ['conv1d_679[0][0]']
#  Normalization)
#
#  batch_normalization_682 (Batch  (None, 2, 96)       6           ['conv1d_682[0][0]']
#  Normalization)
#
#  activation_679 (Activation)    (None, 2, 128)       0           ['batch_normalization_679[0][0]']
#
#  activation_682 (Activation)    (None, 2, 96)        0           ['batch_normalization_682[0][0]']
#
#  max_pooling1d_13 (MaxPooling1D  (None, 2, 288)      0           ['mixed2[0][0]']
#  )
#
#  mixed3 (Concatenate)           (None, 2, 512)       0           ['activation_679[0][0]',
#                                                                   'activation_682[0][0]',
#                                                                   'max_pooling1d_13[0][0]']
#
#  conv1d_687 (Conv1D)            (None, 2, 96)        49152       ['mixed3[0][0]']
#
#  batch_normalization_687 (Batch  (None, 2, 96)       6           ['conv1d_687[0][0]']
#  Normalization)
#
#  activation_687 (Activation)    (None, 2, 96)        0           ['batch_normalization_687[0][0]']
#
#  conv1d_688 (Conv1D)            (None, 2, 96)        64512       ['activation_687[0][0]']
#
#  batch_normalization_688 (Batch  (None, 2, 96)       6           ['conv1d_688[0][0]']
#  Normalization)
#
#  activation_688 (Activation)    (None, 2, 96)        0           ['batch_normalization_688[0][0]']
#
#  conv1d_684 (Conv1D)            (None, 2, 96)        49152       ['mixed3[0][0]']
#
#  conv1d_689 (Conv1D)            (None, 2, 96)        9216        ['activation_688[0][0]']
#
#  batch_normalization_684 (Batch  (None, 2, 96)       6           ['conv1d_684[0][0]']
#  Normalization)
#
#  batch_normalization_689 (Batch  (None, 2, 96)       6           ['conv1d_689[0][0]']
#  Normalization)
#
#  activation_684 (Activation)    (None, 2, 96)        0           ['batch_normalization_684[0][0]']
#
#  activation_689 (Activation)    (None, 2, 96)        0           ['batch_normalization_689[0][0]']
#
#  conv1d_685 (Conv1D)            (None, 2, 96)        9216        ['activation_684[0][0]']
#
#  conv1d_690 (Conv1D)            (None, 2, 96)        64512       ['activation_689[0][0]']
#
#  batch_normalization_685 (Batch  (None, 2, 96)       6           ['conv1d_685[0][0]']
#  Normalization)
#
#  batch_normalization_690 (Batch  (None, 2, 96)       6           ['conv1d_690[0][0]']
#  Normalization)
#
#  activation_685 (Activation)    (None, 2, 96)        0           ['batch_normalization_685[0][0]']
#
#  activation_690 (Activation)    (None, 2, 96)        0           ['batch_normalization_690[0][0]']
#
#  average_pooling1d_11 (AverageP  (None, 2, 512)      0           ['mixed3[0][0]']
#  ooling1D)
#
#  conv1d_683 (Conv1D)            (None, 2, 128)       65536       ['mixed3[0][0]']
#
#  conv1d_686 (Conv1D)            (None, 2, 128)       86016       ['activation_685[0][0]']
#
#  conv1d_691 (Conv1D)            (None, 2, 128)       12288       ['activation_690[0][0]']
#
#  conv1d_692 (Conv1D)            (None, 2, 128)       65536       ['average_pooling1d_11[0][0]']
#
#  batch_normalization_683 (Batch  (None, 2, 128)      6           ['conv1d_683[0][0]']
#  Normalization)
#
#  batch_normalization_686 (Batch  (None, 2, 128)      6           ['conv1d_686[0][0]']
#  Normalization)
#
#  batch_normalization_691 (Batch  (None, 2, 128)      6           ['conv1d_691[0][0]']
#  Normalization)
#
#  batch_normalization_692 (Batch  (None, 2, 128)      6           ['conv1d_692[0][0]']
#  Normalization)
#
#  activation_683 (Activation)    (None, 2, 128)       0           ['batch_normalization_683[0][0]']
#
#  activation_686 (Activation)    (None, 2, 128)       0           ['batch_normalization_686[0][0]']
#
#  activation_691 (Activation)    (None, 2, 128)       0           ['batch_normalization_691[0][0]']
#
#  activation_692 (Activation)    (None, 2, 128)       0           ['batch_normalization_692[0][0]']
#
#  mixed4 (Concatenate)           (None, 2, 512)       0           ['activation_683[0][0]',
#                                                                   'activation_686[0][0]',
#                                                                   'activation_691[0][0]',
#                                                                   'activation_692[0][0]']
#
#  conv1d_694 (Conv1D)            (None, 2, 192)       98304       ['mixed4[0][0]']
#
#  conv1d_697 (Conv1D)            (None, 2, 192)       98304       ['mixed4[0][0]']
#
#  batch_normalization_694 (Batch  (None, 2, 192)      6           ['conv1d_694[0][0]']
#  Normalization)
#
#  batch_normalization_697 (Batch  (None, 2, 192)      6           ['conv1d_697[0][0]']
#  Normalization)
#
#  activation_694 (Activation)    (None, 2, 192)       0           ['batch_normalization_694[0][0]']
#
#  activation_697 (Activation)    (None, 2, 192)       0           ['batch_normalization_697[0][0]']
#
#  conv1d_695 (Conv1D)            (None, 2, 192)       36864       ['activation_694[0][0]']
#
#  conv1d_698 (Conv1D)            (None, 2, 192)       258048      ['activation_697[0][0]']
#
#  batch_normalization_695 (Batch  (None, 2, 192)      6           ['conv1d_695[0][0]']
#  Normalization)
#
#  batch_normalization_698 (Batch  (None, 2, 192)      6           ['conv1d_698[0][0]']
#  Normalization)
#
#  activation_695 (Activation)    (None, 2, 192)       0           ['batch_normalization_695[0][0]']
#
#  activation_698 (Activation)    (None, 2, 192)       0           ['batch_normalization_698[0][0]']
#
#  average_pooling1d_12 (AverageP  (None, 2, 512)      0           ['mixed4[0][0]']
#  ooling1D)
#
#  conv1d_693 (Conv1D)            (None, 2, 192)       98304       ['mixed4[0][0]']
#
#  conv1d_696 (Conv1D)            (None, 2, 192)       258048      ['activation_695[0][0]']
#
#  conv1d_699 (Conv1D)            (None, 2, 192)       36864       ['activation_698[0][0]']
#
#  conv1d_700 (Conv1D)            (None, 2, 192)       98304       ['average_pooling1d_12[0][0]']
#
#  batch_normalization_693 (Batch  (None, 2, 192)      6           ['conv1d_693[0][0]']
#  Normalization)
#
#  batch_normalization_696 (Batch  (None, 2, 192)      6           ['conv1d_696[0][0]']
#  Normalization)
#
#  batch_normalization_699 (Batch  (None, 2, 192)      6           ['conv1d_699[0][0]']
#  Normalization)
#
#  batch_normalization_700 (Batch  (None, 2, 192)      6           ['conv1d_700[0][0]']
#  Normalization)
#
#  activation_693 (Activation)    (None, 2, 192)       0           ['batch_normalization_693[0][0]']
#
#  activation_696 (Activation)    (None, 2, 192)       0           ['batch_normalization_696[0][0]']
#
#  activation_699 (Activation)    (None, 2, 192)       0           ['batch_normalization_699[0][0]']
#
#  activation_700 (Activation)    (None, 2, 192)       0           ['batch_normalization_700[0][0]']
#
#  mixed7 (Concatenate)           (None, 2, 768)       0           ['activation_693[0][0]',
#                                                                   'activation_696[0][0]',
#                                                                   'activation_699[0][0]',
#                                                                   'activation_700[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 768)         0           ['mixed7[0][0]']
#  1D)
#
#  predictions (Dense)            (None, 2)            1538        ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 1,973,000
# Trainable params: 1,972,548
# Non-trainable params: 452
# __________________________________________________________________________________________________
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 37, 1)]      0           []
#
#  conv1d_655 (Conv1D)            (None, 18, 32)       96          ['input_5[0][0]']
#
#  batch_normalization_655 (Batch  (None, 18, 32)      54          ['conv1d_655[0][0]']
#  Normalization)
#
#  activation_655 (Activation)    (None, 18, 32)       0           ['batch_normalization_655[0][0]']
#
#  conv1d_656 (Conv1D)            (None, 16, 32)       3072        ['activation_655[0][0]']
#
#  batch_normalization_656 (Batch  (None, 16, 32)      48          ['conv1d_656[0][0]']
#  Normalization)
#
#  activation_656 (Activation)    (None, 16, 32)       0           ['batch_normalization_656[0][0]']
#
#  conv1d_657 (Conv1D)            (None, 14, 64)       6144        ['activation_656[0][0]']
#
#  batch_normalization_657 (Batch  (None, 14, 64)      42          ['conv1d_657[0][0]']
#  Normalization)
#
#  activation_657 (Activation)    (None, 14, 64)       0           ['batch_normalization_657[0][0]']
#
#  block1_pool (MaxPooling1D)     (None, 6, 64)        0           ['activation_657[0][0]']
#
#  conv1d_661 (Conv1D)            (None, 6, 64)        4096        ['block1_pool[0][0]']
#
#  batch_normalization_661 (Batch  (None, 6, 64)       18          ['conv1d_661[0][0]']
#  Normalization)
#
#  activation_661 (Activation)    (None, 6, 64)        0           ['batch_normalization_661[0][0]']
#
#  conv1d_659 (Conv1D)            (None, 6, 48)        3072        ['block1_pool[0][0]']
#
#  conv1d_662 (Conv1D)            (None, 6, 96)        18432       ['activation_661[0][0]']
#
#  batch_normalization_659 (Batch  (None, 6, 48)       18          ['conv1d_659[0][0]']
# c:\Users\Admin\miniconda3\envs\tensorflow_gpu\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
#  Normalization)
#
#  batch_normalization_662 (Batch  (None, 6, 96)       18          ['conv1d_662[0][0]']
#  Normalization)
#
#  activation_659 (Activation)    (None, 6, 48)        0           ['batch_normalization_659[0][0]']
#
#  activation_662 (Activation)    (None, 6, 96)        0           ['batch_normalization_662[0][0]']
#
#  average_pooling1d_8 (AveragePo  (None, 6, 64)       0           ['block1_pool[0][0]']
#  oling1D)
#
#  conv1d_658 (Conv1D)            (None, 6, 64)        4096        ['block1_pool[0][0]']
#
#  conv1d_660 (Conv1D)            (None, 6, 64)        15360       ['activation_659[0][0]']
#
#  conv1d_663 (Conv1D)            (None, 6, 96)        27648       ['activation_662[0][0]']
#
#  conv1d_664 (Conv1D)            (None, 6, 32)        2048        ['average_pooling1d_8[0][0]']
#
#  batch_normalization_658 (Batch  (None, 6, 64)       18          ['conv1d_658[0][0]']
#  Normalization)
#
#  batch_normalization_660 (Batch  (None, 6, 64)       18          ['conv1d_660[0][0]']
#  Normalization)
#
#  batch_normalization_663 (Batch  (None, 6, 96)       18          ['conv1d_663[0][0]']
#  Normalization)
#
#  batch_normalization_664 (Batch  (None, 6, 32)       18          ['conv1d_664[0][0]']
#  Normalization)
#
#  activation_658 (Activation)    (None, 6, 64)        0           ['batch_normalization_658[0][0]']
#
#  activation_660 (Activation)    (None, 6, 64)        0           ['batch_normalization_660[0][0]']
#
#  activation_663 (Activation)    (None, 6, 96)        0           ['batch_normalization_663[0][0]']
#
#  activation_664 (Activation)    (None, 6, 32)        0           ['batch_normalization_664[0][0]']
#
#  mixed0 (Concatenate)           (None, 6, 256)       0           ['activation_658[0][0]',
#                                                                   'activation_660[0][0]',
#                                                                   'activation_663[0][0]',
#                                                                   'activation_664[0][0]']
#
#  conv1d_668 (Conv1D)            (None, 6, 64)        16384       ['mixed0[0][0]']
#
#  batch_normalization_668 (Batch  (None, 6, 64)       18          ['conv1d_668[0][0]']
#  Normalization)
#
#  activation_668 (Activation)    (None, 6, 64)        0           ['batch_normalization_668[0][0]']
#
#  conv1d_666 (Conv1D)            (None, 6, 48)        12288       ['mixed0[0][0]']
#
#  conv1d_669 (Conv1D)            (None, 6, 96)        18432       ['activation_668[0][0]']
#
#  batch_normalization_666 (Batch  (None, 6, 48)       18          ['conv1d_666[0][0]']
# ...
#  )
#
#  mixed3 (Concatenate)           (None, 2, 512)       0           ['activation_679[0][0]',
#                                                                   'activation_682[0][0]',
#                                                                   'max_pooling1d_13[0][0]']
#
#  conv1d_687 (Conv1D)            (None, 2, 96)        49152       ['mixed3[0][0]']
#
#  batch_normalization_687 (Batch  (None, 2, 96)       6           ['conv1d_687[0][0]']
#  Normalization)
#
#  activation_687 (Activation)    (None, 2, 96)        0           ['batch_normalization_687[0][0]']
#
#  conv1d_688 (Conv1D)            (None, 2, 96)        64512       ['activation_687[0][0]']
#
#  batch_normalization_688 (Batch  (None, 2, 96)       6           ['conv1d_688[0][0]']
#  Normalization)
#
#  activation_688 (Activation)    (None, 2, 96)        0           ['batch_normalization_688[0][0]']
#
#  conv1d_684 (Conv1D)            (None, 2, 96)        49152       ['mixed3[0][0]']
#
#  conv1d_689 (Conv1D)            (None, 2, 96)        9216        ['activation_688[0][0]']
#
#  batch_normalization_684 (Batch  (None, 2, 96)       6           ['conv1d_684[0][0]']
#  Normalization)
#
#  batch_normalization_689 (Batch  (None, 2, 96)       6           ['conv1d_689[0][0]']
#  Normalization)
#
#  activation_684 (Activation)    (None, 2, 96)        0           ['batch_normalization_684[0][0]']
#
#  activation_689 (Activation)    (None, 2, 96)        0           ['batch_normalization_689[0][0]']
#
#  conv1d_685 (Conv1D)            (None, 2, 96)        9216        ['activation_684[0][0]']
#
#  conv1d_690 (Conv1D)            (None, 2, 96)        64512       ['activation_689[0][0]']
#
#  batch_normalization_685 (Batch  (None, 2, 96)       6           ['conv1d_685[0][0]']
#  Normalization)
#
#  batch_normalization_690 (Batch  (None, 2, 96)       6           ['conv1d_690[0][0]']
#  Normalization)
#
#  activation_685 (Activation)    (None, 2, 96)        0           ['batch_normalization_685[0][0]']
#
#  activation_690 (Activation)    (None, 2, 96)        0           ['batch_normalization_690[0][0]']
#
#  average_pooling1d_11 (AverageP  (None, 2, 512)      0           ['mixed3[0][0]']
#  ooling1D)
#
#  conv1d_683 (Conv1D)            (None, 2, 128)       65536       ['mixed3[0][0]']
#
#  conv1d_686 (Conv1D)            (None, 2, 128)       86016       ['activation_685[0][0]']
#
#  conv1d_691 (Conv1D)            (None, 2, 128)       12288       ['activation_690[0][0]']
#
#  conv1d_692 (Conv1D)            (None, 2, 128)       65536       ['average_pooling1d_11[0][0]']
#
#  batch_normalization_683 (Batch  (None, 2, 128)      6           ['conv1d_683[0][0]']
#  Normalization)
#
#  batch_normalization_686 (Batch  (None, 2, 128)      6           ['conv1d_686[0][0]']
#  Normalization)
#
#  batch_normalization_691 (Batch  (None, 2, 128)      6           ['conv1d_691[0][0]']
#  Normalization)
#
#  batch_normalization_692 (Batch  (None, 2, 128)      6           ['conv1d_692[0][0]']
#  Normalization)
#
#  activation_683 (Activation)    (None, 2, 128)       0           ['batch_normalization_683[0][0]']
#
#  activation_686 (Activation)    (None, 2, 128)       0           ['batch_normalization_686[0][0]']
#
#  activation_691 (Activation)    (None, 2, 128)       0           ['batch_normalization_691[0][0]']
#
#  activation_692 (Activation)    (None, 2, 128)       0           ['batch_normalization_692[0][0]']
#
#  mixed4 (Concatenate)           (None, 2, 512)       0           ['activation_683[0][0]',
#                                                                   'activation_686[0][0]',
#                                                                   'activation_691[0][0]',
#                                                                   'activation_692[0][0]']
#
#  conv1d_694 (Conv1D)            (None, 2, 192)       98304       ['mixed4[0][0]']
#
#  conv1d_697 (Conv1D)            (None, 2, 192)       98304       ['mixed4[0][0]']
#
#  batch_normalization_694 (Batch  (None, 2, 192)      6           ['conv1d_694[0][0]']
#  Normalization)
#
#  batch_normalization_697 (Batch  (None, 2, 192)      6           ['conv1d_697[0][0]']
#  Normalization)
#
#  activation_694 (Activation)    (None, 2, 192)       0           ['batch_normalization_694[0][0]']
#
#  activation_697 (Activation)    (None, 2, 192)       0           ['batch_normalization_697[0][0]']
#
#  conv1d_695 (Conv1D)            (None, 2, 192)       36864       ['activation_694[0][0]']
#
#  conv1d_698 (Conv1D)            (None, 2, 192)       258048      ['activation_697[0][0]']
#
#  batch_normalization_695 (Batch  (None, 2, 192)      6           ['conv1d_695[0][0]']
#  Normalization)
#
#  batch_normalization_698 (Batch  (None, 2, 192)      6           ['conv1d_698[0][0]']
#  Normalization)
#
#  activation_695 (Activation)    (None, 2, 192)       0           ['batch_normalization_695[0][0]']
#
#  activation_698 (Activation)    (None, 2, 192)       0           ['batch_normalization_698[0][0]']
#
#  average_pooling1d_12 (AverageP  (None, 2, 512)      0           ['mixed4[0][0]']
#  ooling1D)
#
#  conv1d_693 (Conv1D)            (None, 2, 192)       98304       ['mixed4[0][0]']
#
#  conv1d_696 (Conv1D)            (None, 2, 192)       258048      ['activation_695[0][0]']
#
#  conv1d_699 (Conv1D)            (None, 2, 192)       36864       ['activation_698[0][0]']
#
#  conv1d_700 (Conv1D)            (None, 2, 192)       98304       ['average_pooling1d_12[0][0]']
#
#  batch_normalization_693 (Batch  (None, 2, 192)      6           ['conv1d_693[0][0]']
#  Normalization)
#
#  batch_normalization_696 (Batch  (None, 2, 192)      6           ['conv1d_696[0][0]']
#  Normalization)
#
#  batch_normalization_699 (Batch  (None, 2, 192)      6           ['conv1d_699[0][0]']
#  Normalization)
#
#  batch_normalization_700 (Batch  (None, 2, 192)      6           ['conv1d_700[0][0]']
#  Normalization)
#
#  activation_693 (Activation)    (None, 2, 192)       0           ['batch_normalization_693[0][0]']
#
#  activation_696 (Activation)    (None, 2, 192)       0           ['batch_normalization_696[0][0]']
#
#  activation_699 (Activation)    (None, 2, 192)       0           ['batch_normalization_699[0][0]']
#
#  activation_700 (Activation)    (None, 2, 192)       0           ['batch_normalization_700[0][0]']
#
#  mixed7 (Concatenate)           (None, 2, 768)       0           ['activation_693[0][0]',
#                                                                   'activation_696[0][0]',
#                                                                   'activation_699[0][0]',
#                                                                   'activation_700[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 768)         0           ['mixed7[0][0]']
#  1D)
#
#  predictions (Dense)            (None, 2)            1538        ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 1,973,000
# Trainable params: 1,972,548
# Non-trainable params: 452
# __________________________________________________________________________________________________
# 104/104 [==============================] - 2s 9ms/step
# Accuracy: 0.8987878787878788
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95      3133
#            1       0.05      0.06      0.06       167
#
#     accuracy                           0.90      3300
#    macro avg       0.50      0.50      0.50      3300
# weighted avg       0.90      0.90      0.90      3300
#
# Confusion Matrix:
# [[2956  177]
#  [ 157   10]]
