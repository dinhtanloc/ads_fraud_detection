# %%
# !git clone https://github.com/dinhtanloc/ads_fraud_detection.git

# %%
# pip install kaggle==1.5.0

# %%
# pip install tensorflow==2.12.0
# #

# %%
# pip install joblib cufflinks pydantic-settings mlxtend keras-tuner wandb shap lime tabnet-keras imbalanced-learn scikit-learn-extra xgboost lightgbm faker sdv

# %%
# from kaggle_secrets import UserSecretsClient
# import os
# user_secrets = UserSecretsClient()
# KAGGLE_KEY = user_secrets.get_secret("KAGGLE_KEY")
# KAGGLE_USERNAME = user_secrets.get_secret("KAGGLE_USERNAME")
# os.environ['KAGGLE_USERNAME'] = KAGGLE_USERNAME
# os.environ['KAGGLE_KEY'] = KAGGLE_KEY

# from kaggle.api.kaggle_api_extended import KaggleApi

# api = KaggleApi()
# api.authenticate()

# print("Kaggle API authenticated successfully!")

# %%
# import os
# os.system("kaggle command")

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/1.EDA/EDA_mainbaseline_kaggle.ipynb

# %% [markdown]
# smote

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/2.preprocessing/3.smote/pre-processing-mainbaseline_SMOTE_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/3.smote/VGG16/vgg16_kaggle.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# C:/Users/PC/Data/ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (46631, 2) (292440, 2)
# (46631, 2)
# 43
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 43, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 43, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 43, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 21, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 21, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 21, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 10, 256)           0
#
#  block3_conv1 (Conv1D)       (None, 10, 512)           393728
#
#  block3_conv2 (Conv1D)       (None, 10, 512)           786944
#
#  block3_conv3 (Conv1D)       (None, 10, 512)           786944
#
# ...

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/3.smote/VGG16/vgg16_class_weight_kaggle.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (46631, 2) (292440, 2)
# (46631, 2)
# 43
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 43, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 43, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 43, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 21, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 21, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 21, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 10, 256)           0
#
#  block3_conv1 (Conv1D)       (None, 10, 512)           393728
#
#  block3_conv2 (Conv1D)       (None, 10, 512)           786944
#
#  block3_conv3 (Conv1D)       (None, 10, 512)           786944
#
# ...

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/3.smote/InceptionV3/inceptionv3_kaggle.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (46631, 2) (292440, 2)
# (46631, 2)
# 43
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_3 (InputLayer)           [(None, 43, 1)]      0           []
#
#  conv1d (Conv1D)                (None, 21, 32)       96          ['input_3[0][0]']
#
#  batch_normalization (BatchNorm  (None, 21, 32)      63          ['conv1d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 21, 32)       0           ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 19, 32)       3072        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 19, 32)      57          ['conv1d_1[0][0]']
#  rmalization)
#
# ...

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/3.smote/InceptionV3/inceptionv3_class_weight_kaggle.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (46631, 2) (292440, 2)
# (46631, 2)
# 43
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_4 (InputLayer)           [(None, 43, 1)]      0           []
#
#  conv1d_46 (Conv1D)             (None, 21, 32)       96          ['input_4[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 21, 32)      63          ['conv1d_46[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 21, 32)       0           ['batch_normalization_46[0][0]']
#
#  conv1d_47 (Conv1D)             (None, 19, 32)       3072        ['activation_46[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 19, 32)      57          ['conv1d_47[0][0]']
#  ormalization)
#
# ...

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/3.smote/InceptionV2/inceptionv2_kaggle.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (46631, 2) (292440, 2)
# (46631, 2)
# 43
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_5 (InputLayer)           [(None, 43, 1)]      0           []
#
#  conv1d_92 (Conv1D)             (None, 21, 16)       64          ['input_5[0][0]']
#
#  batch_normalization_92 (BatchN  (None, 21, 16)      63          ['conv1d_92[0][0]']
#  ormalization)
#
#  activation_92 (Activation)     (None, 21, 16)       0           ['batch_normalization_92[0][0]']
#
#  conv1d_93 (Conv1D)             (None, 19, 16)       784         ['activation_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 19, 16)      57          ['conv1d_93[0][0]']
#  ormalization)
#
# ...

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/3.smote/InceptionV2/inceptionv2_class_weight_kaggle.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (46631, 2) (292440, 2)
# (46631, 2)
# c:\ProgramData\miniconda3\envs\tensorflow_gpu\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\ProgramData\miniconda3\envs\tensorflow_gpu\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.11.0 and strictly below 2.14.0 (nightly versions are not supported).
# ...

# %% [markdown]
# gau

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/2.preprocessing/4.synthetic_gau/pre-processing-mainbaseline_GAU_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/4.synthetic_gau/VGG16/vgg16_kaggle.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# C:/Users/PC/Data/ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (46631, 2) (266860, 2)
# (46631, 2)
# 47
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 43, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 43, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 43, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 21, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 21, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 21, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 10, 256)           0
#
#  block3_conv1 (Conv1D)       (None, 10, 512)           393728
#
#  block3_conv2 (Conv1D)       (None, 10, 512)           786944
#
#  block3_conv3 (Conv1D)       (None, 10, 512)           786944
#
# ...

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/4.synthetic_gau/VGG16/vgg16_class_weight_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/4.synthetic_gau/InceptionV2/inceptionv2_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/4.synthetic_gau/InceptionV2/inceptionv2_class_weight_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/4.synthetic_gau/InceptionV3/inceptionv3_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/4.synthetic_gau/InceptionV3/inceptionv3_class_weight_kaggle.ipynb

# %% [markdown]
# gan

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/2.preprocessing/5.synthetic_gan/pre-processing-mainbaseline_GAN_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/5.synthetic_gan/InceptionV3/inceptionv3_kaggle.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (46631, 2) (201728, 2)
# (46631, 2)
# 47
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 43, 1)]      0           []
#
#  conv1d (Conv1D)                (None, 21, 32)       96          ['input_2[0][0]']
#
#  batch_normalization (BatchNorm  (None, 21, 32)      63          ['conv1d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 21, 32)       0           ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 19, 32)       3072        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 19, 32)      57          ['conv1d_1[0][0]']
#  rmalization)
#
# ...

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/5.synthetic_gan/InceptionV3/inceptionv3_class_weight_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/5.synthetic_gan/VGG16/vgg16_class_weight_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/5.synthetic_gan/VGG16/vgg16_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/5.synthetic_gan/InceptionV2/inceptionv2_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/5.synthetic_gan/InceptionV2/inceptionv2_class_weight_kaggle.ipynb

# %% [markdown]
# gancopula

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/2.preprocessing/6.synthetic_gancopula/pre-processing-mainbaseline_noSMOTE_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/6.synthetic_gancopula/InceptionV3/inceptionv3_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/6.synthetic_gancopula/InceptionV3/inceptionv3_class_weight_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/6.synthetic_gancopula/VGG16/vgg16_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/6.synthetic_gancopula/VGG16/vgg16_class_weight_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/6.synthetic_gancopula/InceptionV2/inceptionv2_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/6.synthetic_gancopula/InceptionV2/inceptionv2_class_weight_kaggle.ipynb

# %% [markdown]
# vae

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/2.preprocessing/7.synthetic_vae/pre-processing-mainbaseline_VAE_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/7.synthetic_vae/InceptionV3/inceptionv3_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/7.synthetic_vae/InceptionV3/inceptionv3_class_weight_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/7.synthetic_vae/InceptionV2/inceptionv2_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/7.synthetic_vae/InceptionV2/inceptionv2_class_weight_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/7.synthetic_vae/VGG16/vgg16_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj2/5.deep_learning_model/7.synthetic_vae/VGG16/vgg16_class_weight_kaggle.ipynb
