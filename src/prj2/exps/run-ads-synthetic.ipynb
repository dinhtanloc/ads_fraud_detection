# %%
# !git clone https://github.com/dinhtanloc/ads_fraud_detection.git
# Out:
# Cloning into 'ads_fraud_detection'...
# remote: Enumerating objects: 6968, done.
# remote: Counting objects: 100% (290/290), done.
# remote: Compressing objects: 100% (242/242), done.
# remote: Total 6968 (delta 204), reused 50 (delta 48), pack-reused 6678 (from 2)
# Receiving objects: 100% (6968/6968), 406.41 MiB | 37.62 MiB/s, done.
# Resolving deltas: 100% (4075/4075), done.
# Updating files: 100% (1973/1973), done.

# %%
# pip install kaggle==1.5.0

# %%
# pip install tensorflow==2.12.0
# #

# %%
# pip install joblib cufflinks pydantic-settings mlxtend keras-tuner wandb shap lime tabnet-keras imbalanced-learn scikit-learn-extra xgboost lightgbm faker sdv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 23.6 MB/s eta 0:00:0000:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 61.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.3/69.3 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 79.1 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.4/193.4 kB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.8 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:000:00:0100:01
# ...

# %%
# from kaggle_secrets import UserSecretsClient
# import os
# user_secrets = UserSecretsClient()
# KAGGLE_KEY = user_secrets.get_secret("KAGGLE_KEY")
# KAGGLE_USERNAME = user_secrets.get_secret("KAGGLE_USERNAME")
# os.environ['KAGGLE_USERNAME'] = KAGGLE_USERNAME
# os.environ['KAGGLE_KEY'] = KAGGLE_KEY

# from kaggle.api.kaggle_api_extended import KaggleApi

# api = KaggleApi()
# api.authenticate()

# print("Kaggle API authenticated successfully!")
# Out:
# Kaggle API authenticated successfully!

# %%
# import os
# os.system("kaggle command")
# Out:
# usage: kaggle [-h] [-v] [-W] {competitions,c,datasets,d,kernels,k,models,m,files,f,config} ...
# kaggle: error: argument command: invalid choice: 'command' (choose from 'competitions', 'c', 'datasets', 'd', 'kernels', 'k', 'models', 'm', 'files', 'f', 'config')
# 512

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/1.EDA/EDA_mainbaseline_kaggle.ipynb
# Out:
# /kaggle/working/ads_fraud_detection
# /kaggle/working/ads_fraud_detection
# 2025-05-05 14:30:18.926857: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746455419.152239      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746455419.221922      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2.18.0
# Data download location /kaggle/working/tmp
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ...

# %% [markdown]
# smote

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/2.preprocessing/3.smote/pre-processing-mainbaseline_SMOTE_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/3.smote/VGG16/vgg16_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/3.smote/VGG16/vgg16_class_weight_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/3.smote/InceptionV3/inceptionv3_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/3.smote/InceptionV3/inceptionv3_class_weight_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/3.smote/InceptionV2/inceptionv2_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/3.smote/InceptionV2/inceptionv2_class_weight_kaggle.ipynb

# %% [markdown]
# gau

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/2.preprocessing/4.synthetic_gau/pre-processing-mainbaseline_GAU_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/4.synthetic_gau/VGG16/vgg16_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/4.synthetic_gau/VGG16/vgg16_class_weight_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/4.synthetic_gau/InceptionV2/inceptionv2_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/4.synthetic_gau/InceptionV2/inceptionv2_class_weight_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/4.synthetic_gau/InceptionV3/inceptionv3_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/4.synthetic_gau/InceptionV3/inceptionv3_class_weight_kaggle.ipynb

# %% [markdown]
# gan

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/2.preprocessing/5.synthetic_gan/pre-processing-mainbaseline_GAN_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/5.synthetic_gan/InceptionV3/inceptionv3_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/5.synthetic_gan/InceptionV3/inceptionv3_class_weight_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/5.synthetic_gan/VGG16/vgg16_class_weight_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/5.synthetic_gan/VGG16/vgg16_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/5.synthetic_gan/InceptionV2/inceptionv2_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/5.synthetic_gan/InceptionV2/inceptionv2_class_weight_kaggle.ipynb

# %% [markdown]
# gancopula

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/2.preprocessing/6.synthetic_gancopula/pre-processing-mainbaseline_noSMOTE_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/6.synthetic_gancopula/InceptionV3/inceptionv3_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/6.synthetic_gancopula/InceptionV3/inceptionv3_class_weight_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/6.synthetic_gancopula/VGG16/vgg16_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/6.synthetic_gancopula/VGG16/vgg16_class_weight_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/6.synthetic_gancopula/InceptionV2/inceptionv2_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/6.synthetic_gancopula/InceptionV2/inceptionv2_class_weight_kaggle.ipynb

# %% [markdown]
# vae

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/2.preprocessing/7.synthetic_vae/pre-processing-mainbaseline_VAE_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/7.synthetic_vae/InceptionV3/inceptionv3_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/7.synthetic_vae/InceptionV3/inceptionv3_class_weight_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/7.synthetic_vae/InceptionV2/inceptionv2_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/7.synthetic_vae/InceptionV2/inceptionv2_class_weight_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/7.synthetic_vae/VGG16/vgg16_kaggle.ipynb

# %%
# %run /kaggle/working/ads_fraud_detection/src/prj2/5.deep_learning_model/7.synthetic_vae/VGG16/vgg16_class_weight_kaggle.ipynb
