# %%
# %run "C:\Users\PC\Data\ads_fraud_detection\src\prj2\1.EDA\EDA_mainbaseline.ipynb"
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# C:/Users/PC/Data/ads_fraud_detection
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
# ...

# %%
# %run "C:\Users\PC\Data\ads_fraud_detection\src\prj2\2.preprocessing\3.smote\pre_process_SMOTE.ipynb"
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# (10331, 34) (5089, 34)
# + X_train: 19430
# Fold 0:
# + train_idx: [    0     1     2 ... 19426 19427 19429]
# + valid_idx: [    3     6    19 ... 19417 19418 19428]
# + train / valid: [    3     6    19 ... 19417 19418 19428]
# Fold 1:
# + train_idx: [    1     2     3 ... 19427 19428 19429]
# + valid_idx: [    0     5     8 ... 19423 19425 19426]
# + train / valid: [    0     5     8 ... 19423 19425 19426]
# Fold 2:
# + train_idx: [    0     1     2 ... 19427 19428 19429]
# + valid_idx: [    7    10    12 ... 19406 19419 19421]
# + train / valid: [    7    10    12 ... 19406 19419 19421]
# Fold 3:
# + train_idx: [    0     3     5 ... 19427 19428 19429]
# + valid_idx: [    1     2     4 ... 19410 19414 19424]
# + train / valid: [    1     2     4 ... 19410 19414 19424]
# Fold 4:
# + train_idx: [    0     1     2 ... 19425 19426 19428]
# + valid_idx: [    9    11    13 ... 19422 19427 19429]
# ...

# %%
# %run "C:\Users\PC\Data\ads_fraud_detection\src\prj2\3.feature-selection\3.smote\feature_selection5_1.ipynb"
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# (19430, 33) (19430, 1) (5089, 33) (5089, 1)
# LR
# bi loai bo Empty DataFrame
# Columns: [Feature, Coefficient]
# Index: []
# Xếp hạng các đặc trưng theo mức độ quan trọng:
#                  Feature  Coefficient
# 30            BasePolicy    -0.952028
# 11                 Fault    -0.543516
# 12            PolicyType    -0.521580
# 18  Days_Policy_Accident     0.497618
# 13       VehicleCategory    -0.416372
# 19     Days_Policy_Claim     0.325198
# 17          DriverRating    -0.200395
# 9          MaritalStatus    -0.176299
# 20    PastNumberOfClaims    -0.172854
# 27   AddressChange_Claim     0.172223
# 1            WeekOfMonth    -0.163207
# 10                   Age    -0.157949
# 4           AccidentArea    -0.156432
# 26   NumberOfSuppliments    -0.135931
# 7     WeekOfMonthClaimed    -0.134177
# 2              DayOfWeek    -0.111880
# 28          NumberOfCars    -0.106443
# 16            Deductible     0.102828
# ...

# %%
# %run "C:\Users\PC\Data\ads_fraud_detection\src\prj2\4.traditional_model\3.smote\traditional model5_2.ipynb"
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# (19430, 33) (19430, 1) (5089, 33) (5089, 1)
# (5089, 2) (19430, 2)
# 0    1
# 0.0  1.0    9715
# 1.0  0.0    9715
# Name: count, dtype: int64
# 0    1
# 1.0  0.0    4782
# 0.0  1.0     307
# Name: count, dtype: int64
# Accuracy LR: 84.364% (0.704%)
# Accuracy LDA: 84.143% (0.543%)
# Accuracy DTC: 90.628% (0.408%)
# Accuracy RD: 94.416% (0.363%)
# Accuracy KNC: 80.201% (0.889%)
# Accuracy NB: 79.408% (0.398%)
# Accuracy SVM: 85.970% (0.432%)
# Accuracy NN: 86.835% (0.382%)
# Accuracy BG: 86.629% (0.297%)
# [LightGBM] [Info] Number of positive: 7712, number of negative: 7832
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000319 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 840
# [LightGBM] [Info] Number of data points in the train set: 15544, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.496140 -> initscore=-0.015440
# ...
