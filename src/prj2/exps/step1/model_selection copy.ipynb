# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj2\5.deep_learning_model\3.smote\InceptionV2\inceptionv2_class_weight.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (46631, 2) (292440, 2)
# (46631, 2)
# 43
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_6 (InputLayer)           [(None, 43, 1)]      0           []
#
#  conv1d (Conv1D)                (None, 21, 16)       64          ['input_6[0][0]']
#
#  batch_normalization (BatchNorm  (None, 21, 16)      63          ['conv1d[0][0]']
#  alization)
#
#  activation_25 (Activation)     (None, 21, 16)       0           ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 19, 16)       784         ['activation_25[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 19, 16)      57          ['conv1d_1[0][0]']
#  rmalization)
#
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj2\5.deep_learning_model\3.smote\InceptionV3\inceptionv3_class_weight.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj2\5.deep_learning_model\3.smote\VGG16\vgg16_base.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# C:/Users/Admin/Data/ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (46631, 2) (292440, 2)
# (46631, 2)
# 43
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 43, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 43, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 43, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 21, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 21, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 21, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 10, 256)           0
#
#  block3_conv1 (Conv1D)       (None, 10, 512)           393728
#
#  block3_conv2 (Conv1D)       (None, 10, 512)           786944
#
#  block3_conv3 (Conv1D)       (None, 10, 512)           786944
#
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj2\5.deep_learning_model\3.smote\VGG16\vgg16_class_weight.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# C:/Users/Admin/Data/ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (46631, 2) (292440, 2)
# (46631, 2)
# 43
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 43, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 43, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 43, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 21, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 21, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 21, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 10, 256)           0
#
#  block3_conv1 (Conv1D)       (None, 10, 512)           393728
#
#  block3_conv2 (Conv1D)       (None, 10, 512)           786944
#
#  block3_conv3 (Conv1D)       (None, 10, 512)           786944
#
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj2\5.deep_learning_model\3.smote\VGG19\vgg19_base.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# C:/Users/Admin/Data/ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (46631, 2) (292440, 2)
# (46631, 2)
# 43
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 43, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 43, 256)           1024
#
#  block1_conv2 (Conv1D)       (None, 43, 256)           196864
#
#  block1_pool (MaxPooling1D)  (None, 21, 256)           0
#
#  block2_conv1 (Conv1D)       (None, 21, 512)           393728
#
#  block2_conv2 (Conv1D)       (None, 21, 512)           786944
#
#  block2_pool (MaxPooling1D)  (None, 10, 512)           0
#
#  block3_conv1 (Conv1D)       (None, 10, 768)           1180416
#
#  block3_conv2 (Conv1D)       (None, 10, 768)           1770240
#
#  block3_conv3 (Conv1D)       (None, 10, 768)           1770240
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj2\5.deep_learning_model\3.smote\VGG19\vgg19_class_weight.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (46631, 2) (292440, 2)
# (46631, 2)
# 43
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_4 (InputLayer)        [(None, 43, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 43, 256)           1024
#
#  block1_conv2 (Conv1D)       (None, 43, 256)           196864
#
#  block1_pool (MaxPooling1D)  (None, 21, 256)           0
#
#  block2_conv1 (Conv1D)       (None, 21, 512)           393728
#
#  block2_conv2 (Conv1D)       (None, 21, 512)           786944
#
#  block2_pool (MaxPooling1D)  (None, 10, 512)           0
#
#  block3_conv1 (Conv1D)       (None, 10, 768)           1180416
#
#  block3_conv2 (Conv1D)       (None, 10, 768)           1770240
#
#  block3_conv3 (Conv1D)       (None, 10, 768)           1770240
#
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj2\5.deep_learning_model\3.smote\Resnet50\resnet50_base.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (46631, 2) (292440, 2)
# (46631, 2)
# 43
# Model: "resnet50_1d"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_5 (InputLayer)           [(None, 43, 1)]      0           []
#
#  zero_padding1d (ZeroPadding1D)  (None, 45, 1)       0           ['input_5[0][0]']
#
#  conv1 (Conv1D)                 (None, 23, 64)       512         ['zero_padding1d[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 23, 64)       256         ['conv1[0][0]']
#
#  activation (Activation)        (None, 23, 64)       0           ['bn_conv1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 11, 64)       0           ['activation[0][0]']
#
#  res2a_branch2a (Conv1D)        (None, 11, 32)       2080        ['max_pooling1d[0][0]']
#
# ...
