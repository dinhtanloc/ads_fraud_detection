# %%
# %run C:/Users/Admin/Data/ads_fraud_detection/src/prj2/2.preprocessing/1.base/pre-processing-mainbaseline_noSMOTE.ipynb
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
# ...

# %%
# %run C:/Users/Admin/Data/ads_fraud_detection/src/prj2/exps/step1/model_selection.ipynb
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# No GPU found. Using CPU.
# (330, 2) (1022, 2)
# (330, 2)
# 39
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_1 (InputLayer)        [(None, 39, 1)]              0         []
#
#  conv1d (Conv1D)             (None, 19, 16)               64        ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 19, 16)               57        ['conv1d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 19, 16)               0         ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 17, 16)               784       ['activation[0][0]']
#
# ...

# %%
# %run C:/Users/Admin/Data/ads_fraud_detection/src/prj2/2.preprocessing/3.smote/pre-processing-mainbaseline_smote.ipynb
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# + X_train: 292440
# Fold 0:
# + train_idx: [     1      2      3 ... 292435 292436 292438]
# + valid_idx: [     0      6     11 ... 292432 292437 292439]
# + train / valid: [     0      6     11 ... 292432 292437 292439]
# Fold 1:
# + train_idx: [     0      1      2 ... 292437 292438 292439]
# + valid_idx: [     4     31     34 ... 292416 292423 292426]
# + train / valid: [     4     31     34 ... 292416 292423 292426]
# Fold 2:
# + train_idx: [     0      2      3 ... 292437 292438 292439]
# + valid_idx: [     1     10     20 ... 292412 292415 292420]
# + train / valid: [     1     10     20 ... 292412 292415 292420]
# Fold 3:
# + train_idx: [     0      1      2 ... 292435 292437 292439]
# + valid_idx: [     3      7      8 ... 292434 292436 292438]
# + train / valid: [     3      7      8 ... 292434 292436 292438]
# Fold 4:
# + train_idx: [     0      1      3 ... 292437 292438 292439]
# ...

# %%
# %run C:/Users/Admin/Data/ads_fraud_detection/src/prj2/2.preprocessing/4.synthetic_gau/pre-processing-mainbaseline_GAU.ipynb
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 48/48 [00:00<00:00, 77.43it/s]|
# Data Validity Score: 99.91%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 330.65it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 99.96%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 48/48 [00:03<00:00, 13.35it/s]|
# Column Shapes Score: 75.73%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1128/1128 [00:36<00:00, 30.95it/s]|
# Column Pair Trends Score: 75.62%
#
# Overall Score (Average): 75.68%
#
# LOAN_DEFAULT
# 0    133490
# 1    133490
# Name: count, dtype: int64
# + X_train: 266980
# Fold 0:
# + train_idx: [     0      1      2 ... 266975 266977 266978]
# + valid_idx: [     6     11     12 ... 266968 266976 266979]
# + train / valid: [     6     11     12 ... 266968 266976 266979]
# Fold 1:
# + train_idx: [     2      3      5 ... 266976 266978 266979]
# ...

# %%
# %run C:/Users/Admin/Data/ads_fraud_detection/src/prj2/2.preprocessing/5.synthetic_gan/pre-processing-mainbaseline_GAN.ipynb
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# GAN Synthesizer loaded
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 48/48 [00:00<00:00, 75.09it/s]|
# Data Validity Score: 99.99%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 333.28it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 48/48 [00:04<00:00, 11.18it/s]|
# Column Shapes Score: 86.95%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 1128/1128 [00:38<00:00, 29.01it/s]|
# Column Pair Trends Score: 88.27%
#
# Overall Score (Average): 87.61%
#
# LOAN_DEFAULT
# 1    115875
# 0    115875
# Name: count, dtype: int64
# + X_train: 231750
# Fold 0:
# + train_idx: [     0      1      2 ... 231744 231745 231746]
# + valid_idx: [     4      6     11 ... 231747 231748 231749]
# + train / valid: [     4      6     11 ... 231747 231748 231749]
# Fold 1:
# ...

# %%
# %run C:/Users/Admin/Data/ads_fraud_detection/src/prj2/2.preprocessing/5.synthetic_gan/pre-processing-mainbaseline_GANCopula.ipynb
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
# ...

# %%
# %run C:/Users/Admin/Data/ads_fraud_detection/src/prj2/2.preprocessing/6.synthetic_vae/pre-processing-mainbaseline_VAE.ipynb
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
# ...
