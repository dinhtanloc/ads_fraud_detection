# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)
from config.config import *
from libs.common import *
# Out:
# c:\Users\Admin\Data\ads_fraud_detection
# c:/Users/Admin/Data/ads_fraud_detection
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
save_dir=f"{exps_dir}/exp2"
if os.path.exists(save_dir) == False: 
  os.makedirs(save_dir, exist_ok=True)



test_size=0.33
seed=42

# %%
feature_selection=dict(np.load(f'{save_dir}/feature_model_selection.npz',allow_pickle=True))['feature_model_selection']
feature_selection = {key: value for key, value in feature_selection.item().items()}
feature_selection
# Out:
# {'LR': ['Age',
#   'AgeOfPolicyHolder',
#   'AgentType',
#   'BasePolicy',
#   'Fault',
#   'MaritalStatus',
#   'PoliceReportFiled',
#   'PolicyType',
#   'VehicleCategory',
#   'WitnessPresent'],
#  'LDA': ['AccidentArea',
#   'Age',
#   'AgeOfPolicyHolder',
#   'BasePolicy',
#   'Days_Policy_Claim',
#   'Fault',
#   'MaritalStatus',
#   'NumberOfCars',
#   'PoliceReportFiled',
#   'VehicleCategory'],
#  'DTC': ['Age',
#   'AgeOfVehicle',
#   'BasePolicy',
#   'Fault',
#   'Make',
#   'PastNumberOfClaims',
#   'PolicyNumber',
#   'RepNumber',
#   'week_claimed',
#   'week_incident'],
#  'RD': ['Age',
#   'AgeOfVehicle',
#   'BasePolicy',
#   'Fault',
#   'Make',
#   'PolicyNumber',
#   'PolicyType',
#   'VehicleCategory',
#   'week_claimed',
#   'week_incident'],
#  'KNC': ['DayOfWeek',
#   'AccidentArea',
#   'WeekOfMonthClaimed',
#   'MaritalStatus',
#   'Fault',
#   'PolicyType',
#   'VehicleCategory',
#   'DriverRating',
#   'AgeOfVehicle',
#   'AgeOfPolicyHolder',
#   'BasePolicy'],
#  'GNB': ['DayOfWeek',
#   'AccidentArea',
#   'WeekOfMonthClaimed',
#   'MaritalStatus',
#   'Fault',
#   'PolicyType',
#   'VehicleCategory',
#   'DriverRating',
#   'AgeOfVehicle',
#   'AgeOfPolicyHolder',
#   'BasePolicy'],
#  'NN': ['DayOfWeek',
#   'AccidentArea',
#   'WeekOfMonthClaimed',
#   'MaritalStatus',
#   'Fault',
#   'PolicyType',
#   'VehicleCategory',
#   'DriverRating',
#   'AgeOfVehicle',
#   'AgeOfPolicyHolder',
#   'BasePolicy'],
#  'BG': ['DayOfWeek',
#   'AccidentArea',
#   'WeekOfMonthClaimed',
#   'MaritalStatus',
#   'Fault',
#   'PolicyType',
#   'VehicleCategory',
#   'DriverRating',
#   'AgeOfVehicle',
#   'AgeOfPolicyHolder',
#   'BasePolicy'],
#  'NB': ['DayOfWeek',
#   'AccidentArea',
#   'WeekOfMonthClaimed',
#   'MaritalStatus',
#   'Fault',
#   'PolicyType',
#   'VehicleCategory',
#   'DriverRating',
#   'AgeOfVehicle',
#   'AgeOfPolicyHolder',
#   'BasePolicy'],
#  'SVM': ['DayOfWeek',
#   'AccidentArea',
#   'WeekOfMonthClaimed',
#   'MaritalStatus',
#   'Fault',
#   'PolicyType',
#   'VehicleCategory',
#   'DriverRating',
#   'AgeOfVehicle',
#   'AgeOfPolicyHolder',
#   'BasePolicy']}

# %% [markdown]
# * kiểm tra và tạo các thư mục (nếu chưa có)
# * tập test 33%

# %% [markdown]
# # 5. Xây dựng và đánh giá mô hình học sâu Neutual Network

# %%
bg_model=joblib.load(f'{save_dir}/bg_model.joblib')
rf_model=joblib.load(f'{save_dir}/rf_model.joblib')
svm_model=joblib.load(f'{save_dir}/svm_model.joblib')

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
class_weights_dict=dict(np.load(f'{save_dir}/class_weights_dict.npz',allow_pickle=True))['class_weights_dict']
class_weights_dict = {key: value for key, value in class_weights_dict.item().items()}
class_weights_dict
# Out:
# {0: 0.5317035512094699, 1: 8.385551948051948}

# %%
# Dữ liệu label đã được mã hóa
def oneHot(arr):
    labels = np.array(arr)
    encoder = OneHotEncoder(sparse=False)
    
    labels_reshaped = labels.reshape(-1, 1)
    
    encoder.fit(labels_reshaped)
    
    onehot_labels = encoder.transform(labels_reshaped)
    # onehot_labels=pd.DataFrame(onehot_labels)
    return onehot_labels

y_train_onehot=oneHot(y_train)
y_test_onehot=oneHot(y_test)
print(y_test_onehot.shape,y_train_onehot.shape)
# Out:
# (5089, 2) (19430, 2)

# %%
y_test_onehot.reshape(-1, 1)
print(y_test_onehot.shape)
# Out:
# (5089, 2)

# %%
x_test.shape
# Out:
# (5089, 34)

# %%
x_train.shape
# Out:
# (19430, 34)

# %%
def f1_score(y_true, y_pred):
    """
    Macro F1 score metric.
    """
    y_pred = K.round(y_pred)    
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)), axis=0)
    false_positives = K.sum(K.round(K.clip(y_pred - y_true, 0, 1)), axis=0)
    false_negatives = K.sum(K.round(K.clip(y_true - y_pred, 0, 1)), axis=0)    
    precision = true_positives / (true_positives + false_positives + K.epsilon())
    recall = true_positives / (true_positives + false_negatives + K.epsilon())    
    f1_scores = 2 * (precision * recall) / (precision + recall + K.epsilon())    
    macro_f1_score = K.mean(f1_scores)
    
    return macro_f1_score

# %%
def focal_loss(y_true, y_pred, alpha=0.25, gamma=2.0):
    y_pred = tf.clip_by_value(y_pred, 1e-7, 1 - 1e-7)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    loss = -tf.reduce_mean(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return loss

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return dice

def dice_coef_loss(y_true, y_pred, smooth=0.0001):
    return 1 - dice_coef(y_true, y_pred, smooth)

# %%
def dice_coef_9cat(y_true, y_pred, smooth=1e-7):
    '''
    Dice coefficient for 10 categories. Ignores background pixel label 0
    Pass to model as metric during compile statement
    '''
    y_true_f = K.flatten(K.one_hot(K.cast(y_true, 'int32'), num_classes=10)[...,1:])
    y_pred_f = K.flatten(y_pred[...,1:])
    intersect = K.sum(y_true_f * y_pred_f, axis=-1)
    denom = K.sum(y_true_f + y_pred_f, axis=-1)
    return K.mean((2. * intersect / (denom + smooth)))

def dice_coef_9cat_loss(y_true, y_pred):
    '''
    Dice loss to minimize. Pass to model as loss during compile statement
    '''
    return 1 - dice_coef_9cat(y_true, y_pred)

# %% [markdown]
# #### * Xây dựng model:

# %%
early_stopping = EarlyStopping(monitor='f1_score',
                                mode='max',
    min_delta=0.00005,
    patience=100,
    verbose=1,
    restore_best_weights=True,
)

lr_scheduler = ReduceLROnPlateau(
    monitor='f1_score',
    mode='max',
    factor=0.5,
    patience=10,
    min_lr=0.000001,
    verbose=1,
)
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.h5',  # Đường dẫn để lưu model
    monitor='f1_score',  # Theo dõi val_loss
    mode='max',
    save_best_only=True,  # Lưu lại chỉ model có val_loss tốt nhất
    verbose=1  # Hiển thị thông báo khi lưu model
)

# %% [markdown]
# #### * Xây dựng Stacked_model:

# %%
learning_rate=0.1
tabnet_params = {
    "decision_dim": 16,
    "attention_dim": 16,
    "n_steps": 3,
    "n_shared_glus": 2,
    "n_dependent_glus": 2,
    "relaxation_factor": 1.3,
    "epsilon": 1e-15,
    "momentum": 0.98,
    "mask_type": "softmax", # can be 'sparsemax' or 'softmax'
    "lambda_sparse": 1e-3, 
    "virtual_batch_splits": 8 #number of splits for ghost batch normalization, ideally should evenly divide the batch_size
}



### Classification
model = TabNetClassifier(n_classes = 2, out_activation = 'softmax', **tabnet_params)
# model = TabNetClassifier(n_classes = 2, out_activation = 'softmax', 
#     kernel_regularizer=l2(0.01), **tabnet_params)
# model.compile(loss = 'categorical_crossentropy', optimizer = )
# model.fit(x_train, y_train, epochs = 100, batch_size = 1024)
# model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate), loss='categorical_crossentropy', metrics=['accuracy',f1_score])
# model.compile(optimizer=Adam(lr=learning_rate), loss=f1_loss, metrics=['accuracy',,f1_score])
# model.compile(optimizer=Adam(lr=learning_rate), loss=focal_loss, metrics=['accuracy',f1_score])
model.compile(optimizer=Adam(lr=learning_rate), loss=dice_coef_loss, metrics=['accuracy',f1_score])
early_stopping = EarlyStopping(monitor='val_f1_score',
    min_delta=0.00005,
    patience=60,
    verbose=1,
    restore_best_weights=True,
)

model_checkpoint = ModelCheckpoint('best_model', monitor='val_f1_score', save_best_only=True, save_format='tf')


lr_scheduler = ReduceLROnPlateau(
    monitor='val_f1_score',
    factor=0.5,
    patience=20,
    min_lr=0.000001,
    verbose=1,
)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
model.fit(x=x_train,y=y_train_onehot,
          validation_data=(x_test,y_test_onehot),
          batch_size=64,epochs= 1200, callbacks=[early_stopping,lr_scheduler])
# Out:
# Epoch 1/1200
# 304/304 [==============================] - 44s 16ms/step - loss: 0.2792 - accuracy: 0.7459 - f1_score: 0.7335 - val_loss: 0.2307 - val_accuracy: 0.7750 - val_f1_score: 0.5262 - lr: 0.0010
# Epoch 2/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1911 - accuracy: 0.8210 - f1_score: 0.8193 - val_loss: 0.2206 - val_accuracy: 0.7838 - val_f1_score: 0.5282 - lr: 0.0010
# Epoch 3/1200
# 304/304 [==============================] - 5s 15ms/step - loss: 0.1765 - accuracy: 0.8307 - f1_score: 0.8293 - val_loss: 0.2101 - val_accuracy: 0.7939 - val_f1_score: 0.5364 - lr: 0.0010
# Epoch 4/1200
# 304/304 [==============================] - 5s 15ms/step - loss: 0.1711 - accuracy: 0.8348 - f1_score: 0.8335 - val_loss: 0.2044 - val_accuracy: 0.7976 - val_f1_score: 0.5334 - lr: 0.0010
# Epoch 5/1200
# 304/304 [==============================] - 5s 15ms/step - loss: 0.1633 - accuracy: 0.8433 - f1_score: 0.8421 - val_loss: 0.2009 - val_accuracy: 0.8011 - val_f1_score: 0.5390 - lr: 0.0010
# Epoch 6/1200
# 304/304 [==============================] - 5s 15ms/step - loss: 0.1618 - accuracy: 0.8431 - f1_score: 0.8417 - val_loss: 0.2001 - val_accuracy: 0.8029 - val_f1_score: 0.5418 - lr: 0.0010
# Epoch 7/1200
# 304/304 [==============================] - 5s 15ms/step - loss: 0.1578 - accuracy: 0.8466 - f1_score: 0.8453 - val_loss: 0.1932 - val_accuracy: 0.8092 - val_f1_score: 0.5419 - lr: 0.0010
# Epoch 8/1200
# 304/304 [==============================] - 5s 15ms/step - loss: 0.1523 - accuracy: 0.8530 - f1_score: 0.8516 - val_loss: 0.1875 - val_accuracy: 0.8149 - val_f1_score: 0.5444 - lr: 0.0010
# Epoch 9/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1508 - accuracy: 0.8544 - f1_score: 0.8530 - val_loss: 0.1832 - val_accuracy: 0.8176 - val_f1_score: 0.5404 - lr: 0.0010
# Epoch 10/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1471 - accuracy: 0.8572 - f1_score: 0.8559 - val_loss: 0.1786 - val_accuracy: 0.8249 - val_f1_score: 0.5483 - lr: 0.0010
# Epoch 11/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1452 - accuracy: 0.8593 - f1_score: 0.8581 - val_loss: 0.1812 - val_accuracy: 0.8208 - val_f1_score: 0.5468 - lr: 0.0010
# Epoch 12/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1432 - accuracy: 0.8611 - f1_score: 0.8598 - val_loss: 0.1721 - val_accuracy: 0.8316 - val_f1_score: 0.5506 - lr: 0.0010
# Epoch 13/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1409 - accuracy: 0.8639 - f1_score: 0.8626 - val_loss: 0.1756 - val_accuracy: 0.8269 - val_f1_score: 0.5441 - lr: 0.0010
# Epoch 14/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1370 - accuracy: 0.8679 - f1_score: 0.8667 - val_loss: 0.1681 - val_accuracy: 0.8334 - val_f1_score: 0.5460 - lr: 0.0010
# Epoch 15/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1380 - accuracy: 0.8670 - f1_score: 0.8656 - val_loss: 0.1726 - val_accuracy: 0.8302 - val_f1_score: 0.5496 - lr: 0.0010
# Epoch 16/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1369 - accuracy: 0.8671 - f1_score: 0.8660 - val_loss: 0.1596 - val_accuracy: 0.8436 - val_f1_score: 0.5531 - lr: 0.0010
# Epoch 17/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1307 - accuracy: 0.8739 - f1_score: 0.8724 - val_loss: 0.1631 - val_accuracy: 0.8399 - val_f1_score: 0.5503 - lr: 0.0010
# Epoch 18/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1286 - accuracy: 0.8759 - f1_score: 0.8745 - val_loss: 0.1481 - val_accuracy: 0.8550 - val_f1_score: 0.5586 - lr: 0.0010
# Epoch 19/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1270 - accuracy: 0.8771 - f1_score: 0.8758 - val_loss: 0.1524 - val_accuracy: 0.8511 - val_f1_score: 0.5569 - lr: 0.0010
# Epoch 20/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1312 - accuracy: 0.8728 - f1_score: 0.8715 - val_loss: 0.1579 - val_accuracy: 0.8454 - val_f1_score: 0.5497 - lr: 0.0010
# Epoch 21/1200
# 302/304 [============================>.] - ETA: 0s - loss: 0.1242 - accuracy: 0.8807 - f1_score: 0.8793
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1242 - accuracy: 0.8806 - f1_score: 0.8791 - val_loss: 0.1416 - val_accuracy: 0.8601 - val_f1_score: 0.5575 - lr: 0.0010
# Epoch 22/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1228 - accuracy: 0.8810 - f1_score: 0.8798 - val_loss: 0.1431 - val_accuracy: 0.8601 - val_f1_score: 0.5485 - lr: 5.0000e-04
# Epoch 23/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1202 - accuracy: 0.8839 - f1_score: 0.8825 - val_loss: 0.1402 - val_accuracy: 0.8621 - val_f1_score: 0.5477 - lr: 5.0000e-04
# Epoch 24/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1193 - accuracy: 0.8853 - f1_score: 0.8841 - val_loss: 0.1541 - val_accuracy: 0.8489 - val_f1_score: 0.5491 - lr: 5.0000e-04
# Epoch 25/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1173 - accuracy: 0.8874 - f1_score: 0.8862 - val_loss: 0.1435 - val_accuracy: 0.8601 - val_f1_score: 0.5528 - lr: 5.0000e-04
# Epoch 26/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1153 - accuracy: 0.8896 - f1_score: 0.8881 - val_loss: 0.1523 - val_accuracy: 0.8520 - val_f1_score: 0.5541 - lr: 5.0000e-04
# Epoch 27/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1163 - accuracy: 0.8880 - f1_score: 0.8867 - val_loss: 0.1427 - val_accuracy: 0.8599 - val_f1_score: 0.5496 - lr: 5.0000e-04
# Epoch 28/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1137 - accuracy: 0.8899 - f1_score: 0.8885 - val_loss: 0.1359 - val_accuracy: 0.8672 - val_f1_score: 0.5530 - lr: 5.0000e-04
# Epoch 29/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1125 - accuracy: 0.8913 - f1_score: 0.8901 - val_loss: 0.1374 - val_accuracy: 0.8658 - val_f1_score: 0.5577 - lr: 5.0000e-04
# Epoch 30/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1138 - accuracy: 0.8901 - f1_score: 0.8890 - val_loss: 0.1331 - val_accuracy: 0.8713 - val_f1_score: 0.5594 - lr: 5.0000e-04
# Epoch 31/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1116 - accuracy: 0.8924 - f1_score: 0.8910 - val_loss: 0.1244 - val_accuracy: 0.8790 - val_f1_score: 0.5613 - lr: 5.0000e-04
# Epoch 32/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1121 - accuracy: 0.8923 - f1_score: 0.8912 - val_loss: 0.1391 - val_accuracy: 0.8634 - val_f1_score: 0.5526 - lr: 5.0000e-04
# Epoch 33/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1106 - accuracy: 0.8936 - f1_score: 0.8924 - val_loss: 0.1261 - val_accuracy: 0.8778 - val_f1_score: 0.5583 - lr: 5.0000e-04
# Epoch 34/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1058 - accuracy: 0.8982 - f1_score: 0.8971 - val_loss: 0.1419 - val_accuracy: 0.8609 - val_f1_score: 0.5490 - lr: 5.0000e-04
# Epoch 35/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1083 - accuracy: 0.8962 - f1_score: 0.8949 - val_loss: 0.1416 - val_accuracy: 0.8624 - val_f1_score: 0.5558 - lr: 5.0000e-04
# Epoch 36/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1067 - accuracy: 0.8977 - f1_score: 0.8966 - val_loss: 0.1377 - val_accuracy: 0.8662 - val_f1_score: 0.5540 - lr: 5.0000e-04
# Epoch 37/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1086 - accuracy: 0.8959 - f1_score: 0.8947 - val_loss: 0.1225 - val_accuracy: 0.8807 - val_f1_score: 0.5518 - lr: 5.0000e-04
# Epoch 38/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1087 - accuracy: 0.8948 - f1_score: 0.8937 - val_loss: 0.1302 - val_accuracy: 0.8731 - val_f1_score: 0.5528 - lr: 5.0000e-04
# Epoch 39/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1066 - accuracy: 0.8964 - f1_score: 0.8952 - val_loss: 0.1344 - val_accuracy: 0.8672 - val_f1_score: 0.5509 - lr: 5.0000e-04
# Epoch 40/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1025 - accuracy: 0.9024 - f1_score: 0.9012 - val_loss: 0.1245 - val_accuracy: 0.8786 - val_f1_score: 0.5573 - lr: 5.0000e-04
# Epoch 41/1200
# 304/304 [==============================] - ETA: 0s - loss: 0.1024 - accuracy: 0.9015 - f1_score: 0.9003
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1024 - accuracy: 0.9015 - f1_score: 0.9003 - val_loss: 0.1268 - val_accuracy: 0.8760 - val_f1_score: 0.5612 - lr: 5.0000e-04
# Epoch 42/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1018 - accuracy: 0.9028 - f1_score: 0.9019 - val_loss: 0.1228 - val_accuracy: 0.8811 - val_f1_score: 0.5587 - lr: 2.5000e-04
# Epoch 43/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1010 - accuracy: 0.9031 - f1_score: 0.9018 - val_loss: 0.1195 - val_accuracy: 0.8831 - val_f1_score: 0.5532 - lr: 2.5000e-04
# Epoch 44/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1029 - accuracy: 0.9003 - f1_score: 0.8991 - val_loss: 0.1245 - val_accuracy: 0.8790 - val_f1_score: 0.5559 - lr: 2.5000e-04
# Epoch 45/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1007 - accuracy: 0.9037 - f1_score: 0.9025 - val_loss: 0.1258 - val_accuracy: 0.8780 - val_f1_score: 0.5601 - lr: 2.5000e-04
# Epoch 46/1200
# 304/304 [==============================] - 5s 17ms/step - loss: 0.1033 - accuracy: 0.9004 - f1_score: 0.8993 - val_loss: 0.1235 - val_accuracy: 0.8793 - val_f1_score: 0.5529 - lr: 2.5000e-04
# Epoch 47/1200
# 304/304 [==============================] - 5s 17ms/step - loss: 0.0980 - accuracy: 0.9065 - f1_score: 0.9056 - val_loss: 0.1193 - val_accuracy: 0.8856 - val_f1_score: 0.5636 - lr: 2.5000e-04
# Epoch 48/1200
# 304/304 [==============================] - 5s 16ms/step - loss: 0.1027 - accuracy: 0.9008 - f1_score: 0.8996 - val_loss: 0.1283 - val_accuracy: 0.8744 - val_f1_score: 0.5594 - lr: 2.5000e-04
# Epoch 49/1200
# 304/304 [==============================] - 5s 17ms/step - loss: 0.0999 - accuracy: 0.9043 - f1_score: 0.9031 - val_loss: 0.1203 - val_accuracy: 0.8831 - val_f1_score: 0.5625 - lr: 2.5000e-04
# Epoch 50/1200
# 304/304 [==============================] - 6s 18ms/step - loss: 0.0995 - accuracy: 0.9044 - f1_score: 0.9031 - val_loss: 0.1304 - val_accuracy: 0.8727 - val_f1_score: 0.5547 - lr: 2.5000e-04
# Epoch 51/1200
# 304/304 [==============================] - 6s 20ms/step - loss: 0.0985 - accuracy: 0.9060 - f1_score: 0.9047 - val_loss: 0.1310 - val_accuracy: 0.8727 - val_f1_score: 0.5636 - lr: 2.5000e-04
# Epoch 52/1200
# 304/304 [==============================] - 6s 20ms/step - loss: 0.0987 - accuracy: 0.9056 - f1_score: 0.9041 - val_loss: 0.1303 - val_accuracy: 0.8723 - val_f1_score: 0.5584 - lr: 2.5000e-04
# Epoch 53/1200
# 304/304 [==============================] - 6s 19ms/step - loss: 0.0972 - accuracy: 0.9070 - f1_score: 0.9055 - val_loss: 0.1251 - val_accuracy: 0.8784 - val_f1_score: 0.5662 - lr: 2.5000e-04
# Epoch 54/1200
# 304/304 [==============================] - 6s 20ms/step - loss: 0.0981 - accuracy: 0.9061 - f1_score: 0.9049 - val_loss: 0.1185 - val_accuracy: 0.8843 - val_f1_score: 0.5566 - lr: 2.5000e-04
# Epoch 55/1200
# 304/304 [==============================] - 6s 20ms/step - loss: 0.0967 - accuracy: 0.9074 - f1_score: 0.9064 - val_loss: 0.1190 - val_accuracy: 0.8847 - val_f1_score: 0.5551 - lr: 2.5000e-04
# Epoch 56/1200
# 304/304 [==============================] - 6s 21ms/step - loss: 0.0982 - accuracy: 0.9062 - f1_score: 0.9051 - val_loss: 0.1243 - val_accuracy: 0.8790 - val_f1_score: 0.5497 - lr: 2.5000e-04
# Epoch 57/1200
# 304/304 [==============================] - 6s 19ms/step - loss: 0.0990 - accuracy: 0.9051 - f1_score: 0.9037 - val_loss: 0.1177 - val_accuracy: 0.8866 - val_f1_score: 0.5526 - lr: 2.5000e-04
# Epoch 58/1200
# 304/304 [==============================] - 6s 20ms/step - loss: 0.0956 - accuracy: 0.9080 - f1_score: 0.9071 - val_loss: 0.1227 - val_accuracy: 0.8803 - val_f1_score: 0.5484 - lr: 2.5000e-04
# Epoch 59/1200
# 304/304 [==============================] - 6s 20ms/step - loss: 0.0975 - accuracy: 0.9060 - f1_score: 0.9049 - val_loss: 0.1188 - val_accuracy: 0.8843 - val_f1_score: 0.5559 - lr: 2.5000e-04
# Epoch 60/1200
# 304/304 [==============================] - 6s 20ms/step - loss: 0.0972 - accuracy: 0.9071 - f1_score: 0.9059 - val_loss: 0.1297 - val_accuracy: 0.8733 - val_f1_score: 0.5511 - lr: 2.5000e-04
# Epoch 61/1200
# 303/304 [============================>.] - ETA: 0s - loss: 0.0931 - accuracy: 0.9113 - f1_score: 0.9100Restoring model weights from the end of the best epoch: 1.
#
# Epoch 61: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 304/304 [==============================] - 6s 19ms/step - loss: 0.0934 - accuracy: 0.9110 - f1_score: 0.9095 - val_loss: 0.1232 - val_accuracy: 0.8797 - val_f1_score: 0.5518 - lr: 2.5000e-04
# Epoch 61: early stopping

# %%
model.summary()
# Out:
# Model: "tab_net_classifier"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  tab_net_encoder (TabNetEnc  multiple                  26880
#  oder)
#
#  classifier (Dense)          multiple                  32
#
# =================================================================
# Total params: 26912 (105.12 KB)
# Trainable params: 24592 (96.06 KB)
# Non-trainable params: 2320 (9.06 KB)
# _________________________________________________________________

# %% [markdown]
# #### * Kết quả đánh giá mô hình:

# %%
model.summary()
# Out:
# Model: "tab_net_classifier"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  tab_net_encoder (TabNetEnc  multiple                  26880
#  oder)
#
#  classifier (Dense)          multiple                  32
#
# =================================================================
# Total params: 26912 (105.12 KB)
# Trainable params: 24592 (96.06 KB)
# Non-trainable params: 2320 (9.06 KB)
# _________________________________________________________________

# %%
history=model.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')
axes[1].plot(pd.DataFrame(history))
axes[1].set_title('Training Process')
plt.show()
plt.savefig('train.png')

# %%
y_test_labels = np.argmax(y_test_onehot, axis=1)
predictions = model.predict(x_test)
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_test_labels, predictions)
accuracy
# Out:
# 160/160 [==============================] - 1s 2ms/step
# 0.7750049125564944

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import numpy as np

y_test_labels = np.argmax(y_test_onehot, axis=1)

accuracy = accuracy_score(y_test_labels, predictions)
print("Accuracy:", accuracy)
print("Classification Report:")
print(classification_report(y_test_labels, predictions))

print("Confusion Matrix:")
print(confusion_matrix(y_test_labels, predictions))
# Out:
# Accuracy: 0.7750049125564944
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.80      0.87      4782
#            1       0.12      0.45      0.19       307
#
#     accuracy                           0.78      5089
#    macro avg       0.54      0.62      0.53      5089
# weighted avg       0.91      0.78      0.83      5089
#
# Confusion Matrix:
# [[3806  976]
#  [ 169  138]]

# %%
# Dự đoán


# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 15))

fpr, tpr, _ = roc_curve(y_test, predictions)
    
roc_auc = auc(fpr, tpr)

ax.plot(fpr, tpr, lw=4, color='blue', label='ROC curve (AUC = %0.2f)' % roc_auc)
ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  
ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   
ax.set_title(f'ROC of Voting',fontsize=20, weight='bold')  
ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'}) 
plt.show()

# %%
def check_result(prediction):
    prediction = (prediction > 0.2).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
# solandung=0
# hopdonggianlan=0
# for indx in range(len(x_test)):
#     y_predict = stacked_model.predict(stacked_input)
#     stacked_pred_labels = y_predict.argmax(axis=1)

#     #print(y_predict[0][0])
#     Y_check = check_result(y_test.iloc[indx])
#     print('True:', Y_check)
#     print('Predicted:', check_result(stacked_pred_labels[indx]))
#     print("----------------------------")
#     if Y_check==check_result(stacked_pred_labels[indx]):
#         solandung+=1
#         if Y_check=='Y':
#             hopdonggianlan+=1

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
#       2 print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
#
# NameError: name 'solandung' is not defined
