# %% [markdown]
# #### GAU

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\4.synthetic_gau\InceptionV2\inceptionv2_base.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\4.synthetic_gau\InceptionV2\inceptionv2_class_weight.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\4.synthetic_gau\InceptionV2\inceptionv2_class_weight_dice.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# C:/Users/Admin/Data/ads_fraud_detection
# No GPU found. Using CPU.
# (330, 2) (1022, 2)
# (330, 2)
# 39
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_1 (InputLayer)        [(None, 39, 1)]              0         []
#
#  conv1d (Conv1D)             (None, 19, 16)               64        ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 19, 16)               57        ['conv1d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 19, 16)               0         ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 17, 16)               784       ['activation[0][0]']
#
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\4.synthetic_gau\InceptionV2\inceptionv2_class_weight_focal.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\4.synthetic_gau\InceptionV2\inceptionv2_class_weight_f1.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\4.synthetic_gau\InceptionV3\inceptionv3_base.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\4.synthetic_gau\InceptionV3\inceptionv3_class_weight.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\4.synthetic_gau\InceptionV3\inceptionv3_class_weight_dice.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\4.synthetic_gau\InceptionV3\inceptionv3_class_weight_focal.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\4.synthetic_gau\InceptionV3\inceptionv3_class_weight_f1.ipynb"

# %%
#
