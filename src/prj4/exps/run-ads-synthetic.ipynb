# %%
# !git clone https://github.com/dinhtanloc/ads_fraud_detection.git

# %%
# pip install kaggle==1.5.0

# %%
# pip install tensorflow==2.12.0
# #

# %%
# pip install joblib cufflinks pydantic-settings mlxtend keras-tuner wandb shap lime tabnet-keras imbalanced-learn scikit-learn-extra xgboost lightgbm faker sdv

# %%
# from kaggle_secrets import UserSecretsClient
# import os
# user_secrets = UserSecretsClient()
# KAGGLE_KEY = user_secrets.get_secret("KAGGLE_KEY")
# KAGGLE_USERNAME = user_secrets.get_secret("KAGGLE_USERNAME")
# os.environ['KAGGLE_USERNAME'] = KAGGLE_USERNAME
# os.environ['KAGGLE_KEY'] = KAGGLE_KEY

# from kaggle.api.kaggle_api_extended import KaggleApi

# api = KaggleApi()
# api.authenticate()

# print("Kaggle API authenticated successfully!")

# %%
# import os
# os.system("kaggle command")

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/1.EDA/EDA_mainbaseline_kaggle.ipynb

# %% [markdown]
# smote

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/2.preprocessing/3.smote/pre-processing-mainbaseline_SMOTE_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/3.smote/VGG16/vgg16_kaggle.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (49867, 2) (183458, 2)
# (183458, 56) (183458, 2) (49867, 56) (49867, 2)
# (49867, 2)
# 56
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_3 (InputLayer)        [(None, 56, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 56, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 56, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 28, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 28, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 28, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 14, 256)           0
#
#  block3_conv1 (Conv1D)       (None, 14, 512)           393728
#
#  block3_conv2 (Conv1D)       (None, 14, 512)           786944
#
#  block3_conv3 (Conv1D)       (None, 14, 512)           786944
#
# ...

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/3.smote/VGG16/vgg16_class_weight_kaggle.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (49867, 2) (183458, 2)
# (49867, 2)
# 56
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_4 (InputLayer)        [(None, 56, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 56, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 56, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 28, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 28, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 28, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 14, 256)           0
#
#  block3_conv1 (Conv1D)       (None, 14, 512)           393728
#
#  block3_conv2 (Conv1D)       (None, 14, 512)           786944
#
#  block3_conv3 (Conv1D)       (None, 14, 512)           786944
#
# ...

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/3.smote/VGG19/vgg19_kaggle.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# c:\ProgramData\miniconda3\envs\tensorflow_gpu\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\ProgramData\miniconda3\envs\tensorflow_gpu\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.11.0 and strictly below 2.14.0 (nightly versions are not supported).
# ...

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/3.smote/VGG19/vgg19_class_weight_kaggle.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (49867, 2) (183458, 2)
# (49867, 2)
# 56
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_8 (InputLayer)        [(None, 56, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 56, 256)           1024
#
#  block1_conv2 (Conv1D)       (None, 56, 256)           196864
#
#  block1_pool (MaxPooling1D)  (None, 28, 256)           0
#
#  block2_conv1 (Conv1D)       (None, 28, 512)           393728
#
#  block2_conv2 (Conv1D)       (None, 28, 512)           786944
#
#  block2_pool (MaxPooling1D)  (None, 14, 512)           0
#
#  block3_conv1 (Conv1D)       (None, 14, 768)           1180416
#
#  block3_conv2 (Conv1D)       (None, 14, 768)           1770240
#
#  block3_conv3 (Conv1D)       (None, 14, 768)           1770240
#
# ...

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/3.smote/InceptionV3/inceptionv3_kaggle.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (49867, 2) (183458, 2)
# (49867, 2)
# 56
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_9 (InputLayer)           [(None, 56, 1)]      0           []
#
#  conv1d (Conv1D)                (None, 27, 32)       96          ['input_9[0][0]']
#
#  batch_normalization (BatchNorm  (None, 27, 32)      81          ['conv1d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 27, 32)       0           ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 25, 32)       3072        ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 25, 32)      75          ['conv1d_1[0][0]']
#  rmalization)
#
# ...

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/3.smote/InceptionV3/inceptionv3_class_weight_kaggle.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (49867, 2) (183458, 2)
# (49867, 2)
# 56
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_10 (InputLayer)          [(None, 56, 1)]      0           []
#
#  conv1d_46 (Conv1D)             (None, 27, 32)       96          ['input_10[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 27, 32)      81          ['conv1d_46[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 27, 32)       0           ['batch_normalization_46[0][0]']
#
#  conv1d_47 (Conv1D)             (None, 25, 32)       3072        ['activation_46[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 25, 32)      75          ['conv1d_47[0][0]']
#  ormalization)
#
# ...

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/3.smote/InceptionV2/inceptionv2_kaggle.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (49867, 2) (183458, 2)
# (49867, 2)
# 56
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_11 (InputLayer)          [(None, 56, 1)]      0           []
#
#  conv1d_92 (Conv1D)             (None, 27, 16)       64          ['input_11[0][0]']
#
#  batch_normalization_92 (BatchN  (None, 27, 16)      81          ['conv1d_92[0][0]']
#  ormalization)
#
#  activation_92 (Activation)     (None, 27, 16)       0           ['batch_normalization_92[0][0]']
#
#  conv1d_93 (Conv1D)             (None, 25, 16)       784         ['activation_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 25, 16)      75          ['conv1d_93[0][0]']
#  ormalization)
#
# ...

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/3.smote/InceptionV2/inceptionv2_class_weight_kaggle.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (49867, 2) (183458, 2)
# (49867, 2)
# 56
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_12 (InputLayer)          [(None, 56, 1)]      0           []
#
#  conv1d_295 (Conv1D)            (None, 27, 16)       64          ['input_12[0][0]']
#
#  batch_normalization_295 (Batch  (None, 27, 16)      81          ['conv1d_295[0][0]']
#  Normalization)
#
#  activation_295 (Activation)    (None, 27, 16)       0           ['batch_normalization_295[0][0]']
#
#  conv1d_296 (Conv1D)            (None, 25, 16)       784         ['activation_295[0][0]']
#
#  batch_normalization_296 (Batch  (None, 25, 16)      75          ['conv1d_296[0][0]']
#  Normalization)
#
# ...

# %% [markdown]
# gau

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/2.preprocessing/4.synthetic_gau/pre-processing-mainbaseline_GAU_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/4.synthetic_gau/VGG16/vgg16_kaggle.ipynb
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File c:\ProgramData\miniconda3\envs\tensorflow_gpu\lib\site-packages\IPython\core\magics\execution.py:701, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     700     fpath = arg_lst[0]
# --> 701     filename = file_finder(fpath)
#     702 except IndexError as e:
#
# File c:\ProgramData\miniconda3\envs\tensorflow_gpu\lib\site-packages\IPython\utils\path.py:90, in get_py_filename(name)
#      89         return py_name
# ---> 90 raise IOError("File `%r` not found." % name)
#
# OSError: File `'C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/4.synthetic_gau/VGG16/vgg16_kaggle.ipynb'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[14], line 1
# ...

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/4.synthetic_gau/VGG16/vgg16_class_weight_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/4.synthetic_gau/InceptionV2/inceptionv2_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/4.synthetic_gau/InceptionV2/inceptionv2_class_weight_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/4.synthetic_gau/InceptionV3/inceptionv3_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/4.synthetic_gau/InceptionV3/inceptionv3_class_weight_kaggle.ipynb

# %% [markdown]
# gan

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/2.preprocessing/5.synthetic_gan/pre-processing-mainbaseline_GAN_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/5.synthetic_gan/InceptionV3/inceptionv3_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/5.synthetic_gan/InceptionV3/inceptionv3_class_weight_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/5.synthetic_gan/VGG16/vgg16_class_weight_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/5.synthetic_gan/VGG16/vgg16_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/5.synthetic_gan/InceptionV2/inceptionv2_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/5.synthetic_gan/InceptionV2/inceptionv2_class_weight_kaggle.ipynb

# %% [markdown]
# gancopula

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/2.preprocessing/6.synthetic_gancopula/pre-processing-mainbaseline_noSMOTE_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/6.synthetic_gancopula/InceptionV3/inceptionv3_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/6.synthetic_gancopula/InceptionV3/inceptionv3_class_weight_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/6.synthetic_gancopula/VGG16/vgg16_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/6.synthetic_gancopula/VGG16/vgg16_class_weight_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/6.synthetic_gancopula/InceptionV2/inceptionv2_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/6.synthetic_gancopula/InceptionV2/inceptionv2_class_weight_kaggle.ipynb

# %% [markdown]
# vae

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/2.preprocessing/7.synthetic_vae/pre-processing-mainbaseline_VAE_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/7.synthetic_vae/InceptionV3/inceptionv3_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/7.synthetic_vae/InceptionV3/inceptionv3_class_weight_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/7.synthetic_vae/InceptionV2/inceptionv2_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/7.synthetic_vae/InceptionV2/inceptionv2_class_weight_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/7.synthetic_vae/VGG16/vgg16_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/7.synthetic_vae/VGG16/vgg16_class_weight_kaggle.ipynb
