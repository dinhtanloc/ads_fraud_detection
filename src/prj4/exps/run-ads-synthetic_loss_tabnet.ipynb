# %%
# !git clone https://github.com/dinhtanloc/ads_fraud_detection.git

# %%
# pip install kaggle==1.5.0

# %%
# pip install tensorflow==2.12.0
# #

# %%
# pip install joblib cufflinks pydantic-settings mlxtend keras-tuner wandb shap lime tabnet-keras imbalanced-learn scikit-learn-extra xgboost lightgbm faker sdv

# %%
# from kaggle_secrets import UserSecretsClient
# import os
# user_secrets = UserSecretsClient()
# KAGGLE_KEY = user_secrets.get_secret("KAGGLE_KEY")
# KAGGLE_USERNAME = user_secrets.get_secret("KAGGLE_USERNAME")
# os.environ['KAGGLE_USERNAME'] = KAGGLE_USERNAME
# os.environ['KAGGLE_KEY'] = KAGGLE_KEY

# from kaggle.api.kaggle_api_extended import KaggleApi

# api = KaggleApi()
# api.authenticate()

# print("Kaggle API authenticated successfully!")

# %%
# import os
# os.system("kaggle command")

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj3/1.EDA/EDA_mainbaseline_kaggle.ipynb

# %% [markdown]
# smote

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj3/2.preprocessing/3.smote/pre-processing-mainbaseline_SMOTE_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/3.smote/Tabnet/tabnet_class_weight_kaggle_diceloss.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# C:/Users/PC/Data/ads_fraud_detection
# (49867, 2)
# 56
# c:\ProgramData\miniconda3\envs\tensorflow_gpu\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
#
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#
# c:\ProgramData\miniconda3\envs\tensorflow_gpu\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning:
#
# Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.11.0 and strictly below 2.14.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.1 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
# Epoch 1/1200
# 5734/5734 [==============================] - 434s 70ms/step - loss: 0.5640 - accuracy: 0.8132 - f1_score: 0.8060 - cohen_kappa: -0.9734 - val_loss: 0.0878 - val_accuracy: 0.9155 - val_f1_score: 0.7510 - val_cohen_kappa: -0.2366 - lr: 0.0010
# Epoch 2/1200
# 5734/5734 [==============================] - 404s 70ms/step - loss: 0.5396 - accuracy: 0.8206 - f1_score: 0.8135 - cohen_kappa: -0.9742 - val_loss: 0.1171 - val_accuracy: 0.8859 - val_f1_score: 0.7139 - val_cohen_kappa: -0.2763 - lr: 0.0010
# Epoch 3/1200
# 5734/5734 [==============================] - 403s 70ms/step - loss: 0.5220 - accuracy: 0.8263 - f1_score: 0.8194 - cohen_kappa: -0.9762 - val_loss: 0.0889 - val_accuracy: 0.9142 - val_f1_score: 0.7499 - val_cohen_kappa: -0.2391 - lr: 0.0010
# Epoch 4/1200
# 5733/5734 [============================>.] - ETA: 0s - loss: 0.5197 - accuracy: 0.8271 - f1_score: 0.8203 - cohen_kappa: -0.9763
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 5734/5734 [==============================] - 404s 70ms/step - loss: 0.5197 - accuracy: 0.8271 - f1_score: 0.8202 - cohen_kappa: -0.9763 - val_loss: 0.1128 - val_accuracy: 0.8905 - val_f1_score: 0.7199 - val_cohen_kappa: -0.2716 - lr: 0.0010
# Epoch 5/1200
# 5734/5734 [==============================] - 405s 71ms/step - loss: 0.5182 - accuracy: 0.8273 - f1_score: 0.8202 - cohen_kappa: -0.9765 - val_loss: 0.0936 - val_accuracy: 0.9095 - val_f1_score: 0.7335 - val_cohen_kappa: -0.2345 - lr: 5.0000e-04
# Epoch 6/1200
# 5734/5734 [==============================] - 404s 70ms/step - loss: 0.5176 - accuracy: 0.8278 - f1_score: 0.8209 - cohen_kappa: -0.9765 - val_loss: 0.0900 - val_accuracy: 0.9132 - val_f1_score: 0.7492 - val_cohen_kappa: -0.2414 - lr: 5.0000e-04
# Epoch 7/1200
# 5733/5734 [============================>.] - ETA: 0s - loss: 0.5164 - accuracy: 0.8280 - f1_score: 0.8211 - cohen_kappa: -0.9765
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 5734/5734 [==============================] - 397s 69ms/step - loss: 0.5163 - accuracy: 0.8280 - f1_score: 0.8211 - cohen_kappa: -0.9765 - val_loss: 0.0939 - val_accuracy: 0.9093 - val_f1_score: 0.7445 - val_cohen_kappa: -0.2463 - lr: 5.0000e-04
# Epoch 8/1200
# 5734/5734 [==============================] - 393s 68ms/step - loss: 0.5164 - accuracy: 0.8281 - f1_score: 0.8212 - cohen_kappa: -0.9763 - val_loss: 0.0938 - val_accuracy: 0.9094 - val_f1_score: 0.7342 - val_cohen_kappa: -0.2363 - lr: 2.5000e-04
# Epoch 9/1200
# 5734/5734 [==============================] - 394s 69ms/step - loss: 0.5152 - accuracy: 0.8285 - f1_score: 0.8218 - cohen_kappa: -0.9764 - val_loss: 0.0907 - val_accuracy: 0.9123 - val_f1_score: 0.7485 - val_cohen_kappa: -0.2426 - lr: 2.5000e-04
# Epoch 10/1200
# 5733/5734 [============================>.] - ETA: 0s - loss: 0.5148 - accuracy: 0.8285 - f1_score: 0.8215 - cohen_kappa: -0.9764
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 5734/5734 [==============================] - 392s 68ms/step - loss: 0.5148 - accuracy: 0.8285 - f1_score: 0.8214 - cohen_kappa: -0.9764 - val_loss: 0.1079 - val_accuracy: 0.8952 - val_f1_score: 0.7132 - val_cohen_kappa: -0.2508 - lr: 2.5000e-04
# Epoch 11/1200
# 5733/5734 [============================>.] - ETA: 0s - loss: 0.5148 - accuracy: 0.8286 - f1_score: 0.8218 - cohen_kappa: -0.9764Restoring model weights from the end of the best epoch: 1.
# 5734/5734 [==============================] - 392s 68ms/step - loss: 0.5149 - accuracy: 0.8286 - f1_score: 0.8217 - cohen_kappa: -0.9764 - val_loss: 0.0973 - val_accuracy: 0.9057 - val_f1_score: 0.7275 - val_cohen_kappa: -0.2388 - lr: 1.2500e-04
# Epoch 11: early stopping
# Model: "tab_net_classifier"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  tab_net_encoder (TabNetEnco  multiple                 19207040
#  der)
#
#  classifier (Dense)          multiple                  1024
#
# =================================================================
# Total params: 19,208,064
# Trainable params: 19,142,080
# Non-trainable params: 65,984
# _________________________________________________________________
# Model: "tab_net_classifier"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  tab_net_encoder (TabNetEnco  multiple                 19207040
#  der)
#
#  classifier (Dense)          multiple                  1024
#
# =================================================================
# Total params: 19,208,064
# Trainable params: 19,142,080
# Non-trainable params: 65,984
# _________________________________________________________________
# 1559/1559 [==============================] - 4s 3ms/step
# Accuracy: 0.9154952172779593
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.95     45232
#            1       0.53      0.70      0.61      4635
#
#     accuracy                           0.92     49867
#    macro avg       0.75      0.82      0.78     49867
# weighted avg       0.93      0.92      0.92     49867
#
# Confusion Matrix:
# [[42416  2816]
#  [ 1398  3237]]

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj4/5.deep_learning_model/3.smote/Tabnet/tabnet_class_weight_kaggle_multiloss.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# C:/Users/PC/Data/ads_fraud_detection
# (49867, 2)
# c:\ProgramData\miniconda3\envs\tensorflow_gpu\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
#
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#
# c:\ProgramData\miniconda3\envs\tensorflow_gpu\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning:
#
# Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.11.0 and strictly below 2.14.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.1 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
# 56
# Epoch 1/1200
# 5734/5734 [==============================] - 493s 80ms/step - loss: 1.0149 - accuracy: 0.8170 - f1_score: 0.8103 - cohen_kappa: -0.9771 - val_loss: 0.3550 - val_accuracy: 0.9165 - val_f1_score: 0.7482 - val_cohen_kappa: -0.2309 - lr: 0.0010
# Epoch 2/1200
# 5734/5734 [==============================] - 425s 74ms/step - loss: 0.9659 - accuracy: 0.8260 - f1_score: 0.8191 - cohen_kappa: -0.9754 - val_loss: 0.2821 - val_accuracy: 0.9231 - val_f1_score: 0.7576 - val_cohen_kappa: -0.2220 - lr: 0.0010
# Epoch 3/1200
# 5734/5734 [==============================] - 415s 72ms/step - loss: 0.9483 - accuracy: 0.8278 - f1_score: 0.8207 - cohen_kappa: -0.9756 - val_loss: 0.1881 - val_accuracy: 0.9200 - val_f1_score: 0.7567 - val_cohen_kappa: -0.2301 - lr: 0.0010
# Epoch 4/1200
# 5734/5734 [==============================] - 415s 72ms/step - loss: 0.9218 - accuracy: 0.8316 - f1_score: 0.8249 - cohen_kappa: -0.9786 - val_loss: 0.1731 - val_accuracy: 0.9382 - val_f1_score: 0.7705 - val_cohen_kappa: -0.1920 - lr: 0.0010
# Epoch 5/1200
# 5734/5734 [==============================] - 417s 73ms/step - loss: 0.8618 - accuracy: 0.8457 - f1_score: 0.8401 - cohen_kappa: -0.9859 - val_loss: 0.1487 - val_accuracy: 0.9512 - val_f1_score: 0.7776 - val_cohen_kappa: -0.1626 - lr: 0.0010
# Epoch 6/1200
# 5734/5734 [==============================] - 415s 72ms/step - loss: 0.8093 - accuracy: 0.8566 - f1_score: 0.8515 - cohen_kappa: -0.9875 - val_loss: 0.1605 - val_accuracy: 0.9499 - val_f1_score: 0.7753 - val_cohen_kappa: -0.1639 - lr: 0.0010
# Epoch 7/1200
# 5734/5734 [==============================] - 414s 72ms/step - loss: 0.7929 - accuracy: 0.8596 - f1_score: 0.8545 - cohen_kappa: -0.9873 - val_loss: 0.1640 - val_accuracy: 0.9444 - val_f1_score: 0.7791 - val_cohen_kappa: -0.1813 - lr: 0.0010
# Epoch 8/1200
# 5733/5734 [============================>.] - ETA: 0s - loss: 0.7790 - accuracy: 0.8621 - f1_score: 0.8572 - cohen_kappa: -0.9878
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 5734/5734 [==============================] - 416s 72ms/step - loss: 0.7790 - accuracy: 0.8621 - f1_score: 0.8571 - cohen_kappa: -0.9878 - val_loss: 0.1966 - val_accuracy: 0.9241 - val_f1_score: 0.7588 - val_cohen_kappa: -0.2207 - lr: 0.0010
# Epoch 9/1200
# 5734/5734 [==============================] - 417s 73ms/step - loss: 0.7545 - accuracy: 0.8663 - f1_score: 0.8616 - cohen_kappa: -0.9879 - val_loss: 0.1997 - val_accuracy: 0.9258 - val_f1_score: 0.7518 - val_cohen_kappa: -0.2090 - lr: 5.0000e-04
# Epoch 10/1200
# 5734/5734 [==============================] - 414s 72ms/step - loss: 0.7468 - accuracy: 0.8671 - f1_score: 0.8622 - cohen_kappa: -0.9874 - val_loss: 0.1540 - val_accuracy: 0.9477 - val_f1_score: 0.7759 - val_cohen_kappa: -0.1702 - lr: 5.0000e-04
# Epoch 11/1200
# 5733/5734 [============================>.] - ETA: 0s - loss: 0.7395 - accuracy: 0.8679 - f1_score: 0.8632 - cohen_kappa: -0.9876
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 5734/5734 [==============================] - 418s 73ms/step - loss: 0.7395 - accuracy: 0.8679 - f1_score: 0.8631 - cohen_kappa: -0.9876 - val_loss: 0.1627 - val_accuracy: 0.9471 - val_f1_score: 0.7659 - val_cohen_kappa: -0.1639 - lr: 5.0000e-04
# Epoch 12/1200
# 5734/5734 [==============================] - 418s 73ms/step - loss: 0.7295 - accuracy: 0.8700 - f1_score: 0.8653 - cohen_kappa: -0.9877 - val_loss: 0.2079 - val_accuracy: 0.9185 - val_f1_score: 0.7260 - val_cohen_kappa: -0.2030 - lr: 2.5000e-04
# Epoch 13/1200
# 5734/5734 [==============================] - 415s 72ms/step - loss: 0.7259 - accuracy: 0.8704 - f1_score: 0.8657 - cohen_kappa: -0.9874 - val_loss: 0.1684 - val_accuracy: 0.9441 - val_f1_score: 0.7635 - val_cohen_kappa: -0.1689 - lr: 2.5000e-04
# Epoch 14/1200
# 5733/5734 [============================>.] - ETA: 0s - loss: 0.7227 - accuracy: 0.8707 - f1_score: 0.8662 - cohen_kappa: -0.9873
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 5734/5734 [==============================] - 416s 72ms/step - loss: 0.7227 - accuracy: 0.8707 - f1_score: 0.8662 - cohen_kappa: -0.9873 - val_loss: 0.1520 - val_accuracy: 0.9490 - val_f1_score: 0.7704 - val_cohen_kappa: -0.1614 - lr: 2.5000e-04
# Epoch 15/1200
# 5733/5734 [============================>.] - ETA: 0s - loss: 0.7186 - accuracy: 0.8719 - f1_score: 0.8673 - cohen_kappa: -0.9873Restoring model weights from the end of the best epoch: 5.
# 5734/5734 [==============================] - 417s 73ms/step - loss: 0.7186 - accuracy: 0.8719 - f1_score: 0.8672 - cohen_kappa: -0.9873 - val_loss: 0.2522 - val_accuracy: 0.9308 - val_f1_score: 0.7400 - val_cohen_kappa: -0.1833 - lr: 1.2500e-04
# Epoch 15: early stopping
# Model: "tab_net_classifier"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  tab_net_encoder (TabNetEnco  multiple                 19207040
#  der)
#
#  classifier (Dense)          multiple                  1024
#
# =================================================================
# Total params: 19,208,064
# Trainable params: 19,142,080
# Non-trainable params: 65,984
# _________________________________________________________________
# Model: "tab_net_classifier"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  tab_net_encoder (TabNetEnco  multiple                 19207040
#  der)
#
#  classifier (Dense)          multiple                  1024
#
# =================================================================
# Total params: 19,208,064
# Trainable params: 19,142,080
# Non-trainable params: 65,984
# _________________________________________________________________
# 1559/1559 [==============================] - 5s 3ms/step
# Accuracy: 0.951170112499248
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     45232
#            1       0.88      0.55      0.68      4635
#
#     accuracy                           0.95     49867
#    macro avg       0.92      0.77      0.83     49867
# weighted avg       0.95      0.95      0.95     49867
#
# Confusion Matrix:
# [[44877   355]
#  [ 2080  2555]]
