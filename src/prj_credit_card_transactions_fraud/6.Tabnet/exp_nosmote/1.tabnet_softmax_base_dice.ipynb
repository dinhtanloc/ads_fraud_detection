- accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0606 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 53/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0599 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0606 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 54/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0599 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0605 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 55/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0598 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0605 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 56/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0598 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0605 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 57/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0598 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0604 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 58/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0598 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0604 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 59/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0597 - accuracy: 0.9404 - f1_score: 0.4846 - val_loss: 0.0604 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 60/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0597 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0604 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 61/1200
# 162/162 [==============================] - 2s 14ms/step - loss: 0.0597 - accuracy: 0.9404 - f1_score: 0.4846 - val_loss: 0.0604 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 62/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0597 - accuracy: 0.9404 - f1_score: 0.4844 - val_loss: 0.0604 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 63/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0597 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0604 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 64/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0597 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0604 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 65/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0597 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0604 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 66/1200
# 162/162 [==============================] - 2s 14ms/step - loss: 0.0597 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 67/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0597 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 68/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0597 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 69/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0597 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 70/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0597 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 71/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0597 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 72/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 73/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0597 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0604 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 74/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0597 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0604 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 75/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0597 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 76/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0597 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 77/1200
# 162/162 [==============================] - 2s 14ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 78/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4844 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 79/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4844 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 80/1200
# 158/162 [============================>.] - ETA: 0s - loss: 0.0599 - accuracy: 0.9401 - f1_score: 0.4844
# Epoch 80: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4846 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 0.0010
# Epoch 81/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 5.0000e-04
# Epoch 82/1200
# 162/162 [==============================] - 2s 14ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 5.0000e-04
# Epoch 83/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 5.0000e-04
# Epoch 84/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 5.0000e-04
# Epoch 85/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 5.0000e-04
# Epoch 86/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 5.0000e-04
# Epoch 87/1200
# 162/162 [==============================] - 2s 14ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 5.0000e-04
# Epoch 88/1200
# 162/162 [==============================] - 2s 14ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 5.0000e-04
# Epoch 89/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 5.0000e-04
# Epoch 90/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4846 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 5.0000e-04
# Epoch 91/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 5.0000e-04
# Epoch 92/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4846 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 5.0000e-04
# Epoch 93/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4846 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 5.0000e-04
# Epoch 94/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 5.0000e-04
# Epoch 95/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 5.0000e-04
# Epoch 96/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 5.0000e-04
# Epoch 97/1200
# 162/162 [==============================] - 2s 14ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4846 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 5.0000e-04
# Epoch 98/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4846 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 5.0000e-04
# Epoch 99/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 5.0000e-04
# Epoch 100/1200
# 161/162 [============================>.] - ETA: 0s - loss: 0.0598 - accuracy: 0.9402 - f1_score: 0.4845
# Epoch 100: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4846 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 5.0000e-04
# Epoch 101/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 2.5000e-04
# Epoch 102/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4844 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 2.5000e-04
# Epoch 103/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 2.5000e-04
# Epoch 104/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 2.5000e-04
# Epoch 105/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 2.5000e-04
# Epoch 106/1200
# 162/162 [==============================] - 2s 14ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 2.5000e-04
# Epoch 107/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4846 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 2.5000e-04
# Epoch 108/1200
# 162/162 [==============================] - 2s 14ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 2.5000e-04
# Epoch 109/1200
# 162/162 [==============================] - 2s 13ms/step - loss: 0.0596 - accuracy: 0.9404 - f1_score: 0.4845 - val_loss: 0.0603 - val_accuracy: 0.9397 - val_f1_score: 0.4843 - lr: 2.5000e-04
# Epoch 110/1200
#   5/162 [..............................] - ETA: 1s - loss: 0.0531 - accuracy: 0.9469 - f1_score: 0.4862
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 model.fit(x=x_train,y=y_train_onehot,
#       2           validation_data=(x_test,y_test_onehot),
#       3           batch_size=64,epochs= 1200, callbacks=[early_stopping,lr_scheduler])
#
# File c:\Users\PC\Data\ads_fraud_detection\.conda\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\PC\Data\ads_fraud_detection\.conda\lib\site-packages\keras\src\engine\training.py:1733, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1731 callbacks.on_epoch_begin(epoch)
#    1732 with data_handler.catch_stop_iteration():
# -> 1733     for step in data_handler.steps():
#    1734         with tf.profiler.experimental.Trace(
#    1735             "train",
#    1736             epoch_num=epoch,
#    (...)
#    1739             _r=1,
#    1740         ):
#    1741             callbacks.on_train_batch_begin(step)
#
# File c:\Users\PC\Data\ads_fraud_detection\.conda\lib\site-packages\keras\src\engine\data_adapter.py:1401, in DataHandler.steps(self)
#    1399 if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1400     break
# -> 1401 original_spe = self._steps_per_execution.numpy().item()
#    1402 can_run_full_execution = (
#    1403     original_spe == 1
#    1404     or self._inferred_steps is None
#    1405     or self._inferred_steps - self._current_step >= original_spe
#    1406 )
#    1408 if can_run_full_execution:
#
# File c:\Users\PC\Data\ads_fraud_detection\.conda\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:688, in BaseResourceVariable.numpy(self)
#     686 def numpy(self):
#     687   if context.executing_eagerly():
# --> 688     return self.read_value().numpy()
#     689   raise NotImplementedError(
#     690       "numpy() is only available when eager execution is enabled.")
#
# File c:\Users\PC\Data\ads_fraud_detection\.conda\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:815, in BaseResourceVariable.read_value(self)
#     806 """Constructs an op which reads the value of this variable.
#     807
#     808 Should be used when there are multiple reads, or when it is desirable to
#    (...)
#     812   The value of the variable.
#     813 """
#     814 with ops.name_scope("Read"):
# --> 815   value = self._read_variable_op()
#     816 # Return an identity so it can get placed on whatever device the context
#     817 # specifies instead of the device where the variable is.
#     818 return array_ops.identity(value)
#
# File c:\Users\PC\Data\ads_fraud_detection\.conda\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:794, in BaseResourceVariable._read_variable_op(self, no_copy)
#     792       result = read_and_set_handle(no_copy)
#     793 else:
# --> 794   result = read_and_set_handle(no_copy)
#     796 if not context.executing_eagerly():
#     797   # Note that if a control flow context is active the input of the read op
#     798   # might not actually be the handle. This line bypasses it.
#     799   record.record_operation(
#     800       "ReadVariableOp", [result], [self.handle],
#     801       backward_function=lambda x: [x],
#     802       forward_function=lambda x: [x])
#
# File c:\Users\PC\Data\ads_fraud_detection\.conda\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:784, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle(no_copy)
#     782 if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     783   gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 784 result = gen_resource_variable_ops.read_variable_op(
#     785     self.handle, self._dtype)
#     786 _maybe_set_handle_data(self._dtype, self.handle, result)
#     787 return result
#
# File c:\Users\PC\Data\ads_fraud_detection\.conda\lib\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py:581, in read_variable_op(resource, dtype, name)
#     579 if tld.is_eager:
#     580   try:
# --> 581     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     582       _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     583     return _result
#     584   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
model.summary()
# Out:
# Model: "tab_net_classifier"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  tab_net_encoder (TabNetEnc  multiple                  26880
#  oder)
#
#  classifier (Dense)          multiple                  32
#
# =================================================================
# Total params: 26912 (105.12 KB)
# Trainable params: 24592 (96.06 KB)
# Non-trainable params: 2320 (9.06 KB)
# _________________________________________________________________

# %% [markdown]
# #### * Kết quả đánh giá mô hình:

# %%
model.summary()
# Out:
# Model: "tab_net_classifier"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  tab_net_encoder (TabNetEnc  multiple                  26880
#  oder)
#
#  classifier (Dense)          multiple                  32
#
# =================================================================
# Total params: 26912 (105.12 KB)
# Trainable params: 24592 (96.06 KB)
# Non-trainable params: 2320 (9.06 KB)
# _________________________________________________________________

# %%
history=model.history.history
fig,axes=plt.subplots(1,2, figsize=(15,8))
axes[0].plot(pd.DataFrame(history['val_accuracy']))
axes[0].set_title('Training Process')
axes[1].plot(pd.DataFrame(history))
axes[1].set_title('Training Process')
plt.show()
plt.savefig('train.png')

# %%
y_test_labels = np.argmax(y_test_onehot, axis=1)
predictions = model.predict(x_test)
predictions = np.argmax(predictions, axis=1)
accuracy = accuracy_score(y_test_labels, predictions)
accuracy
# Out:
# 160/160 [==============================] - 1s 1ms/step
# 0.9371192768716841

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import numpy as np

y_test_labels = np.argmax(y_test_onehot, axis=1)

accuracy = accuracy_score(y_test_labels, predictions)
print("Accuracy:", accuracy)
print("Classification Report:")
print(classification_report(y_test_labels, predictions))

print("Confusion Matrix:")
print(confusion_matrix(y_test_labels, predictions))
# Out:
# Accuracy: 0.9371192768716841
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      4782
#            1       0.29      0.03      0.05       307
#
#     accuracy                           0.94      5089
#    macro avg       0.62      0.51      0.51      5089
# weighted avg       0.90      0.94      0.91      5089
#
# Confusion Matrix:
# [[4760   22]
#  [ 298    9]]

# %%
# Dự đoán


# Tính ma trận nhầm lẫn
cm = confusion_matrix(y_test, predictions,labels=[1,0])
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='g', cmap='Blues', xticklabels=[1,0], yticklabels=[1,0])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 15))

fpr, tpr, _ = roc_curve(y_test, predictions)
    
roc_auc = auc(fpr, tpr)

ax.plot(fpr, tpr, lw=4, color='blue', label='ROC curve (AUC = %0.2f)' % roc_auc)
ax.plot([0, 1], [0, 1], color='red', lw=2, linestyle='--')
ax.set_xlim([0.0, 1.0])
ax.set_ylim([0.0, 1.05])
ax.set_xlabel('False Positive Rate', fontsize=12, weight='bold')  
ax.set_ylabel('True Positive Rate', fontsize=12, weight='bold')   
ax.set_title(f'ROC of Voting',fontsize=20, weight='bold')  
ax.legend(loc="lower right", prop={'size': 12, 'weight': 'bold'}) 
plt.show()

# %%
def check_result(prediction):
    prediction = (prediction > 0.2).astype(int)
    if isinstance(prediction, (np.ndarray, pd.Series)):
        prediction = prediction.item()  # Hoặc sử dụng prediction[0] hoặc prediction.iloc[0]
    if prediction==1:
        return "Y"
    else:
        return "N"

# %%
# solandung=0
# hopdonggianlan=0
# for indx in range(len(x_test)):
#     y_predict = stacked_model.predict(stacked_input)
#     stacked_pred_labels = y_predict.argmax(axis=1)

#     #print(y_predict[0][0])
#     Y_check = check_result(y_test.iloc[indx])
#     print('True:', Y_check)
#     print('Predicted:', check_result(stacked_pred_labels[indx]))
#     print("----------------------------")
#     if Y_check==check_result(stacked_pred_labels[indx]):
#         solandung+=1
#         if Y_check=='Y':
#             hopdonggianlan+=1

# %%
print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 print(f"Số lần dự đoán đúng: {solandung} chiếm khoảng {(solandung/len(x_test))*100}% tổng lần dự đoán")
#       2 print(f"Số hợp đồng gian lận trong lần kiểm tra: {hopdonggianlan} chiếm khoảng {(hopdonggianlan/len(y_test[y_test['fraud_reported']==1]))*100}% so với thực tế")
#
# NameError: name 'solandung' is not defined
