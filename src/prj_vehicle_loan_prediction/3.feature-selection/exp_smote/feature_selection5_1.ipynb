# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)
from libs.common import *
from config.config import *
# Out:
# c:\Users\Admin\Data\ads_fraud_detection
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# c:/Users/Admin/Data/ads_fraud_detection

# %% [markdown]
# # Lựa chọn đặc trưng

# %% [markdown]
# ### (1) Tạo thư mục lưu trữ (nếu chưa có)

# %%
save_dir=f"{exps_dir}/exp_prj_vehicle_loan_prediction/exp_smote"

save_dir = f"{save_dir}"
os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %%
x_train=pd.read_csv(f'{save_dir}/x_train.csv')
y_train=pd.read_csv(f'{save_dir}/y_train.csv')
x_test=pd.read_csv(f'{save_dir}/x_test.csv')
y_test=pd.read_csv(f'{save_dir}/y_test.csv')
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# (244730, 45) (244730, 1) (76941, 45) (76941, 1)

# %% [markdown]
# ### (2) Lựa chọn các đặc trưng

# %%
x_train
# Out:
#         UNIQUEID  DISBURSED_AMOUNT  ASSET_COST       LTV  EMPLOYMENT_TYPE  MOBILENO_AVL_FLAG  AADHAR_FLAG  PAN_FLAG  VOTERID_FLAG  DRIVING_FLAG  PASSPORT_FLAG  PERFORM_CNS_SCORE  PERFORM_CNS_SCORE_DESCRIPTION  PRI_NO_OF_ACCTS  PRI_ACTIVE_ACCTS  PRI_OVERDUE_ACCTS  PRI_CURRENT_BALANCE  PRI_SANCTIONED_AMOUNT  PRI_DISBURSED_AMOUNT  SEC_NO_OF_ACCTS  SEC_ACTIVE_ACCTS  SEC_OVERDUE_ACCTS  SEC_CURRENT_BALANCE  SEC_SANCTIONED_AMOUNT  SEC_DISBURSED_AMOUNT  PRIMARY_INSTAL_AMT  SEC_INSTAL_AMT  NEW_ACCTS_IN_LAST_SIX_MONTHS  DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS  AVERAGE_ACCT_AGE  CREDIT_HISTORY_LENGTH  NO_OF_INQUIRIES  DISBURSED_AMOUNT_new  DISBURSED_AMOUNT_bins  ASSET_COST_new  ASSET_COST_bins  LTV_new  LTV_bins  PERFORM_CNS_SCORE_bins  PRI_NO_OF_ACCTS_new  PRI_NO_OF_ACCTS_bins  PRI_OVERDUE_ACCTS_new  PRI_OVERDUE_ACCTS_bins       age  disbursal_time
# 0       0.845535         -0.042843   -0.151742  0.055274                2                  0            1         0             0             0              0          -0.854883                             13        -0.461680                 0                  0            -0.176955              -0.079264             -0.079019                0                 0                  0            -0.033943              -0.045345              -0.04472           -0.084976       -0.022927                             0                                    0         -0.589057              -0.568454                0              0.005415                      3        0.513786                1        0         3                       3                    0                     1                      0                       1  1.839794       -1.007492
# 1      -1.191835          0.028015   -0.680741  1.253429                2                  0            1         0             0             0              0          -0.854883                             13        -0.461680                 0                  0            -0.176955              -0.079264             -0.079019                0                 0                  0            -0.033943              -0.045345              -0.04472           -0.084976       -0.022927                             0                                    0         -0.589057              -0.568454                1              0.088563                      1       -0.540575                2        0         0                       3                    0                     1                      0                       1  2.069620        1.188236
# 2      -0.082136         -0.626317   -0.430638 -0.328694                2                  0            0         1             1             0              0          -0.854883                             13        -0.461680                 0                  0            -0.176955              -0.079264             -0.079019                0                 0                  0            -0.033943              -0.045345              -0.04472           -0.084976       -0.022927                             0                                    0         -0.589057              -0.568454                0             -0.679264                      2       -0.042089                3        0         3                       3                    0                     1                      0                       1 -0.480244        0.017181
# 3       1.042062          0.795720    0.890423 -0.135837                2                  0            1         0             0             0              0           1.127075                              5        -0.083744                 1                  1            -0.176106              -0.072046             -0.078636                0                 0                  0            -0.033943              -0.045345              -0.04472           -0.062714       -0.022927                             1                                    1          0.666672               0.693513                0              0.989427                      0        2.590948                0        0         3                       0                    0                     0                      0                       0  1.650181       -1.080682
# 4       1.355240         -2.128507   -0.231695 -3.236380                2                  0            1         0             0             0              0           1.457894                              1        -0.272712                 1                  0             1.391249               0.471082              0.471187                0                 0                  0            -0.033943              -0.045345              -0.04472           -0.084976       -0.022927                             0                                    0          2.120675               0.868786                0             -2.442010                      2        0.354429                1        0         2                       0                    0                     1                      0                       1  0.886981       -1.227064
# ...          ...               ...         ...       ...              ...                ...          ...       ...           ...           ...            ...                ...                            ...              ...               ...                ...                  ...                    ...                   ...              ...               ...                ...                  ...                    ...                   ...                 ...             ...                           ...                                  ...               ...                    ...              ...                   ...                    ...             ...              ...      ...       ...                     ...                  ...                   ...                    ...                     ...       ...             ...
# 244725  0.730013          0.293311   -0.331305  0.970167                2                  0            1         0             0             0              0           1.192599                              4         0.672128                 1                  0            -0.147365              -0.064635             -0.064394                0                 0                  0            -0.033943              -0.045345              -0.04472           -0.051093       -0.022927                             0                                    0          0.124327               0.300689                0              0.399875                      1        0.155894                3        0         0                       0                    0                     0                      0                       1  0.074867       -0.890717
# 244726 -1.421846         -0.090950   -0.400766  0.505772                2                  0            0         0             0             1              0          -0.854883                             13        -0.461680                 0                  0            -0.176955              -0.079264             -0.079019                0                 0                  0            -0.033943              -0.045345              -0.04472           -0.084976       -0.022927                             0                                    0         -0.589057              -0.568454                0             -0.051036                      3        0.017449                3        0         1                       3                    0                     1                      0                       1  0.768465        1.463741
# 244727 -1.285267         -0.074537    0.717922 -1.161035                2                  0            0         1             1             0              0           1.085723                              5        -0.246601                 1                  0             0.031092              -0.004154             -0.003929                0                 0                  0            -0.033943              -0.045345              -0.04472           -0.041221       -0.022927                             1                                    0         -0.317725              -0.380946                0             -0.031777                      3        2.247132                0        0         2                       0                    0                     0                      0                       1  2.013150        1.316788
# 244728  1.423591          1.540561    1.420279 -0.082880                2                  0            0         0             1             0              0          -0.854883                             13        -0.461680                 0                  0            -0.176955              -0.079264             -0.079019                0                 0                  0            -0.033943              -0.045345              -0.04472           -0.084976       -0.022927                             0                                    0         -0.589057              -0.568454                0              1.863463                      0       -1.424330                0        0         3                       3                    0                     1                      0                       1 -1.100505       -1.243598
# 244729 -0.470540          0.180147   -0.405351  0.894768                2                  0            1         0             0             0              0           1.581951                              0         0.140725                 0                  0            -0.159917              -0.070690             -0.070447                0                 0                  0            -0.033943              -0.045345              -0.04472           -0.055278       -0.022927                             0                                    0          0.788443               0.307912                0              0.267083                      1        0.008311                3        0         0                       0                    0                     0                      0                       1  0.156880        0.421951
#
# [244730 rows x 45 columns]

# %%
def modelcheck_info(model,name):
    print(name)
    try:
        coefficients = model.coef_.flatten()
    except:
        coefficients = model.feature_importances_.flatten()
    feature_importance = pd.DataFrame({
        'Feature': x_train.columns,
        'Coefficient': coefficients
    })

    print('bi loai bo',feature_importance[feature_importance['Coefficient'] == 0])
    feature_importance = feature_importance[feature_importance['Coefficient'] != 0]
    feature_importance['Absolute Coefficient'] = feature_importance['Coefficient'].abs()
    feature_importance.sort_values(by='Absolute Coefficient', ascending=False, inplace=True)

    print("Xếp hạng các đặc trưng theo mức độ quan trọng:")
    print(feature_importance[['Feature', 'Coefficient']])

# %%
models=[]
models.append(LogisticRegression())
models.append(LinearDiscriminantAnalysis())
models.append(DecisionTreeClassifier())
names=['LR','LDA','DTC']
feature_SelectFromModel={}
for model,name in zip(models,names):
    check = model.fit(x_train, y_train)
    selector = SelectFromModel(check, prefit=True)

    selected_features = x_train.columns[(selector.get_support())]
    modelcheck_info(model,name)
    print("Các đặc trưng được chọn:")
    feature_SelectFromModel[name]=list(selected_features)
    print(selected_features)
# Out:
# LR
# bi loai bo                   Feature  Coefficient
# 5       MOBILENO_AVL_FLAG          0.0
# 36                LTV_new          0.0
# 39    PRI_NO_OF_ACCTS_new          0.0
# 41  PRI_OVERDUE_ACCTS_new          0.0
# Xếp hạng các đặc trưng theo mức độ quan trọng:
#                                 Feature  Coefficient
# 9                          DRIVING_FLAG    -2.678834
# 6                           AADHAR_FLAG    -2.028653
# 8                          VOTERID_FLAG    -1.742194
# 0                              UNIQUEID     0.980764
# 44                       disbursal_time     0.899973
# 42               PRI_OVERDUE_ACCTS_bins    -0.765638
# 7                              PAN_FLAG    -0.715931
# 10                        PASSPORT_FLAG    -0.649033
# 3                                   LTV     0.460486
# 1                      DISBURSED_AMOUNT    -0.295922
# 2                            ASSET_COST     0.247016
# 40                 PRI_NO_OF_ACCTS_bins    -0.227932
# 30                CREDIT_HISTORY_LENGTH    -0.215366
# 15                    PRI_OVERDUE_ACCTS    -0.116196
# 43                                  age    -0.106543
# 21                    SEC_OVERDUE_ACCTS    -0.103443
# 28  DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS    -0.100561
# 27         NEW_ACCTS_IN_LAST_SIX_MONTHS    -0.093722
# 35                      ASSET_COST_bins    -0.086240
# 14                     PRI_ACTIVE_ACCTS    -0.075312
# 34                       ASSET_COST_new    -0.065869
# 33                DISBURSED_AMOUNT_bins    -0.063617
# 11                    PERFORM_CNS_SCORE     0.056502
# 19                      SEC_NO_OF_ACCTS    -0.056062
# 20                     SEC_ACTIVE_ACCTS     0.053159
# 37                             LTV_bins    -0.048117
# 29                     AVERAGE_ACCT_AGE     0.047965
# 16                  PRI_CURRENT_BALANCE    -0.046140
# 12        PERFORM_CNS_SCORE_DESCRIPTION     0.037713
# 18                 PRI_DISBURSED_AMOUNT     0.031766
# 31                      NO_OF_INQUIRIES     0.027081
# 32                 DISBURSED_AMOUNT_new     0.021196
# 13                      PRI_NO_OF_ACCTS     0.021022
# 4                       EMPLOYMENT_TYPE     0.019352
# 22                  SEC_CURRENT_BALANCE    -0.014901
# 26                       SEC_INSTAL_AMT     0.009302
# 17                PRI_SANCTIONED_AMOUNT    -0.007738
# 23                SEC_SANCTIONED_AMOUNT     0.005617
# 24                 SEC_DISBURSED_AMOUNT     0.004802
# 25                   PRIMARY_INSTAL_AMT    -0.001951
# 38               PERFORM_CNS_SCORE_bins     0.001404
# Các đặc trưng được chọn:
# Index(['UNIQUEID', 'DISBURSED_AMOUNT', 'LTV', 'AADHAR_FLAG', 'PAN_FLAG', 'VOTERID_FLAG', 'DRIVING_FLAG', 'PASSPORT_FLAG', 'PRI_OVERDUE_ACCTS_bins', 'disbursal_time'], dtype='object')
# LDA
# bi loai bo                   Feature  Coefficient
# 41  PRI_OVERDUE_ACCTS_new          0.0
# Xếp hạng các đặc trưng theo mức độ quan trọng:
#                                 Feature   Coefficient
# 10                        PASSPORT_FLAG -2.704691e+00
# 9                          DRIVING_FLAG -2.156599e+00
# 6                           AADHAR_FLAG -1.747579e+00
# 8                          VOTERID_FLAG -1.431575e+00
# 42               PRI_OVERDUE_ACCTS_bins -9.165636e-01
# 0                              UNIQUEID  9.059588e-01
# 44                       disbursal_time  8.288162e-01
# 7                              PAN_FLAG -6.964077e-01
# 18                 PRI_DISBURSED_AMOUNT  5.976109e-01
# 17                PRI_SANCTIONED_AMOUNT -5.859258e-01
# 3                                   LTV  4.065112e-01
# 40                 PRI_NO_OF_ACCTS_bins -2.831271e-01
# 30                CREDIT_HISTORY_LENGTH -2.160024e-01
# 1                      DISBURSED_AMOUNT -1.964303e-01
# 11                    PERFORM_CNS_SCORE -1.942294e-01
# 2                            ASSET_COST  1.598858e-01
# 15                    PRI_OVERDUE_ACCTS -1.440169e-01
# 43                                  age -1.133883e-01
# 35                      ASSET_COST_bins -1.010730e-01
# 27         NEW_ACCTS_IN_LAST_SIX_MONTHS -8.288686e-02
# 33                DISBURSED_AMOUNT_bins -7.159208e-02
# 37                             LTV_bins -6.892655e-02
# 29                     AVERAGE_ACCT_AGE  6.821581e-02
# 34                       ASSET_COST_new -6.714295e-02
# 28  DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS -6.576461e-02
# 14                     PRI_ACTIVE_ACCTS -6.342524e-02
# 21                    SEC_OVERDUE_ACCTS -5.728927e-02
# 38               PERFORM_CNS_SCORE_bins  3.914057e-02
# 19                      SEC_NO_OF_ACCTS -2.865901e-02
# 31                      NO_OF_INQUIRIES  2.518396e-02
# 16                  PRI_CURRENT_BALANCE -2.464809e-02
# 20                     SEC_ACTIVE_ACCTS  2.166577e-02
# 23                SEC_SANCTIONED_AMOUNT  1.676014e-02
# 13                      PRI_NO_OF_ACCTS  1.523763e-02
# 32                 DISBURSED_AMOUNT_new -1.462710e-02
# 12        PERFORM_CNS_SCORE_DESCRIPTION -1.401916e-02
# 4                       EMPLOYMENT_TYPE -9.703797e-03
# 22                  SEC_CURRENT_BALANCE -9.275632e-03
# 26                       SEC_INSTAL_AMT  7.507950e-03
# 24                 SEC_DISBURSED_AMOUNT -7.332741e-03
# 25                   PRIMARY_INSTAL_AMT  1.737352e-03
# 36                              LTV_new -2.439749e-15
# 5                     MOBILENO_AVL_FLAG -1.448906e-15
# 39                  PRI_NO_OF_ACCTS_new  5.763422e-16
# Các đặc trưng được chọn:
# Index(['UNIQUEID', 'LTV', 'AADHAR_FLAG', 'PAN_FLAG', 'VOTERID_FLAG', 'DRIVING_FLAG', 'PASSPORT_FLAG', 'PRI_SANCTIONED_AMOUNT', 'PRI_DISBURSED_AMOUNT', 'PRI_OVERDUE_ACCTS_bins', 'disbursal_time'], dtype='object')
# DTC
# bi loai bo                   Feature  Coefficient
# 5       MOBILENO_AVL_FLAG          0.0
# 36                LTV_new          0.0
# 39    PRI_NO_OF_ACCTS_new          0.0
# 41  PRI_OVERDUE_ACCTS_new          0.0
# Xếp hạng các đặc trưng theo mức độ quan trọng:
#                                 Feature  Coefficient
# 44                       disbursal_time     0.146078
# 3                                   LTV     0.109978
# 43                                  age     0.106600
# 0                              UNIQUEID     0.083740
# 2                            ASSET_COST     0.058328
# 1                      DISBURSED_AMOUNT     0.054399
# 34                       ASSET_COST_new     0.050438
# 32                 DISBURSED_AMOUNT_new     0.049893
# 13                      PRI_NO_OF_ACCTS     0.043836
# 25                   PRIMARY_INSTAL_AMT     0.043142
# 11                    PERFORM_CNS_SCORE     0.037500
# 29                     AVERAGE_ACCT_AGE     0.027932
# 30                CREDIT_HISTORY_LENGTH     0.026820
# 16                  PRI_CURRENT_BALANCE     0.020002
# 17                PRI_SANCTIONED_AMOUNT     0.017451
# 4                       EMPLOYMENT_TYPE     0.014341
# 18                 PRI_DISBURSED_AMOUNT     0.012860
# 31                      NO_OF_INQUIRIES     0.010544
# 7                              PAN_FLAG     0.008474
# 14                     PRI_ACTIVE_ACCTS     0.007425
# 12        PERFORM_CNS_SCORE_DESCRIPTION     0.007288
# 8                          VOTERID_FLAG     0.007219
# 37                             LTV_bins     0.007038
# 6                           AADHAR_FLAG     0.006954
# 9                          DRIVING_FLAG     0.006906
# 27         NEW_ACCTS_IN_LAST_SIX_MONTHS     0.005520
# 35                      ASSET_COST_bins     0.005387
# 15                    PRI_OVERDUE_ACCTS     0.004043
# 33                DISBURSED_AMOUNT_bins     0.003526
# 38               PERFORM_CNS_SCORE_bins     0.003523
# 42               PRI_OVERDUE_ACCTS_bins     0.003187
# 28  DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS     0.002798
# 40                 PRI_NO_OF_ACCTS_bins     0.002169
# 10                        PASSPORT_FLAG     0.001080
# 19                      SEC_NO_OF_ACCTS     0.000873
# 26                       SEC_INSTAL_AMT     0.000662
# 24                 SEC_DISBURSED_AMOUNT     0.000544
# 23                SEC_SANCTIONED_AMOUNT     0.000479
# 22                  SEC_CURRENT_BALANCE     0.000432
# 20                     SEC_ACTIVE_ACCTS     0.000432
# 21                    SEC_OVERDUE_ACCTS     0.000158
# Các đặc trưng được chọn:
# Index(['UNIQUEID', 'DISBURSED_AMOUNT', 'ASSET_COST', 'LTV', 'PERFORM_CNS_SCORE', 'PRI_NO_OF_ACCTS', 'PRIMARY_INSTAL_AMT', 'AVERAGE_ACCT_AGE', 'CREDIT_HISTORY_LENGTH', 'DISBURSED_AMOUNT_new', 'ASSET_COST_new', 'age', 'disbursal_time'], dtype='object')

# %% [markdown]
# ### Giải thích:
#
# Phương pháp **SelectFromModel** từ thư viện sklearn.feature_selection. Phương pháp này hoạt động bằng cách sử dụng một mô hình học máy để đánh giá độ quan trọng của từng đặc trưng và sau đó chọn những đặc trưng quan trọng nhất.
#
#    Các model được dùng trong phương pháp này:
#    * **'LR'**: LogisticRegression
#    * **'LDA'**: LinearDiscriminantAnalysis
#    * **'DTC'**: DecisionTreeClassifier
#
#        #### 1. LogisticRegression:
#        Các đặc trưng được chọn:
# * Index(['age', 'policy_csl', 'insured_education_level', 'insured_occupation',
#        'incident_severity', 'incident_state', 'incident_city',
#        'incident_hour_of_the_day', 'property_damage', 'witnesses',
#        'property_claim', 'vehicle_claim', 'auto_make'],
#       dtype='object')
#
#    #### 2. LinearDiscriminantAnalysis:
#    Các đặc trưng được chọn:
# * Index(['policy_number', 'policy_annual_premium', 'insured_zip', 'insured_sex',
#        'incident_severity', 'incident_hour_of_the_day', 'property_damage',
#        'total_claim_amount', 'injury_claim', 'property_claim',
#        'vehicle_claim'],
#       dtype='object')
#
#    #### 3. DecisionTreeClassifier:
#    Các đặc trưng được chọn:
# * Index(['policy_number', 'policy_annual_premium', 'insured_zip',
#        'insured_occupation', 'insured_hobbies', 'incident_severity',
#        'incident_location', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'month_policy_bind_date', 'day_incident_date'],
#       dtype='object')

# %%
def feature_selection_inRFE(model,name):
    rfe=RFE(estimator=model, n_features_to_select=10)
    fit=rfe.fit(x_train, y_train)
#     print("Num Features: %d"% fit.n_features_)
#     print("Selected Features: %s" % fit.support_)
#     print("Features Ranking: %s" %fit.ranking_)
#     for index, value in enumerate(fit.ranking_):
#         print(f"{value}: {x_train.columns[index]}")
    sorted_columns = [x for _, x in sorted(zip(fit.ranking_, x_train.columns))]
    sort=sorted(fit.ranking_)

#     for i,j in zip(sort,sorted_columns):
#         print("Columns sorted by RFE ranking",i,":",j)

    return [j for i,j in zip(sort,sorted_columns) if i==1]

# %%
models = [
    LogisticRegression(),
    LinearDiscriminantAnalysis(),
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    LGBMClassifier(),  
    XGBClassifier(use_label_encoder=False)  
]
feature_RFE={}

names = ['LR', 'LDA', 'DTC', 'RD', 'LGBM', 'XGB']
for model,name in zip(models,names):
    print("RFE")
    print(f"Kiểm tra mô hình {name}")
    model.fit(x_train,y_train)
    print(feature_selection_inRFE(model,name))
    feature_RFE[name]=feature_selection_inRFE(model,name)
# Out:
# RFE
# Kiểm tra mô hình LR
# ['AADHAR_FLAG', 'DRIVING_FLAG', 'PAN_FLAG', 'PASSPORT_FLAG', 'PRI_DISBURSED_AMOUNT', 'PRI_OVERDUE_ACCTS_bins', 'PRI_SANCTIONED_AMOUNT', 'UNIQUEID', 'VOTERID_FLAG', 'disbursal_time']
# RFE
# Kiểm tra mô hình LDA
# ['AADHAR_FLAG', 'DRIVING_FLAG', 'PAN_FLAG', 'PASSPORT_FLAG', 'PRI_DISBURSED_AMOUNT', 'PRI_OVERDUE_ACCTS_bins', 'PRI_SANCTIONED_AMOUNT', 'UNIQUEID', 'VOTERID_FLAG', 'disbursal_time']
# RFE
# Kiểm tra mô hình DTC
# ['ASSET_COST', 'ASSET_COST_new', 'CREDIT_HISTORY_LENGTH', 'DISBURSED_AMOUNT', 'DISBURSED_AMOUNT_new', 'LTV', 'PRI_NO_OF_ACCTS', 'UNIQUEID', 'age', 'disbursal_time']
# RFE
# Kiểm tra mô hình RD
# ['ASSET_COST', 'ASSET_COST_new', 'DISBURSED_AMOUNT', 'DISBURSED_AMOUNT_new', 'LTV', 'PERFORM_CNS_SCORE', 'PRI_NO_OF_ACCTS', 'UNIQUEID', 'age', 'disbursal_time']
# RFE
# Kiểm tra mô hình LGBM
# [LightGBM] [Info] Number of positive: 122365, number of negative: 122365
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 1.874511 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5302
# [LightGBM] [Info] Number of data points in the train set: 244730, number of used features: 41
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 122365, number of negative: 122365
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.422750 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5302
# [LightGBM] [Info] Number of data points in the train set: 244730, number of used features: 41
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 122365, number of negative: 122365
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.236747 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5047
# [LightGBM] [Info] Number of data points in the train set: 244730, number of used features: 40
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 122365, number of negative: 122365
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.232026 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5039
# [LightGBM] [Info] Number of data points in the train set: 244730, number of used features: 39
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 16
#      14 print(f"Kiểm tra mô hình {name}")
#      15 model.fit(x_train,y_train)
# ---> 16 print(feature_selection_inRFE(model,name))
#      17 feature_RFE[name]=feature_selection_inRFE(model,name)
#
# Cell In[7], line 3, in feature_selection_inRFE(model, name)
#       1 def feature_selection_inRFE(model,name):
#       2     rfe=RFE(estimator=model, n_features_to_select=10)
# ----> 3     fit=rfe.fit(x_train, y_train)
#       4 #     print("Num Features: %d"% fit.n_features_)
#       5 #     print("Selected Features: %s" % fit.support_)
#       6 #     print("Features Ranking: %s" %fit.ranking_)
#       7 #     for index, value in enumerate(fit.ranking_):
#       8 #         print(f"{value}: {x_train.columns[index]}")
#       9     sorted_columns = [x for _, x in sorted(zip(fit.ranking_, x_train.columns))]
#
# File c:\Users\Admin\Data\ads_fraud_detection\.conda\lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Admin\Data\ads_fraud_detection\.conda\lib\site-packages\sklearn\feature_selection\_rfe.py:249, in RFE.fit(self, X, y, **fit_params)
#     225 @_fit_context(
#     226     # RFE.estimator is not validated yet
#     227     prefer_skip_nested_validation=False
#     228 )
#     229 def fit(self, X, y, **fit_params):
#     230     """Fit the RFE model and then the underlying estimator on the selected features.
#     231
#     232     Parameters
#    (...)
#     247         Fitted estimator.
#     248     """
# --> 249     return self._fit(X, y, **fit_params)
#
# File c:\Users\Admin\Data\ads_fraud_detection\.conda\lib\site-packages\sklearn\feature_selection\_rfe.py:297, in RFE._fit(self, X, y, step_score, **fit_params)
#     294 if self.verbose > 0:
#     295     print("Fitting estimator with %d features." % np.sum(support_))
# --> 297 estimator.fit(X[:, features], y, **fit_params)
#     299 # Get importance and rank them
#     300 importances = _get_feature_importances(
#     301     estimator,
#     302     self.importance_getter,
#     303     transform_func="square",
#     304 )
#
# File c:\Users\Admin\Data\ads_fraud_detection\.conda\lib\site-packages\lightgbm\sklearn.py:1284, in LGBMClassifier.fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1281         else:
#    1282             valid_sets.append((valid_x, self._le.transform(valid_y)))
# -> 1284 super().fit(
#    1285     X,
#    1286     _y,
#    1287     sample_weight=sample_weight,
#    1288     init_score=init_score,
#    1289     eval_set=valid_sets,
#    1290     eval_names=eval_names,
#    1291     eval_sample_weight=eval_sample_weight,
#    1292     eval_class_weight=eval_class_weight,
#    1293     eval_init_score=eval_init_score,
#    1294     eval_metric=eval_metric,
#    1295     feature_name=feature_name,
#    1296     categorical_feature=categorical_feature,
#    1297     callbacks=callbacks,
#    1298     init_model=init_model,
#    1299 )
#    1300 return self
#
# File c:\Users\Admin\Data\ads_fraud_detection\.conda\lib\site-packages\lightgbm\sklearn.py:955, in LGBMModel.fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#     952 evals_result: _EvalResultDict = {}
#     953 callbacks.append(record_evaluation(evals_result))
# --> 955 self._Booster = train(
#     956     params=params,
#     957     train_set=train_set,
#     958     num_boost_round=self.n_estimators,
#     959     valid_sets=valid_sets,
#     960     valid_names=eval_names,
#     961     feval=eval_metrics_callable,  # type: ignore[arg-type]
#     962     init_model=init_model,
#     963     callbacks=callbacks,
#     964 )
#     966 self._evals_result = evals_result
#     967 self._best_iteration = self._Booster.best_iteration
#
# File c:\Users\Admin\Data\ads_fraud_detection\.conda\lib\site-packages\lightgbm\engine.py:307, in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, feature_name, categorical_feature, keep_training_booster, callbacks)
#     295 for cb in callbacks_before_iter:
#     296     cb(
#     297         callback.CallbackEnv(
#     298             model=booster,
#    (...)
#     304         )
#     305     )
# --> 307 booster.update(fobj=fobj)
#     309 evaluation_result_list: List[_LGBM_BoosterEvalMethodResultType] = []
#     310 # check evaluation result.
#
# File c:\Users\Admin\Data\ads_fraud_detection\.conda\lib\site-packages\lightgbm\basic.py:4136, in Booster.update(self, train_set, fobj)
#    4133 if self.__set_objective_to_none:
#    4134     raise LightGBMError("Cannot update due to null objective function.")
#    4135 _safe_call(
# -> 4136     _LIB.LGBM_BoosterUpdateOneIter(
#    4137         self._handle,
#    4138         ctypes.byref(is_finished),
#    4139     )
#    4140 )
#    4141 self.__is_predicted_cur_iter = [False for _ in range(self.__num_dataset)]
#    4142 return is_finished.value == 1
#
# KeyboardInterrupt:

# %% [markdown]
# ### Giải thích:
# **Recursive Feature Elimination (RFE)** là một phương pháp trong lựa chọn đặc trưng (feature selection) được sử dụng trong học máy để giảm số lượng đặc trưng của mô hình mà vẫn giữ được hiệu suất tốt.
#
# Các model được dùng trong phương pháp này:
#    * **'LR'**: LogisticRegression
#    * **'LDA'**: LinearDiscriminantAnalysis
#    * **'DTC'**: DecisionTreeClassifier
#    * **'RD'**: RandomForestClassifier

# %%
special_models=[KNeighborsClassifier(),GaussianNB(),MLPClassifier(),GradientBoostingClassifier(),MultinomialNB(),SVC()]
names=['KNC','GNB','NN','BG','NB','SVM']
def feature_selection_inKBest(model, name):
    k_best = SelectKBest(score_func=f_classif, k=11)
    fit = k_best.fit(x_train, y_train)
    selected_features = fit.get_support()
    selected_column_names = x_train.columns[selected_features]
    return selected_column_names
feature_Kbest={}
for model,name in zip(special_models,names):
    print(f'Lua chon dac trung {name}')
    print(feature_selection_inKBest(model, name))
    feature_Kbest[name]=list(feature_selection_inKBest(model, name))
# Out:
# Lua chon dac trung KNC
# Index(['DISBURSED_AMOUNT', 'LTV', 'VOTERID_FLAG', 'PERFORM_CNS_SCORE', 'PERFORM_CNS_SCORE_DESCRIPTION', 'PRI_OVERDUE_ACCTS', 'DISBURSED_AMOUNT_new', 'DISBURSED_AMOUNT_bins', 'LTV_bins', 'PERFORM_CNS_SCORE_bins', 'PRI_OVERDUE_ACCTS_bins'], dtype='object')
# Lua chon dac trung GNB
# Index(['DISBURSED_AMOUNT', 'LTV', 'VOTERID_FLAG', 'PERFORM_CNS_SCORE', 'PERFORM_CNS_SCORE_DESCRIPTION', 'PRI_OVERDUE_ACCTS', 'DISBURSED_AMOUNT_new', 'DISBURSED_AMOUNT_bins', 'LTV_bins', 'PERFORM_CNS_SCORE_bins', 'PRI_OVERDUE_ACCTS_bins'], dtype='object')
# Lua chon dac trung NN
# Index(['DISBURSED_AMOUNT', 'LTV', 'VOTERID_FLAG', 'PERFORM_CNS_SCORE', 'PERFORM_CNS_SCORE_DESCRIPTION', 'PRI_OVERDUE_ACCTS', 'DISBURSED_AMOUNT_new', 'DISBURSED_AMOUNT_bins', 'LTV_bins', 'PERFORM_CNS_SCORE_bins', 'PRI_OVERDUE_ACCTS_bins'], dtype='object')
# Lua chon dac trung BG
# Index(['DISBURSED_AMOUNT', 'LTV', 'VOTERID_FLAG', 'PERFORM_CNS_SCORE', 'PERFORM_CNS_SCORE_DESCRIPTION', 'PRI_OVERDUE_ACCTS', 'DISBURSED_AMOUNT_new', 'DISBURSED_AMOUNT_bins', 'LTV_bins', 'PERFORM_CNS_SCORE_bins', 'PRI_OVERDUE_ACCTS_bins'], dtype='object')
# Lua chon dac trung NB
# Index(['DISBURSED_AMOUNT', 'LTV', 'VOTERID_FLAG', 'PERFORM_CNS_SCORE', 'PERFORM_CNS_SCORE_DESCRIPTION', 'PRI_OVERDUE_ACCTS', 'DISBURSED_AMOUNT_new', 'DISBURSED_AMOUNT_bins', 'LTV_bins', 'PERFORM_CNS_SCORE_bins', 'PRI_OVERDUE_ACCTS_bins'], dtype='object')
# Lua chon dac trung SVM
# Index(['DISBURSED_AMOUNT', 'LTV', 'VOTERID_FLAG', 'PERFORM_CNS_SCORE', 'PERFORM_CNS_SCORE_DESCRIPTION', 'PRI_OVERDUE_ACCTS', 'DISBURSED_AMOUNT_new', 'DISBURSED_AMOUNT_bins', 'LTV_bins', 'PERFORM_CNS_SCORE_bins', 'PRI_OVERDUE_ACCTS_bins'], dtype='object')

# %% [markdown]
# ### Giải thích:
# Phương pháp **SelectKBest** từ thư viện sklearn.feature_selection để lựa chọn đặc trưng dựa trên kỹ thuật kiểm định thống kê.
#
# Các model được dùng trong phương pháp này:
#    * **'KNC'**: KNeighborsClassifier
#    * **'GNB'**: GaussianNB
#    * **'NN'**: MLPClassifier
#    * **'BG'**: GradientBoostingClassifier
#    * **'NB'**: MultinomialNB
#    * **'SVM'**: SVC

# %%
print(feature_Kbest)
print(feature_SelectFromModel)
print(feature_RFE)
# Out:
# {'KNC': ['DISBURSED_AMOUNT', 'LTV', 'VOTERID_FLAG', 'PERFORM_CNS_SCORE', 'PERFORM_CNS_SCORE_DESCRIPTION', 'PRI_OVERDUE_ACCTS', 'DISBURSED_AMOUNT_new', 'DISBURSED_AMOUNT_bins', 'LTV_bins', 'PERFORM_CNS_SCORE_bins', 'PRI_OVERDUE_ACCTS_bins'], 'GNB': ['DISBURSED_AMOUNT', 'LTV', 'VOTERID_FLAG', 'PERFORM_CNS_SCORE', 'PERFORM_CNS_SCORE_DESCRIPTION', 'PRI_OVERDUE_ACCTS', 'DISBURSED_AMOUNT_new', 'DISBURSED_AMOUNT_bins', 'LTV_bins', 'PERFORM_CNS_SCORE_bins', 'PRI_OVERDUE_ACCTS_bins'], 'NN': ['DISBURSED_AMOUNT', 'LTV', 'VOTERID_FLAG', 'PERFORM_CNS_SCORE', 'PERFORM_CNS_SCORE_DESCRIPTION', 'PRI_OVERDUE_ACCTS', 'DISBURSED_AMOUNT_new', 'DISBURSED_AMOUNT_bins', 'LTV_bins', 'PERFORM_CNS_SCORE_bins', 'PRI_OVERDUE_ACCTS_bins'], 'BG': ['DISBURSED_AMOUNT', 'LTV', 'VOTERID_FLAG', 'PERFORM_CNS_SCORE', 'PERFORM_CNS_SCORE_DESCRIPTION', 'PRI_OVERDUE_ACCTS', 'DISBURSED_AMOUNT_new', 'DISBURSED_AMOUNT_bins', 'LTV_bins', 'PERFORM_CNS_SCORE_bins', 'PRI_OVERDUE_ACCTS_bins'], 'NB': ['DISBURSED_AMOUNT', 'LTV', 'VOTERID_FLAG', 'PERFORM_CNS_SCORE', 'PERFORM_CNS_SCORE_DESCRIPTION', 'PRI_OVERDUE_ACCTS', 'DISBURSED_AMOUNT_new', 'DISBURSED_AMOUNT_bins', 'LTV_bins', 'PERFORM_CNS_SCORE_bins', 'PRI_OVERDUE_ACCTS_bins'], 'SVM': ['DISBURSED_AMOUNT', 'LTV', 'VOTERID_FLAG', 'PERFORM_CNS_SCORE', 'PERFORM_CNS_SCORE_DESCRIPTION', 'PRI_OVERDUE_ACCTS', 'DISBURSED_AMOUNT_new', 'DISBURSED_AMOUNT_bins', 'LTV_bins', 'PERFORM_CNS_SCORE_bins', 'PRI_OVERDUE_ACCTS_bins']}
# {'LR': ['UNIQUEID', 'DISBURSED_AMOUNT', 'ASSET_COST', 'LTV', 'EMPLOYMENT_TYPE', 'AADHAR_FLAG', 'DRIVING_FLAG', 'PASSPORT_FLAG', 'DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS', 'CREDIT_HISTORY_LENGTH', 'NO_OF_INQUIRIES', 'PRI_OVERDUE_ACCTS_bins', 'disbursal_time'], 'LDA': ['UNIQUEID', 'DISBURSED_AMOUNT', 'ASSET_COST', 'LTV', 'AADHAR_FLAG', 'DRIVING_FLAG', 'PASSPORT_FLAG', 'SEC_SANCTIONED_AMOUNT', 'SEC_DISBURSED_AMOUNT', 'DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS', 'NO_OF_INQUIRIES', 'PRI_OVERDUE_ACCTS_bins', 'disbursal_time'], 'DTC': ['UNIQUEID', 'DISBURSED_AMOUNT', 'ASSET_COST', 'LTV', 'PERFORM_CNS_SCORE', 'PRI_CURRENT_BALANCE', 'PRIMARY_INSTAL_AMT', 'AVERAGE_ACCT_AGE', 'CREDIT_HISTORY_LENGTH', 'DISBURSED_AMOUNT_new', 'ASSET_COST_new', 'age', 'disbursal_time']}
# {'LR': ['AADHAR_FLAG', 'ASSET_COST', 'CREDIT_HISTORY_LENGTH', 'DISBURSED_AMOUNT', 'DRIVING_FLAG', 'LTV', 'PASSPORT_FLAG', 'PRI_OVERDUE_ACCTS_bins', 'UNIQUEID', 'disbursal_time'], 'LDA': ['AADHAR_FLAG', 'ASSET_COST', 'DISBURSED_AMOUNT', 'DRIVING_FLAG', 'LTV', 'PASSPORT_FLAG', 'PERFORM_CNS_SCORE', 'PRI_OVERDUE_ACCTS_bins', 'UNIQUEID', 'disbursal_time'], 'DTC': ['ASSET_COST', 'ASSET_COST_new', 'CREDIT_HISTORY_LENGTH', 'DISBURSED_AMOUNT', 'DISBURSED_AMOUNT_new', 'LTV', 'PERFORM_CNS_SCORE', 'PRI_SANCTIONED_AMOUNT', 'UNIQUEID', 'age'], 'RD': ['ASSET_COST', 'ASSET_COST_new', 'DISBURSED_AMOUNT', 'DISBURSED_AMOUNT_new', 'LTV', 'PERFORM_CNS_SCORE', 'PRI_CURRENT_BALANCE', 'UNIQUEID', 'age', 'disbursal_time'], 'LGBM': ['ASSET_COST', 'AVERAGE_ACCT_AGE', 'CREDIT_HISTORY_LENGTH', 'DISBURSED_AMOUNT', 'LTV', 'PERFORM_CNS_SCORE', 'PRIMARY_INSTAL_AMT', 'PRI_SANCTIONED_AMOUNT', 'UNIQUEID', 'age'], 'XGB': ['AADHAR_FLAG', 'DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS', 'EMPLOYMENT_TYPE', 'LTV', 'NO_OF_INQUIRIES', 'PAN_FLAG', 'PERFORM_CNS_SCORE', 'PRI_OVERDUE_ACCTS', 'PRI_SANCTIONED_AMOUNT', 'VOTERID_FLAG']}

# %%
feature_model_selection={**feature_RFE,**feature_Kbest}
np.savez(f'{save_dir}/feature_model_selection.npz', feature_model_selection = feature_model_selection)
feature_model_selection
# Out:
# {'LR': ['AADHAR_FLAG',
#   'ASSET_COST',
#   'CREDIT_HISTORY_LENGTH',
#   'DISBURSED_AMOUNT',
#   'DRIVING_FLAG',
#   'LTV',
#   'PASSPORT_FLAG',
#   'PRI_OVERDUE_ACCTS_bins',
#   'UNIQUEID',
#   'disbursal_time'],
#  'LDA': ['AADHAR_FLAG',
#   'ASSET_COST',
#   'DISBURSED_AMOUNT',
#   'DRIVING_FLAG',
#   'LTV',
#   'PASSPORT_FLAG',
#   'PERFORM_CNS_SCORE',
#   'PRI_OVERDUE_ACCTS_bins',
#   'UNIQUEID',
#   'disbursal_time'],
#  'DTC': ['ASSET_COST',
#   'ASSET_COST_new',
#   'CREDIT_HISTORY_LENGTH',
#   'DISBURSED_AMOUNT',
#   'DISBURSED_AMOUNT_new',
#   'LTV',
#   'PERFORM_CNS_SCORE',
#   'PRI_SANCTIONED_AMOUNT',
#   'UNIQUEID',
#   'age'],
#  'RD': ['ASSET_COST',
#   'ASSET_COST_new',
#   'DISBURSED_AMOUNT',
#   'DISBURSED_AMOUNT_new',
#   'LTV',
#   'PERFORM_CNS_SCORE',
#   'PRI_CURRENT_BALANCE',
#   'UNIQUEID',
#   'age',
#   'disbursal_time'],
#  'LGBM': ['ASSET_COST',
#   'AVERAGE_ACCT_AGE',
#   'CREDIT_HISTORY_LENGTH',
#   'DISBURSED_AMOUNT',
#   'LTV',
#   'PERFORM_CNS_SCORE',
#   'PRIMARY_INSTAL_AMT',
#   'PRI_SANCTIONED_AMOUNT',
#   'UNIQUEID',
#   'age'],
#  'XGB': ['AADHAR_FLAG',
#   'DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS',
#   'EMPLOYMENT_TYPE',
#   'LTV',
#   'NO_OF_INQUIRIES',
#   'PAN_FLAG',
#   'PERFORM_CNS_SCORE',
#   'PRI_OVERDUE_ACCTS',
#   'PRI_SANCTIONED_AMOUNT',
#   'VOTERID_FLAG'],
#  'KNC': ['DISBURSED_AMOUNT',
#   'LTV',
#   'VOTERID_FLAG',
#   'PERFORM_CNS_SCORE',
#   'PERFORM_CNS_SCORE_DESCRIPTION',
#   'PRI_OVERDUE_ACCTS',
#   'DISBURSED_AMOUNT_new',
#   'DISBURSED_AMOUNT_bins',
#   'LTV_bins',
#   'PERFORM_CNS_SCORE_bins',
#   'PRI_OVERDUE_ACCTS_bins'],
#  'GNB': ['DISBURSED_AMOUNT',
#   'LTV',
#   'VOTERID_FLAG',
#   'PERFORM_CNS_SCORE',
#   'PERFORM_CNS_SCORE_DESCRIPTION',
#   'PRI_OVERDUE_ACCTS',
#   'DISBURSED_AMOUNT_new',
#   'DISBURSED_AMOUNT_bins',
#   'LTV_bins',
#   'PERFORM_CNS_SCORE_bins',
#   'PRI_OVERDUE_ACCTS_bins'],
#  'NN': ['DISBURSED_AMOUNT',
#   'LTV',
#   'VOTERID_FLAG',
#   'PERFORM_CNS_SCORE',
#   'PERFORM_CNS_SCORE_DESCRIPTION',
#   'PRI_OVERDUE_ACCTS',
#   'DISBURSED_AMOUNT_new',
#   'DISBURSED_AMOUNT_bins',
#   'LTV_bins',
#   'PERFORM_CNS_SCORE_bins',
#   'PRI_OVERDUE_ACCTS_bins'],
#  'BG': ['DISBURSED_AMOUNT',
#   'LTV',
#   'VOTERID_FLAG',
#   'PERFORM_CNS_SCORE',
#   'PERFORM_CNS_SCORE_DESCRIPTION',
#   'PRI_OVERDUE_ACCTS',
#   'DISBURSED_AMOUNT_new',
#   'DISBURSED_AMOUNT_bins',
#   'LTV_bins',
#   'PERFORM_CNS_SCORE_bins',
#   'PRI_OVERDUE_ACCTS_bins'],
#  'NB': ['DISBURSED_AMOUNT',
#   'LTV',
#   'VOTERID_FLAG',
#   'PERFORM_CNS_SCORE',
#   'PERFORM_CNS_SCORE_DESCRIPTION',
#   'PRI_OVERDUE_ACCTS',
#   'DISBURSED_AMOUNT_new',
#   'DISBURSED_AMOUNT_bins',
#   'LTV_bins',
#   'PERFORM_CNS_SCORE_bins',
#   'PRI_OVERDUE_ACCTS_bins'],
#  'SVM': ['DISBURSED_AMOUNT',
#   'LTV',
#   'VOTERID_FLAG',
#   'PERFORM_CNS_SCORE',
#   'PERFORM_CNS_SCORE_DESCRIPTION',
#   'PRI_OVERDUE_ACCTS',
#   'DISBURSED_AMOUNT_new',
#   'DISBURSED_AMOUNT_bins',
#   'LTV_bins',
#   'PERFORM_CNS_SCORE_bins',
#   'PRI_OVERDUE_ACCTS_bins']}

# %% [markdown]
# * gom nhóm thông tin về các đặc trưng được chọn từ hai phương pháp lựa chọn đặc trưng khác nhau (RFE và SelectKBest) vào từ điển **feature_model_selection**.

# %%
dict(np.load(f'{save_dir}/feature_model_selection.npz',allow_pickle=True))['feature_model_selection']
# Out:
# array({'LR': ['AADHAR_FLAG', 'ASSET_COST', 'CREDIT_HISTORY_LENGTH', 'DISBURSED_AMOUNT', 'DRIVING_FLAG', 'LTV', 'PASSPORT_FLAG', 'PRI_OVERDUE_ACCTS_bins', 'UNIQUEID', 'disbursal_time'], 'LDA': ['AADHAR_FLAG', 'ASSET_COST', 'DISBURSED_AMOUNT', 'DRIVING_FLAG', 'LTV', 'PASSPORT_FLAG', 'PERFORM_CNS_SCORE', 'PRI_OVERDUE_ACCTS_bins', 'UNIQUEID', 'disbursal_time'], 'DTC': ['ASSET_COST', 'ASSET_COST_new', 'CREDIT_HISTORY_LENGTH', 'DISBURSED_AMOUNT', 'DISBURSED_AMOUNT_new', 'LTV', 'PERFORM_CNS_SCORE', 'PRI_SANCTIONED_AMOUNT', 'UNIQUEID', 'age'], 'RD': ['ASSET_COST', 'ASSET_COST_new', 'DISBURSED_AMOUNT', 'DISBURSED_AMOUNT_new', 'LTV', 'PERFORM_CNS_SCORE', 'PRI_CURRENT_BALANCE', 'UNIQUEID', 'age', 'disbursal_time'], 'LGBM': ['ASSET_COST', 'AVERAGE_ACCT_AGE', 'CREDIT_HISTORY_LENGTH', 'DISBURSED_AMOUNT', 'LTV', 'PERFORM_CNS_SCORE', 'PRIMARY_INSTAL_AMT', 'PRI_SANCTIONED_AMOUNT', 'UNIQUEID', 'age'], 'XGB': ['AADHAR_FLAG', 'DELINQUENT_ACCTS_IN_LAST_SIX_MONTHS', 'EMPLOYMENT_TYPE', 'LTV', 'NO_OF_INQUIRIES', 'PAN_FLAG', 'PERFORM_CNS_SCORE', 'PRI_OVERDUE_ACCTS', 'PRI_SANCTIONED_AMOUNT', 'VOTERID_FLAG'], 'KNC': ['DISBURSED_AMOUNT', 'LTV', 'VOTERID_FLAG', 'PERFORM_CNS_SCORE', 'PERFORM_CNS_SCORE_DESCRIPTION', 'PRI_OVERDUE_ACCTS', 'DISBURSED_AMOUNT_new', 'DISBURSED_AMOUNT_bins', 'LTV_bins', 'PERFORM_CNS_SCORE_bins', 'PRI_OVERDUE_ACCTS_bins'], 'GNB': ['DISBURSED_AMOUNT', 'LTV', 'VOTERID_FLAG', 'PERFORM_CNS_SCORE', 'PERFORM_CNS_SCORE_DESCRIPTION', 'PRI_OVERDUE_ACCTS', 'DISBURSED_AMOUNT_new', 'DISBURSED_AMOUNT_bins', 'LTV_bins', 'PERFORM_CNS_SCORE_bins', 'PRI_OVERDUE_ACCTS_bins'], 'NN': ['DISBURSED_AMOUNT', 'LTV', 'VOTERID_FLAG', 'PERFORM_CNS_SCORE', 'PERFORM_CNS_SCORE_DESCRIPTION', 'PRI_OVERDUE_ACCTS', 'DISBURSED_AMOUNT_new', 'DISBURSED_AMOUNT_bins', 'LTV_bins', 'PERFORM_CNS_SCORE_bins', 'PRI_OVERDUE_ACCTS_bins'], 'BG': ['DISBURSED_AMOUNT', 'LTV', 'VOTERID_FLAG', 'PERFORM_CNS_SCORE', 'PERFORM_CNS_SCORE_DESCRIPTION', 'PRI_OVERDUE_ACCTS', 'DISBURSED_AMOUNT_new', 'DISBURSED_AMOUNT_bins', 'LTV_bins', 'PERFORM_CNS_SCORE_bins', 'PRI_OVERDUE_ACCTS_bins'], 'NB': ['DISBURSED_AMOUNT', 'LTV', 'VOTERID_FLAG', 'PERFORM_CNS_SCORE', 'PERFORM_CNS_SCORE_DESCRIPTION', 'PRI_OVERDUE_ACCTS', 'DISBURSED_AMOUNT_new', 'DISBURSED_AMOUNT_bins', 'LTV_bins', 'PERFORM_CNS_SCORE_bins', 'PRI_OVERDUE_ACCTS_bins'], 'SVM': ['DISBURSED_AMOUNT', 'LTV', 'VOTERID_FLAG', 'PERFORM_CNS_SCORE', 'PERFORM_CNS_SCORE_DESCRIPTION', 'PRI_OVERDUE_ACCTS', 'DISBURSED_AMOUNT_new', 'DISBURSED_AMOUNT_bins', 'LTV_bins', 'PERFORM_CNS_SCORE_bins', 'PRI_OVERDUE_ACCTS_bins']},
#       dtype=object)
