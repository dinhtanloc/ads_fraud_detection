# %%
# %run "C:\Users\PC\Data\ads_fraud_detection\src\prj2\5.deep_learning_model\3.smote\InceptionV2\inceptionv2_base.ipynb"
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# C:/Users/PC/Data/ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (5089, 2) (19430, 2)
# (5089, 2)
# 33
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 33, 1)]      0           []
#
#  conv1d (Conv1D)                (None, 16, 16)       64          ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 16, 16)      48          ['conv1d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 16, 16)       0           ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 14, 16)       784         ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 14, 16)      42          ['conv1d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 14, 16)       0           ['batch_normalization_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 14, 32)       1568        ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 14, 32)      42          ['conv1d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 14, 32)       0           ['batch_normalization_2[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 6, 32)        0           ['activation_2[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 6, 80)        2640        ['max_pooling1d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 6, 80)       18          ['conv1d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 6, 80)        0           ['batch_normalization_3[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 4, 192)       46272       ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 4, 192)      12          ['conv1d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 4, 192)       0           ['batch_normalization_4[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 1, 192)      0           ['activation_4[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 1, 32)        6176        ['max_pooling1d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 1, 32)       3           ['conv1d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 1, 32)        0           ['batch_normalization_8[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 1, 48)        9264        ['max_pooling1d_1[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 1, 64)        6208        ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 1, 48)       3           ['conv1d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 1, 64)       3           ['conv1d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 1, 48)        0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 1, 64)        0           ['batch_normalization_9[0][0]']
#
#  average_pooling1d (AveragePool  (None, 1, 192)      0           ['max_pooling1d_1[0][0]']
#  ing1D)
#
#  conv1d_5 (Conv1D)              (None, 1, 64)        12352       ['max_pooling1d_1[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 1, 32)        7712        ['activation_6[0][0]']
#
#  conv1d_10 (Conv1D)             (None, 1, 64)        12352       ['activation_9[0][0]']
#
#  conv1d_11 (Conv1D)             (None, 1, 32)        6176        ['average_pooling1d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 1, 64)       3           ['conv1d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 1, 32)       3           ['conv1d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 1, 64)       3           ['conv1d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 1, 32)       3           ['conv1d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 1, 64)        0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 1, 32)        0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 1, 64)        0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 1, 32)        0           ['batch_normalization_11[0][0]']
#
#  mixed_5b (Concatenate)         (None, 1, 192)       0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 1, 32)        6176        ['mixed_5b[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 1, 32)       3           ['conv1d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 1, 32)        0           ['batch_normalization_15[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 1, 32)        6176        ['mixed_5b[0][0]']
#
#  conv1d_16 (Conv1D)             (None, 1, 48)        4656        ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 1, 32)       3           ['conv1d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 1, 48)       3           ['conv1d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 1, 32)        0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 1, 48)        0           ['batch_normalization_16[0][0]']
#
#  conv1d_12 (Conv1D)             (None, 1, 32)        6176        ['mixed_5b[0][0]']
#
#  conv1d_14 (Conv1D)             (None, 1, 32)        3104        ['activation_13[0][0]']
#
#  conv1d_17 (Conv1D)             (None, 1, 64)        9280        ['activation_16[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 1, 32)       3           ['conv1d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 1, 32)       3           ['conv1d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 1, 64)       3           ['conv1d_17[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 1, 32)        0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 1, 32)        0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 1, 64)        0           ['batch_normalization_17[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 1, 128)       0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]']
#
#  block35_1_conv (Conv1D)        (None, 1, 192)       24768       ['block35_1_mixed[0][0]']
#
#  block35_1_conv_bn (BatchNormal  (None, 1, 192)      3           ['block35_1_conv[0][0]']
#  ization)
#
#  block35_1 (Lambda)             (None, 1, 192)       0           ['mixed_5b[0][0]',
#                                                                   'block35_1_conv_bn[0][0]']
#
#  block35_1_ac (Activation)      (None, 1, 192)       0           ['block35_1[0][0]']
#
#  conv1d_21 (Conv1D)             (None, 1, 32)        6176        ['block35_1_ac[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 1, 32)       3           ['conv1d_21[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 1, 32)        0           ['batch_normalization_21[0][0]']
#
#  conv1d_19 (Conv1D)             (None, 1, 32)        6176        ['block35_1_ac[0][0]']
#
#  conv1d_22 (Conv1D)             (None, 1, 48)        4656        ['activation_21[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 1, 32)       3           ['conv1d_19[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 1, 48)       3           ['conv1d_22[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 1, 32)        0           ['batch_normalization_19[0][0]']
#
#  activation_22 (Activation)     (None, 1, 48)        0           ['batch_normalization_22[0][0]']
#
#  conv1d_18 (Conv1D)             (None, 1, 32)        6176        ['block35_1_ac[0][0]']
#
#  conv1d_20 (Conv1D)             (None, 1, 32)        3104        ['activation_19[0][0]']
#
#  conv1d_23 (Conv1D)             (None, 1, 64)        9280        ['activation_22[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 1, 32)       3           ['conv1d_18[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 1, 32)       3           ['conv1d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 1, 64)       3           ['conv1d_23[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 1, 32)        0           ['batch_normalization_18[0][0]']
#
#  activation_20 (Activation)     (None, 1, 32)        0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 1, 64)        0           ['batch_normalization_23[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 1, 128)       0           ['activation_18[0][0]',
#                                                                   'activation_20[0][0]',
#                                                                   'activation_23[0][0]']
#
#  block35_2_conv (Conv1D)        (None, 1, 192)       24768       ['block35_2_mixed[0][0]']
#
#  block35_2_conv_bn (BatchNormal  (None, 1, 192)      3           ['block35_2_conv[0][0]']
#  ization)
#
#  block35_2 (Lambda)             (None, 1, 192)       0           ['block35_1_ac[0][0]',
#                                                                   'block35_2_conv_bn[0][0]']
#
#  block35_2_ac (Activation)      (None, 1, 192)       0           ['block35_2[0][0]']
#
#  conv1d_27 (Conv1D)             (None, 1, 32)        6176        ['block35_2_ac[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 1, 32)       3           ['conv1d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 1, 32)        0           ['batch_normalization_27[0][0]']
#
#  conv1d_25 (Conv1D)             (None, 1, 32)        6176        ['block35_2_ac[0][0]']
#
#  conv1d_28 (Conv1D)             (None, 1, 48)        4656        ['activation_27[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 1, 32)       3           ['conv1d_25[0][0]']
#  ormalization)
#
#  batch_normalization_28 (BatchN  (None, 1, 48)       3           ['conv1d_28[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 1, 32)        0           ['batch_normalization_25[0][0]']
#
#  activation_28 (Activation)     (None, 1, 48)        0           ['batch_normalization_28[0][0]']
#
#  conv1d_24 (Conv1D)             (None, 1, 32)        6176        ['block35_2_ac[0][0]']
#
#  conv1d_26 (Conv1D)             (None, 1, 32)        3104        ['activation_25[0][0]']
#
#  conv1d_29 (Conv1D)             (None, 1, 64)        9280        ['activation_28[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 1, 32)       3           ['conv1d_24[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 1, 32)       3           ['conv1d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 1, 64)       3           ['conv1d_29[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 1, 32)        0           ['batch_normalization_24[0][0]']
#
#  activation_26 (Activation)     (None, 1, 32)        0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 1, 64)        0           ['batch_normalization_29[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 1, 128)       0           ['activation_24[0][0]',
#                                                                   'activation_26[0][0]',
#                                                                   'activation_29[0][0]']
#
#  block35_3_conv (Conv1D)        (None, 1, 192)       24768       ['block35_3_mixed[0][0]']
#
#  block35_3_conv_bn (BatchNormal  (None, 1, 192)      3           ['block35_3_conv[0][0]']
#  ization)
#
#  block35_3 (Lambda)             (None, 1, 192)       0           ['block35_2_ac[0][0]',
#                                                                   'block35_3_conv_bn[0][0]']
#
#  block35_3_ac (Activation)      (None, 1, 192)       0           ['block35_3[0][0]']
#
#  conv1d_33 (Conv1D)             (None, 1, 32)        6176        ['block35_3_ac[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 1, 32)       3           ['conv1d_33[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 1, 32)        0           ['batch_normalization_33[0][0]']
#
#  conv1d_31 (Conv1D)             (None, 1, 32)        6176        ['block35_3_ac[0][0]']
#
#  conv1d_34 (Conv1D)             (None, 1, 48)        4656        ['activation_33[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 1, 32)       3           ['conv1d_31[0][0]']
#  ormalization)
#
#  batch_normalization_34 (BatchN  (None, 1, 48)       3           ['conv1d_34[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 1, 32)        0           ['batch_normalization_31[0][0]']
#
#  activation_34 (Activation)     (None, 1, 48)        0           ['batch_normalization_34[0][0]']
#
#  conv1d_30 (Conv1D)             (None, 1, 32)        6176        ['block35_3_ac[0][0]']
#
#  conv1d_32 (Conv1D)             (None, 1, 32)        3104        ['activation_31[0][0]']
#
#  conv1d_35 (Conv1D)             (None, 1, 64)        9280        ['activation_34[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 1, 32)       3           ['conv1d_30[0][0]']
#  ormalization)
#
#  batch_normalization_32 (BatchN  (None, 1, 32)       3           ['conv1d_32[0][0]']
#  ormalization)
#
#  batch_normalization_35 (BatchN  (None, 1, 64)       3           ['conv1d_35[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 1, 32)        0           ['batch_normalization_30[0][0]']
#
#  activation_32 (Activation)     (None, 1, 32)        0           ['batch_normalization_32[0][0]']
#
#  activation_35 (Activation)     (None, 1, 64)        0           ['batch_normalization_35[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 1, 128)       0           ['activation_30[0][0]',
#                                                                   'activation_32[0][0]',
#                                                                   'activation_35[0][0]']
#
#  block35_4_conv (Conv1D)        (None, 1, 192)       24768       ['block35_4_mixed[0][0]']
#
#  block35_4_conv_bn (BatchNormal  (None, 1, 192)      3           ['block35_4_conv[0][0]']
#  ization)
#
#  block35_4 (Lambda)             (None, 1, 192)       0           ['block35_3_ac[0][0]',
#                                                                   'block35_4_conv_bn[0][0]']
#
#  block35_4_ac (Activation)      (None, 1, 192)       0           ['block35_4[0][0]']
#
#  conv1d_39 (Conv1D)             (None, 1, 32)        6176        ['block35_4_ac[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 1, 32)       3           ['conv1d_39[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 1, 32)        0           ['batch_normalization_39[0][0]']
#
#  conv1d_37 (Conv1D)             (None, 1, 32)        6176        ['block35_4_ac[0][0]']
#
#  conv1d_40 (Conv1D)             (None, 1, 48)        4656        ['activation_39[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 1, 32)       3           ['conv1d_37[0][0]']
#  ormalization)
#
#  batch_normalization_40 (BatchN  (None, 1, 48)       3           ['conv1d_40[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 1, 32)        0           ['batch_normalization_37[0][0]']
#
#  activation_40 (Activation)     (None, 1, 48)        0           ['batch_normalization_40[0][0]']
#
#  conv1d_36 (Conv1D)             (None, 1, 32)        6176        ['block35_4_ac[0][0]']
#
#  conv1d_38 (Conv1D)             (None, 1, 32)        3104        ['activation_37[0][0]']
#
#  conv1d_41 (Conv1D)             (None, 1, 64)        9280        ['activation_40[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 1, 32)       3           ['conv1d_36[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 1, 32)       3           ['conv1d_38[0][0]']
#  ormalization)
#
#  batch_normalization_41 (BatchN  (None, 1, 64)       3           ['conv1d_41[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 1, 32)        0           ['batch_normalization_36[0][0]']
#
#  activation_38 (Activation)     (None, 1, 32)        0           ['batch_normalization_38[0][0]']
#
#  activation_41 (Activation)     (None, 1, 64)        0           ['batch_normalization_41[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 1, 128)       0           ['activation_36[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_41[0][0]']
#
#  block35_5_conv (Conv1D)        (None, 1, 192)       24768       ['block35_5_mixed[0][0]']
#
#  block35_5_conv_bn (BatchNormal  (None, 1, 192)      3           ['block35_5_conv[0][0]']
#  ization)
#
#  block35_5 (Lambda)             (None, 1, 192)       0           ['block35_4_ac[0][0]',
#                                                                   'block35_5_conv_bn[0][0]']
#
#  block35_5_ac (Activation)      (None, 1, 192)       0           ['block35_5[0][0]']
#
#  conv1d_45 (Conv1D)             (None, 1, 32)        6176        ['block35_5_ac[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 1, 32)       3           ['conv1d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 1, 32)        0           ['batch_normalization_45[0][0]']
#
#  conv1d_43 (Conv1D)             (None, 1, 32)        6176        ['block35_5_ac[0][0]']
#
#  conv1d_46 (Conv1D)             (None, 1, 48)        4656        ['activation_45[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 1, 32)       3           ['conv1d_43[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 1, 48)       3           ['conv1d_46[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 1, 32)        0           ['batch_normalization_43[0][0]']
#
#  activation_46 (Activation)     (None, 1, 48)        0           ['batch_normalization_46[0][0]']
#
#  conv1d_42 (Conv1D)             (None, 1, 32)        6176        ['block35_5_ac[0][0]']
#
#  conv1d_44 (Conv1D)             (None, 1, 32)        3104        ['activation_43[0][0]']
#
#  conv1d_47 (Conv1D)             (None, 1, 64)        9280        ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 1, 32)       3           ['conv1d_42[0][0]']
#  ormalization)
#
#  batch_normalization_44 (BatchN  (None, 1, 32)       3           ['conv1d_44[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 1, 64)       3           ['conv1d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 1, 32)        0           ['batch_normalization_42[0][0]']
#
#  activation_44 (Activation)     (None, 1, 32)        0           ['batch_normalization_44[0][0]']
#
#  activation_47 (Activation)     (None, 1, 64)        0           ['batch_normalization_47[0][0]']
# c:\ProgramData\miniconda3\envs\tensorflow\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
#
#  block35_6_mixed (Concatenate)  (None, 1, 128)       0           ['activation_42[0][0]',
#                                                                   'activation_44[0][0]',
#                                                                   'activation_47[0][0]']
#
#  block35_6_conv (Conv1D)        (None, 1, 192)       24768       ['block35_6_mixed[0][0]']
#
#  block35_6_conv_bn (BatchNormal  (None, 1, 192)      3           ['block35_6_conv[0][0]']
#  ization)
#
#  block35_6 (Lambda)             (None, 1, 192)       0           ['block35_5_ac[0][0]',
#                                                                   'block35_6_conv_bn[0][0]']
#
#  block35_6_ac (Activation)      (None, 1, 192)       0           ['block35_6[0][0]']
#
#  conv1d_51 (Conv1D)             (None, 1, 32)        6176        ['block35_6_ac[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 1, 32)       3           ['conv1d_51[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 1, 32)        0           ['batch_normalization_51[0][0]']
#
#  conv1d_49 (Conv1D)             (None, 1, 32)        6176        ['block35_6_ac[0][0]']
#
#  conv1d_52 (Conv1D)             (None, 1, 48)        4656        ['activation_51[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 1, 32)       3           ['conv1d_49[0][0]']
#  ormalization)
#
#  batch_normalization_52 (BatchN  (None, 1, 48)       3           ['conv1d_52[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 1, 32)        0           ['batch_normalization_49[0][0]']
#
#  activation_52 (Activation)     (None, 1, 48)        0           ['batch_normalization_52[0][0]']
#
#  conv1d_48 (Conv1D)             (None, 1, 32)        6176        ['block35_6_ac[0][0]']
#
#  conv1d_50 (Conv1D)             (None, 1, 32)        3104        ['activation_49[0][0]']
#
#  conv1d_53 (Conv1D)             (None, 1, 64)        9280        ['activation_52[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 1, 32)       3           ['conv1d_48[0][0]']
#  ormalization)
#
#  batch_normalization_50 (BatchN  (None, 1, 32)       3           ['conv1d_50[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 1, 64)       3           ['conv1d_53[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 1, 32)        0           ['batch_normalization_48[0][0]']
#
#  activation_50 (Activation)     (None, 1, 32)        0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 1, 64)        0           ['batch_normalization_53[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 1, 128)       0           ['activation_48[0][0]',
# ...
#  zation)
#
#  block8_7 (Lambda)              (None, 1, 992)       0           ['block8_6_ac[0][0]',
#                                                                   'block8_7_conv_bn[0][0]']
#
#  block8_7_ac (Activation)       (None, 1, 992)       0           ['block8_7[0][0]']
#
#  conv1d_192 (Conv1D)            (None, 1, 192)       190656      ['block8_7_ac[0][0]']
#
#  batch_normalization_192 (Batch  (None, 1, 192)      3           ['conv1d_192[0][0]']
#  Normalization)
#
#  activation_192 (Activation)    (None, 1, 192)       0           ['batch_normalization_192[0][0]']
#
#  conv1d_193 (Conv1D)            (None, 1, 224)       43232       ['activation_192[0][0]']
#
#  batch_normalization_193 (Batch  (None, 1, 224)      3           ['conv1d_193[0][0]']
#  Normalization)
#
#  activation_193 (Activation)    (None, 1, 224)       0           ['batch_normalization_193[0][0]']
#
#  conv1d_191 (Conv1D)            (None, 1, 192)       190656      ['block8_7_ac[0][0]']
#
#  conv1d_194 (Conv1D)            (None, 1, 256)       172288      ['activation_193[0][0]']
#
#  batch_normalization_191 (Batch  (None, 1, 192)      3           ['conv1d_191[0][0]']
#  Normalization)
#
#  batch_normalization_194 (Batch  (None, 1, 256)      3           ['conv1d_194[0][0]']
#  Normalization)
#
#  activation_191 (Activation)    (None, 1, 192)       0           ['batch_normalization_191[0][0]']
#
#  activation_194 (Activation)    (None, 1, 256)       0           ['batch_normalization_194[0][0]']
#
#  block8_8_mixed (Concatenate)   (None, 1, 448)       0           ['activation_191[0][0]',
#                                                                   'activation_194[0][0]']
#
#  block8_8_conv (Conv1D)         (None, 1, 992)       445408      ['block8_8_mixed[0][0]']
#
#  block8_8_conv_bn (BatchNormali  (None, 1, 992)      3           ['block8_8_conv[0][0]']
#  zation)
#
#  block8_8 (Lambda)              (None, 1, 992)       0           ['block8_7_ac[0][0]',
#                                                                   'block8_8_conv_bn[0][0]']
#
#  block8_8_ac (Activation)       (None, 1, 992)       0           ['block8_8[0][0]']
#
#  conv1d_196 (Conv1D)            (None, 1, 192)       190656      ['block8_8_ac[0][0]']
#
#  batch_normalization_196 (Batch  (None, 1, 192)      3           ['conv1d_196[0][0]']
#  Normalization)
#
#  activation_196 (Activation)    (None, 1, 192)       0           ['batch_normalization_196[0][0]']
#
#  conv1d_197 (Conv1D)            (None, 1, 224)       43232       ['activation_196[0][0]']
#
#  batch_normalization_197 (Batch  (None, 1, 224)      3           ['conv1d_197[0][0]']
#  Normalization)
#
#  activation_197 (Activation)    (None, 1, 224)       0           ['batch_normalization_197[0][0]']
#
#  conv1d_195 (Conv1D)            (None, 1, 192)       190656      ['block8_8_ac[0][0]']
#
#  conv1d_198 (Conv1D)            (None, 1, 256)       172288      ['activation_197[0][0]']
#
#  batch_normalization_195 (Batch  (None, 1, 192)      3           ['conv1d_195[0][0]']
#  Normalization)
#
#  batch_normalization_198 (Batch  (None, 1, 256)      3           ['conv1d_198[0][0]']
#  Normalization)
#
#  activation_195 (Activation)    (None, 1, 192)       0           ['batch_normalization_195[0][0]']
#
#  activation_198 (Activation)    (None, 1, 256)       0           ['batch_normalization_198[0][0]']
#
#  block8_9_mixed (Concatenate)   (None, 1, 448)       0           ['activation_195[0][0]',
#                                                                   'activation_198[0][0]']
#
#  block8_9_conv (Conv1D)         (None, 1, 992)       445408      ['block8_9_mixed[0][0]']
#
#  block8_9_conv_bn (BatchNormali  (None, 1, 992)      3           ['block8_9_conv[0][0]']
#  zation)
#
#  block8_9 (Lambda)              (None, 1, 992)       0           ['block8_8_ac[0][0]',
#                                                                   'block8_9_conv_bn[0][0]']
#
#  block8_9_ac (Activation)       (None, 1, 992)       0           ['block8_9[0][0]']
#
#  conv1d_200 (Conv1D)            (None, 1, 192)       190656      ['block8_9_ac[0][0]']
#
#  batch_normalization_200 (Batch  (None, 1, 192)      3           ['conv1d_200[0][0]']
#  Normalization)
#
#  activation_200 (Activation)    (None, 1, 192)       0           ['batch_normalization_200[0][0]']
#
#  conv1d_201 (Conv1D)            (None, 1, 224)       43232       ['activation_200[0][0]']
#
#  batch_normalization_201 (Batch  (None, 1, 224)      3           ['conv1d_201[0][0]']
#  Normalization)
#
#  activation_201 (Activation)    (None, 1, 224)       0           ['batch_normalization_201[0][0]']
#
#  conv1d_199 (Conv1D)            (None, 1, 192)       190656      ['block8_9_ac[0][0]']
#
#  conv1d_202 (Conv1D)            (None, 1, 256)       172288      ['activation_201[0][0]']
#
#  batch_normalization_199 (Batch  (None, 1, 192)      3           ['conv1d_199[0][0]']
#  Normalization)
#
#  batch_normalization_202 (Batch  (None, 1, 256)      3           ['conv1d_202[0][0]']
#  Normalization)
#
#  activation_199 (Activation)    (None, 1, 192)       0           ['batch_normalization_199[0][0]']
#
#  activation_202 (Activation)    (None, 1, 256)       0           ['batch_normalization_202[0][0]']
#
#  block8_10_mixed (Concatenate)  (None, 1, 448)       0           ['activation_199[0][0]',
#                                                                   'activation_202[0][0]']
#
#  block8_10_conv (Conv1D)        (None, 1, 992)       445408      ['block8_10_mixed[0][0]']
#
#  block8_10_conv_bn (BatchNormal  (None, 1, 992)      3           ['block8_10_conv[0][0]']
#  ization)
#
#  block8_10 (Lambda)             (None, 1, 992)       0           ['block8_9_ac[0][0]',
#                                                                   'block8_10_conv_bn[0][0]']
#
#  conv_7b (Conv1D)               (None, 1, 1536)      1525248     ['block8_10[0][0]']
#
#  conv_7b_bn (BatchNormalization  (None, 1, 1536)     3           ['conv_7b[0][0]']
#  )
#
#  conv_7b_ac (Activation)        (None, 1, 1536)      0           ['conv_7b_bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 1536)        0           ['conv_7b_ac[0][0]']
#  1D)
#
#  predictions (Dense)            (None, 2)            3074        ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 24,307,777
# Trainable params: 24,307,191
# Non-trainable params: 586
# __________________________________________________________________________________________________
# Epoch 1/1200
# 608/608 [==============================] - 117s 138ms/step - loss: 0.4495 - accuracy: 0.7892 - f1_score: 0.7780 - val_loss: 0.2568 - val_accuracy: 0.9143 - val_f1_score: 0.5090 - lr: 1.0000e-04
# Epoch 2/1200
# 608/608 [==============================] - 78s 128ms/step - loss: 0.3331 - accuracy: 0.8574 - f1_score: 0.8551 - val_loss: 0.4208 - val_accuracy: 0.8061 - val_f1_score: 0.5323 - lr: 1.0000e-04
# Epoch 3/1200
# 608/608 [==============================] - 80s 131ms/step - loss: 0.3016 - accuracy: 0.8705 - f1_score: 0.8684 - val_loss: 0.2681 - val_accuracy: 0.9208 - val_f1_score: 0.4982 - lr: 1.0000e-04
# Epoch 4/1200
# 608/608 [==============================] - 78s 129ms/step - loss: 0.2860 - accuracy: 0.8805 - f1_score: 0.8783 - val_loss: 0.2969 - val_accuracy: 0.9002 - val_f1_score: 0.5181 - lr: 1.0000e-04
# Epoch 5/1200
# 608/608 [==============================] - 79s 130ms/step - loss: 0.2676 - accuracy: 0.8884 - f1_score: 0.8867 - val_loss: 0.4682 - val_accuracy: 0.7821 - val_f1_score: 0.5221 - lr: 1.0000e-04
# Epoch 6/1200
# 608/608 [==============================] - 78s 129ms/step - loss: 0.2571 - accuracy: 0.8933 - f1_score: 0.8912 - val_loss: 0.4499 - val_accuracy: 0.8057 - val_f1_score: 0.5258 - lr: 1.0000e-04
# Epoch 7/1200
# 608/608 [==============================] - 79s 131ms/step - loss: 0.2474 - accuracy: 0.8980 - f1_score: 0.8960 - val_loss: 0.2974 - val_accuracy: 0.8951 - val_f1_score: 0.5281 - lr: 1.0000e-04
# Epoch 8/1200
# 608/608 [==============================] - 78s 128ms/step - loss: 0.2367 - accuracy: 0.9034 - f1_score: 0.9011 - val_loss: 0.3359 - val_accuracy: 0.9204 - val_f1_score: 0.5033 - lr: 1.0000e-04
# Epoch 9/1200
# 221/608 [=========>....................] - ETA: 47s - loss: 0.2350 - accuracy: 0.9029 - f1_score: 0.9010

# %%
# %run "C:\Users\PC\Data\ads_fraud_detection\src\prj2\5.deep_learning_model\3.smote\InceptionV2\inceptionv2_class_weight.ipynb"

# %%
# %run "C:\Users\PC\Data\ads_fraud_detection\src\prj2\5.deep_learning_model\3.smote\InceptionV3\inceptionv3_base.ipynb"

# %%
# %run "C:\Users\PC\Data\ads_fraud_detection\src\prj2\5.deep_learning_model\3.smote\InceptionV3\inceptionv3_class_weight.ipynb"
