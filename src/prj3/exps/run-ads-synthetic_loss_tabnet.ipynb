# %%
# !git clone https://github.com/dinhtanloc/ads_fraud_detection.git

# %%
# pip install kaggle==1.5.0

# %%
# pip install tensorflow==2.12.0
# #

# %%
# pip install joblib cufflinks pydantic-settings mlxtend keras-tuner wandb shap lime tabnet-keras imbalanced-learn scikit-learn-extra xgboost lightgbm faker sdv

# %%
# from kaggle_secrets import UserSecretsClient
# import os
# user_secrets = UserSecretsClient()
# KAGGLE_KEY = user_secrets.get_secret("KAGGLE_KEY")
# KAGGLE_USERNAME = user_secrets.get_secret("KAGGLE_USERNAME")
# os.environ['KAGGLE_USERNAME'] = KAGGLE_USERNAME
# os.environ['KAGGLE_KEY'] = KAGGLE_KEY

# from kaggle.api.kaggle_api_extended import KaggleApi

# api = KaggleApi()
# api.authenticate()

# print("Kaggle API authenticated successfully!")

# %%
# import os
# os.system("kaggle command")

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj3/1.EDA/EDA_mainbaseline_kaggle.ipynb

# %% [markdown]
# smote

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj3/2.preprocessing/3.smote/pre-processing-mainbaseline_SMOTE_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj3/5.deep_learning_model/3.smote/Tabnet/tabnet_class_weight_kaggle_diceloss.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# C:/Users/PC/Data/ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (29488, 2) (1083018, 2)
# (29488, 2)
# c:\ProgramData\miniconda3\envs\tensorflow_gpu\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\ProgramData\miniconda3\envs\tensorflow_gpu\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.11.0 and strictly below 2.14.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.1 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# 89
# Epoch 1/1200
# 4231/4231 [==============================] - 667s 151ms/step - loss: 1.1536 - accuracy: 0.8461 - f1_score: 0.8457 - cohen_kappa: -0.9996 - val_loss: 0.1132 - val_accuracy: 0.8908 - val_f1_score: 0.5974 - val_cohen_kappa: -0.1644 - lr: 0.0010
# Epoch 2/1200
# 4231/4231 [==============================] - 381s 90ms/step - loss: 0.9756 - accuracy: 0.8698 - f1_score: 0.8694 - cohen_kappa: -0.9995 - val_loss: 0.1276 - val_accuracy: 0.8765 - val_f1_score: 0.5882 - val_cohen_kappa: -0.1841 - lr: 0.0010
# Epoch 3/1200
# 4231/4231 [==============================] - 307s 73ms/step - loss: 0.8739 - accuracy: 0.8834 - f1_score: 0.8831 - cohen_kappa: -0.9998 - val_loss: 0.1387 - val_accuracy: 0.8653 - val_f1_score: 0.5761 - val_cohen_kappa: -0.1963 - lr: 0.0010
# Epoch 4/1200
# 4231/4231 [==============================] - 308s 73ms/step - loss: 0.7808 - accuracy: 0.8959 - f1_score: 0.8956 - cohen_kappa: -0.9996 - val_loss: 0.0991 - val_accuracy: 0.9047 - val_f1_score: 0.6037 - val_cohen_kappa: -0.1449 - lr: 0.0010
# Epoch 5/1200
# 4231/4231 [==============================] - 302s 71ms/step - loss: 0.7133 - accuracy: 0.9050 - f1_score: 0.9047 - cohen_kappa: -0.9997 - val_loss: 0.1096 - val_accuracy: 0.8943 - val_f1_score: 0.5968 - val_cohen_kappa: -0.1590 - lr: 0.0010
# Epoch 6/1200
# 4231/4231 [==============================] - 301s 71ms/step - loss: 0.6632 - accuracy: 0.9117 - f1_score: 0.9115 - cohen_kappa: -0.9996 - val_loss: 0.1297 - val_accuracy: 0.8744 - val_f1_score: 0.5815 - val_cohen_kappa: -0.1843 - lr: 0.0010
# Epoch 7/1200
# 4231/4231 [==============================] - ETA: 0s - loss: 0.6105 - accuracy: 0.9188 - f1_score: 0.9185 - cohen_kappa: -0.9996
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 4231/4231 [==============================] - 300s 71ms/step - loss: 0.6105 - accuracy: 0.9188 - f1_score: 0.9185 - cohen_kappa: -0.9996 - val_loss: 0.1426 - val_accuracy: 0.8614 - val_f1_score: 0.5716 - val_cohen_kappa: -0.2012 - lr: 0.0010
# Epoch 8/1200
# 4231/4231 [==============================] - 302s 71ms/step - loss: 0.5371 - accuracy: 0.9286 - f1_score: 0.9284 - cohen_kappa: -0.9996 - val_loss: 0.1313 - val_accuracy: 0.8728 - val_f1_score: 0.5803 - val_cohen_kappa: -0.1869 - lr: 5.0000e-04
# Epoch 9/1200
# 4231/4231 [==============================] - 302s 71ms/step - loss: 0.5042 - accuracy: 0.9331 - f1_score: 0.9329 - cohen_kappa: -0.9995 - val_loss: 0.1095 - val_accuracy: 0.8946 - val_f1_score: 0.5924 - val_cohen_kappa: -0.1562 - lr: 5.0000e-04
# Epoch 10/1200
# 4231/4231 [==============================] - ETA: 0s - loss: 0.4828 - accuracy: 0.9359 - f1_score: 0.9357 - cohen_kappa: -0.9996
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 4231/4231 [==============================] - 301s 71ms/step - loss: 0.4828 - accuracy: 0.9359 - f1_score: 0.9357 - cohen_kappa: -0.9996 - val_loss: 0.1554 - val_accuracy: 0.8482 - val_f1_score: 0.5616 - val_cohen_kappa: -0.2172 - lr: 5.0000e-04
# Epoch 11/1200
# 4231/4231 [==============================] - 300s 71ms/step - loss: 0.4405 - accuracy: 0.9417 - f1_score: 0.9415 - cohen_kappa: -0.9996 - val_loss: 0.1508 - val_accuracy: 0.8532 - val_f1_score: 0.5634 - val_cohen_kappa: -0.2100 - lr: 2.5000e-04
# Epoch 12/1200
# 4231/4231 [==============================] - 300s 71ms/step - loss: 0.4236 - accuracy: 0.9439 - f1_score: 0.9437 - cohen_kappa: -0.9997 - val_loss: 0.2165 - val_accuracy: 0.7874 - val_f1_score: 0.5243 - val_cohen_kappa: -0.2932 - lr: 2.5000e-04
# Epoch 13/1200
# 4231/4231 [==============================] - ETA: 0s - loss: 0.4088 - accuracy: 0.9460 - f1_score: 0.9458 - cohen_kappa: -0.9996
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 4231/4231 [==============================] - 299s 71ms/step - loss: 0.4088 - accuracy: 0.9460 - f1_score: 0.9458 - cohen_kappa: -0.9996 - val_loss: 0.1283 - val_accuracy: 0.8758 - val_f1_score: 0.5809 - val_cohen_kappa: -0.1814 - lr: 2.5000e-04
# Epoch 14/1200
# 4231/4231 [==============================] - ETA: 0s - loss: 0.3917 - accuracy: 0.9483 - f1_score: 0.9481 - cohen_kappa: -0.9997Restoring model weights from the end of the best epoch: 4.
# 4231/4231 [==============================] - 297s 70ms/step - loss: 0.3917 - accuracy: 0.9483 - f1_score: 0.9481 - cohen_kappa: -0.9997 - val_loss: 0.2656 - val_accuracy: 0.7379 - val_f1_score: 0.4974 - val_cohen_kappa: -0.3584 - lr: 1.2500e-04
# Epoch 14: early stopping
# Model: "tab_net_classifier"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  tab_net_encoder (TabNetEnco  multiple                 19325840
#  der)
#
#  classifier (Dense)          multiple                  1024
#
# =================================================================
# Total params: 19,326,864
# Trainable params: 19,260,616
# Non-trainable params: 66,248
# _________________________________________________________________
# Model: "tab_net_classifier"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  tab_net_encoder (TabNetEnco  multiple                 19325840
#  der)
#
#  classifier (Dense)          multiple                  1024
#
# =================================================================
# Total params: 19,326,864
# Trainable params: 19,260,616
# Non-trainable params: 66,248
# _________________________________________________________________
# 922/922 [==============================] - 3s 3ms/step
# Accuracy: 0.9046730873575691
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95     28319
#            1       0.21      0.51      0.30      1169
#
#     accuracy                           0.90     29488
#    macro avg       0.59      0.72      0.62     29488
# weighted avg       0.95      0.90      0.92     29488
#
# Confusion Matrix:
# [[26081  2238]
#  [  573   596]]

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj3/5.deep_learning_model/3.smote/Tabnet/tabnet_class_weight_kaggle_multiloss.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (29488, 2) (1083018, 2)
# (29488, 2)
# 89
# Epoch 1/1200
# 4231/4231 [==============================] - 332s 72ms/step - loss: 1.3675 - accuracy: 0.9065 - f1_score: 0.9063 - cohen_kappa: -0.9996 - val_loss: 0.3260 - val_accuracy: 0.8454 - val_f1_score: 0.5650 - val_cohen_kappa: -0.2210 - lr: 0.0010
# Epoch 2/1200
# 4231/4231 [==============================] - 301s 71ms/step - loss: 0.8470 - accuracy: 0.9447 - f1_score: 0.9445 - cohen_kappa: -0.9996 - val_loss: 0.2789 - val_accuracy: 0.8715 - val_f1_score: 0.5784 - val_cohen_kappa: -0.1870 - lr: 0.0010
# Epoch 3/1200
# 4231/4231 [==============================] - 300s 71ms/step - loss: 0.6763 - accuracy: 0.9569 - f1_score: 0.9568 - cohen_kappa: -0.9997 - val_loss: 0.6523 - val_accuracy: 0.6172 - val_f1_score: 0.4403 - val_cohen_kappa: -0.5258 - lr: 0.0010
# Epoch 4/1200
# 4231/4231 [==============================] - 301s 71ms/step - loss: 0.5616 - accuracy: 0.9648 - f1_score: 0.9647 - cohen_kappa: -0.9998 - val_loss: 0.2844 - val_accuracy: 0.8711 - val_f1_score: 0.5783 - val_cohen_kappa: -0.1870 - lr: 0.0010
# Epoch 5/1200
# 4231/4231 [==============================] - ETA: 0s - loss: 0.4788 - accuracy: 0.9705 - f1_score: 0.9704 - cohen_kappa: -0.9999
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 4231/4231 [==============================] - 300s 71ms/step - loss: 0.4788 - accuracy: 0.9705 - f1_score: 0.9704 - cohen_kappa: -0.9999 - val_loss: 0.7427 - val_accuracy: 0.6315 - val_f1_score: 0.4471 - val_cohen_kappa: -0.5049 - lr: 0.0010
# Epoch 6/1200
# 4231/4231 [==============================] - 301s 71ms/step - loss: 0.3540 - accuracy: 0.9787 - f1_score: 0.9786 - cohen_kappa: -0.9999 - val_loss: 0.3581 - val_accuracy: 0.8302 - val_f1_score: 0.5482 - val_cohen_kappa: -0.2370 - lr: 5.0000e-04
# Epoch 7/1200
# 4231/4231 [==============================] - 301s 71ms/step - loss: 0.3111 - accuracy: 0.9814 - f1_score: 0.9813 - cohen_kappa: -0.9999 - val_loss: 0.5138 - val_accuracy: 0.7352 - val_f1_score: 0.4965 - val_cohen_kappa: -0.3610 - lr: 5.0000e-04
# Epoch 8/1200
# 4231/4231 [==============================] - ETA: 0s - loss: 0.2776 - accuracy: 0.9836 - f1_score: 0.9836 - cohen_kappa: -1.0000
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 4231/4231 [==============================] - 301s 71ms/step - loss: 0.2776 - accuracy: 0.9836 - f1_score: 0.9836 - cohen_kappa: -1.0000 - val_loss: 0.8508 - val_accuracy: 0.6399 - val_f1_score: 0.4521 - val_cohen_kappa: -0.4945 - lr: 5.0000e-04
# Epoch 9/1200
# 4231/4231 [==============================] - 301s 71ms/step - loss: 0.2179 - accuracy: 0.9873 - f1_score: 0.9873 - cohen_kappa: -1.0000 - val_loss: 0.4544 - val_accuracy: 0.7912 - val_f1_score: 0.5260 - val_cohen_kappa: -0.2876 - lr: 2.5000e-04
# Epoch 10/1200
# 4231/4231 [==============================] - 301s 71ms/step - loss: 0.1946 - accuracy: 0.9888 - f1_score: 0.9888 - cohen_kappa: -1.0000 - val_loss: 0.4519 - val_accuracy: 0.7860 - val_f1_score: 0.5250 - val_cohen_kappa: -0.2961 - lr: 2.5000e-04
# Epoch 11/1200
# 4231/4231 [==============================] - ETA: 0s - loss: 0.1787 - accuracy: 0.9898 - f1_score: 0.9898 - cohen_kappa: -1.0000
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 4231/4231 [==============================] - 302s 71ms/step - loss: 0.1787 - accuracy: 0.9898 - f1_score: 0.9898 - cohen_kappa: -1.0000 - val_loss: 0.3308 - val_accuracy: 0.8629 - val_f1_score: 0.5651 - val_cohen_kappa: -0.1926 - lr: 2.5000e-04
# Epoch 12/1200
# 4231/4231 [==============================] - ETA: 0s - loss: 0.1502 - accuracy: 0.9915 - f1_score: 0.9915 - cohen_kappa: -1.0000Restoring model weights from the end of the best epoch: 2.
# 4231/4231 [==============================] - 304s 72ms/step - loss: 0.1502 - accuracy: 0.9915 - f1_score: 0.9915 - cohen_kappa: -1.0000 - val_loss: 0.3668 - val_accuracy: 0.8330 - val_f1_score: 0.5442 - val_cohen_kappa: -0.2303 - lr: 1.2500e-04
# Epoch 12: early stopping
# Model: "tab_net_classifier_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  tab_net_encoder_1 (TabNetEn  multiple                 19325840
#  coder)
#
#  classifier (Dense)          multiple                  1024
#
# =================================================================
# Total params: 19,326,864
# Trainable params: 19,260,616
# Non-trainable params: 66,248
# _________________________________________________________________
# Model: "tab_net_classifier_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  tab_net_encoder_1 (TabNetEn  multiple                 19325840
#  coder)
#
#  classifier (Dense)          multiple                  1024
#
# =================================================================
# Total params: 19,326,864
# Trainable params: 19,260,616
# Non-trainable params: 66,248
# _________________________________________________________________
# 922/922 [==============================] - 3s 3ms/step
# Accuracy: 0.8714731416169289
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.88      0.93     28319
#            1       0.17      0.55      0.25      1169
#
#     accuracy                           0.87     29488
#    macro avg       0.57      0.72      0.59     29488
# weighted avg       0.95      0.87      0.90     29488
#
# Confusion Matrix:
# [[25050  3269]
#  [  521   648]]
