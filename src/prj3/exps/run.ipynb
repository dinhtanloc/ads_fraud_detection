# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\3.smote\InceptionV2\inceptionv2_base.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (5089, 2) (19430, 2)
# (5089, 2)
# 33
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 33, 1)]      0           []
#
#  conv1d_203 (Conv1D)            (None, 16, 16)       64          ['input_2[0][0]']
#
#  batch_normalization_203 (Batch  (None, 16, 16)      48          ['conv1d_203[0][0]']
#  Normalization)
#
#  activation_203 (Activation)    (None, 16, 16)       0           ['batch_normalization_203[0][0]']
#
#  conv1d_204 (Conv1D)            (None, 14, 16)       784         ['activation_203[0][0]']
#
#  batch_normalization_204 (Batch  (None, 14, 16)      42          ['conv1d_204[0][0]']
#  Normalization)
#
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\3.smote\InceptionV2\inceptionv2_class_weight.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (5089, 2) (19430, 2)
# (5089, 2)
# 33
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_3 (InputLayer)           [(None, 33, 1)]      0           []
#
#  conv1d_406 (Conv1D)            (None, 16, 16)       64          ['input_3[0][0]']
#
#  batch_normalization_406 (Batch  (None, 16, 16)      48          ['conv1d_406[0][0]']
#  Normalization)
#
#  activation_406 (Activation)    (None, 16, 16)       0           ['batch_normalization_406[0][0]']
#
#  conv1d_407 (Conv1D)            (None, 14, 16)       784         ['activation_406[0][0]']
#
#  batch_normalization_407 (Batch  (None, 14, 16)      42          ['conv1d_407[0][0]']
#  Normalization)
#
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\3.smote\InceptionV3\inceptionv3_base.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (5089, 2) (19430, 2)
# (5089, 2)
# 33
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_4 (InputLayer)           [(None, 33, 1)]      0           []
#
#  conv1d_609 (Conv1D)            (None, 16, 32)       96          ['input_4[0][0]']
#
#  batch_normalization_609 (Batch  (None, 16, 32)      48          ['conv1d_609[0][0]']
#  Normalization)
#
#  activation_609 (Activation)    (None, 16, 32)       0           ['batch_normalization_609[0][0]']
#
#  conv1d_610 (Conv1D)            (None, 14, 32)       3072        ['activation_609[0][0]']
#
#  batch_normalization_610 (Batch  (None, 14, 32)      42          ['conv1d_610[0][0]']
#  Normalization)
#
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\3.smote\InceptionV3\inceptionv3_class_weight.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\3.smote\Tabnet\tabnet_base.ipynb"

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\3.smote\Tabnet\tabnet_class_weight.ipynb"
