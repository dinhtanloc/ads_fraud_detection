# %% [markdown]
# #### SMOTE

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\3.smote\InceptionV2\inceptionv2_class_weight_dice.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# C:/Users/Admin/Data/ads_fraud_detection
# No GPU found. Using CPU.
# (3300, 2) (12728, 2)
# (3300, 2)
# 37
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_1 (InputLayer)        [(None, 37, 1)]              0         []
#
#  conv1d (Conv1D)             (None, 18, 16)               64        ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 18, 16)               54        ['conv1d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 18, 16)               0         ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 16, 16)               784       ['activation[0][0]']
#
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\3.smote\InceptionV2\inceptionv2_class_weight_focal.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# No GPU found. Using CPU.
# (3300, 2) (12728, 2)
# (3300, 2)
# 37
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_2 (InputLayer)        [(None, 37, 1)]              0         []
#
#  conv1d_203 (Conv1D)         (None, 18, 16)               64        ['input_2[0][0]']
#
#  batch_normalization_203 (B  (None, 18, 16)               54        ['conv1d_203[0][0]']
#  atchNormalization)
#
#  activation_203 (Activation  (None, 18, 16)               0         ['batch_normalization_203[0][0
#  )                                                                  ]']
#
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\3.smote\InceptionV2\inceptionv2_class_weight_f1.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# No GPU found. Using CPU.
# (3300, 2) (12728, 2)
# (3300, 2)
# 37
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_3 (InputLayer)        [(None, 37, 1)]              0         []
#
#  conv1d_406 (Conv1D)         (None, 18, 16)               64        ['input_3[0][0]']
#
#  batch_normalization_406 (B  (None, 18, 16)               54        ['conv1d_406[0][0]']
#  atchNormalization)
#
#  activation_406 (Activation  (None, 18, 16)               0         ['batch_normalization_406[0][0
#  )                                                                  ]']
#
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\3.smote\InceptionV3\inceptionv3_class_weight_dice.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# No GPU found. Using CPU.
# (3300, 2) (12728, 2)
# (3300, 2)
# 37
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_4 (InputLayer)        [(None, 37, 1)]              0         []
#
#  conv1d_609 (Conv1D)         (None, 18, 32)               96        ['input_4[0][0]']
#
#  batch_normalization_609 (B  (None, 18, 32)               54        ['conv1d_609[0][0]']
#  atchNormalization)
#
#  activation_609 (Activation  (None, 18, 32)               0         ['batch_normalization_609[0][0
#  )                                                                  ]']
#
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\3.smote\InceptionV3\inceptionv3_class_weight_focal.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# No GPU found. Using CPU.
# (3300, 2) (12728, 2)
# (3300, 2)
# 37
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_5 (InputLayer)        [(None, 37, 1)]              0         []
#
#  conv1d_655 (Conv1D)         (None, 18, 32)               96        ['input_5[0][0]']
#
#  batch_normalization_655 (B  (None, 18, 32)               54        ['conv1d_655[0][0]']
#  atchNormalization)
#
#  activation_655 (Activation  (None, 18, 32)               0         ['batch_normalization_655[0][0
#  )                                                                  ]']
#
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\3.smote\InceptionV3\inceptionv3_class_weight_f1.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# No GPU found. Using CPU.
# (3300, 2) (12728, 2)
# (3300, 2)
# 37
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_6 (InputLayer)        [(None, 37, 1)]              0         []
#
#  conv1d_701 (Conv1D)         (None, 18, 32)               96        ['input_6[0][0]']
#
#  batch_normalization_701 (B  (None, 18, 32)               54        ['conv1d_701[0][0]']
#  atchNormalization)
#
#  activation_701 (Activation  (None, 18, 32)               0         ['batch_normalization_701[0][0
#  )                                                                  ]']
#
# ...

# %%
#
