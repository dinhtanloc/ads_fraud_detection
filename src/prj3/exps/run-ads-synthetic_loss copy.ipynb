# %%
# !git clone https://github.com/dinhtanloc/ads_fraud_detection.git

# %%
# pip install kaggle==1.5.0

# %%
# pip install tensorflow==2.12.0
# #

# %%
# pip install joblib cufflinks pydantic-settings mlxtend keras-tuner wandb shap lime tabnet-keras imbalanced-learn scikit-learn-extra xgboost lightgbm faker sdv

# %%
# from kaggle_secrets import UserSecretsClient
# import os
# user_secrets = UserSecretsClient()
# KAGGLE_KEY = user_secrets.get_secret("KAGGLE_KEY")
# KAGGLE_USERNAME = user_secrets.get_secret("KAGGLE_USERNAME")
# os.environ['KAGGLE_USERNAME'] = KAGGLE_USERNAME
# os.environ['KAGGLE_KEY'] = KAGGLE_KEY

# from kaggle.api.kaggle_api_extended import KaggleApi

# api = KaggleApi()
# api.authenticate()

# print("Kaggle API authenticated successfully!")

# %%
# import os
# os.system("kaggle command")

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj3/1.EDA/EDA_mainbaseline_kaggle.ipynb

# %% [markdown]
# smote

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj3/2.preprocessing/3.smote/pre-processing-mainbaseline_SMOTE_kaggle.ipynb

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj3/5.deep_learning_model/3.smote/InceptionV2/inceptionv2_class_weight_kaggle_diceloss.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# C:/Users/PC/Data/ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (29488, 2) (1083018, 2)
# (29488, 2)
# c:\ProgramData\miniconda3\envs\tensorflow_gpu\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\ProgramData\miniconda3\envs\tensorflow_gpu\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.11.0 and strictly below 2.14.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.1 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(
# 89
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 89, 1)]      0           []
#
#  conv1d (Conv1D)                (None, 44, 16)       64          ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 44, 16)      132         ['conv1d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 44, 16)       0           ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 42, 16)       784         ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 42, 16)      126         ['conv1d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 42, 16)       0           ['batch_normalization_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 42, 32)       1568        ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 42, 32)      126         ['conv1d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 42, 32)       0           ['batch_normalization_2[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 20, 32)       0           ['activation_2[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 20, 80)       2640        ['max_pooling1d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 20, 80)      60          ['conv1d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 20, 80)       0           ['batch_normalization_3[0][0]']
#
#  conv1d_4 (Conv1D)              (None, 18, 192)      46272       ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 18, 192)     54          ['conv1d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 18, 192)      0           ['batch_normalization_4[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 8, 192)      0           ['activation_4[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 8, 32)        6176        ['max_pooling1d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 8, 32)       24          ['conv1d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 8, 32)        0           ['batch_normalization_8[0][0]']
#
#  conv1d_6 (Conv1D)              (None, 8, 48)        9264        ['max_pooling1d_1[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 8, 64)        6208        ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 8, 48)       24          ['conv1d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 8, 64)       24          ['conv1d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 8, 48)        0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 8, 64)        0           ['batch_normalization_9[0][0]']
#
#  average_pooling1d (AveragePool  (None, 8, 192)      0           ['max_pooling1d_1[0][0]']
#  ing1D)
#
#  conv1d_5 (Conv1D)              (None, 8, 64)        12352       ['max_pooling1d_1[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 8, 32)        7712        ['activation_6[0][0]']
#
#  conv1d_10 (Conv1D)             (None, 8, 64)        12352       ['activation_9[0][0]']
#
#  conv1d_11 (Conv1D)             (None, 8, 32)        6176        ['average_pooling1d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 8, 64)       24          ['conv1d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 8, 32)       24          ['conv1d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 8, 64)       24          ['conv1d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 8, 32)       24          ['conv1d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 8, 64)        0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 8, 32)        0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 8, 64)        0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 8, 32)        0           ['batch_normalization_11[0][0]']
#
#  mixed_5b (Concatenate)         (None, 8, 192)       0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv1d_15 (Conv1D)             (None, 8, 32)        6176        ['mixed_5b[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 8, 32)       24          ['conv1d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 8, 32)        0           ['batch_normalization_15[0][0]']
#
#  conv1d_13 (Conv1D)             (None, 8, 32)        6176        ['mixed_5b[0][0]']
#
#  conv1d_16 (Conv1D)             (None, 8, 48)        4656        ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 8, 32)       24          ['conv1d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 8, 48)       24          ['conv1d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 8, 32)        0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 8, 48)        0           ['batch_normalization_16[0][0]']
#
#  conv1d_12 (Conv1D)             (None, 8, 32)        6176        ['mixed_5b[0][0]']
#
#  conv1d_14 (Conv1D)             (None, 8, 32)        3104        ['activation_13[0][0]']
#
#  conv1d_17 (Conv1D)             (None, 8, 64)        9280        ['activation_16[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 8, 32)       24          ['conv1d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 8, 32)       24          ['conv1d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 8, 64)       24          ['conv1d_17[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 8, 32)        0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 8, 32)        0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 8, 64)        0           ['batch_normalization_17[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 8, 128)       0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]']
#
#  block35_1_conv (Conv1D)        (None, 8, 192)       24768       ['block35_1_mixed[0][0]']
#
#  block35_1_conv_bn (BatchNormal  (None, 8, 192)      24          ['block35_1_conv[0][0]']
#  ization)
#
#  block35_1 (Lambda)             (None, 8, 192)       0           ['mixed_5b[0][0]',
#                                                                   'block35_1_conv_bn[0][0]']
#
#  block35_1_ac (Activation)      (None, 8, 192)       0           ['block35_1[0][0]']
#
#  conv1d_21 (Conv1D)             (None, 8, 32)        6176        ['block35_1_ac[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 8, 32)       24          ['conv1d_21[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 8, 32)        0           ['batch_normalization_21[0][0]']
#
#  conv1d_19 (Conv1D)             (None, 8, 32)        6176        ['block35_1_ac[0][0]']
#
#  conv1d_22 (Conv1D)             (None, 8, 48)        4656        ['activation_21[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 8, 32)       24          ['conv1d_19[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 8, 48)       24          ['conv1d_22[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 8, 32)        0           ['batch_normalization_19[0][0]']
#
#  activation_22 (Activation)     (None, 8, 48)        0           ['batch_normalization_22[0][0]']
#
#  conv1d_18 (Conv1D)             (None, 8, 32)        6176        ['block35_1_ac[0][0]']
#
#  conv1d_20 (Conv1D)             (None, 8, 32)        3104        ['activation_19[0][0]']
#
#  conv1d_23 (Conv1D)             (None, 8, 64)        9280        ['activation_22[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 8, 32)       24          ['conv1d_18[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 8, 32)       24          ['conv1d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 8, 64)       24          ['conv1d_23[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 8, 32)        0           ['batch_normalization_18[0][0]']
#
#  activation_20 (Activation)     (None, 8, 32)        0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 8, 64)        0           ['batch_normalization_23[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 8, 128)       0           ['activation_18[0][0]',
#                                                                   'activation_20[0][0]',
#                                                                   'activation_23[0][0]']
#
#  block35_2_conv (Conv1D)        (None, 8, 192)       24768       ['block35_2_mixed[0][0]']
#
#  block35_2_conv_bn (BatchNormal  (None, 8, 192)      24          ['block35_2_conv[0][0]']
#  ization)
#
#  block35_2 (Lambda)             (None, 8, 192)       0           ['block35_1_ac[0][0]',
#                                                                   'block35_2_conv_bn[0][0]']
#
#  block35_2_ac (Activation)      (None, 8, 192)       0           ['block35_2[0][0]']
#
#  conv1d_27 (Conv1D)             (None, 8, 32)        6176        ['block35_2_ac[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 8, 32)       24          ['conv1d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 8, 32)        0           ['batch_normalization_27[0][0]']
#
#  conv1d_25 (Conv1D)             (None, 8, 32)        6176        ['block35_2_ac[0][0]']
#
#  conv1d_28 (Conv1D)             (None, 8, 48)        4656        ['activation_27[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 8, 32)       24          ['conv1d_25[0][0]']
#  ormalization)
#
#  batch_normalization_28 (BatchN  (None, 8, 48)       24          ['conv1d_28[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 8, 32)        0           ['batch_normalization_25[0][0]']
#
#  activation_28 (Activation)     (None, 8, 48)        0           ['batch_normalization_28[0][0]']
#
#  conv1d_24 (Conv1D)             (None, 8, 32)        6176        ['block35_2_ac[0][0]']
#
#  conv1d_26 (Conv1D)             (None, 8, 32)        3104        ['activation_25[0][0]']
#
#  conv1d_29 (Conv1D)             (None, 8, 64)        9280        ['activation_28[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 8, 32)       24          ['conv1d_24[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 8, 32)       24          ['conv1d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 8, 64)       24          ['conv1d_29[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 8, 32)        0           ['batch_normalization_24[0][0]']
#
#  activation_26 (Activation)     (None, 8, 32)        0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 8, 64)        0           ['batch_normalization_29[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 8, 128)       0           ['activation_24[0][0]',
#                                                                   'activation_26[0][0]',
#                                                                   'activation_29[0][0]']
#
#  block35_3_conv (Conv1D)        (None, 8, 192)       24768       ['block35_3_mixed[0][0]']
#
#  block35_3_conv_bn (BatchNormal  (None, 8, 192)      24          ['block35_3_conv[0][0]']
#  ization)
#
#  block35_3 (Lambda)             (None, 8, 192)       0           ['block35_2_ac[0][0]',
#                                                                   'block35_3_conv_bn[0][0]']
#
#  block35_3_ac (Activation)      (None, 8, 192)       0           ['block35_3[0][0]']
#
#  conv1d_33 (Conv1D)             (None, 8, 32)        6176        ['block35_3_ac[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 8, 32)       24          ['conv1d_33[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 8, 32)        0           ['batch_normalization_33[0][0]']
#
#  conv1d_31 (Conv1D)             (None, 8, 32)        6176        ['block35_3_ac[0][0]']
#
#  conv1d_34 (Conv1D)             (None, 8, 48)        4656        ['activation_33[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 8, 32)       24          ['conv1d_31[0][0]']
#  ormalization)
#
#  batch_normalization_34 (BatchN  (None, 8, 48)       24          ['conv1d_34[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 8, 32)        0           ['batch_normalization_31[0][0]']
#
#  activation_34 (Activation)     (None, 8, 48)        0           ['batch_normalization_34[0][0]']
#
#  conv1d_30 (Conv1D)             (None, 8, 32)        6176        ['block35_3_ac[0][0]']
#
#  conv1d_32 (Conv1D)             (None, 8, 32)        3104        ['activation_31[0][0]']
#
#  conv1d_35 (Conv1D)             (None, 8, 64)        9280        ['activation_34[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 8, 32)       24          ['conv1d_30[0][0]']
#  ormalization)
#
#  batch_normalization_32 (BatchN  (None, 8, 32)       24          ['conv1d_32[0][0]']
#  ormalization)
#
#  batch_normalization_35 (BatchN  (None, 8, 64)       24          ['conv1d_35[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 8, 32)        0           ['batch_normalization_30[0][0]']
#
#  activation_32 (Activation)     (None, 8, 32)        0           ['batch_normalization_32[0][0]']
#
#  activation_35 (Activation)     (None, 8, 64)        0           ['batch_normalization_35[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 8, 128)       0           ['activation_30[0][0]',
#                                                                   'activation_32[0][0]',
#                                                                   'activation_35[0][0]']
#
#  block35_4_conv (Conv1D)        (None, 8, 192)       24768       ['block35_4_mixed[0][0]']
#
#  block35_4_conv_bn (BatchNormal  (None, 8, 192)      24          ['block35_4_conv[0][0]']
#  ization)
#
#  block35_4 (Lambda)             (None, 8, 192)       0           ['block35_3_ac[0][0]',
#                                                                   'block35_4_conv_bn[0][0]']
#
#  block35_4_ac (Activation)      (None, 8, 192)       0           ['block35_4[0][0]']
#
#  conv1d_39 (Conv1D)             (None, 8, 32)        6176        ['block35_4_ac[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 8, 32)       24          ['conv1d_39[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 8, 32)        0           ['batch_normalization_39[0][0]']
#
#  conv1d_37 (Conv1D)             (None, 8, 32)        6176        ['block35_4_ac[0][0]']
#
#  conv1d_40 (Conv1D)             (None, 8, 48)        4656        ['activation_39[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 8, 32)       24          ['conv1d_37[0][0]']
#  ormalization)
#
#  batch_normalization_40 (BatchN  (None, 8, 48)       24          ['conv1d_40[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 8, 32)        0           ['batch_normalization_37[0][0]']
#
#  activation_40 (Activation)     (None, 8, 48)        0           ['batch_normalization_40[0][0]']
#
#  conv1d_36 (Conv1D)             (None, 8, 32)        6176        ['block35_4_ac[0][0]']
#
#  conv1d_38 (Conv1D)             (None, 8, 32)        3104        ['activation_37[0][0]']
#
#  conv1d_41 (Conv1D)             (None, 8, 64)        9280        ['activation_40[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 8, 32)       24          ['conv1d_36[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 8, 32)       24          ['conv1d_38[0][0]']
#  ormalization)
#
#  batch_normalization_41 (BatchN  (None, 8, 64)       24          ['conv1d_41[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 8, 32)        0           ['batch_normalization_36[0][0]']
#
#  activation_38 (Activation)     (None, 8, 32)        0           ['batch_normalization_38[0][0]']
#
#  activation_41 (Activation)     (None, 8, 64)        0           ['batch_normalization_41[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 8, 128)       0           ['activation_36[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_41[0][0]']
#
#  block35_5_conv (Conv1D)        (None, 8, 192)       24768       ['block35_5_mixed[0][0]']
#
#  block35_5_conv_bn (BatchNormal  (None, 8, 192)      24          ['block35_5_conv[0][0]']
#  ization)
#
#  block35_5 (Lambda)             (None, 8, 192)       0           ['block35_4_ac[0][0]',
#                                                                   'block35_5_conv_bn[0][0]']
#
#  block35_5_ac (Activation)      (None, 8, 192)       0           ['block35_5[0][0]']
#
#  conv1d_45 (Conv1D)             (None, 8, 32)        6176        ['block35_5_ac[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 8, 32)       24          ['conv1d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 8, 32)        0           ['batch_normalization_45[0][0]']
#
#  conv1d_43 (Conv1D)             (None, 8, 32)        6176        ['block35_5_ac[0][0]']
#
#  conv1d_46 (Conv1D)             (None, 8, 48)        4656        ['activation_45[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 8, 32)       24          ['conv1d_43[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 8, 48)       24          ['conv1d_46[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 8, 32)        0           ['batch_normalization_43[0][0]']
#
#  activation_46 (Activation)     (None, 8, 48)        0           ['batch_normalization_46[0][0]']
#
#  conv1d_42 (Conv1D)             (None, 8, 32)        6176        ['block35_5_ac[0][0]']
#
#  conv1d_44 (Conv1D)             (None, 8, 32)        3104        ['activation_43[0][0]']
#
#  conv1d_47 (Conv1D)             (None, 8, 64)        9280        ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 8, 32)       24          ['conv1d_42[0][0]']
#  ormalization)
#
#  batch_normalization_44 (BatchN  (None, 8, 32)       24          ['conv1d_44[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 8, 64)       24          ['conv1d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 8, 32)        0           ['batch_normalization_42[0][0]']
#
#  activation_44 (Activation)     (None, 8, 32)        0           ['batch_normalization_44[0][0]']
#
#  activation_47 (Activation)     (None, 8, 64)        0           ['batch_normalization_47[0][0]']
#
#  block35_6_mixed (Concatenate)  (None, 8, 128)       0           ['activation_42[0][0]',
#                                                                   'activation_44[0][0]',
#                                                                   'activation_47[0][0]']
#
#  block35_6_conv (Conv1D)        (None, 8, 192)       24768       ['block35_6_mixed[0][0]']
#
#  block35_6_conv_bn (BatchNormal  (None, 8, 192)      24          ['block35_6_conv[0][0]']
#  ization)
#
#  block35_6 (Lambda)             (None, 8, 192)       0           ['block35_5_ac[0][0]',
#                                                                   'block35_6_conv_bn[0][0]']
#
#  block35_6_ac (Activation)      (None, 8, 192)       0           ['block35_6[0][0]']
#
#  conv1d_51 (Conv1D)             (None, 8, 32)        6176        ['block35_6_ac[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 8, 32)       24          ['conv1d_51[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 8, 32)        0           ['batch_normalization_51[0][0]']
#
#  conv1d_49 (Conv1D)             (None, 8, 32)        6176        ['block35_6_ac[0][0]']
#
#  conv1d_52 (Conv1D)             (None, 8, 48)        4656        ['activation_51[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 8, 32)       24          ['conv1d_49[0][0]']
#  ormalization)
#
#  batch_normalization_52 (BatchN  (None, 8, 48)       24          ['conv1d_52[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 8, 32)        0           ['batch_normalization_49[0][0]']
#
#  activation_52 (Activation)     (None, 8, 48)        0           ['batch_normalization_52[0][0]']
#
#  conv1d_48 (Conv1D)             (None, 8, 32)        6176        ['block35_6_ac[0][0]']
#
#  conv1d_50 (Conv1D)             (None, 8, 32)        3104        ['activation_49[0][0]']
#
#  conv1d_53 (Conv1D)             (None, 8, 64)        9280        ['activation_52[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 8, 32)       24          ['conv1d_48[0][0]']
#  ormalization)
#
#  batch_normalization_50 (BatchN  (None, 8, 32)       24          ['conv1d_50[0][0]']
#  ormalization)
# ...
#  batch_normalization_190 (Batch  (None, 2, 256)      6           ['conv1d_190[0][0]']
#  Normalization)
#
#  activation_187 (Activation)    (None, 2, 192)       0           ['batch_normalization_187[0][0]']
#
#  activation_190 (Activation)    (None, 2, 256)       0           ['batch_normalization_190[0][0]']
#
#  block8_7_mixed (Concatenate)   (None, 2, 448)       0           ['activation_187[0][0]',
#                                                                   'activation_190[0][0]']
#
#  block8_7_conv (Conv1D)         (None, 2, 992)       445408      ['block8_7_mixed[0][0]']
#
#  block8_7_conv_bn (BatchNormali  (None, 2, 992)      6           ['block8_7_conv[0][0]']
#  zation)
#
#  block8_7 (Lambda)              (None, 2, 992)       0           ['block8_6_ac[0][0]',
#                                                                   'block8_7_conv_bn[0][0]']
#
#  block8_7_ac (Activation)       (None, 2, 992)       0           ['block8_7[0][0]']
#
#  conv1d_192 (Conv1D)            (None, 2, 192)       190656      ['block8_7_ac[0][0]']
#
#  batch_normalization_192 (Batch  (None, 2, 192)      6           ['conv1d_192[0][0]']
#  Normalization)
#
#  activation_192 (Activation)    (None, 2, 192)       0           ['batch_normalization_192[0][0]']
#
#  conv1d_193 (Conv1D)            (None, 2, 224)       43232       ['activation_192[0][0]']
#
#  batch_normalization_193 (Batch  (None, 2, 224)      6           ['conv1d_193[0][0]']
#  Normalization)
#
#  activation_193 (Activation)    (None, 2, 224)       0           ['batch_normalization_193[0][0]']
#
#  conv1d_191 (Conv1D)            (None, 2, 192)       190656      ['block8_7_ac[0][0]']
#
#  conv1d_194 (Conv1D)            (None, 2, 256)       172288      ['activation_193[0][0]']
#
#  batch_normalization_191 (Batch  (None, 2, 192)      6           ['conv1d_191[0][0]']
#  Normalization)
#
#  batch_normalization_194 (Batch  (None, 2, 256)      6           ['conv1d_194[0][0]']
#  Normalization)
#
#  activation_191 (Activation)    (None, 2, 192)       0           ['batch_normalization_191[0][0]']
#
#  activation_194 (Activation)    (None, 2, 256)       0           ['batch_normalization_194[0][0]']
#
#  block8_8_mixed (Concatenate)   (None, 2, 448)       0           ['activation_191[0][0]',
#                                                                   'activation_194[0][0]']
#
#  block8_8_conv (Conv1D)         (None, 2, 992)       445408      ['block8_8_mixed[0][0]']
#
#  block8_8_conv_bn (BatchNormali  (None, 2, 992)      6           ['block8_8_conv[0][0]']
#  zation)
#
#  block8_8 (Lambda)              (None, 2, 992)       0           ['block8_7_ac[0][0]',
#                                                                   'block8_8_conv_bn[0][0]']
#
#  block8_8_ac (Activation)       (None, 2, 992)       0           ['block8_8[0][0]']
#
#  conv1d_196 (Conv1D)            (None, 2, 192)       190656      ['block8_8_ac[0][0]']
#
#  batch_normalization_196 (Batch  (None, 2, 192)      6           ['conv1d_196[0][0]']
#  Normalization)
#
#  activation_196 (Activation)    (None, 2, 192)       0           ['batch_normalization_196[0][0]']
#
#  conv1d_197 (Conv1D)            (None, 2, 224)       43232       ['activation_196[0][0]']
#
#  batch_normalization_197 (Batch  (None, 2, 224)      6           ['conv1d_197[0][0]']
#  Normalization)
#
#  activation_197 (Activation)    (None, 2, 224)       0           ['batch_normalization_197[0][0]']
#
#  conv1d_195 (Conv1D)            (None, 2, 192)       190656      ['block8_8_ac[0][0]']
#
#  conv1d_198 (Conv1D)            (None, 2, 256)       172288      ['activation_197[0][0]']
#
#  batch_normalization_195 (Batch  (None, 2, 192)      6           ['conv1d_195[0][0]']
#  Normalization)
#
#  batch_normalization_198 (Batch  (None, 2, 256)      6           ['conv1d_198[0][0]']
#  Normalization)
#
#  activation_195 (Activation)    (None, 2, 192)       0           ['batch_normalization_195[0][0]']
#
#  activation_198 (Activation)    (None, 2, 256)       0           ['batch_normalization_198[0][0]']
#
#  block8_9_mixed (Concatenate)   (None, 2, 448)       0           ['activation_195[0][0]',
#                                                                   'activation_198[0][0]']
#
#  block8_9_conv (Conv1D)         (None, 2, 992)       445408      ['block8_9_mixed[0][0]']
#
#  block8_9_conv_bn (BatchNormali  (None, 2, 992)      6           ['block8_9_conv[0][0]']
#  zation)
#
#  block8_9 (Lambda)              (None, 2, 992)       0           ['block8_8_ac[0][0]',
#                                                                   'block8_9_conv_bn[0][0]']
#
#  block8_9_ac (Activation)       (None, 2, 992)       0           ['block8_9[0][0]']
#
#  conv1d_200 (Conv1D)            (None, 2, 192)       190656      ['block8_9_ac[0][0]']
#
#  batch_normalization_200 (Batch  (None, 2, 192)      6           ['conv1d_200[0][0]']
#  Normalization)
#
#  activation_200 (Activation)    (None, 2, 192)       0           ['batch_normalization_200[0][0]']
#
#  conv1d_201 (Conv1D)            (None, 2, 224)       43232       ['activation_200[0][0]']
#
#  batch_normalization_201 (Batch  (None, 2, 224)      6           ['conv1d_201[0][0]']
#  Normalization)
#
#  activation_201 (Activation)    (None, 2, 224)       0           ['batch_normalization_201[0][0]']
#
#  conv1d_199 (Conv1D)            (None, 2, 192)       190656      ['block8_9_ac[0][0]']
#
#  conv1d_202 (Conv1D)            (None, 2, 256)       172288      ['activation_201[0][0]']
#
#  batch_normalization_199 (Batch  (None, 2, 192)      6           ['conv1d_199[0][0]']
#  Normalization)
#
#  batch_normalization_202 (Batch  (None, 2, 256)      6           ['conv1d_202[0][0]']
#  Normalization)
#
#  activation_199 (Activation)    (None, 2, 192)       0           ['batch_normalization_199[0][0]']
#
#  activation_202 (Activation)    (None, 2, 256)       0           ['batch_normalization_202[0][0]']
#
#  block8_10_mixed (Concatenate)  (None, 2, 448)       0           ['activation_199[0][0]',
#                                                                   'activation_202[0][0]']
#
#  block8_10_conv (Conv1D)        (None, 2, 992)       445408      ['block8_10_mixed[0][0]']
#
#  block8_10_conv_bn (BatchNormal  (None, 2, 992)      6           ['block8_10_conv[0][0]']
#  ization)
#
#  block8_10 (Lambda)             (None, 2, 992)       0           ['block8_9_ac[0][0]',
#                                                                   'block8_10_conv_bn[0][0]']
#
#  conv_7b (Conv1D)               (None, 2, 1536)      1525248     ['block8_10[0][0]']
#
#  conv_7b_bn (BatchNormalization  (None, 2, 1536)     6           ['conv_7b[0][0]']
#  )
#
#  conv_7b_ac (Activation)        (None, 2, 1536)      0           ['conv_7b_bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 1536)        0           ['conv_7b_ac[0][0]']
#  1D)
#
#  predictions (Dense)            (None, 2)            3074        ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 24,310,888
# Trainable params: 24,308,228
# Non-trainable params: 2,660
# __________________________________________________________________________________________________
# 922/922 [==============================] - 24s 22ms/step
# Accuracy: 0.9618488876831254
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     28319
#            1       0.57      0.16      0.25      1169
#
#     accuracy                           0.96     29488
#    macro avg       0.77      0.58      0.62     29488
# weighted avg       0.95      0.96      0.95     29488
#
# Confusion Matrix:
# [[28172   147]
#  [  978   191]]

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj3/5.deep_learning_model/3.smote/VGG16/vgg16_class_weight_kaggle_diceloss.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (29488, 2) (1083018, 2)
# (1083018, 89) (1083018, 2) (29488, 89) (29488, 2)
# (29488, 2)
# 89
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 89, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 89, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 89, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 44, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 44, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 44, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 22, 256)           0
#
#  block3_conv1 (Conv1D)       (None, 22, 512)           393728
#
#  block3_conv2 (Conv1D)       (None, 22, 512)           786944
#
#  block3_conv3 (Conv1D)       (None, 22, 512)           786944
#
#  block3_pool (MaxPooling1D)  (None, 11, 512)           0
#
#  block4_conv1 (Conv1D)       (None, 11, 1024)          1573888
#
#  block4_conv2 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_conv3 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_pool (MaxPooling1D)  (None, 5, 1024)           0
#
#  block5_conv1 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv2 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv3 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_pool (MaxPooling1D)  (None, 2, 1024)           0
#
#  global_average_pooling1d (G  (None, 1024)             0
#  lobalAveragePooling1D)
#
#  predictions (Dense)         (None, 2)                 2050
#
# =================================================================
# Total params: 19,622,530
# Trainable params: 19,622,530
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1200
# 4231/4231 [==============================] - 162s 38ms/step - loss: 3.7132 - accuracy: 0.5000 - f1_score: 0.3330 - cohen_kappa: -0.6000 - val_loss: 0.9604 - val_accuracy: 0.0396 - val_f1_score: 0.0375 - val_cohen_kappa: -0.9969 - lr: 1.0000e-04
# Epoch 2/1200
# 4231/4231 [==============================] - 160s 38ms/step - loss: 3.7135 - accuracy: 0.5000 - f1_score: 0.3330 - cohen_kappa: -0.6000 - val_loss: 0.9604 - val_accuracy: 0.0396 - val_f1_score: 0.0375 - val_cohen_kappa: -0.9969 - lr: 1.0000e-04
# Epoch 3/1200
# 4231/4231 [==============================] - 160s 38ms/step - loss: 3.7126 - accuracy: 0.5000 - f1_score: 0.3330 - cohen_kappa: -0.6000 - val_loss: 0.9604 - val_accuracy: 0.0396 - val_f1_score: 0.0375 - val_cohen_kappa: -0.9969 - lr: 1.0000e-04
# Epoch 4/1200
# 4231/4231 [==============================] - ETA: 0s - loss: 3.7136 - accuracy: 0.5000 - f1_score: 0.3331 - cohen_kappa: -0.6000
# Epoch 4: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 4231/4231 [==============================] - 160s 38ms/step - loss: 3.7136 - accuracy: 0.5000 - f1_score: 0.3331 - cohen_kappa: -0.6000 - val_loss: 0.9604 - val_accuracy: 0.0396 - val_f1_score: 0.0375 - val_cohen_kappa: -0.9969 - lr: 1.0000e-04
# Epoch 5/1200
# 4231/4231 [==============================] - 160s 38ms/step - loss: 3.7134 - accuracy: 0.5000 - f1_score: 0.3331 - cohen_kappa: -0.6000 - val_loss: 0.9604 - val_accuracy: 0.0396 - val_f1_score: 0.0375 - val_cohen_kappa: -0.9969 - lr: 5.0000e-05
# Epoch 6/1200
# 4231/4231 [==============================] - 161s 38ms/step - loss: 3.7131 - accuracy: 0.5000 - f1_score: 0.3330 - cohen_kappa: -0.6000 - val_loss: 0.9604 - val_accuracy: 0.0396 - val_f1_score: 0.0375 - val_cohen_kappa: -0.9969 - lr: 5.0000e-05
# Epoch 7/1200
# 4231/4231 [==============================] - ETA: 0s - loss: 3.7131 - accuracy: 0.5000 - f1_score: 0.3330 - cohen_kappa: -0.6000
# Epoch 7: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 4231/4231 [==============================] - 160s 38ms/step - loss: 3.7131 - accuracy: 0.5000 - f1_score: 0.3330 - cohen_kappa: -0.6000 - val_loss: 0.9604 - val_accuracy: 0.0396 - val_f1_score: 0.0375 - val_cohen_kappa: -0.9969 - lr: 5.0000e-05
# Epoch 8/1200
# 4231/4231 [==============================] - ETA: 0s - loss: 3.7130 - accuracy: 0.5000 - f1_score: 0.3330 - cohen_kappa: -0.6000Restoring model weights from the end of the best epoch: 1.
# 4231/4231 [==============================] - 160s 38ms/step - loss: 3.7130 - accuracy: 0.5000 - f1_score: 0.3330 - cohen_kappa: -0.6000 - val_loss: 0.9604 - val_accuracy: 0.0396 - val_f1_score: 0.0375 - val_cohen_kappa: -0.9969 - lr: 2.5000e-05
# Epoch 8: early stopping
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 89, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 89, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 89, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 44, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 44, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 44, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 22, 256)           0
#
#  block3_conv1 (Conv1D)       (None, 22, 512)           393728
#
#  block3_conv2 (Conv1D)       (None, 22, 512)           786944
#
#  block3_conv3 (Conv1D)       (None, 22, 512)           786944
#
#  block3_pool (MaxPooling1D)  (None, 11, 512)           0
#
#  block4_conv1 (Conv1D)       (None, 11, 1024)          1573888
#
#  block4_conv2 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_conv3 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_pool (MaxPooling1D)  (None, 5, 1024)           0
#
#  block5_conv1 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv2 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv3 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_pool (MaxPooling1D)  (None, 2, 1024)           0
#
#  global_average_pooling1d (G  (None, 1024)             0
#  lobalAveragePooling1D)
#
#  predictions (Dense)         (None, 2)                 2050
#
# =================================================================
# Total params: 19,622,530
# Trainable params: 19,622,530
# Non-trainable params: 0
# _________________________________________________________________
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 89, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 89, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 89, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 44, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 44, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 44, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 22, 256)           0
#
#  block3_conv1 (Conv1D)       (None, 22, 512)           393728
#
#  block3_conv2 (Conv1D)       (None, 22, 512)           786944
#
#  block3_conv3 (Conv1D)       (None, 22, 512)           786944
#
#  block3_pool (MaxPooling1D)  (None, 11, 512)           0
#
#  block4_conv1 (Conv1D)       (None, 11, 1024)          1573888
#
#  block4_conv2 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_conv3 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_pool (MaxPooling1D)  (None, 5, 1024)           0
#
#  block5_conv1 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv2 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv3 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_pool (MaxPooling1D)  (None, 2, 1024)           0
#
#  global_average_pooling1d (G  (None, 1024)             0
#  lobalAveragePooling1D)
#
#  predictions (Dense)         (None, 2)                 2050
#
# =================================================================
# Total params: 19,622,530
# Trainable params: 19,622,530
# Non-trainable params: 0
# _________________________________________________________________
# 922/922 [==============================] - 4s 4ms/step
# Accuracy: 0.03964324470971243
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     28319
#            1       0.04      1.00      0.08      1169
#
#     accuracy                           0.04     29488
#    macro avg       0.02      0.50      0.04     29488
# weighted avg       0.00      0.04      0.00     29488
#
# Confusion Matrix:
# [[    0 28319]
#  [    0  1169]]
# c:\ProgramData\miniconda3\envs\tensorflow_gpu\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\miniconda3\envs\tensorflow_gpu\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\miniconda3\envs\tensorflow_gpu\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj3/5.deep_learning_model/3.smote/VGG19/vgg19_class_weight_kaggle_diceloss.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (29488, 2) (1083018, 2)
# (29488, 2)
# 89
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 89, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 89, 256)           1024
#
#  block1_conv2 (Conv1D)       (None, 89, 256)           196864
#
#  block1_pool (MaxPooling1D)  (None, 44, 256)           0
#
#  block2_conv1 (Conv1D)       (None, 44, 512)           393728
#
#  block2_conv2 (Conv1D)       (None, 44, 512)           786944
#
#  block2_pool (MaxPooling1D)  (None, 22, 512)           0
#
#  block3_conv1 (Conv1D)       (None, 22, 768)           1180416
#
#  block3_conv2 (Conv1D)       (None, 22, 768)           1770240
#
#  block3_conv3 (Conv1D)       (None, 22, 768)           1770240
#
#  block3_conv4 (Conv1D)       (None, 22, 768)           1770240
#
#  block3_pool (MaxPooling1D)  (None, 11, 768)           0
#
#  block4_conv1 (Conv1D)       (None, 11, 1024)          2360320
#
#  block4_conv2 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_conv3 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_conv4 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_pool (MaxPooling1D)  (None, 5, 1024)           0
#
#  block5_conv1 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv2 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv3 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv4 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_pool (MaxPooling1D)  (None, 2, 1024)           0
#
#  global_average_pooling1d_1   (None, 1024)             0
#  (GlobalAveragePooling1D)
#
#  predictions (Dense)         (None, 2)                 2050
#
# =================================================================
# Total params: 32,259,330
# Trainable params: 32,259,330
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1200
# 4231/4231 [==============================] - 292s 69ms/step - loss: 3.7397 - accuracy: 0.5000 - f1_score: 0.3331 - cohen_kappa: -0.6003 - val_loss: 0.0396 - val_accuracy: 0.9604 - val_f1_score: 0.4898 - val_cohen_kappa: -0.0404 - lr: 0.0010
# Epoch 2/1200
# 4231/4231 [==============================] - 290s 68ms/step - loss: 3.7403 - accuracy: 0.5000 - f1_score: 0.3330 - cohen_kappa: -0.6000 - val_loss: 0.0396 - val_accuracy: 0.9604 - val_f1_score: 0.4898 - val_cohen_kappa: -0.0404 - lr: 0.0010
# Epoch 3/1200
# 4231/4231 [==============================] - 290s 68ms/step - loss: 3.7399 - accuracy: 0.5000 - f1_score: 0.3331 - cohen_kappa: -0.6000 - val_loss: 0.0396 - val_accuracy: 0.9604 - val_f1_score: 0.4898 - val_cohen_kappa: -0.0404 - lr: 0.0010
# Epoch 4/1200
# 4230/4231 [============================>.] - ETA: 0s - loss: 3.7402 - accuracy: 0.5000 - f1_score: 0.3330 - cohen_kappa: -0.6000
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 4231/4231 [==============================] - 290s 68ms/step - loss: 3.7402 - accuracy: 0.5000 - f1_score: 0.3330 - cohen_kappa: -0.6000 - val_loss: 0.0396 - val_accuracy: 0.9604 - val_f1_score: 0.4898 - val_cohen_kappa: -0.0404 - lr: 0.0010
# Epoch 5/1200
# 4231/4231 [==============================] - 290s 68ms/step - loss: 3.7401 - accuracy: 0.5000 - f1_score: 0.3331 - cohen_kappa: -0.6000 - val_loss: 0.0396 - val_accuracy: 0.9604 - val_f1_score: 0.4898 - val_cohen_kappa: -0.0404 - lr: 5.0000e-04
# Epoch 6/1200
# 4231/4231 [==============================] - 290s 68ms/step - loss: 3.7401 - accuracy: 0.5000 - f1_score: 0.3331 - cohen_kappa: -0.6000 - val_loss: 0.0396 - val_accuracy: 0.9604 - val_f1_score: 0.4898 - val_cohen_kappa: -0.0404 - lr: 5.0000e-04
# Epoch 7/1200
# 4230/4231 [============================>.] - ETA: 0s - loss: 3.7403 - accuracy: 0.5000 - f1_score: 0.3330 - cohen_kappa: -0.6000
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 4231/4231 [==============================] - 290s 68ms/step - loss: 3.7402 - accuracy: 0.5000 - f1_score: 0.3330 - cohen_kappa: -0.6000 - val_loss: 0.0396 - val_accuracy: 0.9604 - val_f1_score: 0.4898 - val_cohen_kappa: -0.0404 - lr: 5.0000e-04
# Epoch 8/1200
# 4230/4231 [============================>.] - ETA: 0s - loss: 3.7401 - accuracy: 0.5000 - f1_score: 0.3330 - cohen_kappa: -0.6000Restoring model weights from the end of the best epoch: 1.
# 4231/4231 [==============================] - 290s 69ms/step - loss: 3.7400 - accuracy: 0.5000 - f1_score: 0.3331 - cohen_kappa: -0.6000 - val_loss: 0.0396 - val_accuracy: 0.9604 - val_f1_score: 0.4898 - val_cohen_kappa: -0.0404 - lr: 2.5000e-04
# Epoch 8: early stopping
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 89, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 89, 256)           1024
#
#  block1_conv2 (Conv1D)       (None, 89, 256)           196864
#
#  block1_pool (MaxPooling1D)  (None, 44, 256)           0
#
#  block2_conv1 (Conv1D)       (None, 44, 512)           393728
#
#  block2_conv2 (Conv1D)       (None, 44, 512)           786944
#
#  block2_pool (MaxPooling1D)  (None, 22, 512)           0
#
#  block3_conv1 (Conv1D)       (None, 22, 768)           1180416
#
#  block3_conv2 (Conv1D)       (None, 22, 768)           1770240
#
#  block3_conv3 (Conv1D)       (None, 22, 768)           1770240
#
#  block3_conv4 (Conv1D)       (None, 22, 768)           1770240
#
#  block3_pool (MaxPooling1D)  (None, 11, 768)           0
#
#  block4_conv1 (Conv1D)       (None, 11, 1024)          2360320
#
#  block4_conv2 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_conv3 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_conv4 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_pool (MaxPooling1D)  (None, 5, 1024)           0
#
#  block5_conv1 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv2 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv3 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv4 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_pool (MaxPooling1D)  (None, 2, 1024)           0
#
#  global_average_pooling1d_1   (None, 1024)             0
#  (GlobalAveragePooling1D)
#
#  predictions (Dense)         (None, 2)                 2050
#
# =================================================================
# Total params: 32,259,330
# Trainable params: 32,259,330
# Non-trainable params: 0
# _________________________________________________________________
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 89, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 89, 256)           1024
#
#  block1_conv2 (Conv1D)       (None, 89, 256)           196864
#
#  block1_pool (MaxPooling1D)  (None, 44, 256)           0
#
#  block2_conv1 (Conv1D)       (None, 44, 512)           393728
#
#  block2_conv2 (Conv1D)       (None, 44, 512)           786944
#
#  block2_pool (MaxPooling1D)  (None, 22, 512)           0
#
#  block3_conv1 (Conv1D)       (None, 22, 768)           1180416
#
#  block3_conv2 (Conv1D)       (None, 22, 768)           1770240
#
#  block3_conv3 (Conv1D)       (None, 22, 768)           1770240
#
#  block3_conv4 (Conv1D)       (None, 22, 768)           1770240
#
#  block3_pool (MaxPooling1D)  (None, 11, 768)           0
#
#  block4_conv1 (Conv1D)       (None, 11, 1024)          2360320
#
#  block4_conv2 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_conv3 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_conv4 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_pool (MaxPooling1D)  (None, 5, 1024)           0
#
#  block5_conv1 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv2 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv3 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv4 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_pool (MaxPooling1D)  (None, 2, 1024)           0
#
#  global_average_pooling1d_1   (None, 1024)             0
#  (GlobalAveragePooling1D)
#
#  predictions (Dense)         (None, 2)                 2050
#
# =================================================================
# Total params: 32,259,330
# Trainable params: 32,259,330
# Non-trainable params: 0
# _________________________________________________________________
# 922/922 [==============================] - 6s 6ms/step
# Accuracy: 0.9603567552902875
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98     28319
#            1       0.00      0.00      0.00      1169
#
#     accuracy                           0.96     29488
#    macro avg       0.48      0.50      0.49     29488
# weighted avg       0.92      0.96      0.94     29488
#
# Confusion Matrix:
# [[28319     0]
#  [ 1169     0]]
# c:\ProgramData\miniconda3\envs\tensorflow_gpu\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\miniconda3\envs\tensorflow_gpu\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\miniconda3\envs\tensorflow_gpu\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj3/5.deep_learning_model/3.smote/InceptionV2/inceptionv2_class_weight_kaggle_multiloss.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (29488, 2) (1083018, 2)
# (29488, 2)
# 89
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 89, 1)]      0           []
#
#  conv1d_203 (Conv1D)            (None, 44, 16)       64          ['input_5[0][0]']
#
#  batch_normalization_203 (Batch  (None, 44, 16)      132         ['conv1d_203[0][0]']
#  Normalization)
#
#  activation_203 (Activation)    (None, 44, 16)       0           ['batch_normalization_203[0][0]']
#
#  conv1d_204 (Conv1D)            (None, 42, 16)       784         ['activation_203[0][0]']
#
#  batch_normalization_204 (Batch  (None, 42, 16)      126         ['conv1d_204[0][0]']
#  Normalization)
#
#  activation_204 (Activation)    (None, 42, 16)       0           ['batch_normalization_204[0][0]']
#
#  conv1d_205 (Conv1D)            (None, 42, 32)       1568        ['activation_204[0][0]']
#
#  batch_normalization_205 (Batch  (None, 42, 32)      126         ['conv1d_205[0][0]']
#  Normalization)
#
#  activation_205 (Activation)    (None, 42, 32)       0           ['batch_normalization_205[0][0]']
#
#  max_pooling1d_4 (MaxPooling1D)  (None, 20, 32)      0           ['activation_205[0][0]']
#
#  conv1d_206 (Conv1D)            (None, 20, 80)       2640        ['max_pooling1d_4[0][0]']
#
#  batch_normalization_206 (Batch  (None, 20, 80)      60          ['conv1d_206[0][0]']
#  Normalization)
#
#  activation_206 (Activation)    (None, 20, 80)       0           ['batch_normalization_206[0][0]']
#
#  conv1d_207 (Conv1D)            (None, 18, 192)      46272       ['activation_206[0][0]']
#
#  batch_normalization_207 (Batch  (None, 18, 192)     54          ['conv1d_207[0][0]']
#  Normalization)
#
#  activation_207 (Activation)    (None, 18, 192)      0           ['batch_normalization_207[0][0]']
#
#  max_pooling1d_5 (MaxPooling1D)  (None, 8, 192)      0           ['activation_207[0][0]']
#
#  conv1d_211 (Conv1D)            (None, 8, 32)        6176        ['max_pooling1d_5[0][0]']
#
#  batch_normalization_211 (Batch  (None, 8, 32)       24          ['conv1d_211[0][0]']
#  Normalization)
#
#  activation_211 (Activation)    (None, 8, 32)        0           ['batch_normalization_211[0][0]']
#
#  conv1d_209 (Conv1D)            (None, 8, 48)        9264        ['max_pooling1d_5[0][0]']
#
#  conv1d_212 (Conv1D)            (None, 8, 64)        6208        ['activation_211[0][0]']
#
#  batch_normalization_209 (Batch  (None, 8, 48)       24          ['conv1d_209[0][0]']
#  Normalization)
#
#  batch_normalization_212 (Batch  (None, 8, 64)       24          ['conv1d_212[0][0]']
#  Normalization)
#
#  activation_209 (Activation)    (None, 8, 48)        0           ['batch_normalization_209[0][0]']
#
#  activation_212 (Activation)    (None, 8, 64)        0           ['batch_normalization_212[0][0]']
#
#  average_pooling1d_1 (AveragePo  (None, 8, 192)      0           ['max_pooling1d_5[0][0]']
#  oling1D)
#
#  conv1d_208 (Conv1D)            (None, 8, 64)        12352       ['max_pooling1d_5[0][0]']
#
#  conv1d_210 (Conv1D)            (None, 8, 32)        7712        ['activation_209[0][0]']
#
#  conv1d_213 (Conv1D)            (None, 8, 64)        12352       ['activation_212[0][0]']
#
#  conv1d_214 (Conv1D)            (None, 8, 32)        6176        ['average_pooling1d_1[0][0]']
#
#  batch_normalization_208 (Batch  (None, 8, 64)       24          ['conv1d_208[0][0]']
#  Normalization)
#
#  batch_normalization_210 (Batch  (None, 8, 32)       24          ['conv1d_210[0][0]']
#  Normalization)
#
#  batch_normalization_213 (Batch  (None, 8, 64)       24          ['conv1d_213[0][0]']
#  Normalization)
#
#  batch_normalization_214 (Batch  (None, 8, 32)       24          ['conv1d_214[0][0]']
#  Normalization)
#
#  activation_208 (Activation)    (None, 8, 64)        0           ['batch_normalization_208[0][0]']
#
#  activation_210 (Activation)    (None, 8, 32)        0           ['batch_normalization_210[0][0]']
#
#  activation_213 (Activation)    (None, 8, 64)        0           ['batch_normalization_213[0][0]']
#
#  activation_214 (Activation)    (None, 8, 32)        0           ['batch_normalization_214[0][0]']
#
#  mixed_5b (Concatenate)         (None, 8, 192)       0           ['activation_208[0][0]',
#                                                                   'activation_210[0][0]',
#                                                                   'activation_213[0][0]',
#                                                                   'activation_214[0][0]']
#
#  conv1d_218 (Conv1D)            (None, 8, 32)        6176        ['mixed_5b[0][0]']
#
#  batch_normalization_218 (Batch  (None, 8, 32)       24          ['conv1d_218[0][0]']
#  Normalization)
#
#  activation_218 (Activation)    (None, 8, 32)        0           ['batch_normalization_218[0][0]']
#
#  conv1d_216 (Conv1D)            (None, 8, 32)        6176        ['mixed_5b[0][0]']
#
#  conv1d_219 (Conv1D)            (None, 8, 48)        4656        ['activation_218[0][0]']
#
#  batch_normalization_216 (Batch  (None, 8, 32)       24          ['conv1d_216[0][0]']
#  Normalization)
#
#  batch_normalization_219 (Batch  (None, 8, 48)       24          ['conv1d_219[0][0]']
#  Normalization)
#
#  activation_216 (Activation)    (None, 8, 32)        0           ['batch_normalization_216[0][0]']
#
#  activation_219 (Activation)    (None, 8, 48)        0           ['batch_normalization_219[0][0]']
#
#  conv1d_215 (Conv1D)            (None, 8, 32)        6176        ['mixed_5b[0][0]']
#
#  conv1d_217 (Conv1D)            (None, 8, 32)        3104        ['activation_216[0][0]']
#
#  conv1d_220 (Conv1D)            (None, 8, 64)        9280        ['activation_219[0][0]']
#
#  batch_normalization_215 (Batch  (None, 8, 32)       24          ['conv1d_215[0][0]']
#  Normalization)
#
#  batch_normalization_217 (Batch  (None, 8, 32)       24          ['conv1d_217[0][0]']
#  Normalization)
#
#  batch_normalization_220 (Batch  (None, 8, 64)       24          ['conv1d_220[0][0]']
#  Normalization)
#
#  activation_215 (Activation)    (None, 8, 32)        0           ['batch_normalization_215[0][0]']
#
#  activation_217 (Activation)    (None, 8, 32)        0           ['batch_normalization_217[0][0]']
#
#  activation_220 (Activation)    (None, 8, 64)        0           ['batch_normalization_220[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 8, 128)       0           ['activation_215[0][0]',
#                                                                   'activation_217[0][0]',
#                                                                   'activation_220[0][0]']
#
#  block35_1_conv (Conv1D)        (None, 8, 192)       24768       ['block35_1_mixed[0][0]']
#
#  block35_1_conv_bn (BatchNormal  (None, 8, 192)      24          ['block35_1_conv[0][0]']
#  ization)
#
#  block35_1 (Lambda)             (None, 8, 192)       0           ['mixed_5b[0][0]',
#                                                                   'block35_1_conv_bn[0][0]']
#
#  block35_1_ac (Activation)      (None, 8, 192)       0           ['block35_1[0][0]']
#
#  conv1d_224 (Conv1D)            (None, 8, 32)        6176        ['block35_1_ac[0][0]']
#
#  batch_normalization_224 (Batch  (None, 8, 32)       24          ['conv1d_224[0][0]']
#  Normalization)
#
#  activation_224 (Activation)    (None, 8, 32)        0           ['batch_normalization_224[0][0]']
#
#  conv1d_222 (Conv1D)            (None, 8, 32)        6176        ['block35_1_ac[0][0]']
#
#  conv1d_225 (Conv1D)            (None, 8, 48)        4656        ['activation_224[0][0]']
#
#  batch_normalization_222 (Batch  (None, 8, 32)       24          ['conv1d_222[0][0]']
#  Normalization)
#
#  batch_normalization_225 (Batch  (None, 8, 48)       24          ['conv1d_225[0][0]']
#  Normalization)
#
#  activation_222 (Activation)    (None, 8, 32)        0           ['batch_normalization_222[0][0]']
#
#  activation_225 (Activation)    (None, 8, 48)        0           ['batch_normalization_225[0][0]']
#
#  conv1d_221 (Conv1D)            (None, 8, 32)        6176        ['block35_1_ac[0][0]']
#
#  conv1d_223 (Conv1D)            (None, 8, 32)        3104        ['activation_222[0][0]']
#
#  conv1d_226 (Conv1D)            (None, 8, 64)        9280        ['activation_225[0][0]']
#
#  batch_normalization_221 (Batch  (None, 8, 32)       24          ['conv1d_221[0][0]']
#  Normalization)
#
#  batch_normalization_223 (Batch  (None, 8, 32)       24          ['conv1d_223[0][0]']
#  Normalization)
#
#  batch_normalization_226 (Batch  (None, 8, 64)       24          ['conv1d_226[0][0]']
#  Normalization)
#
#  activation_221 (Activation)    (None, 8, 32)        0           ['batch_normalization_221[0][0]']
#
#  activation_223 (Activation)    (None, 8, 32)        0           ['batch_normalization_223[0][0]']
#
#  activation_226 (Activation)    (None, 8, 64)        0           ['batch_normalization_226[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 8, 128)       0           ['activation_221[0][0]',
#                                                                   'activation_223[0][0]',
#                                                                   'activation_226[0][0]']
#
#  block35_2_conv (Conv1D)        (None, 8, 192)       24768       ['block35_2_mixed[0][0]']
#
#  block35_2_conv_bn (BatchNormal  (None, 8, 192)      24          ['block35_2_conv[0][0]']
#  ization)
#
#  block35_2 (Lambda)             (None, 8, 192)       0           ['block35_1_ac[0][0]',
#                                                                   'block35_2_conv_bn[0][0]']
#
#  block35_2_ac (Activation)      (None, 8, 192)       0           ['block35_2[0][0]']
#
#  conv1d_230 (Conv1D)            (None, 8, 32)        6176        ['block35_2_ac[0][0]']
#
#  batch_normalization_230 (Batch  (None, 8, 32)       24          ['conv1d_230[0][0]']
#  Normalization)
#
#  activation_230 (Activation)    (None, 8, 32)        0           ['batch_normalization_230[0][0]']
#
#  conv1d_228 (Conv1D)            (None, 8, 32)        6176        ['block35_2_ac[0][0]']
#
#  conv1d_231 (Conv1D)            (None, 8, 48)        4656        ['activation_230[0][0]']
#
#  batch_normalization_228 (Batch  (None, 8, 32)       24          ['conv1d_228[0][0]']
#  Normalization)
#
#  batch_normalization_231 (Batch  (None, 8, 48)       24          ['conv1d_231[0][0]']
#  Normalization)
#
#  activation_228 (Activation)    (None, 8, 32)        0           ['batch_normalization_228[0][0]']
#
#  activation_231 (Activation)    (None, 8, 48)        0           ['batch_normalization_231[0][0]']
#
#  conv1d_227 (Conv1D)            (None, 8, 32)        6176        ['block35_2_ac[0][0]']
#
#  conv1d_229 (Conv1D)            (None, 8, 32)        3104        ['activation_228[0][0]']
#
#  conv1d_232 (Conv1D)            (None, 8, 64)        9280        ['activation_231[0][0]']
#
#  batch_normalization_227 (Batch  (None, 8, 32)       24          ['conv1d_227[0][0]']
#  Normalization)
#
#  batch_normalization_229 (Batch  (None, 8, 32)       24          ['conv1d_229[0][0]']
#  Normalization)
#
#  batch_normalization_232 (Batch  (None, 8, 64)       24          ['conv1d_232[0][0]']
#  Normalization)
#
#  activation_227 (Activation)    (None, 8, 32)        0           ['batch_normalization_227[0][0]']
#
#  activation_229 (Activation)    (None, 8, 32)        0           ['batch_normalization_229[0][0]']
#
#  activation_232 (Activation)    (None, 8, 64)        0           ['batch_normalization_232[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 8, 128)       0           ['activation_227[0][0]',
#                                                                   'activation_229[0][0]',
#                                                                   'activation_232[0][0]']
#
#  block35_3_conv (Conv1D)        (None, 8, 192)       24768       ['block35_3_mixed[0][0]']
#
#  block35_3_conv_bn (BatchNormal  (None, 8, 192)      24          ['block35_3_conv[0][0]']
#  ization)
#
#  block35_3 (Lambda)             (None, 8, 192)       0           ['block35_2_ac[0][0]',
#                                                                   'block35_3_conv_bn[0][0]']
#
#  block35_3_ac (Activation)      (None, 8, 192)       0           ['block35_3[0][0]']
#
#  conv1d_236 (Conv1D)            (None, 8, 32)        6176        ['block35_3_ac[0][0]']
#
#  batch_normalization_236 (Batch  (None, 8, 32)       24          ['conv1d_236[0][0]']
#  Normalization)
#
#  activation_236 (Activation)    (None, 8, 32)        0           ['batch_normalization_236[0][0]']
#
#  conv1d_234 (Conv1D)            (None, 8, 32)        6176        ['block35_3_ac[0][0]']
#
#  conv1d_237 (Conv1D)            (None, 8, 48)        4656        ['activation_236[0][0]']
#
#  batch_normalization_234 (Batch  (None, 8, 32)       24          ['conv1d_234[0][0]']
#  Normalization)
#
#  batch_normalization_237 (Batch  (None, 8, 48)       24          ['conv1d_237[0][0]']
#  Normalization)
#
#  activation_234 (Activation)    (None, 8, 32)        0           ['batch_normalization_234[0][0]']
#
#  activation_237 (Activation)    (None, 8, 48)        0           ['batch_normalization_237[0][0]']
#
#  conv1d_233 (Conv1D)            (None, 8, 32)        6176        ['block35_3_ac[0][0]']
#
#  conv1d_235 (Conv1D)            (None, 8, 32)        3104        ['activation_234[0][0]']
#
#  conv1d_238 (Conv1D)            (None, 8, 64)        9280        ['activation_237[0][0]']
#
#  batch_normalization_233 (Batch  (None, 8, 32)       24          ['conv1d_233[0][0]']
#  Normalization)
#
#  batch_normalization_235 (Batch  (None, 8, 32)       24          ['conv1d_235[0][0]']
#  Normalization)
#
#  batch_normalization_238 (Batch  (None, 8, 64)       24          ['conv1d_238[0][0]']
#  Normalization)
#
#  activation_233 (Activation)    (None, 8, 32)        0           ['batch_normalization_233[0][0]']
#
#  activation_235 (Activation)    (None, 8, 32)        0           ['batch_normalization_235[0][0]']
#
#  activation_238 (Activation)    (None, 8, 64)        0           ['batch_normalization_238[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 8, 128)       0           ['activation_233[0][0]',
#                                                                   'activation_235[0][0]',
#                                                                   'activation_238[0][0]']
#
#  block35_4_conv (Conv1D)        (None, 8, 192)       24768       ['block35_4_mixed[0][0]']
#
#  block35_4_conv_bn (BatchNormal  (None, 8, 192)      24          ['block35_4_conv[0][0]']
#  ization)
#
#  block35_4 (Lambda)             (None, 8, 192)       0           ['block35_3_ac[0][0]',
#                                                                   'block35_4_conv_bn[0][0]']
#
#  block35_4_ac (Activation)      (None, 8, 192)       0           ['block35_4[0][0]']
#
#  conv1d_242 (Conv1D)            (None, 8, 32)        6176        ['block35_4_ac[0][0]']
#
#  batch_normalization_242 (Batch  (None, 8, 32)       24          ['conv1d_242[0][0]']
#  Normalization)
#
#  activation_242 (Activation)    (None, 8, 32)        0           ['batch_normalization_242[0][0]']
#
#  conv1d_240 (Conv1D)            (None, 8, 32)        6176        ['block35_4_ac[0][0]']
#
#  conv1d_243 (Conv1D)            (None, 8, 48)        4656        ['activation_242[0][0]']
#
#  batch_normalization_240 (Batch  (None, 8, 32)       24          ['conv1d_240[0][0]']
#  Normalization)
#
#  batch_normalization_243 (Batch  (None, 8, 48)       24          ['conv1d_243[0][0]']
#  Normalization)
#
#  activation_240 (Activation)    (None, 8, 32)        0           ['batch_normalization_240[0][0]']
#
#  activation_243 (Activation)    (None, 8, 48)        0           ['batch_normalization_243[0][0]']
#
#  conv1d_239 (Conv1D)            (None, 8, 32)        6176        ['block35_4_ac[0][0]']
#
#  conv1d_241 (Conv1D)            (None, 8, 32)        3104        ['activation_240[0][0]']
#
#  conv1d_244 (Conv1D)            (None, 8, 64)        9280        ['activation_243[0][0]']
#
#  batch_normalization_239 (Batch  (None, 8, 32)       24          ['conv1d_239[0][0]']
#  Normalization)
#
#  batch_normalization_241 (Batch  (None, 8, 32)       24          ['conv1d_241[0][0]']
#  Normalization)
#
#  batch_normalization_244 (Batch  (None, 8, 64)       24          ['conv1d_244[0][0]']
#  Normalization)
#
#  activation_239 (Activation)    (None, 8, 32)        0           ['batch_normalization_239[0][0]']
#
#  activation_241 (Activation)    (None, 8, 32)        0           ['batch_normalization_241[0][0]']
#
#  activation_244 (Activation)    (None, 8, 64)        0           ['batch_normalization_244[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 8, 128)       0           ['activation_239[0][0]',
#                                                                   'activation_241[0][0]',
#                                                                   'activation_244[0][0]']
#
#  block35_5_conv (Conv1D)        (None, 8, 192)       24768       ['block35_5_mixed[0][0]']
#
#  block35_5_conv_bn (BatchNormal  (None, 8, 192)      24          ['block35_5_conv[0][0]']
#  ization)
#
#  block35_5 (Lambda)             (None, 8, 192)       0           ['block35_4_ac[0][0]',
#                                                                   'block35_5_conv_bn[0][0]']
#
#  block35_5_ac (Activation)      (None, 8, 192)       0           ['block35_5[0][0]']
#
#  conv1d_248 (Conv1D)            (None, 8, 32)        6176        ['block35_5_ac[0][0]']
#
#  batch_normalization_248 (Batch  (None, 8, 32)       24          ['conv1d_248[0][0]']
#  Normalization)
#
#  activation_248 (Activation)    (None, 8, 32)        0           ['batch_normalization_248[0][0]']
#
#  conv1d_246 (Conv1D)            (None, 8, 32)        6176        ['block35_5_ac[0][0]']
#
#  conv1d_249 (Conv1D)            (None, 8, 48)        4656        ['activation_248[0][0]']
#
#  batch_normalization_246 (Batch  (None, 8, 32)       24          ['conv1d_246[0][0]']
#  Normalization)
#
#  batch_normalization_249 (Batch  (None, 8, 48)       24          ['conv1d_249[0][0]']
#  Normalization)
#
#  activation_246 (Activation)    (None, 8, 32)        0           ['batch_normalization_246[0][0]']
#
#  activation_249 (Activation)    (None, 8, 48)        0           ['batch_normalization_249[0][0]']
#
#  conv1d_245 (Conv1D)            (None, 8, 32)        6176        ['block35_5_ac[0][0]']
#
#  conv1d_247 (Conv1D)            (None, 8, 32)        3104        ['activation_246[0][0]']
#
#  conv1d_250 (Conv1D)            (None, 8, 64)        9280        ['activation_249[0][0]']
#
#  batch_normalization_245 (Batch  (None, 8, 32)       24          ['conv1d_245[0][0]']
#  Normalization)
#
#  batch_normalization_247 (Batch  (None, 8, 32)       24          ['conv1d_247[0][0]']
#  Normalization)
#
#  batch_normalization_250 (Batch  (None, 8, 64)       24          ['conv1d_250[0][0]']
#  Normalization)
#
#  activation_245 (Activation)    (None, 8, 32)        0           ['batch_normalization_245[0][0]']
#
#  activation_247 (Activation)    (None, 8, 32)        0           ['batch_normalization_247[0][0]']
#
#  activation_250 (Activation)    (None, 8, 64)        0           ['batch_normalization_250[0][0]']
#
#  block35_6_mixed (Concatenate)  (None, 8, 128)       0           ['activation_245[0][0]',
#                                                                   'activation_247[0][0]',
#                                                                   'activation_250[0][0]']
#
#  block35_6_conv (Conv1D)        (None, 8, 192)       24768       ['block35_6_mixed[0][0]']
#
#  block35_6_conv_bn (BatchNormal  (None, 8, 192)      24          ['block35_6_conv[0][0]']
#  ization)
#
#  block35_6 (Lambda)             (None, 8, 192)       0           ['block35_5_ac[0][0]',
#                                                                   'block35_6_conv_bn[0][0]']
#
#  block35_6_ac (Activation)      (None, 8, 192)       0           ['block35_6[0][0]']
#
#  conv1d_254 (Conv1D)            (None, 8, 32)        6176        ['block35_6_ac[0][0]']
#
#  batch_normalization_254 (Batch  (None, 8, 32)       24          ['conv1d_254[0][0]']
#  Normalization)
#
#  activation_254 (Activation)    (None, 8, 32)        0           ['batch_normalization_254[0][0]']
#
#  conv1d_252 (Conv1D)            (None, 8, 32)        6176        ['block35_6_ac[0][0]']
#
#  conv1d_255 (Conv1D)            (None, 8, 48)        4656        ['activation_254[0][0]']
#
#  batch_normalization_252 (Batch  (None, 8, 32)       24          ['conv1d_252[0][0]']
#  Normalization)
#
#  batch_normalization_255 (Batch  (None, 8, 48)       24          ['conv1d_255[0][0]']
#  Normalization)
#
#  activation_252 (Activation)    (None, 8, 32)        0           ['batch_normalization_252[0][0]']
#
#  activation_255 (Activation)    (None, 8, 48)        0           ['batch_normalization_255[0][0]']
#
#  conv1d_251 (Conv1D)            (None, 8, 32)        6176        ['block35_6_ac[0][0]']
#
#  conv1d_253 (Conv1D)            (None, 8, 32)        3104        ['activation_252[0][0]']
#
#  conv1d_256 (Conv1D)            (None, 8, 64)        9280        ['activation_255[0][0]']
#
#  batch_normalization_251 (Batch  (None, 8, 32)       24          ['conv1d_251[0][0]']
#  Normalization)
#
#  batch_normalization_253 (Batch  (None, 8, 32)       24          ['conv1d_253[0][0]']
#  Normalization)
#
#  batch_normalization_256 (Batch  (None, 8, 64)       24          ['conv1d_256[0][0]']
#  Normalization)
#
#  activation_251 (Activation)    (None, 8, 32)        0           ['batch_normalization_251[0][0]']
#
#  activation_253 (Activation)    (None, 8, 32)        0           ['batch_normalization_253[0][0]']
#
#  activation_256 (Activation)    (None, 8, 64)        0           ['batch_normalization_256[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 8, 128)       0           ['activation_251[0][0]',
#                                                                   'activation_253[0][0]',
#                                                                   'activation_256[0][0]']
#
# ...
#  batch_normalization_393 (Batch  (None, 2, 256)      6           ['conv1d_393[0][0]']
#  Normalization)
#
#  activation_390 (Activation)    (None, 2, 192)       0           ['batch_normalization_390[0][0]']
#
#  activation_393 (Activation)    (None, 2, 256)       0           ['batch_normalization_393[0][0]']
#
#  block8_7_mixed (Concatenate)   (None, 2, 448)       0           ['activation_390[0][0]',
#                                                                   'activation_393[0][0]']
#
#  block8_7_conv (Conv1D)         (None, 2, 992)       445408      ['block8_7_mixed[0][0]']
#
#  block8_7_conv_bn (BatchNormali  (None, 2, 992)      6           ['block8_7_conv[0][0]']
#  zation)
#
#  block8_7 (Lambda)              (None, 2, 992)       0           ['block8_6_ac[0][0]',
#                                                                   'block8_7_conv_bn[0][0]']
#
#  block8_7_ac (Activation)       (None, 2, 992)       0           ['block8_7[0][0]']
#
#  conv1d_395 (Conv1D)            (None, 2, 192)       190656      ['block8_7_ac[0][0]']
#
#  batch_normalization_395 (Batch  (None, 2, 192)      6           ['conv1d_395[0][0]']
#  Normalization)
#
#  activation_395 (Activation)    (None, 2, 192)       0           ['batch_normalization_395[0][0]']
#
#  conv1d_396 (Conv1D)            (None, 2, 224)       43232       ['activation_395[0][0]']
#
#  batch_normalization_396 (Batch  (None, 2, 224)      6           ['conv1d_396[0][0]']
#  Normalization)
#
#  activation_396 (Activation)    (None, 2, 224)       0           ['batch_normalization_396[0][0]']
#
#  conv1d_394 (Conv1D)            (None, 2, 192)       190656      ['block8_7_ac[0][0]']
#
#  conv1d_397 (Conv1D)            (None, 2, 256)       172288      ['activation_396[0][0]']
#
#  batch_normalization_394 (Batch  (None, 2, 192)      6           ['conv1d_394[0][0]']
#  Normalization)
#
#  batch_normalization_397 (Batch  (None, 2, 256)      6           ['conv1d_397[0][0]']
#  Normalization)
#
#  activation_394 (Activation)    (None, 2, 192)       0           ['batch_normalization_394[0][0]']
#
#  activation_397 (Activation)    (None, 2, 256)       0           ['batch_normalization_397[0][0]']
#
#  block8_8_mixed (Concatenate)   (None, 2, 448)       0           ['activation_394[0][0]',
#                                                                   'activation_397[0][0]']
#
#  block8_8_conv (Conv1D)         (None, 2, 992)       445408      ['block8_8_mixed[0][0]']
#
#  block8_8_conv_bn (BatchNormali  (None, 2, 992)      6           ['block8_8_conv[0][0]']
#  zation)
#
#  block8_8 (Lambda)              (None, 2, 992)       0           ['block8_7_ac[0][0]',
#                                                                   'block8_8_conv_bn[0][0]']
#
#  block8_8_ac (Activation)       (None, 2, 992)       0           ['block8_8[0][0]']
#
#  conv1d_399 (Conv1D)            (None, 2, 192)       190656      ['block8_8_ac[0][0]']
#
#  batch_normalization_399 (Batch  (None, 2, 192)      6           ['conv1d_399[0][0]']
#  Normalization)
#
#  activation_399 (Activation)    (None, 2, 192)       0           ['batch_normalization_399[0][0]']
#
#  conv1d_400 (Conv1D)            (None, 2, 224)       43232       ['activation_399[0][0]']
#
#  batch_normalization_400 (Batch  (None, 2, 224)      6           ['conv1d_400[0][0]']
#  Normalization)
#
#  activation_400 (Activation)    (None, 2, 224)       0           ['batch_normalization_400[0][0]']
#
#  conv1d_398 (Conv1D)            (None, 2, 192)       190656      ['block8_8_ac[0][0]']
#
#  conv1d_401 (Conv1D)            (None, 2, 256)       172288      ['activation_400[0][0]']
#
#  batch_normalization_398 (Batch  (None, 2, 192)      6           ['conv1d_398[0][0]']
#  Normalization)
#
#  batch_normalization_401 (Batch  (None, 2, 256)      6           ['conv1d_401[0][0]']
#  Normalization)
#
#  activation_398 (Activation)    (None, 2, 192)       0           ['batch_normalization_398[0][0]']
#
#  activation_401 (Activation)    (None, 2, 256)       0           ['batch_normalization_401[0][0]']
#
#  block8_9_mixed (Concatenate)   (None, 2, 448)       0           ['activation_398[0][0]',
#                                                                   'activation_401[0][0]']
#
#  block8_9_conv (Conv1D)         (None, 2, 992)       445408      ['block8_9_mixed[0][0]']
#
#  block8_9_conv_bn (BatchNormali  (None, 2, 992)      6           ['block8_9_conv[0][0]']
#  zation)
#
#  block8_9 (Lambda)              (None, 2, 992)       0           ['block8_8_ac[0][0]',
#                                                                   'block8_9_conv_bn[0][0]']
#
#  block8_9_ac (Activation)       (None, 2, 992)       0           ['block8_9[0][0]']
#
#  conv1d_403 (Conv1D)            (None, 2, 192)       190656      ['block8_9_ac[0][0]']
#
#  batch_normalization_403 (Batch  (None, 2, 192)      6           ['conv1d_403[0][0]']
#  Normalization)
#
#  activation_403 (Activation)    (None, 2, 192)       0           ['batch_normalization_403[0][0]']
#
#  conv1d_404 (Conv1D)            (None, 2, 224)       43232       ['activation_403[0][0]']
#
#  batch_normalization_404 (Batch  (None, 2, 224)      6           ['conv1d_404[0][0]']
#  Normalization)
#
#  activation_404 (Activation)    (None, 2, 224)       0           ['batch_normalization_404[0][0]']
#
#  conv1d_402 (Conv1D)            (None, 2, 192)       190656      ['block8_9_ac[0][0]']
#
#  conv1d_405 (Conv1D)            (None, 2, 256)       172288      ['activation_404[0][0]']
#
#  batch_normalization_402 (Batch  (None, 2, 192)      6           ['conv1d_402[0][0]']
#  Normalization)
#
#  batch_normalization_405 (Batch  (None, 2, 256)      6           ['conv1d_405[0][0]']
#  Normalization)
#
#  activation_402 (Activation)    (None, 2, 192)       0           ['batch_normalization_402[0][0]']
#
#  activation_405 (Activation)    (None, 2, 256)       0           ['batch_normalization_405[0][0]']
#
#  block8_10_mixed (Concatenate)  (None, 2, 448)       0           ['activation_402[0][0]',
#                                                                   'activation_405[0][0]']
#
#  block8_10_conv (Conv1D)        (None, 2, 992)       445408      ['block8_10_mixed[0][0]']
#
#  block8_10_conv_bn (BatchNormal  (None, 2, 992)      6           ['block8_10_conv[0][0]']
#  ization)
#
#  block8_10 (Lambda)             (None, 2, 992)       0           ['block8_9_ac[0][0]',
#                                                                   'block8_10_conv_bn[0][0]']
#
#  conv_7b (Conv1D)               (None, 2, 1536)      1525248     ['block8_10[0][0]']
#
#  conv_7b_bn (BatchNormalization  (None, 2, 1536)     6           ['conv_7b[0][0]']
#  )
#
#  conv_7b_ac (Activation)        (None, 2, 1536)      0           ['conv_7b_bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 1536)        0           ['conv_7b_ac[0][0]']
#  1D)
#
#  predictions (Dense)            (None, 2)            3074        ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 24,310,888
# Trainable params: 24,308,228
# Non-trainable params: 2,660
# __________________________________________________________________________________________________
# 922/922 [==============================] - 24s 22ms/step
# Accuracy: 0.9412981551817688
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97     28319
#            1       0.32      0.44      0.37      1169
#
#     accuracy                           0.94     29488
#    macro avg       0.65      0.70      0.67     29488
# weighted avg       0.95      0.94      0.95     29488
#
# Confusion Matrix:
# [[27247  1072]
#  [  659   510]]

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj3/5.deep_learning_model/3.smote/VGG16/vgg16_class_weight_kaggle_multiloss.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (29488, 2) (1083018, 2)
# (1083018, 89) (1083018, 2) (29488, 89) (29488, 2)
# (29488, 2)
# 89
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 89, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 89, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 89, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 44, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 44, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 44, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 22, 256)           0
#
#  block3_conv1 (Conv1D)       (None, 22, 512)           393728
#
#  block3_conv2 (Conv1D)       (None, 22, 512)           786944
#
#  block3_conv3 (Conv1D)       (None, 22, 512)           786944
#
#  block3_pool (MaxPooling1D)  (None, 11, 512)           0
#
#  block4_conv1 (Conv1D)       (None, 11, 1024)          1573888
#
#  block4_conv2 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_conv3 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_pool (MaxPooling1D)  (None, 5, 1024)           0
#
#  block5_conv1 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv2 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv3 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_pool (MaxPooling1D)  (None, 2, 1024)           0
#
#  global_average_pooling1d_2   (None, 1024)             0
#  (GlobalAveragePooling1D)
#
#  predictions (Dense)         (None, 2)                 2050
#
# =================================================================
# Total params: 19,622,530
# Trainable params: 19,622,530
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1200
# 4231/4231 [==============================] - 159s 37ms/step - loss: 3.1326 - accuracy: 0.8258 - f1_score: 0.8201 - cohen_kappa: -0.9996 - val_loss: 0.3498 - val_accuracy: 0.8266 - val_f1_score: 0.5511 - val_cohen_kappa: -0.2458 - lr: 1.0000e-04
# Epoch 2/1200
# 4231/4231 [==============================] - 157s 37ms/step - loss: 1.1368 - accuracy: 0.9225 - f1_score: 0.9216 - cohen_kappa: -0.9993 - val_loss: 0.1101 - val_accuracy: 0.9571 - val_f1_score: 0.6742 - val_cohen_kappa: -0.0806 - lr: 1.0000e-04
# Epoch 3/1200
# 4231/4231 [==============================] - 157s 37ms/step - loss: 0.7434 - accuracy: 0.9526 - f1_score: 0.9524 - cohen_kappa: -0.9996 - val_loss: 0.1516 - val_accuracy: 0.9276 - val_f1_score: 0.6336 - val_cohen_kappa: -0.1175 - lr: 1.0000e-04
# Epoch 4/1200
# 4231/4231 [==============================] - 157s 37ms/step - loss: 0.6091 - accuracy: 0.9621 - f1_score: 0.9619 - cohen_kappa: -0.9997 - val_loss: 0.1659 - val_accuracy: 0.9241 - val_f1_score: 0.6344 - val_cohen_kappa: -0.1234 - lr: 1.0000e-04
# Epoch 5/1200
# 4231/4231 [==============================] - ETA: 0s - loss: 0.5226 - accuracy: 0.9679 - f1_score: 0.9677 - cohen_kappa: -0.9997
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 4231/4231 [==============================] - 157s 37ms/step - loss: 0.5226 - accuracy: 0.9679 - f1_score: 0.9677 - cohen_kappa: -0.9997 - val_loss: 0.1201 - val_accuracy: 0.9504 - val_f1_score: 0.6642 - val_cohen_kappa: -0.0882 - lr: 1.0000e-04
# Epoch 6/1200
# 4231/4231 [==============================] - 157s 37ms/step - loss: 0.3918 - accuracy: 0.9766 - f1_score: 0.9766 - cohen_kappa: -0.9998 - val_loss: 0.1005 - val_accuracy: 0.9563 - val_f1_score: 0.6721 - val_cohen_kappa: -0.0789 - lr: 5.0000e-05
# Epoch 7/1200
# 4231/4231 [==============================] - 157s 37ms/step - loss: 0.3446 - accuracy: 0.9798 - f1_score: 0.9797 - cohen_kappa: -0.9999 - val_loss: 0.0841 - val_accuracy: 0.9678 - val_f1_score: 0.6886 - val_cohen_kappa: -0.0645 - lr: 5.0000e-05
# Epoch 8/1200
# 4231/4231 [==============================] - 157s 37ms/step - loss: 0.3137 - accuracy: 0.9817 - f1_score: 0.9817 - cohen_kappa: -0.9999 - val_loss: 0.1068 - val_accuracy: 0.9573 - val_f1_score: 0.6839 - val_cohen_kappa: -0.0806 - lr: 5.0000e-05
# Epoch 9/1200
# 4231/4231 [==============================] - 157s 37ms/step - loss: 0.2817 - accuracy: 0.9837 - f1_score: 0.9836 - cohen_kappa: -0.9999 - val_loss: 0.1030 - val_accuracy: 0.9575 - val_f1_score: 0.6926 - val_cohen_kappa: -0.0842 - lr: 5.0000e-05
# Epoch 10/1200
# 4231/4231 [==============================] - ETA: 0s - loss: 0.2582 - accuracy: 0.9851 - f1_score: 0.9851 - cohen_kappa: -0.9999
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 4231/4231 [==============================] - 157s 37ms/step - loss: 0.2582 - accuracy: 0.9851 - f1_score: 0.9851 - cohen_kappa: -0.9999 - val_loss: 0.1130 - val_accuracy: 0.9529 - val_f1_score: 0.6824 - val_cohen_kappa: -0.0889 - lr: 5.0000e-05
# Epoch 11/1200
# 4231/4231 [==============================] - 157s 37ms/step - loss: 0.1869 - accuracy: 0.9896 - f1_score: 0.9896 - cohen_kappa: -1.0000 - val_loss: 0.1097 - val_accuracy: 0.9592 - val_f1_score: 0.6905 - val_cohen_kappa: -0.0791 - lr: 2.5000e-05
# Epoch 12/1200
# 4231/4231 [==============================] - 157s 37ms/step - loss: 0.1621 - accuracy: 0.9911 - f1_score: 0.9911 - cohen_kappa: -1.0000 - val_loss: 0.1384 - val_accuracy: 0.9514 - val_f1_score: 0.6831 - val_cohen_kappa: -0.0921 - lr: 2.5000e-05
# Epoch 13/1200
# 4231/4231 [==============================] - ETA: 0s - loss: 0.1456 - accuracy: 0.9920 - f1_score: 0.9920 - cohen_kappa: -1.0000
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 4231/4231 [==============================] - 157s 37ms/step - loss: 0.1456 - accuracy: 0.9920 - f1_score: 0.9920 - cohen_kappa: -1.0000 - val_loss: 0.1235 - val_accuracy: 0.9565 - val_f1_score: 0.6853 - val_cohen_kappa: -0.0843 - lr: 2.5000e-05
# Epoch 14/1200
# 4231/4231 [==============================] - ETA: 0s - loss: 0.1017 - accuracy: 0.9946 - f1_score: 0.9946 - cohen_kappa: -1.0000Restoring model weights from the end of the best epoch: 7.
# 4231/4231 [==============================] - 157s 37ms/step - loss: 0.1017 - accuracy: 0.9946 - f1_score: 0.9946 - cohen_kappa: -1.0000 - val_loss: 0.1584 - val_accuracy: 0.9495 - val_f1_score: 0.6752 - val_cohen_kappa: -0.0933 - lr: 1.2500e-05
# Epoch 14: early stopping
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 89, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 89, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 89, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 44, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 44, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 44, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 22, 256)           0
#
#  block3_conv1 (Conv1D)       (None, 22, 512)           393728
#
#  block3_conv2 (Conv1D)       (None, 22, 512)           786944
#
#  block3_conv3 (Conv1D)       (None, 22, 512)           786944
#
#  block3_pool (MaxPooling1D)  (None, 11, 512)           0
#
#  block4_conv1 (Conv1D)       (None, 11, 1024)          1573888
#
#  block4_conv2 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_conv3 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_pool (MaxPooling1D)  (None, 5, 1024)           0
#
#  block5_conv1 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv2 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv3 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_pool (MaxPooling1D)  (None, 2, 1024)           0
#
#  global_average_pooling1d_2   (None, 1024)             0
#  (GlobalAveragePooling1D)
#
#  predictions (Dense)         (None, 2)                 2050
#
# =================================================================
# Total params: 19,622,530
# Trainable params: 19,622,530
# Non-trainable params: 0
# _________________________________________________________________
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 89, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 89, 128)           512
#
#  block1_conv2 (Conv1D)       (None, 89, 128)           49280
#
#  block1_pool (MaxPooling1D)  (None, 44, 128)           0
#
#  block2_conv1 (Conv1D)       (None, 44, 256)           98560
#
#  block2_conv2 (Conv1D)       (None, 44, 256)           196864
#
#  block2_pool (MaxPooling1D)  (None, 22, 256)           0
#
#  block3_conv1 (Conv1D)       (None, 22, 512)           393728
#
#  block3_conv2 (Conv1D)       (None, 22, 512)           786944
#
#  block3_conv3 (Conv1D)       (None, 22, 512)           786944
#
#  block3_pool (MaxPooling1D)  (None, 11, 512)           0
#
#  block4_conv1 (Conv1D)       (None, 11, 1024)          1573888
#
#  block4_conv2 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_conv3 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_pool (MaxPooling1D)  (None, 5, 1024)           0
#
#  block5_conv1 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv2 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv3 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_pool (MaxPooling1D)  (None, 2, 1024)           0
#
#  global_average_pooling1d_2   (None, 1024)             0
#  (GlobalAveragePooling1D)
#
#  predictions (Dense)         (None, 2)                 2050
#
# =================================================================
# Total params: 19,622,530
# Trainable params: 19,622,530
# Non-trainable params: 0
# _________________________________________________________________
# 922/922 [==============================] - 4s 4ms/step
# Accuracy: 0.9678174172544763
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     28319
#            1       0.66      0.38      0.49      1169
#
#     accuracy                           0.97     29488
#    macro avg       0.82      0.69      0.73     29488
# weighted avg       0.96      0.97      0.96     29488
#
# Confusion Matrix:
# [[28091   228]
#  [  721   448]]

# %%
# %run C:/Users/PC/Data/ads_fraud_detection/src/prj3/5.deep_learning_model/3.smote/VGG19/vgg19_class_weight_kaggle_multiloss.ipynb
# Out:
# C:\Users\PC\Data\ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (29488, 2) (1083018, 2)
# (29488, 2)
# 89
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 89, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 89, 256)           1024
#
#  block1_conv2 (Conv1D)       (None, 89, 256)           196864
#
#  block1_pool (MaxPooling1D)  (None, 44, 256)           0
#
#  block2_conv1 (Conv1D)       (None, 44, 512)           393728
#
#  block2_conv2 (Conv1D)       (None, 44, 512)           786944
#
#  block2_pool (MaxPooling1D)  (None, 22, 512)           0
#
#  block3_conv1 (Conv1D)       (None, 22, 768)           1180416
#
#  block3_conv2 (Conv1D)       (None, 22, 768)           1770240
#
#  block3_conv3 (Conv1D)       (None, 22, 768)           1770240
#
#  block3_conv4 (Conv1D)       (None, 22, 768)           1770240
#
#  block3_pool (MaxPooling1D)  (None, 11, 768)           0
#
#  block4_conv1 (Conv1D)       (None, 11, 1024)          2360320
#
#  block4_conv2 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_conv3 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_conv4 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_pool (MaxPooling1D)  (None, 5, 1024)           0
#
#  block5_conv1 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv2 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv3 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv4 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_pool (MaxPooling1D)  (None, 2, 1024)           0
#
#  global_average_pooling1d_3   (None, 1024)             0
#  (GlobalAveragePooling1D)
#
#  predictions (Dense)         (None, 2)                 2050
#
# =================================================================
# Total params: 32,259,330
# Trainable params: 32,259,330
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1200
# 4231/4231 [==============================] - 285s 67ms/step - loss: 97.8630 - accuracy: 0.8769 - f1_score: 0.8683 - cohen_kappa: -1.0000 - val_loss: 0.1233 - val_accuracy: 0.9453 - val_f1_score: 0.6626 - val_cohen_kappa: -0.0974 - lr: 0.0010
# Epoch 2/1200
# 4231/4231 [==============================] - 283s 67ms/step - loss: 0.8802 - accuracy: 0.9528 - f1_score: 0.9523 - cohen_kappa: -0.9995 - val_loss: 0.2023 - val_accuracy: 0.9601 - val_f1_score: 0.5946 - val_cohen_kappa: -0.0585 - lr: 0.0010
# Epoch 3/1200
# 4231/4231 [==============================] - 283s 67ms/step - loss: 0.7312 - accuracy: 0.9538 - f1_score: 0.9536 - cohen_kappa: -0.9994 - val_loss: 0.1276 - val_accuracy: 0.9443 - val_f1_score: 0.6588 - val_cohen_kappa: -0.0980 - lr: 0.0010
# Epoch 4/1200
# 4231/4231 [==============================] - 283s 67ms/step - loss: 0.5599 - accuracy: 0.9668 - f1_score: 0.9667 - cohen_kappa: -0.9996 - val_loss: 0.0924 - val_accuracy: 0.9621 - val_f1_score: 0.6817 - val_cohen_kappa: -0.0729 - lr: 0.0010
# Epoch 5/1200
# 4231/4231 [==============================] - 283s 67ms/step - loss: 0.5419 - accuracy: 0.9682 - f1_score: 0.9681 - cohen_kappa: -0.9996 - val_loss: 0.1169 - val_accuracy: 0.9568 - val_f1_score: 0.6780 - val_cohen_kappa: -0.0814 - lr: 0.0010
# Epoch 6/1200
# 4231/4231 [==============================] - 283s 67ms/step - loss: 0.4564 - accuracy: 0.9735 - f1_score: 0.9734 - cohen_kappa: -0.9996 - val_loss: 0.0909 - val_accuracy: 0.9645 - val_f1_score: 0.6957 - val_cohen_kappa: -0.0725 - lr: 0.0010
# Epoch 7/1200
# 4231/4231 [==============================] - 283s 67ms/step - loss: 0.4275 - accuracy: 0.9753 - f1_score: 0.9752 - cohen_kappa: -0.9997 - val_loss: 0.5473 - val_accuracy: 0.9043 - val_f1_score: 0.6179 - val_cohen_kappa: -0.1499 - lr: 0.0010
# Epoch 8/1200
# 4231/4231 [==============================] - 282s 67ms/step - loss: 0.3941 - accuracy: 0.9775 - f1_score: 0.9774 - cohen_kappa: -0.9997 - val_loss: 0.1022 - val_accuracy: 0.9583 - val_f1_score: 0.6907 - val_cohen_kappa: -0.0826 - lr: 0.0010
# Epoch 9/1200
# 4230/4231 [============================>.] - ETA: 0s - loss: 0.3576 - accuracy: 0.9798 - f1_score: 0.9798 - cohen_kappa: -0.9998
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 4231/4231 [==============================] - 282s 67ms/step - loss: 0.3576 - accuracy: 0.9798 - f1_score: 0.9798 - cohen_kappa: -0.9998 - val_loss: 0.0917 - val_accuracy: 0.9643 - val_f1_score: 0.7050 - val_cohen_kappa: -0.0753 - lr: 0.0010
# Epoch 10/1200
# 4231/4231 [==============================] - 282s 67ms/step - loss: 0.2755 - accuracy: 0.9849 - f1_score: 0.9848 - cohen_kappa: -0.9998 - val_loss: 0.0912 - val_accuracy: 0.9646 - val_f1_score: 0.7073 - val_cohen_kappa: -0.0726 - lr: 5.0000e-04
# Epoch 11/1200
# 4231/4231 [==============================] - 282s 67ms/step - loss: 0.2507 - accuracy: 0.9864 - f1_score: 0.9864 - cohen_kappa: -0.9999 - val_loss: 0.0926 - val_accuracy: 0.9668 - val_f1_score: 0.6956 - val_cohen_kappa: -0.0649 - lr: 5.0000e-04
# Epoch 12/1200
# 4230/4231 [============================>.] - ETA: 0s - loss: 0.2366 - accuracy: 0.9872 - f1_score: 0.9871 - cohen_kappa: -0.9999
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 4231/4231 [==============================] - 282s 67ms/step - loss: 0.2366 - accuracy: 0.9872 - f1_score: 0.9871 - cohen_kappa: -0.9999 - val_loss: 0.1119 - val_accuracy: 0.9602 - val_f1_score: 0.7028 - val_cohen_kappa: -0.0790 - lr: 5.0000e-04
# Epoch 13/1200
# 4230/4231 [============================>.] - ETA: 0s - loss: 0.1912 - accuracy: 0.9900 - f1_score: 0.9899 - cohen_kappa: -0.9999Restoring model weights from the end of the best epoch: 6.
# 4231/4231 [==============================] - 282s 67ms/step - loss: 0.1912 - accuracy: 0.9900 - f1_score: 0.9899 - cohen_kappa: -0.9999 - val_loss: 0.1064 - val_accuracy: 0.9588 - val_f1_score: 0.7039 - val_cohen_kappa: -0.0815 - lr: 2.5000e-04
# Epoch 13: early stopping
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 89, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 89, 256)           1024
#
#  block1_conv2 (Conv1D)       (None, 89, 256)           196864
#
#  block1_pool (MaxPooling1D)  (None, 44, 256)           0
#
#  block2_conv1 (Conv1D)       (None, 44, 512)           393728
#
#  block2_conv2 (Conv1D)       (None, 44, 512)           786944
#
#  block2_pool (MaxPooling1D)  (None, 22, 512)           0
#
#  block3_conv1 (Conv1D)       (None, 22, 768)           1180416
#
#  block3_conv2 (Conv1D)       (None, 22, 768)           1770240
#
#  block3_conv3 (Conv1D)       (None, 22, 768)           1770240
#
#  block3_conv4 (Conv1D)       (None, 22, 768)           1770240
#
#  block3_pool (MaxPooling1D)  (None, 11, 768)           0
#
#  block4_conv1 (Conv1D)       (None, 11, 1024)          2360320
#
#  block4_conv2 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_conv3 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_conv4 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_pool (MaxPooling1D)  (None, 5, 1024)           0
#
#  block5_conv1 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv2 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv3 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv4 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_pool (MaxPooling1D)  (None, 2, 1024)           0
#
#  global_average_pooling1d_3   (None, 1024)             0
#  (GlobalAveragePooling1D)
#
#  predictions (Dense)         (None, 2)                 2050
#
# =================================================================
# Total params: 32,259,330
# Trainable params: 32,259,330
# Non-trainable params: 0
# _________________________________________________________________
# Model: "vgg19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 89, 1)]           0
#
#  block1_conv1 (Conv1D)       (None, 89, 256)           1024
#
#  block1_conv2 (Conv1D)       (None, 89, 256)           196864
#
#  block1_pool (MaxPooling1D)  (None, 44, 256)           0
#
#  block2_conv1 (Conv1D)       (None, 44, 512)           393728
#
#  block2_conv2 (Conv1D)       (None, 44, 512)           786944
#
#  block2_pool (MaxPooling1D)  (None, 22, 512)           0
#
#  block3_conv1 (Conv1D)       (None, 22, 768)           1180416
#
#  block3_conv2 (Conv1D)       (None, 22, 768)           1770240
#
#  block3_conv3 (Conv1D)       (None, 22, 768)           1770240
#
#  block3_conv4 (Conv1D)       (None, 22, 768)           1770240
#
#  block3_pool (MaxPooling1D)  (None, 11, 768)           0
#
#  block4_conv1 (Conv1D)       (None, 11, 1024)          2360320
#
#  block4_conv2 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_conv3 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_conv4 (Conv1D)       (None, 11, 1024)          3146752
#
#  block4_pool (MaxPooling1D)  (None, 5, 1024)           0
#
#  block5_conv1 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv2 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv3 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_conv4 (Conv1D)       (None, 5, 1024)           3146752
#
#  block5_pool (MaxPooling1D)  (None, 2, 1024)           0
#
#  global_average_pooling1d_3   (None, 1024)             0
#  (GlobalAveragePooling1D)
#
#  predictions (Dense)         (None, 2)                 2050
#
# =================================================================
# Total params: 32,259,330
# Trainable params: 32,259,330
# Non-trainable params: 0
# _________________________________________________________________
# 922/922 [==============================] - 6s 6ms/step
# Accuracy: 0.9645279435702658
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98     28319
#            1       0.57      0.44      0.49      1169
#
#     accuracy                           0.96     29488
#    macro avg       0.77      0.71      0.74     29488
# weighted avg       0.96      0.96      0.96     29488
#
# Confusion Matrix:
# [[27932   387]
#  [  659   510]]
