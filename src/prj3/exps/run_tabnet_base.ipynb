# %%
# %run "C:/Users/Admin/Data/ads_fraud_detection/src/prj3/5.deep_learning_model/1.base/Tabnet/tabnet_base_kaggle.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# C:/Users/Admin/Data/ads_fraud_detection
# (29488, 2) (561003, 2)
# (29488, 2)
# 89
# Epoch 1/1200
# 2192/2192 [==============================] - 699s 304ms/step - loss: 0.1254 - accuracy: 0.9686 - f1_score: 0.6233 - val_loss: 0.1759 - val_accuracy: 0.9621 - val_f1_score: 0.5809 - lr: 0.0010
# Epoch 2/1200
# 2192/2192 [==============================] - 666s 304ms/step - loss: 0.1101 - accuracy: 0.9717 - f1_score: 0.6749 - val_loss: 0.1676 - val_accuracy: 0.9504 - val_f1_score: 0.6013 - lr: 0.0010
# Epoch 3/1200
# 2192/2192 [==============================] - 665s 303ms/step - loss: 0.1057 - accuracy: 0.9727 - f1_score: 0.6920 - val_loss: 0.2072 - val_accuracy: 0.9370 - val_f1_score: 0.6033 - lr: 0.0010
# Epoch 4/1200
# 2192/2192 [==============================] - 668s 305ms/step - loss: 0.1009 - accuracy: 0.9741 - f1_score: 0.7151 - val_loss: 0.2514 - val_accuracy: 0.9165 - val_f1_score: 0.5858 - lr: 0.0010
# Epoch 5/1200
# ...

# %%
# %run "C:/Users/Admin/Data/ads_fraud_detection/src/prj3/5.deep_learning_model/1.base/Tabnet/tabnet_class_weight_kaggle.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# C:/Users/Admin/Data/ads_fraud_detection
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# (29488, 2) (561003, 2)
# (29488, 2)
# 89
# Epoch 1/1200
# 2192/2192 [==============================] - 237s 93ms/step - loss: 0.5505 - accuracy: 0.7739 - f1_score: 0.5247 - val_loss: 0.7715 - val_accuracy: 0.5847 - val_f1_score: 0.4251 - lr: 0.0010
# Epoch 2/1200
# 2192/2192 [==============================] - 206s 94ms/step - loss: 0.4835 - accuracy: 0.8056 - f1_score: 0.5484 - val_loss: 0.7749 - val_accuracy: 0.6315 - val_f1_score: 0.4511 - lr: 0.0010
# Epoch 3/1200
# 2192/2192 [==============================] - 203s 93ms/step - loss: 0.4693 - accuracy: 0.8152 - f1_score: 0.5565 - val_loss: 1.5351 - val_accuracy: 0.4691 - val_f1_score: 0.3630 - lr: 0.0010
# Epoch 4/1200
# 2192/2192 [==============================] - ETA: 0s - loss: 0.4509 - accuracy: 0.8263 - f1_score: 0.5663
# ...
