# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../..')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)
from libs.common import *
from config.config import *
# Out:
# c:\Users\PC\Data\ads_fraud_detection
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# c:/Users/PC/Data/ads_fraud_detection

# %% [markdown]
# # Lựa chọn đặc trưng

# %% [markdown]
# ### (1) Tạo thư mục lưu trữ (nếu chưa có)

# %%
save_dir=f"{exps_dir}/exp3/exp3_noSMOTE"

os.makedirs(save_dir, exist_ok=True)
test_size=0.33
seed=42

# %%
x_train=pd.read_excel(f'{save_dir}/x_train.xlsx')
y_train=pd.read_excel(f'{save_dir}/y_train.xlsx')
x_test=pd.read_excel(f'{save_dir}/x_test.xlsx')
y_test=pd.read_excel(f'{save_dir}/y_test.xlsx')
print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# (6700, 47) (6700, 1) (3300, 47) (3300, 1)

# %% [markdown]
# ### (2) Lựa chọn các đặc trưng

# %%
x_train
# Out:
#       TXN_DATE_TIME  TRANSACTION_ID  CUSTOMER_ID  POLICY_NUMBER  POLICY_EFF_DT  LOSS_DT  REPORT_DT  INSURANCE_TYPE  PREMIUM_AMOUNT  CLAIM_AMOUNT  CUSTOMER_NAME  ADDRESS_LINE1  ADDRESS_LINE2  CITY  STATE  POSTAL_CODE   SSN  MARITAL_STATUS       AGE    TENURE  EMPLOYMENT_STATUS  NO_OF_FAMILY_MEMBERS  RISK_SEGMENTATION  HOUSE_TYPE  SOCIAL_CLASS  ROUTING_NUMBER  ACCT_NUMBER  CUSTOMER_EDUCATION_LEVEL  INCIDENT_SEVERITY  AUTHORITY_CONTACTED  ANY_INJURY  POLICE_REPORT_AVAILABLE  INCIDENT_STATE  INCIDENT_CITY  INCIDENT_HOUR_OF_THE_DAY  AGENT_ID  VENDOR_ID  Squared_PREMIUM_AMOUNT  Cubed_PREMIUM_AMOUNT  BoxCox_PREMIUM_AMOUNT  YeoJohnson_PREMIUM_AMOUNT  Quantile_PREMIUM_AMOUNT  Log_CLAIM_AMOUNT  Sqrt_CLAIM_AMOUNT  BoxCox_CLAIM_AMOUNT  YeoJohnson_CLAIM_AMOUNT  Quantile_CLAIM_AMOUNT
# 0               331            5597         1080           1445           2584      336        336               4        1.059664      1.048541           2212           2196            238   240     13     0.755751  5705               1 -0.291432 -0.166450                  0                     2                  2           2             2       -0.838468         4971                         2                  0                    0           1                        1               9             32                        12       100        222                1.056653              0.895968               1.033749                   1.035805                 1.069418          1.119164           1.251315             1.193095                 1.193152               1.015912
# 1               201            3341         2021           5059           1658      215        212               5        0.236995     -0.529300           6354           1124            238   141      4     1.415580  4836               0 -1.596059 -0.958591                  1                     2                  0           2             1        0.654859         2834                         0                  2                    0           1                        1               7            356                         1       718        140               -0.020573             -0.193664               0.278710                   0.276207                 0.292025         -0.084880          -0.441937            -0.198503                -0.198518              -0.096797
# 2               365            6152         2755            727           1682      365        365               1       -0.029627      1.409191           2340           2153            238    11      5     0.967508  2427               1  1.708997 -1.202327                  1                     3                  1           1             0        1.486289          528                         0                  0                    0           1                        1               4            343                         0       408        407               -0.292882             -0.406885               0.024474                   0.020967                -0.050115          1.224732           1.501316             1.333984                 1.334003               1.102537
# 3               160            2632         1805           3006           2415      173        170               5        0.028632     -0.664544           4233           2673            238     3      0     1.568327  5985               0  0.578320  0.046819                  1                     0                  2           1             0        1.463306         5682                         0                  1                    0           0                        1               8            176                         0       108        407               -0.236591             -0.365250               0.080503                   0.077191                 0.028947         -0.615433          -0.782309            -0.702070                -0.702270              -0.473977
# 4               270            4581         5516           1290           1652      287        282               2       -1.634744     -0.741182           3682            766            238   185      6    -1.311586  6296               1  0.056469  0.290555                  1                     2                  1           0             0       -1.674580         1555                         0                  2                    0           1                        1              15             42                        18        53        160               -1.137646             -0.821003              -1.718306                  -1.713061                -1.307600         -1.713908          -1.141167            -1.572276                -1.572366              -1.209905
# ...             ...             ...          ...            ...            ...      ...        ...             ...             ...           ...            ...            ...            ...   ...    ...          ...   ...             ...       ...       ...                ...                   ...                ...         ...           ...             ...          ...                       ...                ...                  ...         ...                      ...             ...            ...                       ...       ...        ...                     ...                   ...                    ...                        ...                      ...               ...                ...                  ...                      ...                    ...
# 6695            228            3819         2023           4678            162      238        236               1       -0.361348      0.282161           3571           1000            238   220     14    -0.350978  3960               1 -1.422108  0.595225                  1                     5                  1           0             2       -1.165659         3944                         4                  2                    0           0                        0               3            117                         8       817         21               -0.579185             -0.596680              -0.300343                  -0.304642                -0.477390          0.798741           0.618192             0.785335                 0.785455               0.624584
# 6696            207            3455         4779           5055             55      210        210               0        1.545014     -0.529300           2236           1599            238   220     14    -0.351132   197               0 -1.422108  0.717093                  0                     1                  2           1             2       -1.558464         3149                         2                  0                    0           1                        0               5             11                         0       152        407                1.860089              1.916036               1.462859                   1.468362                 1.551928         -0.084880          -0.441937            -0.198503                -0.198518              -0.096797
# 6697            215            3585         1923           2966            289      218        218               5       -0.308065     -0.529300           3316            154            238   318     15    -1.331276  3583               1  1.535046  0.412423                  1                     3                  0           1             2       -0.313148         5737                         0                  0                    0           1                        1               3            117                         0       436         87               -0.537122             -0.571259              -0.247451                  -0.251663                -0.412500         -0.084880          -0.441937            -0.198503                -0.198518              -0.096797
# 6698             34             548         5239           4031            866       38         38               1        0.110940     -0.213732           3806            453            238   210      1    -0.384874  6047               0 -0.378407 -0.745322                  1                     1                  2           0             2       -1.206484         6635                         1                  0                    3           1                        0               9            303                        20       673         11               -0.154003             -0.301808               0.159196                   0.156183                 0.131213          0.422036           0.066655             0.341966                 0.342074               0.266723
# 6699            287            4868         5183           5686           1485      305        300               2       -1.605511     -0.723149           4365           2784            238   168      8    -0.464036  2295               1 -1.509084  0.899895                  1                     3                  2           0             2       -1.519394         5792                         2                  0                    3           1                        1              13            238                         5       229        121               -1.134445             -0.820734              -1.678761                  -1.674482                -1.100594         -1.223303          -1.021503            -1.209966                -1.210282              -0.760203
#
# [6700 rows x 47 columns]

# %%
def modelcheck_info(model,name):
    print(name)
    try:
        coefficients = model.coef_.flatten()
    except:
        coefficients = model.feature_importances_.flatten()
    feature_importance = pd.DataFrame({
        'Feature': x_train.columns,
        'Coefficient': coefficients
    })

    print('bi loai bo',feature_importance[feature_importance['Coefficient'] == 0])
    feature_importance = feature_importance[feature_importance['Coefficient'] != 0]
    feature_importance['Absolute Coefficient'] = feature_importance['Coefficient'].abs()
    feature_importance.sort_values(by='Absolute Coefficient', ascending=False, inplace=True)

    print("Xếp hạng các đặc trưng theo mức độ quan trọng:")
    print(feature_importance[['Feature', 'Coefficient']])

# %%
models=[]
models.append(LogisticRegression())
models.append(LinearDiscriminantAnalysis())
models.append(DecisionTreeClassifier())
names=['LR','LDA','DTC']
feature_SelectFromModel={}
for model,name in zip(models,names):
    check = model.fit(x_train, y_train)
    selector = SelectFromModel(check, prefit=True)

    selected_features = x_train.columns[(selector.get_support())]
    modelcheck_info(model,name)
    print("Các đặc trưng được chọn:")
    feature_SelectFromModel[name]=list(selected_features)
    print(selected_features)
# Out:
# LR
# bi loai bo Empty DataFrame
# Columns: [Feature, Coefficient]
# Index: []
# Xếp hạng các đặc trưng theo mức độ quan trọng:
#                       Feature  Coefficient
# 34   INCIDENT_HOUR_OF_THE_DAY    -0.008586
# 5                     LOSS_DT    -0.008526
# 6                   REPORT_DT    -0.008429
# 32             INCIDENT_STATE    -0.004063
# 14                      STATE    -0.002681
# 27   CUSTOMER_EDUCATION_LEVEL    -0.002476
# 0               TXN_DATE_TIME    -0.002400
# 29        AUTHORITY_CONTACTED    -0.002286
# 13                       CITY    -0.001760
# 23                 HOUSE_TYPE    -0.001645
# 12              ADDRESS_LINE2    -0.001594
# 24               SOCIAL_CLASS    -0.001408
# 30                 ANY_INJURY    -0.001341
# 1              TRANSACTION_ID     0.001052
# 17             MARITAL_STATUS    -0.000979
# 33              INCIDENT_CITY    -0.000910
# 20          EMPLOYMENT_STATUS    -0.000887
# 21       NO_OF_FAMILY_MEMBERS    -0.000862
# 28          INCIDENT_SEVERITY    -0.000792
# 46      Quantile_CLAIM_AMOUNT    -0.000625
# 45    YeoJohnson_CLAIM_AMOUNT    -0.000623
# 44        BoxCox_CLAIM_AMOUNT    -0.000623
# 42           Log_CLAIM_AMOUNT    -0.000616
# 43          Sqrt_CLAIM_AMOUNT    -0.000587
# 36                  VENDOR_ID    -0.000579
# 7              INSURANCE_TYPE    -0.000495
# 9                CLAIM_AMOUNT    -0.000485
# 15                POSTAL_CODE    -0.000484
# 22          RISK_SEGMENTATION    -0.000473
# 31    POLICE_REPORT_AVAILABLE    -0.000369
# 25             ROUTING_NUMBER     0.000322
# 35                   AGENT_ID    -0.000313
# 19                     TENURE    -0.000228
# 11              ADDRESS_LINE1    -0.000139
# 4               POLICY_EFF_DT    -0.000137
# 18                        AGE     0.000118
# 41    Quantile_PREMIUM_AMOUNT     0.000093
# 10              CUSTOMER_NAME    -0.000069
# 2                 CUSTOMER_ID    -0.000058
# 38       Cubed_PREMIUM_AMOUNT    -0.000057
# 26                ACCT_NUMBER    -0.000055
# 8              PREMIUM_AMOUNT     0.000034
# 37     Squared_PREMIUM_AMOUNT     0.000030
# 3               POLICY_NUMBER    -0.000024
# 40  YeoJohnson_PREMIUM_AMOUNT     0.000022
# 39      BoxCox_PREMIUM_AMOUNT     0.000021
# 16                        SSN    -0.000017
# Các đặc trưng được chọn:
# Index(['TXN_DATE_TIME', 'LOSS_DT', 'REPORT_DT', 'ADDRESS_LINE2', 'CITY', 'STATE', 'HOUSE_TYPE', 'SOCIAL_CLASS', 'CUSTOMER_EDUCATION_LEVEL', 'AUTHORITY_CONTACTED', 'ANY_INJURY', 'INCIDENT_STATE', 'INCIDENT_HOUR_OF_THE_DAY'], dtype='object')
# LDA
# bi loai bo Empty DataFrame
# Columns: [Feature, Coefficient]
# Index: []
# Xếp hạng các đặc trưng theo mức độ quan trọng:
#                       Feature  Coefficient
# 8              PREMIUM_AMOUNT     5.746086
# 42           Log_CLAIM_AMOUNT     3.434798
# 39      BoxCox_PREMIUM_AMOUNT    -3.086313
# 45    YeoJohnson_CLAIM_AMOUNT    -2.514393
# 44        BoxCox_CLAIM_AMOUNT    -2.419402
# 40  YeoJohnson_PREMIUM_AMOUNT    -2.027789
# 43          Sqrt_CLAIM_AMOUNT     1.987566
# 38       Cubed_PREMIUM_AMOUNT    -0.391793
# 30                 ANY_INJURY    -0.339297
# 37     Squared_PREMIUM_AMOUNT    -0.320558
# 9                CLAIM_AMOUNT    -0.292426
# 46      Quantile_CLAIM_AMOUNT    -0.180543
# 20          EMPLOYMENT_STATUS    -0.173950
# 17             MARITAL_STATUS    -0.142664
# 6                   REPORT_DT    -0.134166
# 23                 HOUSE_TYPE    -0.117178
# 22          RISK_SEGMENTATION     0.108339
# 5                     LOSS_DT     0.098098
# 29        AUTHORITY_CONTACTED    -0.086548
# 41    Quantile_PREMIUM_AMOUNT     0.067106
# 24               SOCIAL_CLASS    -0.051958
# 7              INSURANCE_TYPE     0.047307
# 31    POLICE_REPORT_AVAILABLE     0.044544
# 21       NO_OF_FAMILY_MEMBERS     0.041759
# 25             ROUTING_NUMBER     0.034883
# 27   CUSTOMER_EDUCATION_LEVEL    -0.029661
# 15                POSTAL_CODE     0.029598
# 18                        AGE     0.021384
# 19                     TENURE    -0.014160
# 0               TXN_DATE_TIME     0.010147
# 28          INCIDENT_SEVERITY    -0.009276
# 14                      STATE     0.004359
# 12              ADDRESS_LINE2     0.002565
# 1              TRANSACTION_ID     0.001495
# 34   INCIDENT_HOUR_OF_THE_DAY     0.001097
# 33              INCIDENT_CITY    -0.000582
# 13                       CITY    -0.000518
# 32             INCIDENT_STATE     0.000421
# 36                  VENDOR_ID     0.000114
# 35                   AGENT_ID     0.000053
# 16                        SSN     0.000037
# 4               POLICY_EFF_DT    -0.000025
# 3               POLICY_NUMBER     0.000023
# 10              CUSTOMER_NAME    -0.000017
# 11              ADDRESS_LINE1     0.000011
# 2                 CUSTOMER_ID    -0.000005
# 26                ACCT_NUMBER    -0.000003
# Các đặc trưng được chọn:
# Index(['PREMIUM_AMOUNT', 'BoxCox_PREMIUM_AMOUNT', 'YeoJohnson_PREMIUM_AMOUNT', 'Log_CLAIM_AMOUNT', 'Sqrt_CLAIM_AMOUNT', 'BoxCox_CLAIM_AMOUNT', 'YeoJohnson_CLAIM_AMOUNT'], dtype='object')
# DTC
# bi loai bo               Feature  Coefficient
# 28  INCIDENT_SEVERITY          0.0
# Xếp hạng các đặc trưng theo mức độ quan trọng:
#                       Feature  Coefficient
# 26                ACCT_NUMBER     0.069752
# 25             ROUTING_NUMBER     0.059694
# 19                     TENURE     0.050833
# 16                        SSN     0.050279
# 2                 CUSTOMER_ID     0.046069
# 11              ADDRESS_LINE1     0.045811
# 10              CUSTOMER_NAME     0.044071
# 3               POLICY_NUMBER     0.039803
# 4               POLICY_EFF_DT     0.037659
# 35                   AGENT_ID     0.034512
# 33              INCIDENT_CITY     0.033523
# 32             INCIDENT_STATE     0.031862
# 13                       CITY     0.031784
# 8              PREMIUM_AMOUNT     0.026820
# 14                      STATE     0.026192
# 18                        AGE     0.025569
# 5                     LOSS_DT     0.025312
# 6                   REPORT_DT     0.024019
# 34   INCIDENT_HOUR_OF_THE_DAY     0.022933
# 36                  VENDOR_ID     0.022741
# 1              TRANSACTION_ID     0.018393
# 41    Quantile_PREMIUM_AMOUNT     0.018366
# 15                POSTAL_CODE     0.015810
# 0               TXN_DATE_TIME     0.014503
# 24               SOCIAL_CLASS     0.014125
# 46      Quantile_CLAIM_AMOUNT     0.012806
# 37     Squared_PREMIUM_AMOUNT     0.012709
# 23                 HOUSE_TYPE     0.011990
# 27   CUSTOMER_EDUCATION_LEVEL     0.011797
# 29        AUTHORITY_CONTACTED     0.011156
# 40  YeoJohnson_PREMIUM_AMOUNT     0.011132
# 38       Cubed_PREMIUM_AMOUNT     0.011123
# 42           Log_CLAIM_AMOUNT     0.010433
# 21       NO_OF_FAMILY_MEMBERS     0.009191
# 43          Sqrt_CLAIM_AMOUNT     0.009018
# 7              INSURANCE_TYPE     0.008638
# 9                CLAIM_AMOUNT     0.007778
# 31    POLICE_REPORT_AVAILABLE     0.007460
# 45    YeoJohnson_CLAIM_AMOUNT     0.007368
# 12              ADDRESS_LINE2     0.006525
# 20          EMPLOYMENT_STATUS     0.005723
# 39      BoxCox_PREMIUM_AMOUNT     0.004544
# 44        BoxCox_CLAIM_AMOUNT     0.004388
# 30                 ANY_INJURY     0.003642
# 22          RISK_SEGMENTATION     0.001716
# 17             MARITAL_STATUS     0.000426
# Các đặc trưng được chọn:
# Index(['CUSTOMER_ID', 'POLICY_NUMBER', 'POLICY_EFF_DT', 'LOSS_DT', 'REPORT_DT', 'PREMIUM_AMOUNT', 'CUSTOMER_NAME', 'ADDRESS_LINE1', 'CITY', 'STATE', 'SSN', 'AGE', 'TENURE', 'ROUTING_NUMBER', 'ACCT_NUMBER', 'INCIDENT_STATE', 'INCIDENT_CITY', 'INCIDENT_HOUR_OF_THE_DAY', 'AGENT_ID', 'VENDOR_ID'], dtype='object')

# %% [markdown]
# ### Giải thích:
#
# Phương pháp **SelectFromModel** từ thư viện sklearn.feature_selection. Phương pháp này hoạt động bằng cách sử dụng một mô hình học máy để đánh giá độ quan trọng của từng đặc trưng và sau đó chọn những đặc trưng quan trọng nhất.
#
#    Các model được dùng trong phương pháp này:
#    * **'LR'**: LogisticRegression
#    * **'LDA'**: LinearDiscriminantAnalysis
#    * **'DTC'**: DecisionTreeClassifier
#
#        #### 1. LogisticRegression:
#        Các đặc trưng được chọn:
# * Index(['age', 'policy_csl', 'insured_education_level', 'insured_occupation',
#        'incident_severity', 'incident_state', 'incident_city',
#        'incident_hour_of_the_day', 'property_damage', 'witnesses',
#        'property_claim', 'vehicle_claim', 'auto_make'],
#       dtype='object')
#
#    #### 2. LinearDiscriminantAnalysis:
#    Các đặc trưng được chọn:
# * Index(['policy_number', 'policy_annual_premium', 'insured_zip', 'insured_sex',
#        'incident_severity', 'incident_hour_of_the_day', 'property_damage',
#        'total_claim_amount', 'injury_claim', 'property_claim',
#        'vehicle_claim'],
#       dtype='object')
#
#    #### 3. DecisionTreeClassifier:
#    Các đặc trưng được chọn:
# * Index(['policy_number', 'policy_annual_premium', 'insured_zip',
#        'insured_occupation', 'insured_hobbies', 'incident_severity',
#        'incident_location', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'month_policy_bind_date', 'day_incident_date'],
#       dtype='object')

# %%
def feature_selection_inRFE(model,name):
    rfe=RFE(estimator=model, n_features_to_select=10)
    fit=rfe.fit(x_train, y_train)
#     print("Num Features: %d"% fit.n_features_)
#     print("Selected Features: %s" % fit.support_)
#     print("Features Ranking: %s" %fit.ranking_)
#     for index, value in enumerate(fit.ranking_):
#         print(f"{value}: {x_train.columns[index]}")
    sorted_columns = [x for _, x in sorted(zip(fit.ranking_, x_train.columns))]
    sort=sorted(fit.ranking_)

#     for i,j in zip(sort,sorted_columns):
#         print("Columns sorted by RFE ranking",i,":",j)

    return [j for i,j in zip(sort,sorted_columns) if i==1]

# %%
models = [
    LogisticRegression(),
    LinearDiscriminantAnalysis(),
    DecisionTreeClassifier(),
    RandomForestClassifier(),
    LGBMClassifier(),  
    XGBClassifier(use_label_encoder=False)  
]
feature_RFE={}

names = ['LR', 'LDA', 'DTC', 'RD', 'LGBM', 'XGB']
for model,name in zip(models,names):
    print("RFE")
    print(f"Kiểm tra mô hình {name}")
    model.fit(x_train,y_train)
    print(feature_selection_inRFE(model,name))
    feature_RFE[name]=feature_selection_inRFE(model,name)
# Out:
# RFE
# Kiểm tra mô hình LR
# ['ANY_INJURY', 'AUTHORITY_CONTACTED', 'EMPLOYMENT_STATUS', 'HOUSE_TYPE', 'LOSS_DT', 'MARITAL_STATUS', 'Quantile_CLAIM_AMOUNT', 'REPORT_DT', 'SOCIAL_CLASS', 'TXN_DATE_TIME']
# RFE
# Kiểm tra mô hình LDA
# ['ANY_INJURY', 'BoxCox_CLAIM_AMOUNT', 'BoxCox_PREMIUM_AMOUNT', 'CLAIM_AMOUNT', 'Cubed_PREMIUM_AMOUNT', 'Log_CLAIM_AMOUNT', 'PREMIUM_AMOUNT', 'Sqrt_CLAIM_AMOUNT', 'YeoJohnson_CLAIM_AMOUNT', 'YeoJohnson_PREMIUM_AMOUNT']
# RFE
# Kiểm tra mô hình DTC
# ['ACCT_NUMBER', 'ADDRESS_LINE1', 'AGENT_ID', 'CUSTOMER_NAME', 'POLICY_EFF_DT', 'POLICY_NUMBER', 'ROUTING_NUMBER', 'SSN', 'Squared_PREMIUM_AMOUNT', 'TENURE']
# RFE
# Kiểm tra mô hình RD
# ['ACCT_NUMBER', 'ADDRESS_LINE1', 'CUSTOMER_ID', 'CUSTOMER_NAME', 'POLICY_EFF_DT', 'POLICY_NUMBER', 'Quantile_PREMIUM_AMOUNT', 'ROUTING_NUMBER', 'SSN', 'TRANSACTION_ID']
# RFE
# Kiểm tra mô hình LGBM
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001210 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6817
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 47
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001170 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6817
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 47
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001147 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6709
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 46
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001132 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6601
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 45
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000899 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6493
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 44
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001186 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6385
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 43
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000834 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6130
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 42
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001020 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5875
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 41
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001010 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5620
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 40
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000761 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5618
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 39
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000938 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5616
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 38
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000936 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5614
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 37
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000963 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5506
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000766 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5251
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 35
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000901 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5248
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 34
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000899 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4993
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 33
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000725 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4990
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 32
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000596 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4987
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 31
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000845 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4985
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000861 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4982
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 29
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000780 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4978
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000773 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4972
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 27
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000516 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4812
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 26
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000549 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4566
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000561 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4560
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000787 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4305
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000492 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4298
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 22
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000640 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4282
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000675 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4061
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000635 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4045
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 19
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000420 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3796
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 18
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000558 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3772
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 17
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000447 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3731
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 16
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000545 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3492
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000479 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3384
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000432 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3155
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000231 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2914
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000153 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2659
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000170 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2404
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# ['ACCT_NUMBER', 'ADDRESS_LINE1', 'AGENT_ID', 'CUSTOMER_ID', 'CUSTOMER_NAME', 'POSTAL_CODE', 'PREMIUM_AMOUNT', 'ROUTING_NUMBER', 'SSN', 'TENURE']
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001171 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6817
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 47
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000948 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6709
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 46
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000945 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6601
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 45
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001117 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6493
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 44
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001179 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6385
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 43
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000824 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 6130
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 42
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000812 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5875
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 41
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000780 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5620
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 40
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000999 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5618
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 39
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001020 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5616
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 38
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000711 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5614
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 37
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000731 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5506
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 36
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000677 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5251
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 35
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000841 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5248
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 34
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000884 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4993
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 33
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000907 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4990
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 32
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000634 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4987
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 31
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000809 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4985
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000832 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4982
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 29
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000600 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4978
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 28
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000579 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4972
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 27
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000524 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4812
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 26
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000711 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4566
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 25
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000563 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4560
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000685 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4305
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000702 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4298
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 22
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000534 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4282
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000700 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4061
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 20
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000450 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4045
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 19
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000575 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3796
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 18
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000587 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3772
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 17
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000543 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3731
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 16
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000501 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3492
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 15
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000487 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3384
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000214 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3155
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000165 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2914
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000205 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2659
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# [LightGBM] [Info] Number of positive: 336, number of negative: 6364
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000186 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2404
# [LightGBM] [Info] Number of data points in the train set: 6700, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.050149 -> initscore=-2.941301
# [LightGBM] [Info] Start training from score -2.941301
# RFE
# Kiểm tra mô hình XGB
# ['ACCT_NUMBER', 'ADDRESS_LINE1', 'AGE', 'CLAIM_AMOUNT', 'CUSTOMER_ID', 'INCIDENT_STATE', 'ROUTING_NUMBER', 'SOCIAL_CLASS', 'SSN', 'TENURE']

# %% [markdown]
# ### Giải thích:
# **Recursive Feature Elimination (RFE)** là một phương pháp trong lựa chọn đặc trưng (feature selection) được sử dụng trong học máy để giảm số lượng đặc trưng của mô hình mà vẫn giữ được hiệu suất tốt.
#
# Các model được dùng trong phương pháp này:
#    * **'LR'**: LogisticRegression
#    * **'LDA'**: LinearDiscriminantAnalysis
#    * **'DTC'**: DecisionTreeClassifier
#    * **'RD'**: RandomForestClassifier

# %%
special_models=[KNeighborsClassifier(),GaussianNB(),MLPClassifier(),GradientBoostingClassifier(),MultinomialNB(),SVC()]
names=['KNC','GNB','NN','BG','NB','SVM']
def feature_selection_inKBest(model, name):
    k_best = SelectKBest(score_func=f_classif, k=11)
    fit = k_best.fit(x_train, y_train)
    selected_features = fit.get_support()
    selected_column_names = x_train.columns[selected_features]
    return selected_column_names
feature_Kbest={}
for model,name in zip(special_models,names):
    print(f'Lua chon dac trung {name}')
    print(feature_selection_inKBest(model, name))
    feature_Kbest[name]=list(feature_selection_inKBest(model, name))
# Out:
# Lua chon dac trung KNC
# Index(['TXN_DATE_TIME', 'REPORT_DT', 'INSURANCE_TYPE', 'ADDRESS_LINE2', 'SSN', 'MARITAL_STATUS', 'RISK_SEGMENTATION', 'HOUSE_TYPE', 'AUTHORITY_CONTACTED', 'ANY_INJURY', 'INCIDENT_CITY'], dtype='object')
# Lua chon dac trung GNB
# Index(['TXN_DATE_TIME', 'REPORT_DT', 'INSURANCE_TYPE', 'ADDRESS_LINE2', 'SSN', 'MARITAL_STATUS', 'RISK_SEGMENTATION', 'HOUSE_TYPE', 'AUTHORITY_CONTACTED', 'ANY_INJURY', 'INCIDENT_CITY'], dtype='object')
# Lua chon dac trung NN
# Index(['TXN_DATE_TIME', 'REPORT_DT', 'INSURANCE_TYPE', 'ADDRESS_LINE2', 'SSN', 'MARITAL_STATUS', 'RISK_SEGMENTATION', 'HOUSE_TYPE', 'AUTHORITY_CONTACTED', 'ANY_INJURY', 'INCIDENT_CITY'], dtype='object')
# Lua chon dac trung BG
# Index(['TXN_DATE_TIME', 'REPORT_DT', 'INSURANCE_TYPE', 'ADDRESS_LINE2', 'SSN', 'MARITAL_STATUS', 'RISK_SEGMENTATION', 'HOUSE_TYPE', 'AUTHORITY_CONTACTED', 'ANY_INJURY', 'INCIDENT_CITY'], dtype='object')
# Lua chon dac trung NB
# Index(['TXN_DATE_TIME', 'REPORT_DT', 'INSURANCE_TYPE', 'ADDRESS_LINE2', 'SSN', 'MARITAL_STATUS', 'RISK_SEGMENTATION', 'HOUSE_TYPE', 'AUTHORITY_CONTACTED', 'ANY_INJURY', 'INCIDENT_CITY'], dtype='object')
# Lua chon dac trung SVM
# Index(['TXN_DATE_TIME', 'REPORT_DT', 'INSURANCE_TYPE', 'ADDRESS_LINE2', 'SSN', 'MARITAL_STATUS', 'RISK_SEGMENTATION', 'HOUSE_TYPE', 'AUTHORITY_CONTACTED', 'ANY_INJURY', 'INCIDENT_CITY'], dtype='object')

# %% [markdown]
# ### Giải thích:
# Phương pháp **SelectKBest** từ thư viện sklearn.feature_selection để lựa chọn đặc trưng dựa trên kỹ thuật kiểm định thống kê.
#
# Các model được dùng trong phương pháp này:
#    * **'KNC'**: KNeighborsClassifier
#    * **'GNB'**: GaussianNB
#    * **'NN'**: MLPClassifier
#    * **'BG'**: GradientBoostingClassifier
#    * **'NB'**: MultinomialNB
#    * **'SVM'**: SVC

# %%
print(feature_Kbest)
print(feature_SelectFromModel)
print(feature_RFE)
# Out:
# {'KNC': ['TXN_DATE_TIME', 'REPORT_DT', 'INSURANCE_TYPE', 'ADDRESS_LINE2', 'SSN', 'MARITAL_STATUS', 'RISK_SEGMENTATION', 'HOUSE_TYPE', 'AUTHORITY_CONTACTED', 'ANY_INJURY', 'INCIDENT_CITY'], 'GNB': ['TXN_DATE_TIME', 'REPORT_DT', 'INSURANCE_TYPE', 'ADDRESS_LINE2', 'SSN', 'MARITAL_STATUS', 'RISK_SEGMENTATION', 'HOUSE_TYPE', 'AUTHORITY_CONTACTED', 'ANY_INJURY', 'INCIDENT_CITY'], 'NN': ['TXN_DATE_TIME', 'REPORT_DT', 'INSURANCE_TYPE', 'ADDRESS_LINE2', 'SSN', 'MARITAL_STATUS', 'RISK_SEGMENTATION', 'HOUSE_TYPE', 'AUTHORITY_CONTACTED', 'ANY_INJURY', 'INCIDENT_CITY'], 'BG': ['TXN_DATE_TIME', 'REPORT_DT', 'INSURANCE_TYPE', 'ADDRESS_LINE2', 'SSN', 'MARITAL_STATUS', 'RISK_SEGMENTATION', 'HOUSE_TYPE', 'AUTHORITY_CONTACTED', 'ANY_INJURY', 'INCIDENT_CITY'], 'NB': ['TXN_DATE_TIME', 'REPORT_DT', 'INSURANCE_TYPE', 'ADDRESS_LINE2', 'SSN', 'MARITAL_STATUS', 'RISK_SEGMENTATION', 'HOUSE_TYPE', 'AUTHORITY_CONTACTED', 'ANY_INJURY', 'INCIDENT_CITY'], 'SVM': ['TXN_DATE_TIME', 'REPORT_DT', 'INSURANCE_TYPE', 'ADDRESS_LINE2', 'SSN', 'MARITAL_STATUS', 'RISK_SEGMENTATION', 'HOUSE_TYPE', 'AUTHORITY_CONTACTED', 'ANY_INJURY', 'INCIDENT_CITY']}
# {'LR': ['TXN_DATE_TIME', 'LOSS_DT', 'REPORT_DT', 'ADDRESS_LINE2', 'CITY', 'STATE', 'HOUSE_TYPE', 'SOCIAL_CLASS', 'CUSTOMER_EDUCATION_LEVEL', 'AUTHORITY_CONTACTED', 'ANY_INJURY', 'INCIDENT_STATE', 'INCIDENT_HOUR_OF_THE_DAY'], 'LDA': ['PREMIUM_AMOUNT', 'BoxCox_PREMIUM_AMOUNT', 'YeoJohnson_PREMIUM_AMOUNT', 'Log_CLAIM_AMOUNT', 'Sqrt_CLAIM_AMOUNT', 'BoxCox_CLAIM_AMOUNT', 'YeoJohnson_CLAIM_AMOUNT'], 'DTC': ['CUSTOMER_ID', 'POLICY_NUMBER', 'POLICY_EFF_DT', 'LOSS_DT', 'REPORT_DT', 'PREMIUM_AMOUNT', 'CUSTOMER_NAME', 'ADDRESS_LINE1', 'CITY', 'STATE', 'SSN', 'AGE', 'TENURE', 'ROUTING_NUMBER', 'ACCT_NUMBER', 'INCIDENT_STATE', 'INCIDENT_CITY', 'INCIDENT_HOUR_OF_THE_DAY', 'AGENT_ID', 'VENDOR_ID']}
# {'LR': ['ANY_INJURY', 'AUTHORITY_CONTACTED', 'EMPLOYMENT_STATUS', 'HOUSE_TYPE', 'LOSS_DT', 'MARITAL_STATUS', 'Quantile_CLAIM_AMOUNT', 'REPORT_DT', 'SOCIAL_CLASS', 'TXN_DATE_TIME'], 'LDA': ['ANY_INJURY', 'BoxCox_CLAIM_AMOUNT', 'BoxCox_PREMIUM_AMOUNT', 'CLAIM_AMOUNT', 'Cubed_PREMIUM_AMOUNT', 'Log_CLAIM_AMOUNT', 'PREMIUM_AMOUNT', 'Sqrt_CLAIM_AMOUNT', 'YeoJohnson_CLAIM_AMOUNT', 'YeoJohnson_PREMIUM_AMOUNT'], 'DTC': ['ACCT_NUMBER', 'ADDRESS_LINE1', 'AGENT_ID', 'CUSTOMER_ID', 'CUSTOMER_NAME', 'POLICY_EFF_DT', 'Quantile_PREMIUM_AMOUNT', 'ROUTING_NUMBER', 'SSN', 'TENURE'], 'RD': ['ACCT_NUMBER', 'ADDRESS_LINE1', 'CUSTOMER_ID', 'CUSTOMER_NAME', 'Cubed_PREMIUM_AMOUNT', 'POLICY_EFF_DT', 'POLICY_NUMBER', 'ROUTING_NUMBER', 'SSN', 'TRANSACTION_ID'], 'LGBM': ['ACCT_NUMBER', 'ADDRESS_LINE1', 'AGENT_ID', 'CUSTOMER_ID', 'CUSTOMER_NAME', 'POSTAL_CODE', 'PREMIUM_AMOUNT', 'ROUTING_NUMBER', 'SSN', 'TENURE'], 'XGB': ['ACCT_NUMBER', 'ADDRESS_LINE1', 'AGE', 'CLAIM_AMOUNT', 'CUSTOMER_ID', 'INCIDENT_STATE', 'ROUTING_NUMBER', 'SOCIAL_CLASS', 'SSN', 'TENURE']}

# %%
feature_model_selection={**feature_RFE,**feature_Kbest}
np.savez(f'{save_dir}/feature_model_selection.npz', feature_model_selection = feature_model_selection)
feature_model_selection
# Out:
# {'LR': ['ANY_INJURY',
#   'AUTHORITY_CONTACTED',
#   'EMPLOYMENT_STATUS',
#   'HOUSE_TYPE',
#   'LOSS_DT',
#   'MARITAL_STATUS',
#   'Quantile_CLAIM_AMOUNT',
#   'REPORT_DT',
#   'SOCIAL_CLASS',
#   'TXN_DATE_TIME'],
#  'LDA': ['ANY_INJURY',
#   'BoxCox_CLAIM_AMOUNT',
#   'BoxCox_PREMIUM_AMOUNT',
#   'CLAIM_AMOUNT',
#   'Cubed_PREMIUM_AMOUNT',
#   'Log_CLAIM_AMOUNT',
#   'PREMIUM_AMOUNT',
#   'Sqrt_CLAIM_AMOUNT',
#   'YeoJohnson_CLAIM_AMOUNT',
#   'YeoJohnson_PREMIUM_AMOUNT'],
#  'DTC': ['ACCT_NUMBER',
#   'ADDRESS_LINE1',
#   'AGENT_ID',
#   'CUSTOMER_ID',
#   'CUSTOMER_NAME',
#   'POLICY_EFF_DT',
#   'Quantile_PREMIUM_AMOUNT',
#   'ROUTING_NUMBER',
#   'SSN',
#   'TENURE'],
#  'RD': ['ACCT_NUMBER',
#   'ADDRESS_LINE1',
#   'CUSTOMER_ID',
#   'CUSTOMER_NAME',
#   'Cubed_PREMIUM_AMOUNT',
#   'POLICY_EFF_DT',
#   'POLICY_NUMBER',
#   'ROUTING_NUMBER',
#   'SSN',
#   'TRANSACTION_ID'],
#  'LGBM': ['ACCT_NUMBER',
#   'ADDRESS_LINE1',
#   'AGENT_ID',
#   'CUSTOMER_ID',
#   'CUSTOMER_NAME',
#   'POSTAL_CODE',
#   'PREMIUM_AMOUNT',
#   'ROUTING_NUMBER',
#   'SSN',
#   'TENURE'],
#  'XGB': ['ACCT_NUMBER',
#   'ADDRESS_LINE1',
#   'AGE',
#   'CLAIM_AMOUNT',
#   'CUSTOMER_ID',
#   'INCIDENT_STATE',
#   'ROUTING_NUMBER',
#   'SOCIAL_CLASS',
#   'SSN',
#   'TENURE'],
#  'KNC': ['TXN_DATE_TIME',
#   'REPORT_DT',
#   'INSURANCE_TYPE',
#   'ADDRESS_LINE2',
#   'SSN',
#   'MARITAL_STATUS',
#   'RISK_SEGMENTATION',
#   'HOUSE_TYPE',
#   'AUTHORITY_CONTACTED',
#   'ANY_INJURY',
#   'INCIDENT_CITY'],
#  'GNB': ['TXN_DATE_TIME',
#   'REPORT_DT',
#   'INSURANCE_TYPE',
#   'ADDRESS_LINE2',
#   'SSN',
#   'MARITAL_STATUS',
#   'RISK_SEGMENTATION',
#   'HOUSE_TYPE',
#   'AUTHORITY_CONTACTED',
#   'ANY_INJURY',
#   'INCIDENT_CITY'],
#  'NN': ['TXN_DATE_TIME',
#   'REPORT_DT',
#   'INSURANCE_TYPE',
#   'ADDRESS_LINE2',
#   'SSN',
#   'MARITAL_STATUS',
#   'RISK_SEGMENTATION',
#   'HOUSE_TYPE',
#   'AUTHORITY_CONTACTED',
#   'ANY_INJURY',
#   'INCIDENT_CITY'],
#  'BG': ['TXN_DATE_TIME',
#   'REPORT_DT',
#   'INSURANCE_TYPE',
#   'ADDRESS_LINE2',
#   'SSN',
#   'MARITAL_STATUS',
#   'RISK_SEGMENTATION',
#   'HOUSE_TYPE',
#   'AUTHORITY_CONTACTED',
#   'ANY_INJURY',
#   'INCIDENT_CITY'],
#  'NB': ['TXN_DATE_TIME',
#   'REPORT_DT',
#   'INSURANCE_TYPE',
#   'ADDRESS_LINE2',
#   'SSN',
#   'MARITAL_STATUS',
#   'RISK_SEGMENTATION',
#   'HOUSE_TYPE',
#   'AUTHORITY_CONTACTED',
#   'ANY_INJURY',
#   'INCIDENT_CITY'],
#  'SVM': ['TXN_DATE_TIME',
#   'REPORT_DT',
#   'INSURANCE_TYPE',
#   'ADDRESS_LINE2',
#   'SSN',
#   'MARITAL_STATUS',
#   'RISK_SEGMENTATION',
#   'HOUSE_TYPE',
#   'AUTHORITY_CONTACTED',
#   'ANY_INJURY',
#   'INCIDENT_CITY']}

# %% [markdown]
# * gom nhóm thông tin về các đặc trưng được chọn từ hai phương pháp lựa chọn đặc trưng khác nhau (RFE và SelectKBest) vào từ điển **feature_model_selection**.

# %%
dict(np.load(f'{save_dir}/feature_model_selection.npz',allow_pickle=True))['feature_model_selection']
# Out:
# array({'LR': ['ANY_INJURY', 'AUTHORITY_CONTACTED', 'EMPLOYMENT_STATUS', 'HOUSE_TYPE', 'LOSS_DT', 'MARITAL_STATUS', 'Quantile_CLAIM_AMOUNT', 'REPORT_DT', 'SOCIAL_CLASS', 'TXN_DATE_TIME'], 'LDA': ['ANY_INJURY', 'BoxCox_CLAIM_AMOUNT', 'BoxCox_PREMIUM_AMOUNT', 'CLAIM_AMOUNT', 'Cubed_PREMIUM_AMOUNT', 'Log_CLAIM_AMOUNT', 'PREMIUM_AMOUNT', 'Sqrt_CLAIM_AMOUNT', 'YeoJohnson_CLAIM_AMOUNT', 'YeoJohnson_PREMIUM_AMOUNT'], 'DTC': ['ACCT_NUMBER', 'ADDRESS_LINE1', 'AGENT_ID', 'CUSTOMER_ID', 'CUSTOMER_NAME', 'POLICY_EFF_DT', 'Quantile_PREMIUM_AMOUNT', 'ROUTING_NUMBER', 'SSN', 'TENURE'], 'RD': ['ACCT_NUMBER', 'ADDRESS_LINE1', 'CUSTOMER_ID', 'CUSTOMER_NAME', 'Cubed_PREMIUM_AMOUNT', 'POLICY_EFF_DT', 'POLICY_NUMBER', 'ROUTING_NUMBER', 'SSN', 'TRANSACTION_ID'], 'LGBM': ['ACCT_NUMBER', 'ADDRESS_LINE1', 'AGENT_ID', 'CUSTOMER_ID', 'CUSTOMER_NAME', 'POSTAL_CODE', 'PREMIUM_AMOUNT', 'ROUTING_NUMBER', 'SSN', 'TENURE'], 'XGB': ['ACCT_NUMBER', 'ADDRESS_LINE1', 'AGE', 'CLAIM_AMOUNT', 'CUSTOMER_ID', 'INCIDENT_STATE', 'ROUTING_NUMBER', 'SOCIAL_CLASS', 'SSN', 'TENURE'], 'KNC': ['TXN_DATE_TIME', 'REPORT_DT', 'INSURANCE_TYPE', 'ADDRESS_LINE2', 'SSN', 'MARITAL_STATUS', 'RISK_SEGMENTATION', 'HOUSE_TYPE', 'AUTHORITY_CONTACTED', 'ANY_INJURY', 'INCIDENT_CITY'], 'GNB': ['TXN_DATE_TIME', 'REPORT_DT', 'INSURANCE_TYPE', 'ADDRESS_LINE2', 'SSN', 'MARITAL_STATUS', 'RISK_SEGMENTATION', 'HOUSE_TYPE', 'AUTHORITY_CONTACTED', 'ANY_INJURY', 'INCIDENT_CITY'], 'NN': ['TXN_DATE_TIME', 'REPORT_DT', 'INSURANCE_TYPE', 'ADDRESS_LINE2', 'SSN', 'MARITAL_STATUS', 'RISK_SEGMENTATION', 'HOUSE_TYPE', 'AUTHORITY_CONTACTED', 'ANY_INJURY', 'INCIDENT_CITY'], 'BG': ['TXN_DATE_TIME', 'REPORT_DT', 'INSURANCE_TYPE', 'ADDRESS_LINE2', 'SSN', 'MARITAL_STATUS', 'RISK_SEGMENTATION', 'HOUSE_TYPE', 'AUTHORITY_CONTACTED', 'ANY_INJURY', 'INCIDENT_CITY'], 'NB': ['TXN_DATE_TIME', 'REPORT_DT', 'INSURANCE_TYPE', 'ADDRESS_LINE2', 'SSN', 'MARITAL_STATUS', 'RISK_SEGMENTATION', 'HOUSE_TYPE', 'AUTHORITY_CONTACTED', 'ANY_INJURY', 'INCIDENT_CITY'], 'SVM': ['TXN_DATE_TIME', 'REPORT_DT', 'INSURANCE_TYPE', 'ADDRESS_LINE2', 'SSN', 'MARITAL_STATUS', 'RISK_SEGMENTATION', 'HOUSE_TYPE', 'AUTHORITY_CONTACTED', 'ANY_INJURY', 'INCIDENT_CITY']},
#       dtype=object)
