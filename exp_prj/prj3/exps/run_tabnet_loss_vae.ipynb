# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\7.synthetic_vae\Tabnet\tabnet_class_weight_dice.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# (3300, 2) (12728, 2)
# (3300, 2)
# 37
# Epoch 1/1200
# 398/398 [==============================] - 39s 14ms/step - loss: 2.2001 - accuracy: 0.6076 - f1_score: 0.5845 - val_loss: 0.4043 - val_accuracy: 0.6082 - val_f1_score: 0.4154 - lr: 0.0010
# Epoch 2/1200
# 398/398 [==============================] - 6s 14ms/step - loss: 1.7862 - accuracy: 0.6701 - f1_score: 0.6658 - val_loss: 0.3447 - val_accuracy: 0.6645 - val_f1_score: 0.4420 - lr: 0.0010
# Epoch 3/1200
# 398/398 [==============================] - 6s 15ms/step - loss: 1.6647 - accuracy: 0.6915 - f1_score: 0.6875 - val_loss: 0.3178 - val_accuracy: 0.6885 - val_f1_score: 0.4455 - lr: 0.0010
# Epoch 4/1200
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\7.synthetic_vae\Tabnet\tabnet_class_weight_f1.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# (3300, 2) (12728, 2)
# (3300, 2)
# 37
# Epoch 1/1200
# 398/398 [==============================] - 42s 14ms/step - loss: 2.2253 - accuracy: 0.6074 - f1_score: 0.6019 - val_loss: 0.5885 - val_accuracy: 0.6188 - val_f1_score: 0.4130 - lr: 0.0010
# Epoch 2/1200
# 398/398 [==============================] - 6s 14ms/step - loss: 1.8037 - accuracy: 0.6721 - f1_score: 0.6682 - val_loss: 0.5579 - val_accuracy: 0.6833 - val_f1_score: 0.4429 - lr: 0.0010
# Epoch 3/1200
# 398/398 [==============================] - 6s 15ms/step - loss: 1.7268 - accuracy: 0.6812 - f1_score: 0.6779 - val_loss: 0.5545 - val_accuracy: 0.7109 - val_f1_score: 0.4495 - lr: 0.0010
# Epoch 4/1200
# ...

# %%
# %run "C:\Users\Admin\Data\ads_fraud_detection\src\prj3\5.deep_learning_model\7.synthetic_vae\Tabnet\tabnet_class_weight_focal.ipynb"
# Out:
# C:\Users\Admin\Data\ads_fraud_detection
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# (3300, 2) (12728, 2)
# (3300, 2)
# 37
# Epoch 1/1200
# 398/398 [==============================] - 49s 18ms/step - loss: 0.0846 - accuracy: 0.5009 - f1_score: 0.3342 - val_loss: 0.6758 - val_accuracy: 0.0561 - val_f1_score: 0.0526 - lr: 0.0010
# Epoch 2/1200
# 398/398 [==============================] - 7s 17ms/step - loss: 0.0732 - accuracy: 0.5014 - f1_score: 0.3345 - val_loss: 0.5460 - val_accuracy: 0.0715 - val_f1_score: 0.0684 - lr: 0.0010
# Epoch 3/1200
# 398/398 [==============================] - 7s 17ms/step - loss: 0.0715 - accuracy: 0.5005 - f1_score: 0.3322 - val_loss: 0.5649 - val_accuracy: 0.0552 - val_f1_score: 0.0514 - lr: 0.0010
# Epoch 4/1200
# ...
